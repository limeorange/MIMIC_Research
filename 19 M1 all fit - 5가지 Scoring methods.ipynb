# %% [markdown]
# # Library

# %%
import numpy as np, os
import pandas as pd
import tensorflow as tf
from tqdm import tqdm
import seaborn as sns
import matplotlib.pyplot as plt

# 결과 확인을 용이하게 하기 위한 코드
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

#한글설정
import matplotlib.font_manager as fm

font_dirs = ['/usr/share/fonts/truetype/nanum', ]
font_files = fm.findSystemFonts(fontpaths=font_dirs)

for font_file in font_files:
    fm.fontManager.addfont(font_file)
    
# 한글 출력을 위해서 폰트 옵션을 설정합니다.
# "axes.unicode_minus" : 마이너스가 깨질 것을 방지

sns.set(font="NanumBarunGothic", 
        rc={"axes.unicode_minus":False},
        style='darkgrid')

# GPU 용량 설정
gpus = tf.config.experimental.list_physical_devices('GPU')
print(gpus)
if gpus:  # gpu가 있다면, 용량 한도를 5GB로 설정
    tf.config.experimental.set_virtual_device_configuration(gpus[0], 
                                                            [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5*1024)])
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %% [markdown]
# # 함수 모음

# %% [markdown]
# ## RF_정확도(itemlist, name)

# %%
def RF_정확도(itemlist,name):

    # itemlist만을 가진 x_(7727,10)_itemlist 만들기
    item_list = list(total_data['ITEMID'].sort_values().unique())
    
    item_index = []
    for i in itemlist:
        item_index.append(item_list.index(i))

    print('itemlist의 index : ',item_index)

    x = np.load('x_(7727,4068).npy')
    x_2d = x[:,item_index]
    x_2d
    
    np.save(f'x_(7727,10)_{name}.npy',x_2d)
    
    import random
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.metrics import accuracy_score

    model = RandomForestClassifier()

    data={}
    for seed in range(0, 50):
        random.seed(seed)
        
        x = np.load(f'./x_(7727,10)_{name}.npy')
        y = np.load('./y_(7727,1).npy')

        idx = list(range(len(x)))
        random.shuffle(idx)

        i = round(x.shape[0]*0.8)
        X_train, y_train = x[idx[:i],:], y[idx[:i]]
        X_test, y_test = x[idx[i:],:], y[idx[i:]]

        _ = model.fit(X_train, y_train)
        y_pred_train = model.predict(X_train)
        y_pred_test = model.predict(X_test)

        acc = accuracy_score(y_test, y_pred_test)
        data[seed]=acc
        print(f'정확도 : {acc}, seed_num = {seed}')

    df = pd.DataFrame.from_dict(data, orient='index')
    print(f'정확도 df 만들고 평균 확인 : {df.mean().values}')

# %% [markdown]
# ## LSTM_정확도(itemlist, name)

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, InputLayer
from tensorflow.keras.callbacks import EarlyStopping
from sklearn import metrics 
from tensorflow import keras
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

import random

def LSTM_정확도(itemlist, name):

    # itemlist만을 가진 x_(7727,10,10)_itemlist 만들기
    total_data = pd.read_csv('total_data_7727.csv')
    item_list = list(total_data['ITEMID'].sort_values().unique())

    item_index = []
    for i in itemlist:
        item_index.append(item_list.index(i))

    print('itemlist의 index : ',item_index)

    x = np.load('x_(7727,10,4068).npy')
    x_3d = x[:,:,item_index]
    
    np.save(f'x_(7727,10,10)_{name}.npy',x_3d)
    
    seed_num = 42
    random.seed(seed_num)
    
    x = np.load(f'x_(7727,10,10)_{name}.npy')
    y = np.load('y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
    X_test, y_test = x[idx[i:],:,:], y[idx[i:]]

    # ---------------------
    seed_num = 42 
    # ---------------------
    tf.random.set_seed(seed_num)

    lstm = Sequential()
    lstm.add(InputLayer(input_shape=(X_train.shape[1],X_train.shape[2])))
    lstm.add(LSTM(units=128, activation='hard_sigmoid', return_sequences=True))
    lstm.add(LSTM(units=64, activation='hard_sigmoid', return_sequences=True))
    lstm.add(Dropout(0.2))
    lstm.add(LSTM(units=64, activation='hard_sigmoid', return_sequences=True))
    lstm.add(LSTM(units=32, activation='hard_sigmoid', return_sequences=False))
    lstm.add(Dropout(0.2))
    lstm.add(Dense(units=1, activation='sigmoid'))

    from tensorflow.keras.callbacks import ModelCheckpoint
    import os

    MODEL_SAVE_FOLDER_PATH = f'./model/{name}'
    if not os.path.exists(MODEL_SAVE_FOLDER_PATH):
        os.mkdir(MODEL_SAVE_FOLDER_PATH)

    model_path = MODEL_SAVE_FOLDER_PATH + f'/{name}_seed42-'+'{epoch:02d}'+'-{val_loss:.4f}.hdf5'

    cb_checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss',
                                    verbose=1, save_best_only=True)

    early_stop = EarlyStopping(monitor='val_acc', patience=50, verbose=1, restore_best_weights=False)
    lstm.compile(optimizer= keras.optimizers.Adam(learning_rate = 0.001), loss = "binary_crossentropy", metrics=['acc'])
    lstm.fit(X_train, y_train, validation_split=0.25, batch_size=128, epochs=500,  callbacks=[early_stop,cb_checkpoint], shuffle=False)
    
    with tf.device('/device:GPU:0'):
        tf.config.experimental.set_virtual_device_configuration(gpus[0], 
                                                            [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5*1024)])

        from pathlib import Path
        paths = sorted(Path(MODEL_SAVE_FOLDER_PATH).iterdir(), key=os.path.getmtime)[-1]
        best_model_path = str(paths)

        from keras.models import load_model
        best_model = load_model(best_model_path) 

        dic_42={}
        for seed in range(0, 50):
            random.seed(seed)

            x = np.load(f'x_(7727,10,10)_{name}.npy')
            y = np.load('y_(7727,1).npy')

            idx = list(range(len(x)))
            random.shuffle(idx)

            i = round(x.shape[0]*0.8)
            X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
            X_test, y_test = x[idx[i:],:,:], y[idx[i:]]

            pred = best_model.predict(X_test, batch_size=10000, workers=-1, use_multiprocessing=True)
            pred[pred>0.5]=1
            pred[pred<=0.5]=0
            acc = metrics.accuracy_score(y_test, pred)
            dic_42[seed]=acc
            print(f'정확도 :{metrics.accuracy_score(y_test, pred)}, seed_num = {seed}')

        df_42 = pd.DataFrame.from_dict(dic_42, orient='index')
        print(f'정확도 df 만들고 평균 확인 : {df_42.mean().values}')

# %% [markdown]
# ## absum(item_list)
# - 18에 비해서 hyperparameter 1개로 조정

# %%
total_data = pd.read_csv('total_data_7727.csv')
x = np.load('/project/LSH/x_(7727,10,4068).npy')

def absum(itemlist):
    # 1) PRE_top10의 index 구하기
    item_list = total_data['ITEMID'].sort_values().unique()

    PPL_index = []
    for i in itemlist:
        a = list(item_list).index(i)
        PPL_index.append(a)
    
    # 2) 생존자 index 구하기 
    sub7727 = total_data['SUBJECT_ID'].unique()

    patient = pd.read_csv('폐렴환자.csv')
    patient = patient.sort_values(by='SUBJECT_ID')
    patient = patient[patient['SUBJECT_ID'].isin(sub7727)]
    sub_1_list = patient[patient['EXPIRE_FLAG']==0]['SUBJECT_ID'].values

    생존자_index = []
    for i in sub_1_list:
        생존자_index.append(list(sub7727).index(i))
        
    # 3) 생존자 3009명의 D-10 ~ D-1 feature별 abnormal sum 
    x_생존자 = x[생존자_index,:,:]

    result1 = []
    for i in PPL_index:
        for j in range(10):
            result1.append(x_생존자[:,j,i].sum())

    result1 = np.array(result1)
    result1 = result1.reshape(10,-1)
    df_PPL = pd.DataFrame(result1)
    df_PPL.columns = [f'D-{i}' for i in range(10,0,-1)]
    df_PPL.index = itemlist

    # 생존한 4718명에 대한 비율 계산
    for i in itemlist:
        df_PPL.loc[f'{i}_생존'] = df_PPL.loc[i].iloc[:]/x_생존자.shape[0]
        
    # 4) 사망자 4718명의 D-10 ~ D-1 feature별 abnormal sum 
    사망자_index = list(set(range(0,7727))-set(생존자_index))

    x_사망자 = x[사망자_index,:,:]

    result2 = []
    for i in PPL_index:
        for j in range(10):
            result2.append(x_사망자[:,j,i].sum())

    result2 = np.array(result2)
    result2 = result2.reshape(10,-1)
    df_PPL_사망자 = pd.DataFrame(result2)
    df_PPL_사망자.columns = [f'D-{i}' for i in range(10,0,-1)]
    df_PPL_사망자.index = itemlist

    # 사망한 3009명에 대한 비율 계산
    for i in itemlist:
        df_PPL_사망자.loc[f'{i}_사망'] = df_PPL_사망자.loc[i]/x_사망자.shape[0] 
        
    # 5) for문으로 각 feature에 대한 비율 추이 그래프 그리기 

    df_PPL_trans = df_PPL.transpose()
    df_PPL_사망자_trans = df_PPL_사망자.transpose()

    _ = plt.figure(figsize = (13,12),dpi=150)
    for i, f in enumerate(itemlist): 
        _ = plt.subplot(4,3,1+i)
        _ = plt.title(f)
        _ = ax = sns.lineplot(data = df_PPL_사망자_trans, x = df_PPL_사망자_trans.index, y = f'{f}_사망')
        _ = ax = sns.lineplot(data = df_PPL_trans, x = df_PPL_trans.index, y = f'{f}_생존')
        _ = ax.legend(labels = ['사망', '생존'], loc = 'upper left', fontsize=12)
        _ = ax.set_ylabel('per', fontsize = 12)

    plt.tight_layout()

# %% [markdown]
# ## violin_allfit(itemlist)

# %%
def violin_allfit(itemlist):
    
    # 1) DATA 
    x = np.load('/project/LSH/x_(7727,10,4068).npy')
    y = np.load('/project/LSH/y_(7727,1).npy')
    
    with tf.device('/device:GPU:0'):
        tf.config.experimental.set_virtual_device_configuration(gpus[0], 
                                                            [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5*1024)])
        # 2) MODEL
        from keras.models import load_model
        lstm2 = load_model('./model/allfit2_seed42-06-0.5519.hdf5')

        _ = plt.figure(figsize = (13,12),dpi=150)

        for j, itemid in tqdm(enumerate(itemlist)):

            # 3) 환자별 base pred (Y')
            base_pred = pd.DataFrame(lstm2.predict(x, batch_size=10000, workers=-1, use_multiprocessing=True))

            total_data = pd.read_csv('total_data_7727.csv')
            features = total_data['ITEMID'].sort_values().unique()

            k = list(features).index(itemid)
            save_col = x[:,:,k].copy()

            # 4) 0 to 1
            x[:,:,k]= np.where(x[:,:,k]==0, 1, x[:,:,k])
            pred_0to1 = pd.DataFrame(lstm2.predict(x, batch_size=10000, workers=-1, use_multiprocessing=True))

            # 5) 1 to 0
            x[:,:,k] = np.where(x[:,:,k]==1, 0, x[:,:,k])
            pred_1to0 = pd.DataFrame(lstm2.predict(x, batch_size=10000, workers=-1, use_multiprocessing=True))

            # 6) inverse
            x[:,:,k] = save_col
            x[:,:,k] = np.where(x[:,:,k]==1, 2, x[:,:,k])
            x[:,:,k] = np.where(x[:,:,k]==0, 1, x[:,:,k])
            x[:,:,k] = np.where(x[:,:,k]==2, 0, x[:,:,k])
            pred_inverse = pd.DataFrame(lstm2.predict(x, batch_size=10000, workers=-1, use_multiprocessing=True))

            x[:,:,k] = save_col

            # 7) Merge & Visualize
            FI_merge_df = pd.concat([base_pred, pred_0to1, pred_1to0, pred_inverse], axis=1)
            FI_merge_df.columns = ['base_pred', 'pred_0to1', 'pred_1to0', 'pred_inverse']
            FI_merge_visual = FI_merge_df.melt(value_vars=['base_pred','pred_0to1','pred_1to0','pred_inverse'])
            FI_merge_visual.columns = ['method','pred_value']

            _ = plt.subplot(4,3,1+j)
            _ = plt.title(itemid)
            ax = sns.violinplot(data=FI_merge_visual, x='method',y='pred_value',
                                palette="Set2", inner="quartile")
    plt.tight_layout()

# %% [markdown]
# # 1️⃣ m1_allfit
# - feature별 `E(0to1)-E(1to0)`이 담긴 df 생성

# %% [markdown]
# ## LSTM / all fit / 약 2h 10m
# - `LSH/model/allfit3_seed42-06-0.5525.hdf5`

# %%
# 1) DATA 
import random    
seed_num = 42
random.seed(seed_num)

x = np.load('/project/LSH/x_(7727,10,4068).npy')
y = np.load('/project/LSH/y_(7727,1).npy')

total_data = pd.read_csv('total_data_7727.csv')
features = total_data['ITEMID'].sort_values().unique()

# 2) MODEL
from keras.models import load_model
lstm2 = load_model('./model/allfit3_seed42-06-0.5525.hdf5')

results = []
with tf.device('/device:GPU:0'):
    
    for i in tqdm(range(len(features))):

        save_col = x[:,:,i].copy()

        # 3) E(0to1)
        x[:,:,i] = np.where(x[:,:,i]==0, 1, x[:,:,i])
        pred_0to1 = np.mean(lstm2.predict(x, batch_size=10000, workers=-1, use_multiprocessing=True))

        # 4) E(1to0)
        x[:,:,i] = np.where(x[:,:,i]==1, 0, x[:,:,i])
        pred_1to0 = np.mean(lstm2.predict(x, batch_size=10000, workers=-1, use_multiprocessing=True))

        x[:,:,i] = save_col

        # 5) Merge
        mean_diff = pred_0to1 - pred_1to0
        results.append({'feature':features[i],'mean_diff':mean_diff})
# Out:
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 100%|██████████| 4068/4068 [2:19:28<00:00,  2.06s/it]

# %%
df = pd.DataFrame(results)
# df.to_csv('m1_allfit.csv',index = False)

# %% [markdown]
# ## CuDNNLSTM / all fit / 약 2h 10m
# - `LSH/model/CuDNNLSTM/4068_allfit_noearly-386-0.6526.hdf5`
# - 예상과 달리 시간 단축이 안됨
# - CuDNNLSTM이 LSTM에 비해 학습할 때는 속도가 3~4배 정도 빠른데 predict할 때는 속도가 비슷함

# %%
# 1) DATA 
import random    
seed_num = 42
random.seed(seed_num)

x = np.load('/project/LSH/x_(7727,10,4068).npy')
y = np.load('/project/LSH/y_(7727,1).npy')

total_data = pd.read_csv('total_data_7727.csv')
features = total_data['ITEMID'].sort_values().unique()

# 2) MODEL
from keras.models import load_model
lstm2 = load_model('./model/CuDNNLSTM/4068_allfit_noearly-386-0.6526.hdf5')

results = []
with tf.device('/device:GPU:0'):
    tf.config.experimental.set_virtual_device_configuration(gpus[0], 
                                                            [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=10*1024)])
    
    for i in tqdm(range(len(features))):

        save_col = x[:,:,i].copy()

        # 3) E(0to1)
        x[:,:,i] = np.where(x[:,:,i]==0, 1, x[:,:,i])
        pred_0to1 = np.mean(lstm2.predict(x, batch_size=10000, workers=-1, use_multiprocessing=True))

        # 4) E(1to0)
        x[:,:,i] = np.where(x[:,:,i]==1, 0, x[:,:,i])
        pred_1to0 = np.mean(lstm2.predict(x, batch_size=10000, workers=-1, use_multiprocessing=True))

        x[:,:,i] = save_col

        # 5) Merge
        mean_diff = pred_0to1 - pred_1to0
        results.append({'feature':features[i],'mean_diff':mean_diff})
# Out:
#   2%|▏         | 94/4068 [03:09<2:13:51,  2.02s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-7273fbc9d2a6> in <module>
#      29         # 4) E(1to0)
#      30         x[:,:,i] = np.where(x[:,:,i]==1, 0, x[:,:,i])
# ---> 31         pred_1to0 = np.mean(lstm2.predict(x, batch_size=10000, workers=-1, use_multiprocessing=True))
#      32
#      33         x[:,:,i] = save_col
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1694                         '. Consider setting it to AutoShardPolicy.DATA.')
#    1695
# -> 1696       data_handler = data_adapter.get_data_handler(
#    1697           x=x,
#    1698           batch_size=batch_size,
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/keras/engine/data_adapter.py in get_data_handler(*args, **kwargs)
#    1362   if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1363     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1364   return DataHandler(*args, **kwargs)
#    1365
#    1366
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/keras/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1152     adapter_cls = select_data_adapter(x, y)
#    1153     self._verify_data_adapter_compatibility(adapter_cls)
# -> 1154     self._adapter = adapter_cls(
#    1155         x,
#    1156         y,
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     245                **kwargs):
#     246     super(TensorLikeDataAdapter, self).__init__(x, y, **kwargs)
# --> 247     x, y, sample_weights = _process_tensorlike((x, y, sample_weights))
#     248     sample_weight_modes = broadcast_sample_weight_modes(
#     249         sample_weights, sample_weight_modes)
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/keras/engine/data_adapter.py in _process_tensorlike(inputs)
#    1044     return x
#    1045
# -> 1046   inputs = nest.map_structure(_convert_numpy_and_scipy, inputs)
#    1047   return nest.list_to_tuple(inputs)
#    1048
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     865
#     866   return pack_sequence_as(
# --> 867       structure[0], [func(*x) for x in entries],
#     868       expand_composites=expand_composites)
#     869
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     865
#     866   return pack_sequence_as(
# --> 867       structure[0], [func(*x) for x in entries],
#     868       expand_composites=expand_composites)
#     869
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/keras/engine/data_adapter.py in _convert_numpy_and_scipy(x)
#    1039       if issubclass(x.dtype.type, np.floating):
#    1040         dtype = backend.floatx()
# -> 1041       return ops.convert_to_tensor_v2_with_dispatch(x, dtype=dtype)
#    1042     elif _is_scipy_sparse(x):
#    1043       return _scipy_sparse_to_sparse_tensor(x)
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py in convert_to_tensor_v2_with_dispatch(value, dtype, dtype_hint, name)
#    1428     ValueError: If the `value` is a tensor not of given `dtype` in graph mode.
#    1429   """
# -> 1430   return convert_to_tensor_v2(
#    1431       value, dtype=dtype, dtype_hint=dtype_hint, name=name)
#    1432
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#    1434 def convert_to_tensor_v2(value, dtype=None, dtype_hint=None, name=None):
#    1435   """Converts the given `value` to a `Tensor`."""
# -> 1436   return convert_to_tensor(
#    1437       value=value,
#    1438       dtype=dtype,
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     161         with Trace(trace_name, **trace_kwargs):
#     162           return func(*args, **kwargs)
# --> 163       return func(*args, **kwargs)
#     164
#     165     return wrapped
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1564
#    1565     if ret is None:
# -> 1566       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1567
#    1568     if ret is NotImplemented:
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/tensor_conversion_registry.py in _default_conversion_function(***failed resolving arguments***)
#      50 def _default_conversion_function(value, dtype, name, as_ref):
#      51   del as_ref  # Unused.
# ---> 52   return constant_op.constant(value, dtype, name=name)
#      53
#      54
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     262     ValueError: if called on a symbolic tensor.
#     263   """
# --> 264   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     265                         allow_broadcast=True)
#     266
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     274       with trace.Trace("tf.constant"):
#     275         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 276     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     277
#     278   g = ops.get_default_graph()
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     299 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     300   """Implementation of eager constant."""
# --> 301   t = convert_to_eager_tensor(value, ctx, dtype)
#     302   if shape is None:
#     303     return t
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#      96       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#      97   ctx.ensure_initialized()
# ---> 98   return ops.EagerTensor(value, ctx.device_name, dtype)
#      99
#     100
#
# KeyboardInterrupt:

# %% [markdown]
# ## (66.6) LSTM

# %%
m1_allfit = pd.read_csv('m1_allfit.csv')
m1_allfit = m1_allfit.sort_values(by='mean_diff', ascending=False)
m1_allfit_top10 = m1_allfit['feature'].values[:10]

# %%
LSTM_정확도(m1_allfit_top10,'m1_allfit_top10')
# Out:
# itemlist의 index :  [2195, 1081, 1276, 2148, 1011, 206, 1733, 3204, 3788, 3960]
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/500
# 37/37 [==============================] - 6s 80ms/step - loss: 0.6759 - acc: 0.5984 - val_loss: 0.6660 - val_acc: 0.6177
#
# Epoch 00001: val_loss improved from inf to 0.66602, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-01-0.6660.hdf5
# Epoch 2/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.6732 - acc: 0.6068 - val_loss: 0.6662 - val_acc: 0.6177
#
# Epoch 00002: val_loss did not improve from 0.66602
# Epoch 3/500
# 37/37 [==============================] - 3s 73ms/step - loss: 0.6740 - acc: 0.6083 - val_loss: 0.6655 - val_acc: 0.6177
#
# Epoch 00003: val_loss improved from 0.66602 to 0.66549, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-03-0.6655.hdf5
# Epoch 4/500
# 37/37 [==============================] - 3s 71ms/step - loss: 0.6710 - acc: 0.6100 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00004: val_loss improved from 0.66549 to 0.66520, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-04-0.6652.hdf5
# Epoch 5/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.6705 - acc: 0.6098 - val_loss: 0.6650 - val_acc: 0.6177
#
# Epoch 00005: val_loss improved from 0.66520 to 0.66499, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-05-0.6650.hdf5
# Epoch 6/500
# 37/37 [==============================] - 3s 71ms/step - loss: 0.6718 - acc: 0.6113 - val_loss: 0.6646 - val_acc: 0.6177
#
# Epoch 00006: val_loss improved from 0.66499 to 0.66464, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-06-0.6646.hdf5
# Epoch 7/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.6689 - acc: 0.6107 - val_loss: 0.6595 - val_acc: 0.6177
#
# Epoch 00007: val_loss improved from 0.66464 to 0.65950, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-07-0.6595.hdf5
# Epoch 8/500
# 37/37 [==============================] - 3s 71ms/step - loss: 0.6565 - acc: 0.6111 - val_loss: 0.6409 - val_acc: 0.6177
#
# Epoch 00008: val_loss improved from 0.65950 to 0.64087, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-08-0.6409.hdf5
# Epoch 9/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.6444 - acc: 0.6139 - val_loss: 0.6378 - val_acc: 0.6177
#
# Epoch 00009: val_loss improved from 0.64087 to 0.63783, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-09-0.6378.hdf5
# Epoch 10/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.6369 - acc: 0.6225 - val_loss: 0.6362 - val_acc: 0.6177
#
# Epoch 00010: val_loss improved from 0.63783 to 0.63615, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-10-0.6362.hdf5
# Epoch 11/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.6343 - acc: 0.6292 - val_loss: 0.6330 - val_acc: 0.6177
#
# Epoch 00011: val_loss improved from 0.63615 to 0.63296, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-11-0.6330.hdf5
# Epoch 12/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.6301 - acc: 0.6460 - val_loss: 0.6307 - val_acc: 0.6177
#
# Epoch 00012: val_loss improved from 0.63296 to 0.63074, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-12-0.6307.hdf5
# Epoch 13/500
# 37/37 [==============================] - 3s 71ms/step - loss: 0.6270 - acc: 0.6406 - val_loss: 0.6280 - val_acc: 0.6177
#
# Epoch 00013: val_loss improved from 0.63074 to 0.62805, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-13-0.6280.hdf5
# Epoch 14/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.6225 - acc: 0.6486 - val_loss: 0.6256 - val_acc: 0.6177
#
# Epoch 00014: val_loss improved from 0.62805 to 0.62564, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-14-0.6256.hdf5
# Epoch 15/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.6202 - acc: 0.6579 - val_loss: 0.6226 - val_acc: 0.6177
#
# Epoch 00015: val_loss improved from 0.62564 to 0.62255, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-15-0.6226.hdf5
# Epoch 16/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.6188 - acc: 0.6512 - val_loss: 0.6217 - val_acc: 0.6177
#
# Epoch 00016: val_loss improved from 0.62255 to 0.62170, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-16-0.6217.hdf5
# Epoch 17/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.6186 - acc: 0.6529 - val_loss: 0.6184 - val_acc: 0.6604
#
# Epoch 00017: val_loss improved from 0.62170 to 0.61845, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-17-0.6184.hdf5
# Epoch 18/500
# 37/37 [==============================] - 3s 71ms/step - loss: 0.6139 - acc: 0.6564 - val_loss: 0.6195 - val_acc: 0.6177
#
# Epoch 00018: val_loss did not improve from 0.61845
# Epoch 19/500
# 37/37 [==============================] - 3s 73ms/step - loss: 0.6151 - acc: 0.6471 - val_loss: 0.6149 - val_acc: 0.6636
#
# Epoch 00019: val_loss improved from 0.61845 to 0.61487, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-19-0.6149.hdf5
# Epoch 20/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.6126 - acc: 0.6495 - val_loss: 0.6131 - val_acc: 0.6643
#
# Epoch 00020: val_loss improved from 0.61487 to 0.61312, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-20-0.6131.hdf5
# Epoch 21/500
# 37/37 [==============================] - 3s 73ms/step - loss: 0.6099 - acc: 0.6551 - val_loss: 0.6127 - val_acc: 0.6630
#
# Epoch 00021: val_loss improved from 0.61312 to 0.61270, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-21-0.6127.hdf5
# Epoch 22/500
# 37/37 [==============================] - 3s 72ms/step - loss: 0.6094 - acc: 0.6538 - val_loss: 0.6125 - val_acc: 0.6630
#
# Epoch 00022: val_loss improved from 0.61270 to 0.61252, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-22-0.6125.hdf5
# Epoch 23/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.6102 - acc: 0.6566 - val_loss: 0.6090 - val_acc: 0.6656
#
# Epoch 00023: val_loss improved from 0.61252 to 0.60896, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-23-0.6090.hdf5
# Epoch 24/500
# 37/37 [==============================] - 3s 72ms/step - loss: 0.6055 - acc: 0.6506 - val_loss: 0.6084 - val_acc: 0.6669
#
# Epoch 00024: val_loss improved from 0.60896 to 0.60836, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-24-0.6084.hdf5
# Epoch 25/500
# 37/37 [==============================] - 3s 73ms/step - loss: 0.6059 - acc: 0.6594 - val_loss: 0.6064 - val_acc: 0.6662
#
# Epoch 00025: val_loss improved from 0.60836 to 0.60642, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-25-0.6064.hdf5
# Epoch 26/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.6031 - acc: 0.6637 - val_loss: 0.6056 - val_acc: 0.6656
#
# Epoch 00026: val_loss improved from 0.60642 to 0.60565, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-26-0.6056.hdf5
# Epoch 27/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.6009 - acc: 0.6583 - val_loss: 0.6039 - val_acc: 0.6630
#
# Epoch 00027: val_loss improved from 0.60565 to 0.60391, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-27-0.6039.hdf5
# Epoch 28/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.6000 - acc: 0.6652 - val_loss: 0.6040 - val_acc: 0.6649
#
# Epoch 00028: val_loss did not improve from 0.60391
# Epoch 29/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5995 - acc: 0.6609 - val_loss: 0.6026 - val_acc: 0.6636
#
# Epoch 00029: val_loss improved from 0.60391 to 0.60258, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-29-0.6026.hdf5
# Epoch 30/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.6009 - acc: 0.6557 - val_loss: 0.6015 - val_acc: 0.6643
#
# Epoch 00030: val_loss improved from 0.60258 to 0.60153, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-30-0.6015.hdf5
# Epoch 31/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5969 - acc: 0.6639 - val_loss: 0.6016 - val_acc: 0.6630
#
# Epoch 00031: val_loss did not improve from 0.60153
# Epoch 32/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5988 - acc: 0.6620 - val_loss: 0.6007 - val_acc: 0.6643
#
# Epoch 00032: val_loss improved from 0.60153 to 0.60068, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-32-0.6007.hdf5
# Epoch 33/500
# 37/37 [==============================] - 3s 71ms/step - loss: 0.5977 - acc: 0.6607 - val_loss: 0.6006 - val_acc: 0.6636
#
# Epoch 00033: val_loss improved from 0.60068 to 0.60059, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-33-0.6006.hdf5
# Epoch 34/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5968 - acc: 0.6678 - val_loss: 0.6002 - val_acc: 0.6630
#
# Epoch 00034: val_loss improved from 0.60059 to 0.60017, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-34-0.6002.hdf5
# Epoch 35/500
# 37/37 [==============================] - 3s 71ms/step - loss: 0.5969 - acc: 0.6620 - val_loss: 0.6000 - val_acc: 0.6611
#
# Epoch 00035: val_loss improved from 0.60017 to 0.59999, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-35-0.6000.hdf5
# Epoch 36/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5969 - acc: 0.6566 - val_loss: 0.5992 - val_acc: 0.6649
#
# Epoch 00036: val_loss improved from 0.59999 to 0.59924, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-36-0.5992.hdf5
# Epoch 37/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5942 - acc: 0.6629 - val_loss: 0.5993 - val_acc: 0.6649
#
# Epoch 00037: val_loss did not improve from 0.59924
# Epoch 38/500
# 37/37 [==============================] - 3s 72ms/step - loss: 0.5948 - acc: 0.6654 - val_loss: 0.5983 - val_acc: 0.6643
#
# Epoch 00038: val_loss improved from 0.59924 to 0.59834, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-38-0.5983.hdf5
# Epoch 39/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5936 - acc: 0.6633 - val_loss: 0.5989 - val_acc: 0.6636
#
# Epoch 00039: val_loss did not improve from 0.59834
# Epoch 40/500
# 37/37 [==============================] - 3s 73ms/step - loss: 0.5927 - acc: 0.6665 - val_loss: 0.5984 - val_acc: 0.6611
#
# Epoch 00040: val_loss did not improve from 0.59834
# Epoch 41/500
# 37/37 [==============================] - 3s 71ms/step - loss: 0.5944 - acc: 0.6654 - val_loss: 0.5984 - val_acc: 0.6649
#
# Epoch 00041: val_loss did not improve from 0.59834
# Epoch 42/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5918 - acc: 0.6618 - val_loss: 0.5985 - val_acc: 0.6643
#
# Epoch 00042: val_loss did not improve from 0.59834
# Epoch 43/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5937 - acc: 0.6659 - val_loss: 0.5983 - val_acc: 0.6611
#
# Epoch 00043: val_loss improved from 0.59834 to 0.59833, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-43-0.5983.hdf5
# Epoch 44/500
# 37/37 [==============================] - 3s 72ms/step - loss: 0.5931 - acc: 0.6639 - val_loss: 0.5980 - val_acc: 0.6624
#
# Epoch 00044: val_loss improved from 0.59833 to 0.59802, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-44-0.5980.hdf5
# Epoch 45/500
# 37/37 [==============================] - 3s 68ms/step - loss: 0.5913 - acc: 0.6670 - val_loss: 0.5991 - val_acc: 0.6617
#
# Epoch 00045: val_loss did not improve from 0.59802
# Epoch 46/500
# 37/37 [==============================] - 3s 73ms/step - loss: 0.5939 - acc: 0.6682 - val_loss: 0.5977 - val_acc: 0.6643
#
# Epoch 00046: val_loss improved from 0.59802 to 0.59767, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-46-0.5977.hdf5
# Epoch 47/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5913 - acc: 0.6659 - val_loss: 0.5978 - val_acc: 0.6643
#
# Epoch 00047: val_loss did not improve from 0.59767
# Epoch 48/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5925 - acc: 0.6646 - val_loss: 0.5989 - val_acc: 0.6636
#
# Epoch 00048: val_loss did not improve from 0.59767
# Epoch 49/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5918 - acc: 0.6723 - val_loss: 0.5976 - val_acc: 0.6624
#
# Epoch 00049: val_loss improved from 0.59767 to 0.59762, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-49-0.5976.hdf5
# Epoch 50/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5936 - acc: 0.6672 - val_loss: 0.5977 - val_acc: 0.6630
#
# Epoch 00050: val_loss did not improve from 0.59762
# Epoch 51/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5907 - acc: 0.6672 - val_loss: 0.5980 - val_acc: 0.6624
#
# Epoch 00051: val_loss did not improve from 0.59762
# Epoch 52/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5906 - acc: 0.6693 - val_loss: 0.5980 - val_acc: 0.6630
#
# Epoch 00052: val_loss did not improve from 0.59762
# Epoch 53/500
# 37/37 [==============================] - 3s 71ms/step - loss: 0.5928 - acc: 0.6648 - val_loss: 0.5980 - val_acc: 0.6611
#
# Epoch 00053: val_loss did not improve from 0.59762
# Epoch 54/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5909 - acc: 0.6657 - val_loss: 0.5981 - val_acc: 0.6617
#
# Epoch 00054: val_loss did not improve from 0.59762
# Epoch 55/500
# 37/37 [==============================] - 3s 71ms/step - loss: 0.5923 - acc: 0.6726 - val_loss: 0.5979 - val_acc: 0.6617
#
# Epoch 00055: val_loss did not improve from 0.59762
# Epoch 56/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5891 - acc: 0.6702 - val_loss: 0.5983 - val_acc: 0.6617
#
# Epoch 00056: val_loss did not improve from 0.59762
# Epoch 57/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5914 - acc: 0.6672 - val_loss: 0.5980 - val_acc: 0.6611
#
# Epoch 00057: val_loss did not improve from 0.59762
# Epoch 58/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5895 - acc: 0.6687 - val_loss: 0.5984 - val_acc: 0.6617
#
# Epoch 00058: val_loss did not improve from 0.59762
# Epoch 59/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5913 - acc: 0.6667 - val_loss: 0.5974 - val_acc: 0.6611
#
# Epoch 00059: val_loss improved from 0.59762 to 0.59739, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-59-0.5974.hdf5
# Epoch 60/500
# 37/37 [==============================] - 3s 71ms/step - loss: 0.5894 - acc: 0.6687 - val_loss: 0.5983 - val_acc: 0.6624
#
# Epoch 00060: val_loss did not improve from 0.59739
# Epoch 61/500
# 37/37 [==============================] - 3s 68ms/step - loss: 0.5912 - acc: 0.6682 - val_loss: 0.5976 - val_acc: 0.6624
#
# Epoch 00061: val_loss did not improve from 0.59739
# Epoch 62/500
# 37/37 [==============================] - 3s 71ms/step - loss: 0.5920 - acc: 0.6665 - val_loss: 0.5982 - val_acc: 0.6624
#
# Epoch 00062: val_loss did not improve from 0.59739
# Epoch 63/500
# 37/37 [==============================] - 3s 71ms/step - loss: 0.5900 - acc: 0.6698 - val_loss: 0.5981 - val_acc: 0.6617
#
# Epoch 00063: val_loss did not improve from 0.59739
# Epoch 64/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5916 - acc: 0.6644 - val_loss: 0.5972 - val_acc: 0.6624
#
# Epoch 00064: val_loss improved from 0.59739 to 0.59720, saving model to ./model/m1_allfit_top10/m1_allfit_top10_seed42-64-0.5972.hdf5
# Epoch 65/500
# 37/37 [==============================] - 3s 72ms/step - loss: 0.5891 - acc: 0.6689 - val_loss: 0.5992 - val_acc: 0.6617
#
# Epoch 00065: val_loss did not improve from 0.59720
# Epoch 66/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5884 - acc: 0.6713 - val_loss: 0.5984 - val_acc: 0.6624
#
# Epoch 00066: val_loss did not improve from 0.59720
# Epoch 67/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5884 - acc: 0.6708 - val_loss: 0.5983 - val_acc: 0.6617
#
# Epoch 00067: val_loss did not improve from 0.59720
# Epoch 68/500
# 37/37 [==============================] - 3s 71ms/step - loss: 0.5902 - acc: 0.6719 - val_loss: 0.5982 - val_acc: 0.6624
#
# Epoch 00068: val_loss did not improve from 0.59720
# Epoch 69/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5896 - acc: 0.6708 - val_loss: 0.5975 - val_acc: 0.6624
#
# Epoch 00069: val_loss did not improve from 0.59720
# Epoch 70/500
# 37/37 [==============================] - 3s 71ms/step - loss: 0.5898 - acc: 0.6680 - val_loss: 0.5987 - val_acc: 0.6636
#
# Epoch 00070: val_loss did not improve from 0.59720
# Epoch 71/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5870 - acc: 0.6698 - val_loss: 0.5987 - val_acc: 0.6611
#
# Epoch 00071: val_loss did not improve from 0.59720
# Epoch 72/500
# 37/37 [==============================] - 3s 72ms/step - loss: 0.5878 - acc: 0.6698 - val_loss: 0.6003 - val_acc: 0.6643
#
# Epoch 00072: val_loss did not improve from 0.59720
# Epoch 73/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5886 - acc: 0.6721 - val_loss: 0.5988 - val_acc: 0.6624
#
# Epoch 00073: val_loss did not improve from 0.59720
# Epoch 74/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5891 - acc: 0.6695 - val_loss: 0.6004 - val_acc: 0.6630
#
# Epoch 00074: val_loss did not improve from 0.59720
# Epoch 00074: early stopping
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 정확도 :0.6537216828478964, seed_num = 0
# 정확도 :0.6679611650485436, seed_num = 1
# 정확도 :0.6731391585760518, seed_num = 2
# 정확도 :0.6828478964401294, seed_num = 3
# 정확도 :0.6744336569579288, seed_num = 4
# 정확도 :0.6718446601941748, seed_num = 5
# 정확도 :0.6640776699029126, seed_num = 6
# 정확도 :0.6634304207119741, seed_num = 7
# 정확도 :0.6640776699029126, seed_num = 8
# 정확도 :0.6621359223300971, seed_num = 9
# 정확도 :0.6750809061488673, seed_num = 10
# 정확도 :0.6660194174757281, seed_num = 11
# 정확도 :0.6757281553398058, seed_num = 12
# 정확도 :0.6647249190938511, seed_num = 13
# 정확도 :0.6731391585760518, seed_num = 14
# 정확도 :0.6673139158576051, seed_num = 15
# 정확도 :0.655663430420712, seed_num = 16
# 정확도 :0.6511326860841424, seed_num = 17
# 정확도 :0.6576051779935275, seed_num = 18
# 정확도 :0.6711974110032363, seed_num = 19
# 정확도 :0.6634304207119741, seed_num = 20
# 정확도 :0.656957928802589, seed_num = 21
# 정확도 :0.6750809061488673, seed_num = 22
# 정확도 :0.6446601941747573, seed_num = 23
# 정확도 :0.6601941747572816, seed_num = 24
# 정확도 :0.6634304207119741, seed_num = 25
# 정확도 :0.6524271844660194, seed_num = 26
# 정확도 :0.6660194174757281, seed_num = 27
# 정확도 :0.6660194174757281, seed_num = 28
# 정확도 :0.658252427184466, seed_num = 29
# 정확도 :0.6783171521035599, seed_num = 30
# 정확도 :0.6692556634304208, seed_num = 31
# 정확도 :0.6601941747572816, seed_num = 32
# 정확도 :0.658252427184466, seed_num = 33
# 정확도 :0.6660194174757281, seed_num = 34
# 정확도 :0.6640776699029126, seed_num = 35
# 정확도 :0.6640776699029126, seed_num = 36
# 정확도 :0.7029126213592233, seed_num = 37
# 정확도 :0.6601941747572816, seed_num = 38
# 정확도 :0.6770226537216828, seed_num = 39
# 정확도 :0.684789644012945, seed_num = 40
# 정확도 :0.6757281553398058, seed_num = 41
# 정확도 :0.6504854368932039, seed_num = 42
# 정확도 :0.6699029126213593, seed_num = 43
# 정확도 :0.6576051779935275, seed_num = 44
# 정확도 :0.6524271844660194, seed_num = 45
# 정확도 :0.6511326860841424, seed_num = 46
# 정확도 :0.6815533980582524, seed_num = 47
# 정확도 :0.6983818770226538, seed_num = 48
# 정확도 :0.655663430420712, seed_num = 49
# 정확도 df 만들고 평균 확인 : [0.66639482]

# %% [markdown]
# ## (66.2) RF

# %%
RF_정확도(m1_allfit_top10,'m1_allfit_top10')
# Out:
# itemlist의 index :  [2195, 1081, 1276, 2148, 1011, 206, 1733, 3204, 3788, 3960]
# 정확도 : 0.6459546925566343, seed_num = 0
# 정확도 : 0.6699029126213593, seed_num = 1
# 정확도 : 0.6634304207119741, seed_num = 2
# 정확도 : 0.6802588996763754, seed_num = 3
# 정확도 : 0.683495145631068, seed_num = 4
# 정확도 : 0.6763754045307443, seed_num = 5
# 정확도 : 0.6699029126213593, seed_num = 6
# 정확도 : 0.6679611650485436, seed_num = 7
# 정확도 : 0.6627831715210356, seed_num = 8
# 정확도 : 0.6627831715210356, seed_num = 9
# 정확도 : 0.6608414239482201, seed_num = 10
# 정확도 : 0.6595469255663431, seed_num = 11
# 정확도 : 0.6731391585760518, seed_num = 12
# 정확도 : 0.6524271844660194, seed_num = 13
# 정확도 : 0.6634304207119741, seed_num = 14
# 정확도 : 0.655663430420712, seed_num = 15
# 정확도 : 0.6588996763754046, seed_num = 16
# 정확도 : 0.6517799352750809, seed_num = 17
# 정확도 : 0.6614886731391586, seed_num = 18
# 정확도 : 0.6699029126213593, seed_num = 19
# 정확도 : 0.6601941747572816, seed_num = 20
# 정확도 : 0.6517799352750809, seed_num = 21
# 정확도 : 0.6653721682847896, seed_num = 22
# 정확도 : 0.6401294498381876, seed_num = 23
# 정확도 : 0.6478964401294498, seed_num = 24
# 정확도 : 0.6627831715210356, seed_num = 25
# 정확도 : 0.654368932038835, seed_num = 26
# 정확도 : 0.6517799352750809, seed_num = 27
# 정확도 : 0.6666666666666666, seed_num = 28
# 정확도 : 0.6524271844660194, seed_num = 29
# 정확도 : 0.6744336569579288, seed_num = 30
# 정확도 : 0.6595469255663431, seed_num = 31
# 정확도 : 0.6550161812297735, seed_num = 32
# 정확도 : 0.6550161812297735, seed_num = 33
# 정확도 : 0.6647249190938511, seed_num = 34
# 정확도 : 0.6634304207119741, seed_num = 35
# 정확도 : 0.658252427184466, seed_num = 36
# 정확도 : 0.6873786407766991, seed_num = 37
# 정확도 : 0.6563106796116505, seed_num = 38
# 정확도 : 0.6757281553398058, seed_num = 39
# 정확도 : 0.6815533980582524, seed_num = 40
# 정확도 : 0.6692556634304208, seed_num = 41
# 정확도 : 0.6466019417475728, seed_num = 42
# 정확도 : 0.6601941747572816, seed_num = 43
# 정확도 : 0.655663430420712, seed_num = 44
# 정확도 : 0.6466019417475728, seed_num = 45
# 정확도 : 0.6440129449838188, seed_num = 46
# 정확도 : 0.6711974110032363, seed_num = 47
# 정확도 : 0.6906148867313916, seed_num = 48
# 정확도 : 0.6537216828478964, seed_num = 49
# 정확도 df 만들고 평균 확인 : [0.66225243]

# %% [markdown]
# ## absum 그래프

# %%
absum(m1_allfit_top10)

# %% [markdown]
# ## violin plot

# %%
violin_allfit(m1_allfit_top10)
# Out:
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 10it [01:23,  8.32s/it]

# %% [markdown]
# # 2️⃣ m1_allfit_entropy

# %%
entropy = pd.read_csv('m1_entropy.csv')
entropy = entropy.sort_values(by='feature')
entropy.index = range(4068)

m1_allfit = pd.read_csv('m1_allfit.csv')
m1_allfit_entropy = m1_allfit.copy()
m1_allfit_entropy['diff*entropy'] = entropy['entropy'] * m1_allfit['mean_diff']
m1_allfit_entropy = m1_allfit_entropy.sort_values(by='diff*entropy', ascending=False)
m1_allfit_entropy
# m1_allfit_entropy.to_csv('m1_allfit_entropy.csv', index=False)
# Out:
#           feature  mean_diff  diff*entropy
# 206         51277   0.116958      0.107523
# 121         51006   0.086929      0.085272
# 56          50912   0.068324      0.057957
# 2148    409176230   0.119119      0.045340
# 34          50882   0.057849      0.044414
# ...           ...        ...           ...
# 187         51249  -0.058820     -0.032506
# 0               0  -0.038682     -0.034603
# 619       8084199  -0.060372     -0.036869
# 19          50861  -0.100435     -0.040175
# 3832  63323026201  -0.067375     -0.053592
#
# [4068 rows x 3 columns]

# %%
# m1_allfit_entropy_top10
m1_allfit_entropy = pd.read_csv('m1_allfit_entropy.csv')
m1_allfit_entropy_top10 = m1_allfit_entropy['feature'].values[:10]

# %% [markdown]
# ## (70.1) LSTM

# %%
LSTM_정확도(m1_allfit_entropy_top10,'m1_allfit_entropy_top10')
# Out:
# itemlist의 index :  [206, 121, 56, 2148, 34, 41, 103, 119, 20, 203]
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/500
# 37/37 [==============================] - 6s 81ms/step - loss: 0.6758 - acc: 0.5984 - val_loss: 0.6660 - val_acc: 0.6177
#
# Epoch 00001: val_loss improved from inf to 0.66597, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-01-0.6660.hdf5
# Epoch 2/500
# 37/37 [==============================] - 3s 72ms/step - loss: 0.6731 - acc: 0.6068 - val_loss: 0.6661 - val_acc: 0.6177
#
# Epoch 00002: val_loss did not improve from 0.66597
# Epoch 3/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.6734 - acc: 0.6083 - val_loss: 0.6645 - val_acc: 0.6177
#
# Epoch 00003: val_loss improved from 0.66597 to 0.66453, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-03-0.6645.hdf5
# Epoch 4/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.6636 - acc: 0.6119 - val_loss: 0.6472 - val_acc: 0.6177
#
# Epoch 00004: val_loss improved from 0.66453 to 0.64724, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-04-0.6472.hdf5
# Epoch 5/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.6399 - acc: 0.6176 - val_loss: 0.6294 - val_acc: 0.6268
#
# Epoch 00005: val_loss improved from 0.64724 to 0.62939, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-05-0.6294.hdf5
# Epoch 6/500
# 37/37 [==============================] - 3s 68ms/step - loss: 0.6230 - acc: 0.6536 - val_loss: 0.6153 - val_acc: 0.6708
#
# Epoch 00006: val_loss improved from 0.62939 to 0.61535, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-06-0.6153.hdf5
# Epoch 7/500
# 37/37 [==============================] - 3s 71ms/step - loss: 0.6121 - acc: 0.6719 - val_loss: 0.6151 - val_acc: 0.6714
#
# Epoch 00007: val_loss improved from 0.61535 to 0.61512, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-07-0.6151.hdf5
# Epoch 8/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.6102 - acc: 0.6771 - val_loss: 0.6155 - val_acc: 0.6727
#
# Epoch 00008: val_loss did not improve from 0.61512
# Epoch 9/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.6053 - acc: 0.6814 - val_loss: 0.6160 - val_acc: 0.6727
#
# Epoch 00009: val_loss did not improve from 0.61512
# Epoch 10/500
# 37/37 [==============================] - 3s 71ms/step - loss: 0.6010 - acc: 0.6868 - val_loss: 0.6121 - val_acc: 0.6746
#
# Epoch 00010: val_loss improved from 0.61512 to 0.61213, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-10-0.6121.hdf5
# Epoch 11/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.6005 - acc: 0.6903 - val_loss: 0.6099 - val_acc: 0.6714
#
# Epoch 00011: val_loss improved from 0.61213 to 0.60993, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-11-0.6099.hdf5
# Epoch 12/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5960 - acc: 0.6911 - val_loss: 0.6082 - val_acc: 0.6708
#
# Epoch 00012: val_loss improved from 0.60993 to 0.60820, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-12-0.6082.hdf5
# Epoch 13/500
# 37/37 [==============================] - 3s 71ms/step - loss: 0.5943 - acc: 0.6954 - val_loss: 0.6037 - val_acc: 0.6714
#
# Epoch 00013: val_loss improved from 0.60820 to 0.60368, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-13-0.6037.hdf5
# Epoch 14/500
# 37/37 [==============================] - 3s 68ms/step - loss: 0.5921 - acc: 0.6898 - val_loss: 0.6032 - val_acc: 0.6734
#
# Epoch 00014: val_loss improved from 0.60368 to 0.60317, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-14-0.6032.hdf5
# Epoch 15/500
# 37/37 [==============================] - 3s 71ms/step - loss: 0.5908 - acc: 0.6952 - val_loss: 0.6010 - val_acc: 0.6746
#
# Epoch 00015: val_loss improved from 0.60317 to 0.60098, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-15-0.6010.hdf5
# Epoch 16/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5896 - acc: 0.6941 - val_loss: 0.5995 - val_acc: 0.6766
#
# Epoch 00016: val_loss improved from 0.60098 to 0.59945, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-16-0.5995.hdf5
# Epoch 17/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5902 - acc: 0.6948 - val_loss: 0.5982 - val_acc: 0.6759
#
# Epoch 00017: val_loss improved from 0.59945 to 0.59818, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-17-0.5982.hdf5
# Epoch 18/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5854 - acc: 0.6974 - val_loss: 0.5983 - val_acc: 0.6746
#
# Epoch 00018: val_loss did not improve from 0.59818
# Epoch 19/500
# 37/37 [==============================] - 3s 71ms/step - loss: 0.5872 - acc: 0.6937 - val_loss: 0.5967 - val_acc: 0.6792
#
# Epoch 00019: val_loss improved from 0.59818 to 0.59674, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-19-0.5967.hdf5
# Epoch 20/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5865 - acc: 0.6972 - val_loss: 0.5951 - val_acc: 0.6779
#
# Epoch 00020: val_loss improved from 0.59674 to 0.59509, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-20-0.5951.hdf5
# Epoch 21/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5839 - acc: 0.6987 - val_loss: 0.5954 - val_acc: 0.6785
#
# Epoch 00021: val_loss did not improve from 0.59509
# Epoch 22/500
# 37/37 [==============================] - 3s 71ms/step - loss: 0.5840 - acc: 0.7015 - val_loss: 0.5947 - val_acc: 0.6785
#
# Epoch 00022: val_loss improved from 0.59509 to 0.59470, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-22-0.5947.hdf5
# Epoch 23/500
# 37/37 [==============================] - 3s 71ms/step - loss: 0.5846 - acc: 0.6961 - val_loss: 0.5940 - val_acc: 0.6798
#
# Epoch 00023: val_loss improved from 0.59470 to 0.59404, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-23-0.5940.hdf5
# Epoch 24/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5826 - acc: 0.6980 - val_loss: 0.5919 - val_acc: 0.6805
#
# Epoch 00024: val_loss improved from 0.59404 to 0.59190, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-24-0.5919.hdf5
# Epoch 25/500
# 37/37 [==============================] - 3s 73ms/step - loss: 0.5823 - acc: 0.7017 - val_loss: 0.5917 - val_acc: 0.6818
#
# Epoch 00025: val_loss improved from 0.59190 to 0.59169, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-25-0.5917.hdf5
# Epoch 26/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5805 - acc: 0.6993 - val_loss: 0.5912 - val_acc: 0.6811
#
# Epoch 00026: val_loss improved from 0.59169 to 0.59123, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-26-0.5912.hdf5
# Epoch 27/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5792 - acc: 0.7036 - val_loss: 0.5907 - val_acc: 0.6805
#
# Epoch 00027: val_loss improved from 0.59123 to 0.59073, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-27-0.5907.hdf5
# Epoch 28/500
# 37/37 [==============================] - 3s 72ms/step - loss: 0.5773 - acc: 0.7030 - val_loss: 0.5904 - val_acc: 0.6798
#
# Epoch 00028: val_loss improved from 0.59073 to 0.59045, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-28-0.5904.hdf5
# Epoch 29/500
# 37/37 [==============================] - 2s 68ms/step - loss: 0.5786 - acc: 0.7043 - val_loss: 0.5903 - val_acc: 0.6811
#
# Epoch 00029: val_loss improved from 0.59045 to 0.59032, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-29-0.5903.hdf5
# Epoch 30/500
# 37/37 [==============================] - 3s 71ms/step - loss: 0.5786 - acc: 0.7036 - val_loss: 0.5898 - val_acc: 0.6818
#
# Epoch 00030: val_loss improved from 0.59032 to 0.58976, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-30-0.5898.hdf5
# Epoch 31/500
# 37/37 [==============================] - 3s 68ms/step - loss: 0.5761 - acc: 0.7045 - val_loss: 0.5904 - val_acc: 0.6824
#
# Epoch 00031: val_loss did not improve from 0.58976
# Epoch 32/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5793 - acc: 0.7032 - val_loss: 0.5893 - val_acc: 0.6831
#
# Epoch 00032: val_loss improved from 0.58976 to 0.58933, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-32-0.5893.hdf5
# Epoch 33/500
# 37/37 [==============================] - 3s 72ms/step - loss: 0.5768 - acc: 0.7034 - val_loss: 0.5881 - val_acc: 0.6876
#
# Epoch 00033: val_loss improved from 0.58933 to 0.58811, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-33-0.5881.hdf5
# Epoch 34/500
# 37/37 [==============================] - 3s 68ms/step - loss: 0.5747 - acc: 0.7025 - val_loss: 0.5887 - val_acc: 0.6824
#
# Epoch 00034: val_loss did not improve from 0.58811
# Epoch 35/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5755 - acc: 0.7010 - val_loss: 0.5898 - val_acc: 0.6798
#
# Epoch 00035: val_loss did not improve from 0.58811
# Epoch 36/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5768 - acc: 0.7053 - val_loss: 0.5880 - val_acc: 0.6850
#
# Epoch 00036: val_loss improved from 0.58811 to 0.58800, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-36-0.5880.hdf5
# Epoch 37/500
# 37/37 [==============================] - 3s 71ms/step - loss: 0.5734 - acc: 0.7028 - val_loss: 0.5878 - val_acc: 0.6869
#
# Epoch 00037: val_loss improved from 0.58800 to 0.58777, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-37-0.5878.hdf5
# Epoch 38/500
# 37/37 [==============================] - 3s 72ms/step - loss: 0.5741 - acc: 0.7075 - val_loss: 0.5881 - val_acc: 0.6843
#
# Epoch 00038: val_loss did not improve from 0.58777
# Epoch 39/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5755 - acc: 0.7041 - val_loss: 0.5869 - val_acc: 0.6882
#
# Epoch 00039: val_loss improved from 0.58777 to 0.58689, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-39-0.5869.hdf5
# Epoch 40/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5738 - acc: 0.7058 - val_loss: 0.5870 - val_acc: 0.6908
#
# Epoch 00040: val_loss did not improve from 0.58689
# Epoch 41/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5750 - acc: 0.7032 - val_loss: 0.5874 - val_acc: 0.6850
#
# Epoch 00041: val_loss did not improve from 0.58689
# Epoch 42/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5710 - acc: 0.7075 - val_loss: 0.5875 - val_acc: 0.6837
#
# Epoch 00042: val_loss did not improve from 0.58689
# Epoch 43/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5732 - acc: 0.7077 - val_loss: 0.5878 - val_acc: 0.6843
#
# Epoch 00043: val_loss did not improve from 0.58689
# Epoch 44/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5727 - acc: 0.7058 - val_loss: 0.5868 - val_acc: 0.6843
#
# Epoch 00044: val_loss improved from 0.58689 to 0.58678, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-44-0.5868.hdf5
# Epoch 45/500
# 37/37 [==============================] - 3s 71ms/step - loss: 0.5716 - acc: 0.7082 - val_loss: 0.5875 - val_acc: 0.6843
#
# Epoch 00045: val_loss did not improve from 0.58678
# Epoch 46/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5738 - acc: 0.7058 - val_loss: 0.5869 - val_acc: 0.6843
#
# Epoch 00046: val_loss did not improve from 0.58678
# Epoch 47/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5713 - acc: 0.7088 - val_loss: 0.5868 - val_acc: 0.6856
#
# Epoch 00047: val_loss did not improve from 0.58678
# Epoch 48/500
# 37/37 [==============================] - 3s 71ms/step - loss: 0.5719 - acc: 0.7099 - val_loss: 0.5869 - val_acc: 0.6869
#
# Epoch 00048: val_loss did not improve from 0.58678
# Epoch 49/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5716 - acc: 0.7090 - val_loss: 0.5863 - val_acc: 0.6850
#
# Epoch 00049: val_loss improved from 0.58678 to 0.58634, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-49-0.5863.hdf5
# Epoch 50/500
# 37/37 [==============================] - 3s 72ms/step - loss: 0.5719 - acc: 0.7118 - val_loss: 0.5862 - val_acc: 0.6869
#
# Epoch 00050: val_loss improved from 0.58634 to 0.58624, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-50-0.5862.hdf5
# Epoch 51/500
# 37/37 [==============================] - 3s 80ms/step - loss: 0.5693 - acc: 0.7105 - val_loss: 0.5861 - val_acc: 0.6876
#
# Epoch 00051: val_loss improved from 0.58624 to 0.58607, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-51-0.5861.hdf5
# Epoch 52/500
# 37/37 [==============================] - 3s 79ms/step - loss: 0.5695 - acc: 0.7064 - val_loss: 0.5864 - val_acc: 0.6863
#
# Epoch 00052: val_loss did not improve from 0.58607
# Epoch 53/500
# 37/37 [==============================] - 3s 80ms/step - loss: 0.5712 - acc: 0.7082 - val_loss: 0.5859 - val_acc: 0.6869
#
# Epoch 00053: val_loss improved from 0.58607 to 0.58595, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-53-0.5859.hdf5
# Epoch 54/500
# 37/37 [==============================] - 3s 80ms/step - loss: 0.5693 - acc: 0.7077 - val_loss: 0.5871 - val_acc: 0.6895
#
# Epoch 00054: val_loss did not improve from 0.58595
# Epoch 55/500
# 37/37 [==============================] - 3s 81ms/step - loss: 0.5696 - acc: 0.7064 - val_loss: 0.5869 - val_acc: 0.6869
#
# Epoch 00055: val_loss did not improve from 0.58595
# Epoch 56/500
# 37/37 [==============================] - 3s 80ms/step - loss: 0.5677 - acc: 0.7105 - val_loss: 0.5866 - val_acc: 0.6889
#
# Epoch 00056: val_loss did not improve from 0.58595
# Epoch 57/500
# 37/37 [==============================] - 3s 80ms/step - loss: 0.5689 - acc: 0.7112 - val_loss: 0.5867 - val_acc: 0.6895
#
# Epoch 00057: val_loss did not improve from 0.58595
# Epoch 58/500
# 37/37 [==============================] - 3s 82ms/step - loss: 0.5668 - acc: 0.7118 - val_loss: 0.5870 - val_acc: 0.6856
#
# Epoch 00058: val_loss did not improve from 0.58595
# Epoch 59/500
# 37/37 [==============================] - 3s 81ms/step - loss: 0.5689 - acc: 0.7116 - val_loss: 0.5866 - val_acc: 0.6876
#
# Epoch 00059: val_loss did not improve from 0.58595
# Epoch 60/500
# 37/37 [==============================] - 3s 79ms/step - loss: 0.5662 - acc: 0.7118 - val_loss: 0.5866 - val_acc: 0.6882
#
# Epoch 00060: val_loss did not improve from 0.58595
# Epoch 61/500
# 37/37 [==============================] - 3s 78ms/step - loss: 0.5679 - acc: 0.7112 - val_loss: 0.5866 - val_acc: 0.6869
#
# Epoch 00061: val_loss did not improve from 0.58595
# Epoch 62/500
# 37/37 [==============================] - 3s 80ms/step - loss: 0.5680 - acc: 0.7129 - val_loss: 0.5871 - val_acc: 0.6882
#
# Epoch 00062: val_loss did not improve from 0.58595
# Epoch 63/500
# 37/37 [==============================] - 3s 80ms/step - loss: 0.5676 - acc: 0.7112 - val_loss: 0.5871 - val_acc: 0.6882
#
# Epoch 00063: val_loss did not improve from 0.58595
# Epoch 64/500
# 37/37 [==============================] - 3s 73ms/step - loss: 0.5674 - acc: 0.7151 - val_loss: 0.5858 - val_acc: 0.6876
#
# Epoch 00064: val_loss improved from 0.58595 to 0.58580, saving model to ./model/m1_allfit_entropy_top10/m1_allfit_entropy_top10_seed42-64-0.5858.hdf5
# Epoch 65/500
# 37/37 [==============================] - 3s 71ms/step - loss: 0.5655 - acc: 0.7103 - val_loss: 0.5869 - val_acc: 0.6908
#
# Epoch 00065: val_loss did not improve from 0.58580
# Epoch 66/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5649 - acc: 0.7110 - val_loss: 0.5860 - val_acc: 0.6895
#
# Epoch 00066: val_loss did not improve from 0.58580
# Epoch 67/500
# 37/37 [==============================] - 3s 73ms/step - loss: 0.5636 - acc: 0.7129 - val_loss: 0.5871 - val_acc: 0.6953
#
# Epoch 00067: val_loss did not improve from 0.58580
# Epoch 68/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5655 - acc: 0.7114 - val_loss: 0.5869 - val_acc: 0.6928
#
# Epoch 00068: val_loss did not improve from 0.58580
# Epoch 69/500
# 37/37 [==============================] - 3s 72ms/step - loss: 0.5647 - acc: 0.7148 - val_loss: 0.5864 - val_acc: 0.6921
#
# Epoch 00069: val_loss did not improve from 0.58580
# Epoch 70/500
# 37/37 [==============================] - 3s 71ms/step - loss: 0.5659 - acc: 0.7118 - val_loss: 0.5865 - val_acc: 0.6908
#
# Epoch 00070: val_loss did not improve from 0.58580
# Epoch 71/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5609 - acc: 0.7138 - val_loss: 0.5869 - val_acc: 0.6940
#
# Epoch 00071: val_loss did not improve from 0.58580
# Epoch 72/500
# 37/37 [==============================] - 3s 71ms/step - loss: 0.5620 - acc: 0.7097 - val_loss: 0.5873 - val_acc: 0.6928
#
# Epoch 00072: val_loss did not improve from 0.58580
# Epoch 73/500
# 37/37 [==============================] - 3s 68ms/step - loss: 0.5624 - acc: 0.7146 - val_loss: 0.5867 - val_acc: 0.6940
#
# Epoch 00073: val_loss did not improve from 0.58580
# Epoch 74/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5636 - acc: 0.7116 - val_loss: 0.5863 - val_acc: 0.6915
#
# Epoch 00074: val_loss did not improve from 0.58580
# Epoch 75/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5631 - acc: 0.7099 - val_loss: 0.5867 - val_acc: 0.6895
#
# Epoch 00075: val_loss did not improve from 0.58580
# Epoch 76/500
# 37/37 [==============================] - 3s 71ms/step - loss: 0.5626 - acc: 0.7148 - val_loss: 0.5863 - val_acc: 0.6889
#
# Epoch 00076: val_loss did not improve from 0.58580
# Epoch 77/500
# 37/37 [==============================] - 3s 71ms/step - loss: 0.5598 - acc: 0.7142 - val_loss: 0.5872 - val_acc: 0.6928
#
# Epoch 00077: val_loss did not improve from 0.58580
# Epoch 78/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5618 - acc: 0.7151 - val_loss: 0.5866 - val_acc: 0.6908
#
# Epoch 00078: val_loss did not improve from 0.58580
# Epoch 79/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5635 - acc: 0.7166 - val_loss: 0.5862 - val_acc: 0.6902
#
# Epoch 00079: val_loss did not improve from 0.58580
# Epoch 80/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5611 - acc: 0.7133 - val_loss: 0.5872 - val_acc: 0.6889
#
# Epoch 00080: val_loss did not improve from 0.58580
# Epoch 81/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5614 - acc: 0.7140 - val_loss: 0.5862 - val_acc: 0.6895
#
# Epoch 00081: val_loss did not improve from 0.58580
# Epoch 82/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5613 - acc: 0.7172 - val_loss: 0.5865 - val_acc: 0.6895
#
# Epoch 00082: val_loss did not improve from 0.58580
# Epoch 83/500
# 37/37 [==============================] - 3s 71ms/step - loss: 0.5581 - acc: 0.7192 - val_loss: 0.5877 - val_acc: 0.6915
#
# Epoch 00083: val_loss did not improve from 0.58580
# Epoch 84/500
# 37/37 [==============================] - 2s 67ms/step - loss: 0.5607 - acc: 0.7168 - val_loss: 0.5871 - val_acc: 0.6882
#
# Epoch 00084: val_loss did not improve from 0.58580
# Epoch 85/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5604 - acc: 0.7129 - val_loss: 0.5866 - val_acc: 0.6889
#
# Epoch 00085: val_loss did not improve from 0.58580
# Epoch 86/500
# 37/37 [==============================] - 3s 68ms/step - loss: 0.5603 - acc: 0.7174 - val_loss: 0.5873 - val_acc: 0.6889
#
# Epoch 00086: val_loss did not improve from 0.58580
# Epoch 87/500
# 37/37 [==============================] - 3s 72ms/step - loss: 0.5601 - acc: 0.7176 - val_loss: 0.5864 - val_acc: 0.6889
#
# Epoch 00087: val_loss did not improve from 0.58580
# Epoch 88/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5584 - acc: 0.7185 - val_loss: 0.5878 - val_acc: 0.6882
#
# Epoch 00088: val_loss did not improve from 0.58580
# Epoch 89/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5580 - acc: 0.7161 - val_loss: 0.5876 - val_acc: 0.6876
#
# Epoch 00089: val_loss did not improve from 0.58580
# Epoch 90/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5580 - acc: 0.7172 - val_loss: 0.5877 - val_acc: 0.6921
#
# Epoch 00090: val_loss did not improve from 0.58580
# Epoch 91/500
# 37/37 [==============================] - 3s 71ms/step - loss: 0.5569 - acc: 0.7192 - val_loss: 0.5878 - val_acc: 0.6889
#
# Epoch 00091: val_loss did not improve from 0.58580
# Epoch 92/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5556 - acc: 0.7166 - val_loss: 0.5871 - val_acc: 0.6895
#
# Epoch 00092: val_loss did not improve from 0.58580
# Epoch 93/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5580 - acc: 0.7181 - val_loss: 0.5876 - val_acc: 0.6902
#
# Epoch 00093: val_loss did not improve from 0.58580
# Epoch 94/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5585 - acc: 0.7168 - val_loss: 0.5875 - val_acc: 0.6915
#
# Epoch 00094: val_loss did not improve from 0.58580
# Epoch 95/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5562 - acc: 0.7181 - val_loss: 0.5882 - val_acc: 0.6921
#
# Epoch 00095: val_loss did not improve from 0.58580
# Epoch 96/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5557 - acc: 0.7226 - val_loss: 0.5885 - val_acc: 0.6869
#
# Epoch 00096: val_loss did not improve from 0.58580
# Epoch 97/500
# 37/37 [==============================] - 3s 72ms/step - loss: 0.5560 - acc: 0.7185 - val_loss: 0.5889 - val_acc: 0.6843
#
# Epoch 00097: val_loss did not improve from 0.58580
# Epoch 98/500
# 37/37 [==============================] - 3s 68ms/step - loss: 0.5558 - acc: 0.7183 - val_loss: 0.5885 - val_acc: 0.6843
#
# Epoch 00098: val_loss did not improve from 0.58580
# Epoch 99/500
# 37/37 [==============================] - 3s 71ms/step - loss: 0.5573 - acc: 0.7187 - val_loss: 0.5877 - val_acc: 0.6837
#
# Epoch 00099: val_loss did not improve from 0.58580
# Epoch 100/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5561 - acc: 0.7174 - val_loss: 0.5886 - val_acc: 0.6818
#
# Epoch 00100: val_loss did not improve from 0.58580
# Epoch 101/500
# 37/37 [==============================] - 3s 72ms/step - loss: 0.5550 - acc: 0.7179 - val_loss: 0.5901 - val_acc: 0.6843
#
# Epoch 00101: val_loss did not improve from 0.58580
# Epoch 102/500
# 37/37 [==============================] - 2s 68ms/step - loss: 0.5558 - acc: 0.7181 - val_loss: 0.5887 - val_acc: 0.6831
#
# Epoch 00102: val_loss did not improve from 0.58580
# Epoch 103/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5533 - acc: 0.7168 - val_loss: 0.5888 - val_acc: 0.6863
#
# Epoch 00103: val_loss did not improve from 0.58580
# Epoch 104/500
# 37/37 [==============================] - 2s 68ms/step - loss: 0.5527 - acc: 0.7174 - val_loss: 0.5904 - val_acc: 0.6843
#
# Epoch 00104: val_loss did not improve from 0.58580
# Epoch 105/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5555 - acc: 0.7220 - val_loss: 0.5879 - val_acc: 0.6831
#
# Epoch 00105: val_loss did not improve from 0.58580
# Epoch 106/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5556 - acc: 0.7198 - val_loss: 0.5883 - val_acc: 0.6824
#
# Epoch 00106: val_loss did not improve from 0.58580
# Epoch 107/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5546 - acc: 0.7204 - val_loss: 0.5890 - val_acc: 0.6811
#
# Epoch 00107: val_loss did not improve from 0.58580
# Epoch 108/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5533 - acc: 0.7196 - val_loss: 0.5898 - val_acc: 0.6837
#
# Epoch 00108: val_loss did not improve from 0.58580
# Epoch 109/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5511 - acc: 0.7192 - val_loss: 0.5900 - val_acc: 0.6856
#
# Epoch 00109: val_loss did not improve from 0.58580
# Epoch 110/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5517 - acc: 0.7224 - val_loss: 0.5893 - val_acc: 0.6811
#
# Epoch 00110: val_loss did not improve from 0.58580
# Epoch 111/500
# 37/37 [==============================] - 3s 69ms/step - loss: 0.5521 - acc: 0.7189 - val_loss: 0.5886 - val_acc: 0.6831
#
# Epoch 00111: val_loss did not improve from 0.58580
# Epoch 112/500
# 37/37 [==============================] - 3s 72ms/step - loss: 0.5518 - acc: 0.7224 - val_loss: 0.5894 - val_acc: 0.6856
#
# Epoch 00112: val_loss did not improve from 0.58580
# Epoch 113/500
# 37/37 [==============================] - 3s 72ms/step - loss: 0.5505 - acc: 0.7215 - val_loss: 0.5892 - val_acc: 0.6882
#
# Epoch 00113: val_loss did not improve from 0.58580
# Epoch 114/500
# 37/37 [==============================] - 2s 68ms/step - loss: 0.5524 - acc: 0.7224 - val_loss: 0.5884 - val_acc: 0.6850
#
# Epoch 00114: val_loss did not improve from 0.58580
# Epoch 115/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5523 - acc: 0.7239 - val_loss: 0.5886 - val_acc: 0.6837
#
# Epoch 00115: val_loss did not improve from 0.58580
# Epoch 116/500
# 37/37 [==============================] - 3s 70ms/step - loss: 0.5502 - acc: 0.7224 - val_loss: 0.5893 - val_acc: 0.6856
#
# Epoch 00116: val_loss did not improve from 0.58580
# Epoch 117/500
# 37/37 [==============================] - 3s 72ms/step - loss: 0.5495 - acc: 0.7235 - val_loss: 0.5897 - val_acc: 0.6831
#
# Epoch 00117: val_loss did not improve from 0.58580
# Epoch 00117: early stopping
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 정확도 :0.7074433656957929, seed_num = 0
# 정확도 :0.7048543689320388, seed_num = 1
# 정확도 :0.6938511326860841, seed_num = 2
# 정확도 :0.7067961165048544, seed_num = 3
# 정확도 :0.6964401294498382, seed_num = 4
# 정확도 :0.6983818770226538, seed_num = 5
# 정확도 :0.6899676375404531, seed_num = 6
# 정확도 :0.6964401294498382, seed_num = 7
# 정확도 :0.7119741100323624, seed_num = 8
# 정확도 :0.6996763754045308, seed_num = 9
# 정확도 :0.7016181229773463, seed_num = 10
# 정확도 :0.7055016181229773, seed_num = 11
# 정확도 :0.7093851132686084, seed_num = 12
# 정확도 :0.7080906148867314, seed_num = 13
# 정확도 :0.6951456310679611, seed_num = 14
# 정확도 :0.6957928802588996, seed_num = 15
# 정확도 :0.7158576051779936, seed_num = 16
# 정확도 :0.7009708737864078, seed_num = 17
# 정확도 :0.7210355987055016, seed_num = 18
# 정확도 :0.7042071197411003, seed_num = 19
# 정확도 :0.6970873786407767, seed_num = 20
# 정확도 :0.6873786407766991, seed_num = 21
# 정확도 :0.6996763754045308, seed_num = 22
# 정확도 :0.6796116504854369, seed_num = 23
# 정확도 :0.6886731391585761, seed_num = 24
# 정확도 :0.7158576051779936, seed_num = 25
# 정확도 :0.6880258899676376, seed_num = 26
# 정확도 :0.6912621359223301, seed_num = 27
# 정확도 :0.7042071197411003, seed_num = 28
# 정확도 :0.6893203883495146, seed_num = 29
# 정확도 :0.713915857605178, seed_num = 30
# 정확도 :0.6970873786407767, seed_num = 31
# 정확도 :0.7055016181229773, seed_num = 32
# 정확도 :0.7042071197411003, seed_num = 33
# 정확도 :0.7080906148867314, seed_num = 34
# 정확도 :0.6977346278317152, seed_num = 35
# 정확도 :0.7100323624595469, seed_num = 36
# 정확도 :0.7216828478964401, seed_num = 37
# 정확도 :0.7009708737864078, seed_num = 38
# 정확도 :0.7210355987055016, seed_num = 39
# 정확도 :0.7113268608414239, seed_num = 40
# 정확도 :0.7132686084142394, seed_num = 41
# 정확도 :0.6815533980582524, seed_num = 42
# 정확도 :0.6983818770226538, seed_num = 43
# 정확도 :0.6744336569579288, seed_num = 44
# 정확도 :0.6925566343042071, seed_num = 45
# 정확도 :0.7093851132686084, seed_num = 46
# 정확도 :0.7067961165048544, seed_num = 47
# 정확도 :0.7145631067961165, seed_num = 48
# 정확도 :0.6996763754045308, seed_num = 49
# 정확도 df 만들고 평균 확인 : [0.70173463]

# %% [markdown]
# ## (65.1) RF

# %%
RF_정확도(m1_allfit_entropy_top10,'m1_allfit_entropy_top10')
# Out:
# itemlist의 index :  [206, 121, 56, 2148, 34, 41, 103, 119, 20, 203]
# 정확도 : 0.6388349514563106, seed_num = 0
# 정확도 : 0.6407766990291263, seed_num = 1
# 정확도 : 0.6446601941747573, seed_num = 2
# 정확도 : 0.6420711974110033, seed_num = 3
# 정확도 : 0.654368932038835, seed_num = 4
# 정확도 : 0.6563106796116505, seed_num = 5
# 정확도 : 0.6453074433656958, seed_num = 6
# 정확도 : 0.6485436893203883, seed_num = 7
# 정확도 : 0.6601941747572816, seed_num = 8
# 정확도 : 0.6414239482200648, seed_num = 9
# 정확도 : 0.6504854368932039, seed_num = 10
# 정확도 : 0.6498381877022654, seed_num = 11
# 정확도 : 0.6679611650485436, seed_num = 12
# 정확도 : 0.655663430420712, seed_num = 13
# 정확도 : 0.6517799352750809, seed_num = 14
# 정확도 : 0.6588996763754046, seed_num = 15
# 정확도 : 0.6796116504854369, seed_num = 16
# 정확도 : 0.6414239482200648, seed_num = 17
# 정확도 : 0.6576051779935275, seed_num = 18
# 정확도 : 0.6537216828478964, seed_num = 19
# 정확도 : 0.6381877022653721, seed_num = 20
# 정확도 : 0.6550161812297735, seed_num = 21
# 정확도 : 0.6388349514563106, seed_num = 22
# 정확도 : 0.6297734627831715, seed_num = 23
# 정확도 : 0.6362459546925566, seed_num = 24
# 정확도 : 0.6466019417475728, seed_num = 25
# 정확도 : 0.6517799352750809, seed_num = 26
# 정확도 : 0.6401294498381876, seed_num = 27
# 정확도 : 0.6563106796116505, seed_num = 28
# 정확도 : 0.6446601941747573, seed_num = 29
# 정확도 : 0.6692556634304208, seed_num = 30
# 정확도 : 0.6440129449838188, seed_num = 31
# 정확도 : 0.658252427184466, seed_num = 32
# 정확도 : 0.6530744336569579, seed_num = 33
# 정확도 : 0.6537216828478964, seed_num = 34
# 정확도 : 0.655663430420712, seed_num = 35
# 정확도 : 0.6621359223300971, seed_num = 36
# 정확도 : 0.6576051779935275, seed_num = 37
# 정확도 : 0.6731391585760518, seed_num = 38
# 정확도 : 0.6653721682847896, seed_num = 39
# 정확도 : 0.6563106796116505, seed_num = 40
# 정확도 : 0.6588996763754046, seed_num = 41
# 정확도 : 0.6343042071197411, seed_num = 42
# 정확도 : 0.6362459546925566, seed_num = 43
# 정확도 : 0.6284789644012945, seed_num = 44
# 정확도 : 0.6530744336569579, seed_num = 45
# 정확도 : 0.6388349514563106, seed_num = 46
# 정확도 : 0.6640776699029126, seed_num = 47
# 정확도 : 0.6666666666666666, seed_num = 48
# 정확도 : 0.6472491909385113, seed_num = 49
# 정확도 df 만들고 평균 확인 : [0.65106796]

# %% [markdown]
# ## absum 그래프

# %%
absum(m1_allfit_entropy_top10)

# %% [markdown]
# ## violin plot

# %%
violin_allfit(m1_allfit_entropy_top10)
# Out:
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 10it [01:18,  7.87s/it]

# %% [markdown]
# # 3️⃣ m1_sequential

# %% [markdown]
# ## code test - df_2

# %%
# 1st top1 : 409606211

m1_allfit = pd.read_csv('m1_allfit.csv')
m1_allfit = m1_allfit.sort_values(by='mean_diff', ascending=False)
m1_allfit

top1_1 = m1_allfit['feature'].values[0]
top1_1
# Out:
#           feature  mean_diff
# 2195    409606211   0.163214
# 1081     67434504   0.143361
# 1276     74606211   0.126000
# 2148    409176230   0.119119
# 1011     54858516   0.118077
# ...           ...        ...
# 3113  51079028520  -0.079562
# 2106    406051262  -0.083803
# 2824  17714002001  -0.086603
# 469       4003822  -0.091247
# 19          50861  -0.100435
#
# [4068 rows x 2 columns]
# 409606211

# %%
# 1) DATA 
import random    
seed_num = 42
random.seed(seed_num)

total_data = pd.read_csv('total_data_7727.csv')
features = list(total_data['ITEMID'].sort_values().unique())

x = np.load('/project/LSH/x_(7727,10,4068).npy')
y = np.load('/project/LSH/y_(7727,1).npy')

# ----------- top1_1의 index ----------------------
m1_allfit = pd.read_csv('m1_allfit.csv')
m1_allfit = m1_allfit.sort_values(by='mean_diff', ascending=False)
top1_1 = m1_allfit['feature'].values[0]
top1_1_idx = features.index(top1_1)

# 2) MODEL
from keras.models import load_model
lstm2 = load_model('./model/allfit3_seed42-06-0.5525.hdf5')

results = []
with tf.device('/device:GPU:0'):

    for i in tqdm(range(len(features))):

        save_col = x[:,:,[i,top1_1_idx]].copy()

        # 3) E(0to1)
        x[:,:,[i,top1_1_idx]] = 1
        pred_0to1 = np.mean(lstm2.predict(x, batch_size=10000, workers=-1, use_multiprocessing=True))

        # 4) E(1to0)
        x[:,:,[i,top1_1_idx]] = 0
        pred_1to0 = np.mean(lstm2.predict(x, batch_size=10000, workers=-1, use_multiprocessing=True))

        x[:,:,[i,top1_1_idx]] = save_col

        # 5) Merge
        mean_diff = pred_0to1 - pred_1to0
        results.append({'feature':features[i],'mean_diff':mean_diff})
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#   5%|▌         | 214/4068 [06:26<1:56:01,  1.81s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-80a17aedc996> in <module>
#      29         # 3) E(0to1)
#      30         x[:,:,[i,top1_1_idx]] = 1
# ---> 31         pred_0to1 = np.mean(lstm2.predict(x, batch_size=10000, workers=-1, use_multiprocessing=True))
#      32
#      33         # 4) E(1to0)
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1694                         '. Consider setting it to AutoShardPolicy.DATA.')
#    1695
# -> 1696       data_handler = data_adapter.get_data_handler(
#    1697           x=x,
#    1698           batch_size=batch_size,
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/keras/engine/data_adapter.py in get_data_handler(*args, **kwargs)
#    1362   if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1363     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1364   return DataHandler(*args, **kwargs)
#    1365
#    1366
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/keras/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1152     adapter_cls = select_data_adapter(x, y)
#    1153     self._verify_data_adapter_compatibility(adapter_cls)
# -> 1154     self._adapter = adapter_cls(
#    1155         x,
#    1156         y,
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     245                **kwargs):
#     246     super(TensorLikeDataAdapter, self).__init__(x, y, **kwargs)
# --> 247     x, y, sample_weights = _process_tensorlike((x, y, sample_weights))
#     248     sample_weight_modes = broadcast_sample_weight_modes(
#     249         sample_weights, sample_weight_modes)
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/keras/engine/data_adapter.py in _process_tensorlike(inputs)
#    1044     return x
#    1045
# -> 1046   inputs = nest.map_structure(_convert_numpy_and_scipy, inputs)
#    1047   return nest.list_to_tuple(inputs)
#    1048
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     865
#     866   return pack_sequence_as(
# --> 867       structure[0], [func(*x) for x in entries],
#     868       expand_composites=expand_composites)
#     869
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     865
#     866   return pack_sequence_as(
# --> 867       structure[0], [func(*x) for x in entries],
#     868       expand_composites=expand_composites)
#     869
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/keras/engine/data_adapter.py in _convert_numpy_and_scipy(x)
#    1039       if issubclass(x.dtype.type, np.floating):
#    1040         dtype = backend.floatx()
# -> 1041       return ops.convert_to_tensor_v2_with_dispatch(x, dtype=dtype)
#    1042     elif _is_scipy_sparse(x):
#    1043       return _scipy_sparse_to_sparse_tensor(x)
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py in convert_to_tensor_v2_with_dispatch(value, dtype, dtype_hint, name)
#    1428     ValueError: If the `value` is a tensor not of given `dtype` in graph mode.
#    1429   """
# -> 1430   return convert_to_tensor_v2(
#    1431       value, dtype=dtype, dtype_hint=dtype_hint, name=name)
#    1432
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#    1434 def convert_to_tensor_v2(value, dtype=None, dtype_hint=None, name=None):
#    1435   """Converts the given `value` to a `Tensor`."""
# -> 1436   return convert_to_tensor(
#    1437       value=value,
#    1438       dtype=dtype,
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     161         with Trace(trace_name, **trace_kwargs):
#     162           return func(*args, **kwargs)
# --> 163       return func(*args, **kwargs)
#     164
#     165     return wrapped
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1564
#    1565     if ret is None:
# -> 1566       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1567
#    1568     if ret is NotImplemented:
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/tensor_conversion_registry.py in _default_conversion_function(***failed resolving arguments***)
#      50 def _default_conversion_function(value, dtype, name, as_ref):
#      51   del as_ref  # Unused.
# ---> 52   return constant_op.constant(value, dtype, name=name)
#      53
#      54
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     262     ValueError: if called on a symbolic tensor.
#     263   """
# --> 264   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     265                         allow_broadcast=True)
#     266
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     274       with trace.Trace("tf.constant"):
#     275         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 276     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     277
#     278   g = ops.get_default_graph()
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     299 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     300   """Implementation of eager constant."""
# --> 301   t = convert_to_eager_tensor(value, ctx, dtype)
#     302   if shape is None:
#     303     return t
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#      96       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#      97   ctx.ensure_initialized()
# ---> 98   return ops.EagerTensor(value, ctx.device_name, dtype)
#      99
#     100
#
# KeyboardInterrupt:

# %%
df_2 = pd.DataFrame(results)
df_2 = df_2.sort_values(by='mean_diff', ascending=False)
df_2
# df_2.to_csv('df_2.csv', index=False)

# %%
df_2_test = pd.read_csv('df_2.csv')
df_2_test
# Out:
#           feature  mean_diff
# 0        67434504   0.279540
# 1           51277   0.270293
# 2        74606211   0.266377
# 3       409176230   0.264936
# 4        54858516   0.260672
# ...           ...        ...
# 4063  63323038810   0.086737
# 4064    406051262   0.082551
# 4065  17714002001   0.079593
# 4066      4003822   0.074138
# 4067        50861   0.063923
#
# [4068 rows x 2 columns]

# %% [markdown]
# ## code test - feature n개
# - feature n개로 지정해서 df_2 ~ df_10의 top1_features 확인
# - n : 10, 20, 100

# %%
# test
from tqdm.notebook import tqdm

# 1) DATA 
import random    
seed_num = 42
random.seed(seed_num)

total_data = pd.read_csv('total_data_7727.csv')
features = list(total_data['ITEMID'].sort_values().unique())

x = np.load('/project/LSH/x_(7727,10,4068).npy')
y = np.load('/project/LSH/y_(7727,1).npy')

# ----------- top1_1의 index ----------------------
top1_1 = 0
top1_1_idx = features.index(top1_1)
# -------------------------------------------------

# 2) MODEL
from keras.models import load_model
lstm2 = load_model('./model/allfit3_seed42-06-0.5525.hdf5')

top1_features = []

with tf.device('/device:GPU:0'):
    for j in tqdm(range(2,11)):
        results = []
        if j == 2: # top1_1을 아는 상태 -> top1_2를 구해야함 
            for i in tqdm(range(len(features[:100]))):

                save_col = x[:,:,[i,top1_1_idx]].copy()

                # 3) E(0to1)
                x[:,:,[i,top1_1_idx]] = 1
                pred_0to1 = np.mean(lstm2.predict(x, batch_size=10000, workers=-1, use_multiprocessing=True))

                # 4) E(1to0)
                x[:,:,[i,top1_1_idx]] = 0
                pred_1to0 = np.mean(lstm2.predict(x, batch_size=10000, workers=-1, use_multiprocessing=True))

                x[:,:,[i,top1_1_idx]] = save_col

                # 5) Merge
                mean_diff = pred_0to1 - pred_1to0
                results.append({'feature':features[i],'mean_diff':mean_diff})
            globals()[f'df_{j}'] = pd.DataFrame(results) # df_2 정의 
            globals()[f'df_{j}'] = globals()[f'df_{j}'].sort_values(by='mean_diff', ascending=False)
            globals()[f'top1_{j}'] = globals()[f'df_{j}']['feature'].values[0]
            top1_features.append(globals()[f'top1_{j}'])
        else:
            globals()[f'top1_{j}_idx'] = features.index(top1_features[-1])
            
            for i in tqdm(range(len(features[:100]))):
                
                save_col = x[:,:,[i,globals()[f'top1_{j}_idx']]].copy()

                # 3) E(0to1)
                x[:,:,[i,globals()[f'top1_{j}_idx']]] = 1
                pred_0to1 = np.mean(lstm2.predict(x, batch_size=10000, workers=-1, use_multiprocessing=True))

                # 4) E(1to0)
                x[:,:,[i,globals()[f'top1_{j}_idx']]] = 0
                pred_1to0 = np.mean(lstm2.predict(x, batch_size=10000, workers=-1, use_multiprocessing=True))

                x[:,:,[i,globals()[f'top1_{j}_idx']]] = save_col

                # 5) Merge
                mean_diff = pred_0to1 - pred_1to0
                results.append({'feature':features[i],'mean_diff':mean_diff})
            globals()[f'df_{j}'] = pd.DataFrame(results) # df_3, df_4, ..., df_10정의  
            globals()[f'df_{j}'] = globals()[f'df_{j}'].sort_values(by='mean_diff', ascending=False)
            globals()[f'top1_{j}'] = globals()[f'df_{j}']['feature'].values[0]
            top1_features.append(globals()[f'top1_{j}'])
# Out:
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#   0%|          | 0/9 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
# feature[:100]
top1_features
# Out:
# [50912, 50868, 50912, 50868, 50912, 50868, 50912, 50868, 50912]

# %%
# feature[:100]
df_3.head(3)['feature'].values
df_4.head(3)['feature'].values
df_5.head(3)['feature'].values

df_3.tail(3)['feature'].values
df_4.tail(3)['feature'].values
df_5.tail(3)['feature'].values
# Out:
# array([50868, 50813, 50882])
# array([50912, 50813, 50882])
# array([50868, 50813, 50882])
# array([50922, 50924, 50861])
# array([50922, 50924, 50861])
# array([50922, 50924, 50861])

# %%
# feature[:20]
top1_features
# Out:
# [50813, 50809, 50813, 50809, 50813, 50809, 50813, 50809, 50813]

# %%
# feature[:20]
df_3.head(3)['feature'].values
df_4.head(3)['feature'].values
df_5.head(3)['feature'].values

df_3.tail(3)['feature'].values
df_4.tail(3)['feature'].values
df_5.tail(3)['feature'].values
# Out:
# array([50809, 50820, 50806])
# array([50813, 50820, 50806])
# array([50809, 50820, 50806])
# array([    0, 50856, 50861])
# array([    0, 50856, 50861])
# array([    0, 50856, 50861])

# %%
# feature[:10]
df_3.head(3)['feature'].values
df_4.head(3)['feature'].values
df_5.head(3)['feature'].values

df_3.tail(3)['feature'].values
df_4.tail(3)['feature'].values
df_5.tail(3)['feature'].values
# Out:
# array([50809, 50820, 50806])
# array([50813, 50820, 50806])
# array([50809, 50820, 50806])
# array([    0, 50856, 50861])
# array([    0, 50856, 50861])
# array([    0, 50856, 50861])

# %% [markdown]
# ## 본 코드

# %%
from tqdm.notebook import tqdm

# 1) DATA 
import random    
seed_num = 42
random.seed(seed_num)

total_data = pd.read_csv('total_data_7727.csv')
features = list(total_data['ITEMID'].sort_values().unique())

x = np.load('/project/LSH/x_(7727,10,4068).npy')
y = np.load('/project/LSH/y_(7727,1).npy')

# ----------- top1_1의 index ----------------------
m1_allfit = pd.read_csv('m1_allfit.csv')
m1_allfit = m1_allfit.sort_values(by='mean_diff', ascending=False)
top1_1 = m1_allfit['feature'].values[0]
top1_1_idx = features.index(top1_1)

# 2) MODEL
from keras.models import load_model
lstm2 = load_model('./model/allfit3_seed42-06-0.5525.hdf5')

top1_features = []

with tf.device('/device:GPU:0'):
    for j in tqdm(range(2,11)):
        results = []
        if j == 2: # top1_1을 아는 상태 -> top1_2를 구해야함 
            for i in tqdm(range(len(features))):

                save_col = x[:,:,[i,top1_1_idx]].copy()

                # 3) E(0to1)
                x[:,:,[i,top1_1_idx]] = 1
                pred_0to1 = np.mean(lstm2.predict(x, batch_size=10000, workers=-1, use_multiprocessing=True))

                # 4) E(1to0)
                x[:,:,[i,top1_1_idx]] = 0
                pred_1to0 = np.mean(lstm2.predict(x, batch_size=10000, workers=-1, use_multiprocessing=True))

                x[:,:,[i,top1_1_idx]] = save_col

                # 5) Merge
                mean_diff = pred_0to1 - pred_1to0
                results.append({'feature':features[i],'mean_diff':mean_diff})
            globals()[f'df_{j}'] = pd.DataFrame(results) # df_2 정의 
            globals()[f'df_{j}'] = globals()[f'df_{j}'].sort_values(by='mean_diff', ascending=False)
            globals()[f'top1_{j}'] = globals()[f'df_{j}']['feature'].values[0]
            top1_features.append(globals()[f'top1_{j}'])
        else:
            globals()[f'top1_{j}_idx'] = features.index(top1_features[-1])
            
            for i in tqdm(range(len(features))):
                
                save_col = x[:,:,[i,globals()[f'top1_{j}_idx']]].copy()

                # 3) E(0to1)
                x[:,:,[i,globals()[f'top1_{j}_idx']]] = 1
                pred_0to1 = np.mean(lstm2.predict(x, batch_size=10000, workers=-1, use_multiprocessing=True))

                # 4) E(1to0)
                x[:,:,[i,globals()[f'top1_{j}_idx']]] = 0
                pred_1to0 = np.mean(lstm2.predict(x, batch_size=10000, workers=-1, use_multiprocessing=True))

                x[:,:,[i,globals()[f'top1_{j}_idx']]] = save_col

                # 5) Merge
                mean_diff = pred_0to1 - pred_1to0
                results.append({'feature':features[i],'mean_diff':mean_diff})
            globals()[f'df_{j}'] = pd.DataFrame(results) # df_3, df_4, ..., df_10정의  
            globals()[f'df_{j}'] = globals()[f'df_{j}'].sort_values(by='mean_diff', ascending=False)
            globals()[f'top1_{j}'] = globals()[f'df_{j}']['feature'].values[0]
            top1_features.append(globals()[f'top1_{j}'])
# Out:
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#   0%|          | 0/9 [00:00<?, ?it/s]
#   0%|          | 0/4068 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-4771cc9141db> in <module>
#      34                 # 3) E(0to1)
#      35                 x[:,:,[i,top1_1_idx]] = 1
# ---> 36                 pred_0to1 = np.mean(lstm2.predict(x, batch_size=10000, workers=-1, use_multiprocessing=True))
#      37
#      38                 # 4) E(1to0)
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1721       callbacks.on_predict_begin()
#    1722       batch_outputs = None
# -> 1723       for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    1724         with data_handler.catch_stop_iteration():
#    1725           for step in data_handler.steps():
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/keras/engine/data_adapter.py in enumerate_epochs(self)
#    1197     """Yields `(epoch, tf.data.Iterator)`."""
#    1198     with self._truncate_execution_to_epoch():
# -> 1199       data_iterator = iter(self._dataset)
#    1200       for epoch in range(self._initial_epoch, self._epochs):
#    1201         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/data/ops/dataset_ops.py in __iter__(self)
#     484     if context.executing_eagerly() or ops.inside_function():
#     485       with ops.colocate_with(self._variant_tensor):
# --> 486         return iterator_ops.OwnedIterator(self)
#     487     else:
#     488       raise RuntimeError("__iter__() is only supported inside of tf.function "
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/data/ops/iterator_ops.py in __init__(self, dataset, components, element_spec)
#     694       if (components is not None or element_spec is not None):
#     695         raise ValueError(error_message)
# --> 696       self._create_iterator(dataset)
#     697
#     698   def _create_iterator(self, dataset):
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/data/ops/iterator_ops.py in _create_iterator(self, dataset)
#     717               output_types=self._flat_output_types,
#     718               output_shapes=self._flat_output_shapes))
# --> 719       gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#     720       # Delete the resource when this object is deleted
#     721       self._resource_deleter = IteratorResourceDeleter(
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/gen_dataset_ops.py in make_iterator(dataset, iterator, name)
#    3118   if tld.is_eager:
#    3119     try:
# -> 3120       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3121         _ctx, "MakeIterator", name, dataset, iterator)
#    3122       return _result
#
# KeyboardInterrupt:

# %% [markdown]
# # 4️⃣ m1_sequential_entropy

# %% [markdown]
# # 5️⃣ RF_top10

# %%
rf_top10 = [51277, 50912, 51006, 63323026201, 50862, 50983, 51003, 51275, 904224461, 50882]

# %% [markdown]
# ## (71.6) LSTM

# %%
LSTM_정확도(rf_top10,'rf_top10')
# Out:
# itemlist의 index :  [206, 56, 121, 3832, 20, 103, 119, 204, 2611, 34]
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/500
# 37/37 [==============================] - 6s 75ms/step - loss: 0.6758 - acc: 0.5984 - val_loss: 0.6660 - val_acc: 0.6177
#
# Epoch 00001: val_loss improved from inf to 0.66595, saving model to ./model/rf_top10/rf_top10_seed42-01-0.6660.hdf5
# Epoch 2/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6730 - acc: 0.6068 - val_loss: 0.6660 - val_acc: 0.6177
#
# Epoch 00002: val_loss did not improve from 0.66595
# Epoch 3/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6731 - acc: 0.6087 - val_loss: 0.6631 - val_acc: 0.6177
#
# Epoch 00003: val_loss improved from 0.66595 to 0.66314, saving model to ./model/rf_top10/rf_top10_seed42-03-0.6631.hdf5
# Epoch 4/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.6546 - acc: 0.6156 - val_loss: 0.6224 - val_acc: 0.6177
#
# Epoch 00004: val_loss improved from 0.66314 to 0.62244, saving model to ./model/rf_top10/rf_top10_seed42-04-0.6224.hdf5
# Epoch 5/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.6090 - acc: 0.6633 - val_loss: 0.5912 - val_acc: 0.6869
#
# Epoch 00005: val_loss improved from 0.62244 to 0.59122, saving model to ./model/rf_top10/rf_top10_seed42-05-0.5912.hdf5
# Epoch 6/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5933 - acc: 0.6851 - val_loss: 0.5839 - val_acc: 0.6979
#
# Epoch 00006: val_loss improved from 0.59122 to 0.58392, saving model to ./model/rf_top10/rf_top10_seed42-06-0.5839.hdf5
# Epoch 7/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5895 - acc: 0.6924 - val_loss: 0.5790 - val_acc: 0.6915
#
# Epoch 00007: val_loss improved from 0.58392 to 0.57899, saving model to ./model/rf_top10/rf_top10_seed42-07-0.5790.hdf5
# Epoch 8/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5865 - acc: 0.6967 - val_loss: 0.5777 - val_acc: 0.6940
#
# Epoch 00008: val_loss improved from 0.57899 to 0.57772, saving model to ./model/rf_top10/rf_top10_seed42-08-0.5777.hdf5
# Epoch 9/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5823 - acc: 0.6980 - val_loss: 0.5787 - val_acc: 0.6986
#
# Epoch 00009: val_loss did not improve from 0.57772
# Epoch 10/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.5792 - acc: 0.7010 - val_loss: 0.5786 - val_acc: 0.6979
#
# Epoch 00010: val_loss did not improve from 0.57772
# Epoch 11/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5811 - acc: 0.6931 - val_loss: 0.5822 - val_acc: 0.6940
#
# Epoch 00011: val_loss did not improve from 0.57772
# Epoch 12/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5794 - acc: 0.6967 - val_loss: 0.5871 - val_acc: 0.6934
#
# Epoch 00012: val_loss did not improve from 0.57772
# Epoch 13/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5805 - acc: 0.6920 - val_loss: 0.5857 - val_acc: 0.6940
#
# Epoch 00013: val_loss did not improve from 0.57772
# Epoch 14/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5791 - acc: 0.6948 - val_loss: 0.5875 - val_acc: 0.6928
#
# Epoch 00014: val_loss did not improve from 0.57772
# Epoch 15/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5802 - acc: 0.7006 - val_loss: 0.5845 - val_acc: 0.6960
#
# Epoch 00015: val_loss did not improve from 0.57772
# Epoch 16/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.5784 - acc: 0.6991 - val_loss: 0.5822 - val_acc: 0.7038
#
# Epoch 00016: val_loss did not improve from 0.57772
# Epoch 17/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5784 - acc: 0.7036 - val_loss: 0.5811 - val_acc: 0.7018
#
# Epoch 00017: val_loss did not improve from 0.57772
# Epoch 18/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5747 - acc: 0.7034 - val_loss: 0.5820 - val_acc: 0.7031
#
# Epoch 00018: val_loss did not improve from 0.57772
# Epoch 19/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5773 - acc: 0.7025 - val_loss: 0.5798 - val_acc: 0.7005
#
# Epoch 00019: val_loss did not improve from 0.57772
# Epoch 20/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.5758 - acc: 0.7062 - val_loss: 0.5788 - val_acc: 0.7018
#
# Epoch 00020: val_loss did not improve from 0.57772
# Epoch 21/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5737 - acc: 0.7038 - val_loss: 0.5805 - val_acc: 0.7025
#
# Epoch 00021: val_loss did not improve from 0.57772
# Epoch 22/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5737 - acc: 0.7086 - val_loss: 0.5785 - val_acc: 0.7018
#
# Epoch 00022: val_loss did not improve from 0.57772
# Epoch 23/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.5741 - acc: 0.7079 - val_loss: 0.5777 - val_acc: 0.7012
#
# Epoch 00023: val_loss improved from 0.57772 to 0.57771, saving model to ./model/rf_top10/rf_top10_seed42-23-0.5777.hdf5
# Epoch 24/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5722 - acc: 0.7084 - val_loss: 0.5765 - val_acc: 0.6999
#
# Epoch 00024: val_loss improved from 0.57771 to 0.57655, saving model to ./model/rf_top10/rf_top10_seed42-24-0.5765.hdf5
# Epoch 25/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5727 - acc: 0.7092 - val_loss: 0.5754 - val_acc: 0.6986
#
# Epoch 00025: val_loss improved from 0.57655 to 0.57542, saving model to ./model/rf_top10/rf_top10_seed42-25-0.5754.hdf5
# Epoch 26/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.5700 - acc: 0.7094 - val_loss: 0.5760 - val_acc: 0.7005
#
# Epoch 00026: val_loss did not improve from 0.57542
# Epoch 27/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.5691 - acc: 0.7118 - val_loss: 0.5743 - val_acc: 0.6979
#
# Epoch 00027: val_loss improved from 0.57542 to 0.57426, saving model to ./model/rf_top10/rf_top10_seed42-27-0.5743.hdf5
# Epoch 28/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5676 - acc: 0.7151 - val_loss: 0.5728 - val_acc: 0.6986
#
# Epoch 00028: val_loss improved from 0.57426 to 0.57283, saving model to ./model/rf_top10/rf_top10_seed42-28-0.5728.hdf5
# Epoch 29/500
# 37/37 [==============================] - 2s 67ms/step - loss: 0.5669 - acc: 0.7112 - val_loss: 0.5731 - val_acc: 0.6992
#
# Epoch 00029: val_loss did not improve from 0.57283
# Epoch 30/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5691 - acc: 0.7101 - val_loss: 0.5719 - val_acc: 0.6986
#
# Epoch 00030: val_loss improved from 0.57283 to 0.57192, saving model to ./model/rf_top10/rf_top10_seed42-30-0.5719.hdf5
# Epoch 31/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5657 - acc: 0.7101 - val_loss: 0.5722 - val_acc: 0.6979
#
# Epoch 00031: val_loss did not improve from 0.57192
# Epoch 32/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.5677 - acc: 0.7116 - val_loss: 0.5701 - val_acc: 0.6973
#
# Epoch 00032: val_loss improved from 0.57192 to 0.57007, saving model to ./model/rf_top10/rf_top10_seed42-32-0.5701.hdf5
# Epoch 33/500
# 37/37 [==============================] - 2s 68ms/step - loss: 0.5653 - acc: 0.7097 - val_loss: 0.5702 - val_acc: 0.6986
#
# Epoch 00033: val_loss did not improve from 0.57007
# Epoch 34/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5631 - acc: 0.7146 - val_loss: 0.5699 - val_acc: 0.6986
#
# Epoch 00034: val_loss improved from 0.57007 to 0.56989, saving model to ./model/rf_top10/rf_top10_seed42-34-0.5699.hdf5
# Epoch 35/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.5639 - acc: 0.7166 - val_loss: 0.5697 - val_acc: 0.6986
#
# Epoch 00035: val_loss improved from 0.56989 to 0.56968, saving model to ./model/rf_top10/rf_top10_seed42-35-0.5697.hdf5
# Epoch 36/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.5649 - acc: 0.7097 - val_loss: 0.5687 - val_acc: 0.7012
#
# Epoch 00036: val_loss improved from 0.56968 to 0.56867, saving model to ./model/rf_top10/rf_top10_seed42-36-0.5687.hdf5
# Epoch 37/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5627 - acc: 0.7151 - val_loss: 0.5678 - val_acc: 0.7025
#
# Epoch 00037: val_loss improved from 0.56867 to 0.56776, saving model to ./model/rf_top10/rf_top10_seed42-37-0.5678.hdf5
# Epoch 38/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5620 - acc: 0.7140 - val_loss: 0.5675 - val_acc: 0.7038
#
# Epoch 00038: val_loss improved from 0.56776 to 0.56755, saving model to ./model/rf_top10/rf_top10_seed42-38-0.5675.hdf5
# Epoch 39/500
# 37/37 [==============================] - 2s 67ms/step - loss: 0.5628 - acc: 0.7118 - val_loss: 0.5660 - val_acc: 0.7018
#
# Epoch 00039: val_loss improved from 0.56755 to 0.56600, saving model to ./model/rf_top10/rf_top10_seed42-39-0.5660.hdf5
# Epoch 40/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5615 - acc: 0.7185 - val_loss: 0.5665 - val_acc: 0.7050
#
# Epoch 00040: val_loss did not improve from 0.56600
# Epoch 41/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5624 - acc: 0.7140 - val_loss: 0.5663 - val_acc: 0.7050
#
# Epoch 00041: val_loss did not improve from 0.56600
# Epoch 42/500
# 37/37 [==============================] - 2s 67ms/step - loss: 0.5584 - acc: 0.7133 - val_loss: 0.5667 - val_acc: 0.7044
#
# Epoch 00042: val_loss did not improve from 0.56600
# Epoch 43/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.5621 - acc: 0.7161 - val_loss: 0.5662 - val_acc: 0.7025
#
# Epoch 00043: val_loss did not improve from 0.56600
# Epoch 44/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5605 - acc: 0.7204 - val_loss: 0.5646 - val_acc: 0.7012
#
# Epoch 00044: val_loss improved from 0.56600 to 0.56455, saving model to ./model/rf_top10/rf_top10_seed42-44-0.5646.hdf5
# Epoch 45/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.5578 - acc: 0.7153 - val_loss: 0.5661 - val_acc: 0.7018
#
# Epoch 00045: val_loss did not improve from 0.56455
# Epoch 46/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5607 - acc: 0.7159 - val_loss: 0.5652 - val_acc: 0.7025
#
# Epoch 00046: val_loss did not improve from 0.56455
# Epoch 47/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.5565 - acc: 0.7161 - val_loss: 0.5651 - val_acc: 0.7012
#
# Epoch 00047: val_loss did not improve from 0.56455
# Epoch 48/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5588 - acc: 0.7174 - val_loss: 0.5655 - val_acc: 0.7031
#
# Epoch 00048: val_loss did not improve from 0.56455
# Epoch 49/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5583 - acc: 0.7194 - val_loss: 0.5645 - val_acc: 0.7025
#
# Epoch 00049: val_loss improved from 0.56455 to 0.56454, saving model to ./model/rf_top10/rf_top10_seed42-49-0.5645.hdf5
# Epoch 50/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.5589 - acc: 0.7151 - val_loss: 0.5642 - val_acc: 0.7012
#
# Epoch 00050: val_loss improved from 0.56454 to 0.56417, saving model to ./model/rf_top10/rf_top10_seed42-50-0.5642.hdf5
# Epoch 51/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5568 - acc: 0.7196 - val_loss: 0.5642 - val_acc: 0.6999
#
# Epoch 00051: val_loss did not improve from 0.56417
# Epoch 52/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5560 - acc: 0.7174 - val_loss: 0.5642 - val_acc: 0.7012
#
# Epoch 00052: val_loss did not improve from 0.56417
# Epoch 53/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5569 - acc: 0.7183 - val_loss: 0.5641 - val_acc: 0.7005
#
# Epoch 00053: val_loss improved from 0.56417 to 0.56410, saving model to ./model/rf_top10/rf_top10_seed42-53-0.5641.hdf5
# Epoch 54/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5560 - acc: 0.7140 - val_loss: 0.5639 - val_acc: 0.7025
#
# Epoch 00054: val_loss improved from 0.56410 to 0.56391, saving model to ./model/rf_top10/rf_top10_seed42-54-0.5639.hdf5
# Epoch 55/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5561 - acc: 0.7187 - val_loss: 0.5636 - val_acc: 0.7031
#
# Epoch 00055: val_loss improved from 0.56391 to 0.56359, saving model to ./model/rf_top10/rf_top10_seed42-55-0.5636.hdf5
# Epoch 56/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.5545 - acc: 0.7189 - val_loss: 0.5640 - val_acc: 0.7018
#
# Epoch 00056: val_loss did not improve from 0.56359
# Epoch 57/500
# 37/37 [==============================] - 2s 67ms/step - loss: 0.5548 - acc: 0.7185 - val_loss: 0.5648 - val_acc: 0.7031
#
# Epoch 00057: val_loss did not improve from 0.56359
# Epoch 58/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5546 - acc: 0.7209 - val_loss: 0.5643 - val_acc: 0.7018
#
# Epoch 00058: val_loss did not improve from 0.56359
# Epoch 59/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5557 - acc: 0.7213 - val_loss: 0.5638 - val_acc: 0.7031
#
# Epoch 00059: val_loss did not improve from 0.56359
# Epoch 60/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5529 - acc: 0.7183 - val_loss: 0.5632 - val_acc: 0.7018
#
# Epoch 00060: val_loss improved from 0.56359 to 0.56322, saving model to ./model/rf_top10/rf_top10_seed42-60-0.5632.hdf5
# Epoch 61/500
# 37/37 [==============================] - 2s 67ms/step - loss: 0.5531 - acc: 0.7211 - val_loss: 0.5634 - val_acc: 0.7031
#
# Epoch 00061: val_loss did not improve from 0.56322
# Epoch 62/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5549 - acc: 0.7200 - val_loss: 0.5634 - val_acc: 0.7025
#
# Epoch 00062: val_loss did not improve from 0.56322
# Epoch 63/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5549 - acc: 0.7215 - val_loss: 0.5645 - val_acc: 0.7038
#
# Epoch 00063: val_loss did not improve from 0.56322
# Epoch 64/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.5543 - acc: 0.7211 - val_loss: 0.5623 - val_acc: 0.7005
#
# Epoch 00064: val_loss improved from 0.56322 to 0.56231, saving model to ./model/rf_top10/rf_top10_seed42-64-0.5623.hdf5
# Epoch 65/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5512 - acc: 0.7245 - val_loss: 0.5628 - val_acc: 0.7005
#
# Epoch 00065: val_loss did not improve from 0.56231
# Epoch 66/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5510 - acc: 0.7226 - val_loss: 0.5622 - val_acc: 0.6992
#
# Epoch 00066: val_loss improved from 0.56231 to 0.56222, saving model to ./model/rf_top10/rf_top10_seed42-66-0.5622.hdf5
# Epoch 67/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.5510 - acc: 0.7241 - val_loss: 0.5635 - val_acc: 0.7012
#
# Epoch 00067: val_loss did not improve from 0.56222
# Epoch 68/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5512 - acc: 0.7241 - val_loss: 0.5634 - val_acc: 0.7005
#
# Epoch 00068: val_loss did not improve from 0.56222
# Epoch 69/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5536 - acc: 0.7230 - val_loss: 0.5625 - val_acc: 0.7012
#
# Epoch 00069: val_loss did not improve from 0.56222
# Epoch 70/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.5514 - acc: 0.7235 - val_loss: 0.5636 - val_acc: 0.7012
#
# Epoch 00070: val_loss did not improve from 0.56222
# Epoch 71/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.5504 - acc: 0.7254 - val_loss: 0.5631 - val_acc: 0.7005
#
# Epoch 00071: val_loss did not improve from 0.56222
# Epoch 72/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5494 - acc: 0.7271 - val_loss: 0.5635 - val_acc: 0.6986
#
# Epoch 00072: val_loss did not improve from 0.56222
# Epoch 73/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.5504 - acc: 0.7228 - val_loss: 0.5633 - val_acc: 0.6992
#
# Epoch 00073: val_loss did not improve from 0.56222
# Epoch 74/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5498 - acc: 0.7250 - val_loss: 0.5638 - val_acc: 0.6992
#
# Epoch 00074: val_loss did not improve from 0.56222
# Epoch 75/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.5508 - acc: 0.7248 - val_loss: 0.5630 - val_acc: 0.6999
# Epoch 00075: val_loss did not improve from 0.56222
# Epoch 76/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.5509 - acc: 0.7278 - val_loss: 0.5618 - val_acc: 0.7012
#
# Epoch 00076: val_loss improved from 0.56222 to 0.56180, saving model to ./model/rf_top10/rf_top10_seed42-76-0.5618.hdf5
# Epoch 77/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5478 - acc: 0.7222 - val_loss: 0.5624 - val_acc: 0.7018
#
# Epoch 00077: val_loss did not improve from 0.56180
# Epoch 78/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5509 - acc: 0.7217 - val_loss: 0.5624 - val_acc: 0.6999
#
# Epoch 00078: val_loss did not improve from 0.56180
# Epoch 79/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5494 - acc: 0.7230 - val_loss: 0.5625 - val_acc: 0.7012
#
# Epoch 00079: val_loss did not improve from 0.56180
# Epoch 80/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5490 - acc: 0.7252 - val_loss: 0.5626 - val_acc: 0.6992
#
# Epoch 00080: val_loss did not improve from 0.56180
# Epoch 81/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5474 - acc: 0.7261 - val_loss: 0.5622 - val_acc: 0.6999
#
# Epoch 00081: val_loss did not improve from 0.56180
# Epoch 82/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5485 - acc: 0.7230 - val_loss: 0.5620 - val_acc: 0.7005
#
# Epoch 00082: val_loss did not improve from 0.56180
# Epoch 83/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5452 - acc: 0.7243 - val_loss: 0.5631 - val_acc: 0.7012
#
# Epoch 00083: val_loss did not improve from 0.56180
# Epoch 84/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5474 - acc: 0.7271 - val_loss: 0.5628 - val_acc: 0.7018
#
# Epoch 00084: val_loss did not improve from 0.56180
# Epoch 85/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5462 - acc: 0.7265 - val_loss: 0.5629 - val_acc: 0.7025
#
# Epoch 00085: val_loss did not improve from 0.56180
# Epoch 86/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5467 - acc: 0.7254 - val_loss: 0.5630 - val_acc: 0.7018
#
# Epoch 00086: val_loss did not improve from 0.56180
# Epoch 87/500
# 37/37 [==============================] - 2s 67ms/step - loss: 0.5478 - acc: 0.7265 - val_loss: 0.5629 - val_acc: 0.7018
#
# Epoch 00087: val_loss did not improve from 0.56180
# Epoch 88/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5467 - acc: 0.7256 - val_loss: 0.5637 - val_acc: 0.7018
#
# Epoch 00088: val_loss did not improve from 0.56180
# Epoch 89/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5455 - acc: 0.7269 - val_loss: 0.5637 - val_acc: 0.7005
#
# Epoch 00089: val_loss did not improve from 0.56180
# Epoch 90/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5468 - acc: 0.7241 - val_loss: 0.5639 - val_acc: 0.6986
#
# Epoch 00090: val_loss did not improve from 0.56180
# Epoch 00090: early stopping
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 정확도 :0.7080906148867314, seed_num = 0
# 정확도 :0.7197411003236246, seed_num = 1
# 정확도 :0.7152103559870551, seed_num = 2
# 정확도 :0.7080906148867314, seed_num = 3
# 정확도 :0.7119741100323624, seed_num = 4
# 정확도 :0.713915857605178, seed_num = 5
# 정확도 :0.7171521035598706, seed_num = 6
# 정확도 :0.7190938511326861, seed_num = 7
# 정확도 :0.7197411003236246, seed_num = 8
# 정확도 :0.7100323624595469, seed_num = 9
# 정확도 :0.7190938511326861, seed_num = 10
# 정확도 :0.7275080906148867, seed_num = 11
# 정확도 :0.7313915857605178, seed_num = 12
# 정확도 :0.7249190938511327, seed_num = 13
# 정확도 :0.7210355987055016, seed_num = 14
# 정확도 :0.7242718446601941, seed_num = 15
# 정확도 :0.7288025889967638, seed_num = 16
# 정확도 :0.7165048543689321, seed_num = 17
# 정확도 :0.7229773462783171, seed_num = 18
# 정확도 :0.7093851132686084, seed_num = 19
# 정확도 :0.7055016181229773, seed_num = 20
# 정확도 :0.6957928802588996, seed_num = 21
# 정확도 :0.7119741100323624, seed_num = 22
# 정확도 :0.7080906148867314, seed_num = 23
# 정확도 :0.7003236245954693, seed_num = 24
# 정확도 :0.7197411003236246, seed_num = 25
# 정확도 :0.7132686084142394, seed_num = 26
# 정확도 :0.7022653721682848, seed_num = 27
# 정확도 :0.7190938511326861, seed_num = 28
# 정확도 :0.7113268608414239, seed_num = 29
# 정확도 :0.7262135922330097, seed_num = 30
# 정확도 :0.7061488673139159, seed_num = 31
# 정확도 :0.7119741100323624, seed_num = 32
# 정확도 :0.7184466019417476, seed_num = 33
# 정확도 :0.7307443365695793, seed_num = 34
# 정확도 :0.713915857605178, seed_num = 35
# 정확도 :0.7067961165048544, seed_num = 36
# 정확도 :0.7320388349514563, seed_num = 37
# 정확도 :0.7249190938511327, seed_num = 38
# 정확도 :0.7190938511326861, seed_num = 39
# 정확도 :0.7177993527508091, seed_num = 40
# 정확도 :0.7158576051779936, seed_num = 41
# 정확도 :0.7132686084142394, seed_num = 42
# 정확도 :0.7223300970873786, seed_num = 43
# 정확도 :0.6996763754045308, seed_num = 44
# 정확도 :0.7035598705501618, seed_num = 45
# 정확도 :0.7203883495145631, seed_num = 46
# 정확도 :0.7203883495145631, seed_num = 47
# 정확도 :0.7372168284789644, seed_num = 48
# 정확도 :0.7061488673139159, seed_num = 49
# 정확도 df 만들고 평균 확인 : [0.71606472]

# %% [markdown]
# ## (67.8) RF

# %%
RF_정확도(rf_top10,'rf_top10')
# Out:
# itemlist의 index :  [206, 56, 121, 3832, 20, 103, 119, 204, 2611, 34]
# 정확도 : 0.6666666666666666, seed_num = 0
# 정확도 : 0.6886731391585761, seed_num = 1
# 정확도 : 0.6789644012944984, seed_num = 2
# 정확도 : 0.6705501618122978, seed_num = 3
# 정확도 : 0.6621359223300971, seed_num = 4
# 정확도 : 0.6854368932038835, seed_num = 5
# 정확도 : 0.6763754045307443, seed_num = 6
# 정확도 : 0.6809061488673139, seed_num = 7
# 정확도 : 0.6964401294498382, seed_num = 8
# 정확도 : 0.6763754045307443, seed_num = 9
# 정확도 : 0.6880258899676376, seed_num = 10
# 정확도 : 0.6893203883495146, seed_num = 11
# 정확도 : 0.6841423948220064, seed_num = 12
# 정확도 : 0.6925566343042071, seed_num = 13
# 정확도 : 0.6750809061488673, seed_num = 14
# 정확도 : 0.6893203883495146, seed_num = 15
# 정확도 : 0.6880258899676376, seed_num = 16
# 정확도 : 0.6705501618122978, seed_num = 17
# 정확도 : 0.686084142394822, seed_num = 18
# 정확도 : 0.6757281553398058, seed_num = 19
# 정확도 : 0.6744336569579288, seed_num = 20
# 정확도 : 0.6925566343042071, seed_num = 21
# 정확도 : 0.6711974110032363, seed_num = 22
# 정확도 : 0.6427184466019418, seed_num = 23
# 정확도 : 0.658252427184466, seed_num = 24
# 정확도 : 0.6776699029126214, seed_num = 25
# 정확도 : 0.6724919093851133, seed_num = 26
# 정확도 : 0.6809061488673139, seed_num = 27
# 정확도 : 0.6750809061488673, seed_num = 28
# 정확도 : 0.6776699029126214, seed_num = 29
# 정확도 : 0.6919093851132686, seed_num = 30
# 정확도 : 0.6660194174757281, seed_num = 31
# 정확도 : 0.6796116504854369, seed_num = 32
# 정확도 : 0.6802588996763754, seed_num = 33
# 정확도 : 0.6906148867313916, seed_num = 34
# 정확도 : 0.6711974110032363, seed_num = 35
# 정확도 : 0.6906148867313916, seed_num = 36
# 정확도 : 0.6822006472491909, seed_num = 37
# 정확도 : 0.6854368932038835, seed_num = 38
# 정확도 : 0.6796116504854369, seed_num = 39
# 정확도 : 0.6783171521035599, seed_num = 40
# 정확도 : 0.6621359223300971, seed_num = 41
# 정확도 : 0.6660194174757281, seed_num = 42
# 정확도 : 0.6783171521035599, seed_num = 43
# 정확도 : 0.6634304207119741, seed_num = 44
# 정확도 : 0.6802588996763754, seed_num = 45
# 정확도 : 0.6776699029126214, seed_num = 46
# 정확도 : 0.6757281553398058, seed_num = 47
# 정확도 : 0.7061488673139159, seed_num = 48
# 정확도 : 0.6873786407766991, seed_num = 49
# 정확도 df 만들고 평균 확인 : [0.67874434]

# %% [markdown]
# ## absum 그래프

# %%
absum(rf_top10)

# %% [markdown]
# ## violin plot

# %%
violin_allfit(rf_top10)
# Out:
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 10it [01:10,  7.08s/it]
