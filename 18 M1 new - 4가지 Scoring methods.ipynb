# %% [markdown]
# # Library

# %%
import numpy as np, os
import pandas as pd
import tensorflow as tf
from tqdm import tqdm
import seaborn as sns
import matplotlib.pyplot as plt

# 결과 확인을 용이하게 하기 위한 코드
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

#한글설정
import matplotlib.font_manager as fm

font_dirs = ['/usr/share/fonts/truetype/nanum', ]
font_files = fm.findSystemFonts(fontpaths=font_dirs)

for font_file in font_files:
    fm.fontManager.addfont(font_file)
    
# 한글 출력을 위해서 폰트 옵션을 설정합니다.
# "axes.unicode_minus" : 마이너스가 깨질 것을 방지

sns.set(font="NanumBarunGothic", 
        rc={"axes.unicode_minus":False},
        style='darkgrid')

# GPU 용량 설정
gpus = tf.config.experimental.list_physical_devices('GPU')
print(gpus)
if gpus:  # gpu가 있다면, 용량 한도를 5GB로 설정
    tf.config.experimental.set_virtual_device_configuration(gpus[0], 
                                                            [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5*1024)])
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %% [markdown]
# # 함수 모음

# %% [markdown]
# ## RF_정확도(itemlist, name)

# %%
def RF_정확도(itemlist,name):

    # itemlist만을 가진 x_(7727,10)_itemlist 만들기
    item_list = list(total_data['ITEMID'].sort_values().unique())
    
    item_index = []
    for i in itemlist:
        item_index.append(item_list.index(i))

    print('itemlist의 index : ',item_index)

    x = np.load('x_(7727,4068).npy')
    x_2d = x[:,item_index]
    x_2d
    
    np.save(f'x_(7727,10)_{name}.npy',x_2d)
    
    import random
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.metrics import accuracy_score

    model = RandomForestClassifier()

    data={}
    for seed in range(42, 52):
        random.seed(seed)
        
        x = np.load(f'./x_(7727,10)_{name}.npy')
        y = np.load('./y_(7727,1).npy')

        idx = list(range(len(x)))
        random.shuffle(idx)

        i = round(x.shape[0]*0.8)
        X_train, y_train = x[idx[:i],:], y[idx[:i]]
        X_test, y_test = x[idx[i:],:], y[idx[i:]]

        _ = model.fit(X_train, y_train)
        y_pred_train = model.predict(X_train)
        y_pred_test = model.predict(X_test)

        acc = accuracy_score(y_test, y_pred_test)
        data[seed]=acc
        print(f'정확도 : {acc}, seed_num = {seed}')

    df = pd.DataFrame.from_dict(data, orient='index')
    print(f'정확도 df 만들고 평균 확인 : {df.mean().values}')

# %% [markdown]
# ## LSTM_정확도(itemlist, name)

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, InputLayer
from tensorflow.keras.callbacks import EarlyStopping
from sklearn import metrics 
from tensorflow import keras
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

import random

def LSTM_정확도(itemlist, name):

    # itemlist만을 가진 x_(7727,10,10)_itemlist 만들기
    total_data = pd.read_csv('total_data_7727.csv')
    item_list = list(total_data['ITEMID'].sort_values().unique())

    item_index = []
    for i in itemlist:
        item_index.append(item_list.index(i))

    print('itemlist의 index : ',item_index)

    x = np.load('x_(7727,10,4068).npy')
    x_3d = x[:,:,item_index]
    
    np.save(f'x_(7727,10,10)_{name}.npy',x_3d)
    
    seed_num = 42
    random.seed(seed_num)
    
    x = np.load(f'x_(7727,10,10)_{name}.npy')
    y = np.load('y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
    X_test, y_test = x[idx[i:],:,:], y[idx[i:]]

    # ---------------------
    seed_num = 42 
    # ---------------------
    tf.random.set_seed(seed_num)

    lstm = Sequential()
    lstm.add(InputLayer(input_shape=(X_train.shape[1],X_train.shape[2])))
    lstm.add(LSTM(units=128, activation='hard_sigmoid', return_sequences=True))
    lstm.add(LSTM(units=64, activation='hard_sigmoid', return_sequences=True))
    lstm.add(Dropout(0.2))
    lstm.add(LSTM(units=64, activation='hard_sigmoid', return_sequences=True))
    lstm.add(LSTM(units=32, activation='hard_sigmoid', return_sequences=False))
    lstm.add(Dropout(0.2))
    lstm.add(Dense(units=1, activation='sigmoid'))

    from tensorflow.keras.callbacks import ModelCheckpoint
    import os

    MODEL_SAVE_FOLDER_PATH = f'./model/{name}'
    if not os.path.exists(MODEL_SAVE_FOLDER_PATH):
        os.mkdir(MODEL_SAVE_FOLDER_PATH)

    model_path = MODEL_SAVE_FOLDER_PATH + f'/{name}_seed42-'+'{epoch:02d}'+'-{val_loss:.4f}.hdf5'

    cb_checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss',
                                    verbose=1, save_best_only=True)

    early_stop = EarlyStopping(monitor='val_acc', patience=50, verbose=1, restore_best_weights=True)
    lstm.compile(optimizer= keras.optimizers.Adam(learning_rate = 0.001), loss = "binary_crossentropy", metrics=['acc'])
    lstm.fit(X_train, y_train, validation_split=0.25, batch_size=128, epochs=500,  callbacks=[early_stop,cb_checkpoint], shuffle=False)
    
    with tf.device('/device:GPU:0'):
        tf.config.experimental.set_virtual_device_configuration(gpus[0], 
                                                            [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5*1024)])

        from pathlib import Path
        paths = sorted(Path(MODEL_SAVE_FOLDER_PATH).iterdir(), key=os.path.getmtime)[-1]
        best_model_path = str(paths)

        from keras.models import load_model
        best_model = load_model(best_model_path) 

        dic_42={}
        for seed in range(0, 50):
            random.seed(seed)

            x = np.load(f'x_(7727,10,10)_{name}.npy')
            y = np.load('y_(7727,1).npy')

            idx = list(range(len(x)))
            random.shuffle(idx)

            i = round(x.shape[0]*0.8)
            X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
            X_test, y_test = x[idx[i:],:,:], y[idx[i:]]

            pred = best_model.predict(X_test)
            pred[pred>0.5]=1
            pred[pred<=0.5]=0
            acc = metrics.accuracy_score(y_test, pred)
            dic_42[seed]=acc
            print(f'정확도 :{metrics.accuracy_score(y_test, pred)}, seed_num = {seed}')

        df_42 = pd.DataFrame.from_dict(dic_42, orient='index')
        print(f'정확도 df 만들고 평균 확인 : {df_42.mean().values}')

# %% [markdown]
# ## absum(PPL_list, top_or_down)

# %%
total_data = pd.read_csv('total_data_7727.csv')
x = np.load('/project/LSH/x_(7727,10,4068).npy')

def absum(PPL_list,top_or_down):
    # 1) PRE_top10의 index 구하기
    PPL_top10 = top_or_down
    item_list = total_data['ITEMID'].sort_values().unique()

    PPL_index = []
    for i in PPL_top10:
        a = list(item_list).index(i)
        PPL_index.append(a)
    
    # 2) 생존자 index 구하기 
    sub7727 = total_data['SUBJECT_ID'].unique()

    patient = pd.read_csv('폐렴환자.csv')
    patient = patient.sort_values(by='SUBJECT_ID')
    patient = patient[patient['SUBJECT_ID'].isin(sub7727)]
    sub_1_list = patient[patient['EXPIRE_FLAG']==0]['SUBJECT_ID'].values

    생존자_index = []
    for i in sub_1_list:
        생존자_index.append(list(sub7727).index(i))
        
    # 3) 생존자 3009명의 D-10 ~ D-1 feature별 abnormal sum 
    x_생존자 = x[생존자_index,:,:]

    result1 = []
    for i in PPL_index:
        for j in range(10):
            result1.append(x_생존자[:,j,i].sum())

    result1 = np.array(result1)
    result1 = result1.reshape(10,-1)
    df_PPL = pd.DataFrame(result1)
    df_PPL.columns = [f'D-{i}' for i in range(10,0,-1)]
    df_PPL.index = PPL_top10

    # 생존한 4718명에 대한 비율 계산
    for i in PPL_top10:
        df_PPL.loc[f'{i}_생존'] = df_PPL.loc[i].iloc[:]/x_생존자.shape[0]
        
    # 4) 사망자 4718명의 D-10 ~ D-1 feature별 abnormal sum 
    사망자_index = list(set(range(0,7727))-set(생존자_index))

    x_사망자 = x[사망자_index,:,:]

    result2 = []
    for i in PPL_index:
        for j in range(10):
            result2.append(x_사망자[:,j,i].sum())

    result2 = np.array(result2)
    result2 = result2.reshape(10,-1)
    df_PPL_사망자 = pd.DataFrame(result2)
    df_PPL_사망자.columns = [f'D-{i}' for i in range(10,0,-1)]
    df_PPL_사망자.index = PPL_top10

    # 사망한 3009명에 대한 비율 계산
    for i in PPL_top10:
        df_PPL_사망자.loc[f'{i}_사망'] = df_PPL_사망자.loc[i]/x_사망자.shape[0] 
        
    # 5) for문으로 각 feature에 대한 비율 추이 그래프 그리기 

    df_PPL_trans = df_PPL.transpose()
    df_PPL_사망자_trans = df_PPL_사망자.transpose()

    _ = plt.figure(figsize = (13,12),dpi=150)
    for i, f in enumerate(PPL_top10): 
        _ = plt.subplot(4,3,1+i)
        _ = plt.title(f)
        _ = ax = sns.lineplot(data = df_PPL_사망자_trans, x = df_PPL_사망자_trans.index, y = f'{f}_사망')
        _ = ax = sns.lineplot(data = df_PPL_trans, x = df_PPL_trans.index, y = f'{f}_생존')
        _ = ax.legend(labels = ['사망', '생존'], loc = 'upper left', fontsize=12)
        _ = ax.set_ylabel('per', fontsize = 12)

    plt.tight_layout()

# %% [markdown]
# ## FI_merge_list(itemlist) / ALL fit

# %%
def FI_merge_list(itemlist):
    
    # 1) DATA 
    x = np.load('/project/LSH/x_(7727,10,4068).npy')
    y = np.load('/project/LSH/y_(7727,1).npy')
    
    with tf.device('/device:GPU:0'):
        tf.config.experimental.set_virtual_device_configuration(gpus[0], 
                                                            [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5*1024)])
        # 2) MODEL
        from keras.models import load_model
        lstm2 = load_model('./model/allfit2_seed42-06-0.5519.hdf5')

        _ = plt.figure(figsize = (13,12),dpi=150)

        for j, itemid in tqdm(enumerate(itemlist)):

            # 3) 환자별 base pred (Y')
            base_pred = pd.DataFrame(lstm2.predict(x))

            total_data = pd.read_csv('total_data_7727.csv')
            features = total_data['ITEMID'].sort_values().unique()

            k = list(features).index(itemid)
            save_col = x[:,:,k].copy()

            # 4) 0 to 1
            x[:,:,k]= np.where(x[:,:,k]==0, 1, x[:,:,k])
            pred_0to1 = pd.DataFrame(lstm2.predict(x))

            # 5) 1 to 0
            x[:,:,k] = np.where(x[:,:,k]==1, 0, x[:,:,k])
            pred_1to0 = pd.DataFrame(lstm2.predict(x))

            # 6) inverse
            x[:,:,k] = save_col
            x[:,:,k] = np.where(x[:,:,k]==1, 2, x[:,:,k])
            x[:,:,k] = np.where(x[:,:,k]==0, 1, x[:,:,k])
            x[:,:,k] = np.where(x[:,:,k]==2, 0, x[:,:,k])
            pred_inverse = pd.DataFrame(lstm2.predict(x))

            x[:,:,k] = save_col

            # 7) Merge & Visualize
            FI_merge_df = pd.concat([base_pred, pred_0to1, pred_1to0, pred_inverse], axis=1)
            FI_merge_df.columns = ['base_pred', 'pred_0to1', 'pred_1to0', 'pred_inverse']
            FI_merge_visual = FI_merge_df.melt(value_vars=['base_pred','pred_0to1','pred_1to0','pred_inverse'])
            FI_merge_visual.columns = ['method','pred_value']

            _ = plt.subplot(4,3,1+j)
            _ = plt.title(itemid)
            ax = sns.violinplot(data=FI_merge_visual, x='method',y='pred_value',
                                palette="Set2", inner="quartile")
    plt.tight_layout()

# %% [markdown]
# # 1️⃣ E(0to1) - E(1to0)
# - 최종 df : `m1_new.csv`

# %%
entropy = pd.read_csv('m1_entropy.csv')
entropy = entropy.sort_values(by='feature')
entropy.index = range(4068)

mm = pd.read_csv('FI_mean_merge.csv')
mm['mean_diff'] = mm['pred_0to1']-mm['pred_1to0']
mm = mm.sort_values(by='feature')
mm['entropy'] = entropy['entropy']
mm['m1_new'] = mm['mean_diff'] * mm['entropy']
m1_new = mm.sort_values(by='m1_new', ascending=False)
# m1_new.to_csv('m1_new.csv',index=False)

# %%
m1_new = pd.read_csv('m1_new.csv')
m1_new
# Out:
#           feature  pred_0to1  pred_1to0  pred_inverse  baseline  mean_diff  \
# 0           51277   0.718487   0.582343      0.693639  0.636932   0.136144
# 1           51006   0.692667   0.581710      0.668543  0.636932   0.110958
# 2           50912   0.678140   0.607378      0.676969  0.636932   0.070762
# 3           50882   0.682766   0.607949      0.682174  0.636932   0.074817
# 4       409176230   0.719983   0.615389      0.724965  0.636932   0.104593
# ...           ...        ...        ...           ...       ...        ...
# 4063        51237   0.592904   0.628682      0.613074  0.636932  -0.035778
# 4064        50861   0.529173   0.629188      0.549854  0.636932  -0.100014
# 4065        51249   0.556241   0.631692      0.579608  0.636932  -0.075451
# 4066            0   0.602555   0.664229      0.658366  0.636932  -0.061674
# 4067  63323026201   0.541691   0.651021      0.584650  0.636932  -0.109330
#
#        entropy    m1_new
# 0     0.919332  0.125161
# 1     0.980942  0.108843
# 2     0.848272  0.060025
# 3     0.767764  0.057442
# 4     0.380630  0.039811
# ...        ...       ...
# 4063  0.742306 -0.026558
# 4064  0.400005 -0.040006
# 4065  0.552624 -0.041696
# 4066  0.894548 -0.055171
# 4067  0.795432 -0.086965
#
# [4068 rows x 8 columns]

# %% [markdown]
# ## m1_new_top10

# %%
m1_new = pd.read_csv('m1_new.csv')
m1_new_top10 = m1_new['feature'].values[:10]
m1_new_top10
# Out:
# array([    51277,     51006,     50912,     50882, 409176230,     50862,
#            51003,     50983,     50893, 487980125])

# %% [markdown]
# ### (65.5) RF

# %%
RF_정확도(m1_new_top10,'m1_new_top10')
# Out:
# itemlist의 index :  [206, 121, 56, 34, 2148, 20, 119, 103, 41, 2291]
# 정확도 : 0.6608414239482201, seed_num = 42
# 정확도 : 0.6537216828478964, seed_num = 43
# 정확도 : 0.6323624595469256, seed_num = 44
# 정확도 : 0.6388349514563106, seed_num = 45
# 정확도 : 0.658252427184466, seed_num = 46
# 정확도 : 0.6660194174757281, seed_num = 47
# 정확도 : 0.6770226537216828, seed_num = 48
# 정확도 : 0.656957928802589, seed_num = 49
# 정확도 : 0.6595469255663431, seed_num = 50
# 정확도 : 0.6498381877022654, seed_num = 51
# 정확도 df 만들고 평균 확인 : [0.65533981]

# %% [markdown]
# ### (70.4) LSTM

# %%
LSTM_정확도(m1_new_top10,'m1_new_top10')
# Out:
# itemlist의 index :  [206, 121, 56, 34, 2148, 20, 119, 103, 41, 2291]
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/500
# 37/37 [==============================] - 6s 74ms/step - loss: 0.6758 - acc: 0.5984 - val_loss: 0.6660 - val_acc: 0.6177
#
# Epoch 00001: val_loss improved from inf to 0.66597, saving model to ./model/m1_new_top10/m1_new_top10_seed42-01-0.6660.hdf5
# Epoch 2/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6731 - acc: 0.6068 - val_loss: 0.6661 - val_acc: 0.6177
#
# Epoch 00002: val_loss did not improve from 0.66597
# Epoch 3/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6734 - acc: 0.6083 - val_loss: 0.6646 - val_acc: 0.6177
#
# Epoch 00003: val_loss improved from 0.66597 to 0.66464, saving model to ./model/m1_new_top10/m1_new_top10_seed42-03-0.6646.hdf5
# Epoch 4/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6646 - acc: 0.6117 - val_loss: 0.6475 - val_acc: 0.6177
#
# Epoch 00004: val_loss improved from 0.66464 to 0.64746, saving model to ./model/m1_new_top10/m1_new_top10_seed42-04-0.6475.hdf5
# Epoch 5/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6420 - acc: 0.6113 - val_loss: 0.6334 - val_acc: 0.6177
#
# Epoch 00005: val_loss improved from 0.64746 to 0.63337, saving model to ./model/m1_new_top10/m1_new_top10_seed42-05-0.6334.hdf5
# Epoch 6/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6266 - acc: 0.6467 - val_loss: 0.6214 - val_acc: 0.6688
#
# Epoch 00006: val_loss improved from 0.63337 to 0.62139, saving model to ./model/m1_new_top10/m1_new_top10_seed42-06-0.6214.hdf5
# Epoch 7/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6159 - acc: 0.6624 - val_loss: 0.6227 - val_acc: 0.6656
#
# Epoch 00007: val_loss did not improve from 0.62139
# Epoch 8/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6139 - acc: 0.6687 - val_loss: 0.6146 - val_acc: 0.6798
#
# Epoch 00008: val_loss improved from 0.62139 to 0.61463, saving model to ./model/m1_new_top10/m1_new_top10_seed42-08-0.6146.hdf5
# Epoch 9/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6068 - acc: 0.6728 - val_loss: 0.6097 - val_acc: 0.6721
#
# Epoch 00009: val_loss improved from 0.61463 to 0.60972, saving model to ./model/m1_new_top10/m1_new_top10_seed42-09-0.6097.hdf5
# Epoch 10/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6013 - acc: 0.6831 - val_loss: 0.6076 - val_acc: 0.6714
#
# Epoch 00010: val_loss improved from 0.60972 to 0.60756, saving model to ./model/m1_new_top10/m1_new_top10_seed42-10-0.6076.hdf5
# Epoch 11/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6009 - acc: 0.6877 - val_loss: 0.6061 - val_acc: 0.6766
#
# Epoch 00011: val_loss improved from 0.60756 to 0.60611, saving model to ./model/m1_new_top10/m1_new_top10_seed42-11-0.6061.hdf5
# Epoch 12/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5964 - acc: 0.6855 - val_loss: 0.6051 - val_acc: 0.6811
#
# Epoch 00012: val_loss improved from 0.60611 to 0.60513, saving model to ./model/m1_new_top10/m1_new_top10_seed42-12-0.6051.hdf5
# Epoch 13/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5950 - acc: 0.6892 - val_loss: 0.6022 - val_acc: 0.6734
#
# Epoch 00013: val_loss improved from 0.60513 to 0.60220, saving model to ./model/m1_new_top10/m1_new_top10_seed42-13-0.6022.hdf5
# Epoch 14/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5934 - acc: 0.6892 - val_loss: 0.6010 - val_acc: 0.6759
#
# Epoch 00014: val_loss improved from 0.60220 to 0.60104, saving model to ./model/m1_new_top10/m1_new_top10_seed42-14-0.6010.hdf5
# Epoch 15/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5921 - acc: 0.6911 - val_loss: 0.5989 - val_acc: 0.6753
#
# Epoch 00015: val_loss improved from 0.60104 to 0.59894, saving model to ./model/m1_new_top10/m1_new_top10_seed42-15-0.5989.hdf5
# Epoch 16/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5904 - acc: 0.6915 - val_loss: 0.5980 - val_acc: 0.6772
#
# Epoch 00016: val_loss improved from 0.59894 to 0.59797, saving model to ./model/m1_new_top10/m1_new_top10_seed42-16-0.5980.hdf5
# Epoch 17/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5912 - acc: 0.6931 - val_loss: 0.5968 - val_acc: 0.6779
#
# Epoch 00017: val_loss improved from 0.59797 to 0.59682, saving model to ./model/m1_new_top10/m1_new_top10_seed42-17-0.5968.hdf5
# Epoch 18/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5864 - acc: 0.6980 - val_loss: 0.5976 - val_acc: 0.6779
#
# Epoch 00018: val_loss did not improve from 0.59682
# Epoch 19/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5887 - acc: 0.6920 - val_loss: 0.5951 - val_acc: 0.6792
#
# Epoch 00019: val_loss improved from 0.59682 to 0.59508, saving model to ./model/m1_new_top10/m1_new_top10_seed42-19-0.5951.hdf5
# Epoch 20/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5873 - acc: 0.6928 - val_loss: 0.5934 - val_acc: 0.6766
#
# Epoch 00020: val_loss improved from 0.59508 to 0.59336, saving model to ./model/m1_new_top10/m1_new_top10_seed42-20-0.5934.hdf5
# Epoch 21/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5847 - acc: 0.6993 - val_loss: 0.5945 - val_acc: 0.6818
#
# Epoch 00021: val_loss did not improve from 0.59336
# Epoch 22/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5853 - acc: 0.6967 - val_loss: 0.5931 - val_acc: 0.6818
#
# Epoch 00022: val_loss improved from 0.59336 to 0.59308, saving model to ./model/m1_new_top10/m1_new_top10_seed42-22-0.5931.hdf5
# Epoch 23/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5857 - acc: 0.6941 - val_loss: 0.5924 - val_acc: 0.6811
#
# Epoch 00023: val_loss improved from 0.59308 to 0.59238, saving model to ./model/m1_new_top10/m1_new_top10_seed42-23-0.5924.hdf5
# Epoch 24/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5835 - acc: 0.6937 - val_loss: 0.5904 - val_acc: 0.6805
#
# Epoch 00024: val_loss improved from 0.59238 to 0.59041, saving model to ./model/m1_new_top10/m1_new_top10_seed42-24-0.5904.hdf5
# Epoch 25/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5833 - acc: 0.7013 - val_loss: 0.5900 - val_acc: 0.6785
#
# Epoch 00025: val_loss improved from 0.59041 to 0.58997, saving model to ./model/m1_new_top10/m1_new_top10_seed42-25-0.5900.hdf5
# Epoch 26/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5812 - acc: 0.7002 - val_loss: 0.5897 - val_acc: 0.6792
#
# Epoch 00026: val_loss improved from 0.58997 to 0.58968, saving model to ./model/m1_new_top10/m1_new_top10_seed42-26-0.5897.hdf5
# Epoch 27/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5803 - acc: 0.7021 - val_loss: 0.5888 - val_acc: 0.6811
#
# Epoch 00027: val_loss improved from 0.58968 to 0.58879, saving model to ./model/m1_new_top10/m1_new_top10_seed42-27-0.5888.hdf5
# Epoch 28/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5784 - acc: 0.7017 - val_loss: 0.5886 - val_acc: 0.6798
#
# Epoch 00028: val_loss improved from 0.58879 to 0.58857, saving model to ./model/m1_new_top10/m1_new_top10_seed42-28-0.5886.hdf5
# Epoch 29/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5795 - acc: 0.7015 - val_loss: 0.5879 - val_acc: 0.6792
#
# Epoch 00029: val_loss improved from 0.58857 to 0.58788, saving model to ./model/m1_new_top10/m1_new_top10_seed42-29-0.5879.hdf5
# Epoch 30/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5795 - acc: 0.7023 - val_loss: 0.5876 - val_acc: 0.6779
#
# Epoch 00030: val_loss improved from 0.58788 to 0.58762, saving model to ./model/m1_new_top10/m1_new_top10_seed42-30-0.5876.hdf5
# Epoch 31/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5768 - acc: 0.7008 - val_loss: 0.5878 - val_acc: 0.6831
#
# Epoch 00031: val_loss did not improve from 0.58762
# Epoch 32/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5802 - acc: 0.7021 - val_loss: 0.5863 - val_acc: 0.6805
#
# Epoch 00032: val_loss improved from 0.58762 to 0.58634, saving model to ./model/m1_new_top10/m1_new_top10_seed42-32-0.5863.hdf5
# Epoch 33/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5777 - acc: 0.7032 - val_loss: 0.5862 - val_acc: 0.6779
#
# Epoch 00033: val_loss improved from 0.58634 to 0.58621, saving model to ./model/m1_new_top10/m1_new_top10_seed42-33-0.5862.hdf5
# Epoch 34/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5756 - acc: 0.7041 - val_loss: 0.5867 - val_acc: 0.6818
#
# Epoch 00034: val_loss did not improve from 0.58621
# Epoch 35/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5769 - acc: 0.7030 - val_loss: 0.5873 - val_acc: 0.6811
#
# Epoch 00035: val_loss did not improve from 0.58621
# Epoch 36/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5780 - acc: 0.7000 - val_loss: 0.5854 - val_acc: 0.6785
#
# Epoch 00036: val_loss improved from 0.58621 to 0.58545, saving model to ./model/m1_new_top10/m1_new_top10_seed42-36-0.5854.hdf5
# Epoch 37/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5744 - acc: 0.7023 - val_loss: 0.5850 - val_acc: 0.6766
#
# Epoch 00037: val_loss improved from 0.58545 to 0.58502, saving model to ./model/m1_new_top10/m1_new_top10_seed42-37-0.5850.hdf5
# Epoch 38/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5748 - acc: 0.7049 - val_loss: 0.5854 - val_acc: 0.6824
#
# Epoch 00038: val_loss did not improve from 0.58502
# Epoch 39/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5765 - acc: 0.7010 - val_loss: 0.5843 - val_acc: 0.6805
#
# Epoch 00039: val_loss improved from 0.58502 to 0.58426, saving model to ./model/m1_new_top10/m1_new_top10_seed42-39-0.5843.hdf5
# Epoch 40/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5748 - acc: 0.7030 - val_loss: 0.5846 - val_acc: 0.6785
#
# Epoch 00040: val_loss did not improve from 0.58426
# Epoch 41/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5763 - acc: 0.7013 - val_loss: 0.5848 - val_acc: 0.6811
#
# Epoch 00041: val_loss did not improve from 0.58426
# Epoch 42/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5723 - acc: 0.7077 - val_loss: 0.5846 - val_acc: 0.6824
#
# Epoch 00042: val_loss did not improve from 0.58426
# Epoch 43/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5746 - acc: 0.7047 - val_loss: 0.5847 - val_acc: 0.6837
#
# Epoch 00043: val_loss did not improve from 0.58426
# Epoch 44/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5734 - acc: 0.7021 - val_loss: 0.5835 - val_acc: 0.6805
#
# Epoch 00044: val_loss improved from 0.58426 to 0.58349, saving model to ./model/m1_new_top10/m1_new_top10_seed42-44-0.5835.hdf5
# Epoch 45/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5721 - acc: 0.7034 - val_loss: 0.5852 - val_acc: 0.6863
#
# Epoch 00045: val_loss did not improve from 0.58349
# Epoch 46/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5751 - acc: 0.7028 - val_loss: 0.5842 - val_acc: 0.6818
#
# Epoch 00046: val_loss did not improve from 0.58349
# Epoch 47/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5722 - acc: 0.7045 - val_loss: 0.5836 - val_acc: 0.6824
#
# Epoch 00047: val_loss did not improve from 0.58349
# Epoch 48/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5726 - acc: 0.7053 - val_loss: 0.5843 - val_acc: 0.6863
#
# Epoch 00048: val_loss did not improve from 0.58349
# Epoch 49/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5723 - acc: 0.7030 - val_loss: 0.5832 - val_acc: 0.6811
#
# Epoch 00049: val_loss improved from 0.58349 to 0.58323, saving model to ./model/m1_new_top10/m1_new_top10_seed42-49-0.5832.hdf5
# Epoch 50/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5716 - acc: 0.7056 - val_loss: 0.5833 - val_acc: 0.6811
#
# Epoch 00050: val_loss did not improve from 0.58323
# Epoch 51/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5697 - acc: 0.7021 - val_loss: 0.5831 - val_acc: 0.6824
#
# Epoch 00051: val_loss improved from 0.58323 to 0.58306, saving model to ./model/m1_new_top10/m1_new_top10_seed42-51-0.5831.hdf5
# Epoch 52/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5699 - acc: 0.7041 - val_loss: 0.5833 - val_acc: 0.6831
#
# Epoch 00052: val_loss did not improve from 0.58306
# Epoch 53/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5711 - acc: 0.7049 - val_loss: 0.5829 - val_acc: 0.6824
#
# Epoch 00053: val_loss improved from 0.58306 to 0.58289, saving model to ./model/m1_new_top10/m1_new_top10_seed42-53-0.5829.hdf5
# Epoch 54/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5687 - acc: 0.7066 - val_loss: 0.5840 - val_acc: 0.6824
#
# Epoch 00054: val_loss did not improve from 0.58289
# Epoch 55/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5698 - acc: 0.7086 - val_loss: 0.5839 - val_acc: 0.6837
#
# Epoch 00055: val_loss did not improve from 0.58289
# Epoch 56/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5673 - acc: 0.7062 - val_loss: 0.5832 - val_acc: 0.6843
#
# Epoch 00056: val_loss did not improve from 0.58289
# Epoch 57/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5693 - acc: 0.7082 - val_loss: 0.5833 - val_acc: 0.6843
#
# Epoch 00057: val_loss did not improve from 0.58289
# Epoch 58/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5671 - acc: 0.7082 - val_loss: 0.5839 - val_acc: 0.6889
#
# Epoch 00058: val_loss did not improve from 0.58289
# Epoch 59/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5684 - acc: 0.7099 - val_loss: 0.5832 - val_acc: 0.6876
#
# Epoch 00059: val_loss did not improve from 0.58289
# Epoch 60/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5662 - acc: 0.7060 - val_loss: 0.5828 - val_acc: 0.6895
#
# Epoch 00060: val_loss improved from 0.58289 to 0.58278, saving model to ./model/m1_new_top10/m1_new_top10_seed42-60-0.5828.hdf5
# Epoch 61/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5672 - acc: 0.7049 - val_loss: 0.5828 - val_acc: 0.6876
#
# Epoch 00061: val_loss did not improve from 0.58278
# Epoch 62/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5681 - acc: 0.7069 - val_loss: 0.5830 - val_acc: 0.6895
#
# Epoch 00062: val_loss did not improve from 0.58278
# Epoch 63/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5675 - acc: 0.7094 - val_loss: 0.5833 - val_acc: 0.6908
#
# Epoch 00063: val_loss did not improve from 0.58278
# Epoch 64/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5672 - acc: 0.7086 - val_loss: 0.5821 - val_acc: 0.6889
#
# Epoch 00064: val_loss improved from 0.58278 to 0.58214, saving model to ./model/m1_new_top10/m1_new_top10_seed42-64-0.5821.hdf5
# Epoch 65/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5652 - acc: 0.7107 - val_loss: 0.5838 - val_acc: 0.6908
#
# Epoch 00065: val_loss did not improve from 0.58214
# Epoch 66/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5651 - acc: 0.7082 - val_loss: 0.5819 - val_acc: 0.6928
#
# Epoch 00066: val_loss improved from 0.58214 to 0.58186, saving model to ./model/m1_new_top10/m1_new_top10_seed42-66-0.5819.hdf5
# Epoch 67/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5634 - acc: 0.7135 - val_loss: 0.5830 - val_acc: 0.6908
#
# Epoch 00067: val_loss did not improve from 0.58186
# Epoch 68/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5656 - acc: 0.7112 - val_loss: 0.5828 - val_acc: 0.6934
#
# Epoch 00068: val_loss did not improve from 0.58186
# Epoch 69/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5642 - acc: 0.7097 - val_loss: 0.5827 - val_acc: 0.6902
#
# Epoch 00069: val_loss did not improve from 0.58186
# Epoch 70/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5660 - acc: 0.7129 - val_loss: 0.5823 - val_acc: 0.6928
#
# Epoch 00070: val_loss did not improve from 0.58186
# Epoch 71/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5609 - acc: 0.7079 - val_loss: 0.5830 - val_acc: 0.6921
#
# Epoch 00071: val_loss did not improve from 0.58186
# Epoch 72/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5626 - acc: 0.7099 - val_loss: 0.5836 - val_acc: 0.6902
#
# Epoch 00072: val_loss did not improve from 0.58186
# Epoch 73/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5627 - acc: 0.7110 - val_loss: 0.5822 - val_acc: 0.6921
#
# Epoch 00073: val_loss did not improve from 0.58186
# Epoch 74/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5636 - acc: 0.7138 - val_loss: 0.5824 - val_acc: 0.6921
#
# Epoch 00074: val_loss did not improve from 0.58186
# Epoch 75/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5627 - acc: 0.7088 - val_loss: 0.5825 - val_acc: 0.6908
#
# Epoch 00075: val_loss did not improve from 0.58186
# Epoch 76/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5627 - acc: 0.7120 - val_loss: 0.5815 - val_acc: 0.6915
#
# Epoch 00076: val_loss improved from 0.58186 to 0.58154, saving model to ./model/m1_new_top10/m1_new_top10_seed42-76-0.5815.hdf5
# Epoch 77/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5594 - acc: 0.7133 - val_loss: 0.5830 - val_acc: 0.6889
#
# Epoch 00077: val_loss did not improve from 0.58154
# Epoch 78/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5623 - acc: 0.7090 - val_loss: 0.5822 - val_acc: 0.6895
#
# Epoch 00078: val_loss did not improve from 0.58154
# Epoch 79/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5632 - acc: 0.7146 - val_loss: 0.5814 - val_acc: 0.6921
#
# Epoch 00079: val_loss improved from 0.58154 to 0.58141, saving model to ./model/m1_new_top10/m1_new_top10_seed42-79-0.5814.hdf5
# Epoch 80/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5606 - acc: 0.7135 - val_loss: 0.5825 - val_acc: 0.6895
#
# Epoch 00080: val_loss did not improve from 0.58141
# Epoch 81/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5608 - acc: 0.7131 - val_loss: 0.5810 - val_acc: 0.6902
#
# Epoch 00081: val_loss improved from 0.58141 to 0.58105, saving model to ./model/m1_new_top10/m1_new_top10_seed42-81-0.5810.hdf5
# Epoch 82/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5607 - acc: 0.7138 - val_loss: 0.5818 - val_acc: 0.6902
#
# Epoch 00082: val_loss did not improve from 0.58105
# Epoch 83/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5586 - acc: 0.7144 - val_loss: 0.5824 - val_acc: 0.6869
#
# Epoch 00083: val_loss did not improve from 0.58105
# Epoch 84/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5608 - acc: 0.7140 - val_loss: 0.5813 - val_acc: 0.6889
#
# Epoch 00084: val_loss did not improve from 0.58105
# Epoch 85/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5603 - acc: 0.7120 - val_loss: 0.5818 - val_acc: 0.6882
#
# Epoch 00085: val_loss did not improve from 0.58105
# Epoch 86/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5605 - acc: 0.7181 - val_loss: 0.5813 - val_acc: 0.6921
#
# Epoch 00086: val_loss did not improve from 0.58105
# Epoch 87/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5596 - acc: 0.7166 - val_loss: 0.5807 - val_acc: 0.6928
#
# Epoch 00087: val_loss improved from 0.58105 to 0.58074, saving model to ./model/m1_new_top10/m1_new_top10_seed42-87-0.5807.hdf5
# Epoch 88/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5581 - acc: 0.7151 - val_loss: 0.5818 - val_acc: 0.6934
#
# Epoch 00088: val_loss did not improve from 0.58074
# Epoch 89/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5579 - acc: 0.7161 - val_loss: 0.5810 - val_acc: 0.6947
#
# Epoch 00089: val_loss did not improve from 0.58074
# Epoch 90/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5577 - acc: 0.7148 - val_loss: 0.5820 - val_acc: 0.6869
#
# Epoch 00090: val_loss did not improve from 0.58074
# Epoch 91/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5570 - acc: 0.7153 - val_loss: 0.5811 - val_acc: 0.6915
#
# Epoch 00091: val_loss did not improve from 0.58074
# Epoch 92/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5556 - acc: 0.7157 - val_loss: 0.5811 - val_acc: 0.6928
#
# Epoch 00092: val_loss did not improve from 0.58074
# Epoch 93/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5584 - acc: 0.7164 - val_loss: 0.5814 - val_acc: 0.6902
#
# Epoch 00093: val_loss did not improve from 0.58074
# Epoch 94/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5579 - acc: 0.7166 - val_loss: 0.5810 - val_acc: 0.6940
#
# Epoch 00094: val_loss did not improve from 0.58074
# Epoch 95/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5554 - acc: 0.7166 - val_loss: 0.5821 - val_acc: 0.6876
#
# Epoch 00095: val_loss did not improve from 0.58074
# Epoch 96/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5562 - acc: 0.7181 - val_loss: 0.5817 - val_acc: 0.6902
#
# Epoch 00096: val_loss did not improve from 0.58074
# Epoch 97/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5560 - acc: 0.7172 - val_loss: 0.5819 - val_acc: 0.6915
#
# Epoch 00097: val_loss did not improve from 0.58074
# Epoch 98/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5561 - acc: 0.7127 - val_loss: 0.5805 - val_acc: 0.6921
#
# Epoch 00098: val_loss improved from 0.58074 to 0.58051, saving model to ./model/m1_new_top10/m1_new_top10_seed42-98-0.5805.hdf5
# Epoch 99/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5571 - acc: 0.7151 - val_loss: 0.5809 - val_acc: 0.6908
#
# Epoch 00099: val_loss did not improve from 0.58051
# Epoch 100/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5559 - acc: 0.7153 - val_loss: 0.5807 - val_acc: 0.6882
#
# Epoch 00100: val_loss did not improve from 0.58051
# Epoch 101/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5547 - acc: 0.7144 - val_loss: 0.5815 - val_acc: 0.6895
#
# Epoch 00101: val_loss did not improve from 0.58051
# Epoch 102/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5547 - acc: 0.7168 - val_loss: 0.5813 - val_acc: 0.6928
#
# Epoch 00102: val_loss did not improve from 0.58051
# Epoch 103/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5527 - acc: 0.7170 - val_loss: 0.5828 - val_acc: 0.6902
#
# Epoch 00103: val_loss did not improve from 0.58051
# Epoch 104/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5525 - acc: 0.7174 - val_loss: 0.5825 - val_acc: 0.6921
#
# Epoch 00104: val_loss did not improve from 0.58051
# Epoch 105/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5549 - acc: 0.7170 - val_loss: 0.5815 - val_acc: 0.6928
#
# Epoch 00105: val_loss did not improve from 0.58051
# Epoch 106/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5571 - acc: 0.7187 - val_loss: 0.5805 - val_acc: 0.6921
#
# Epoch 00106: val_loss did not improve from 0.58051
# Epoch 107/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5544 - acc: 0.7185 - val_loss: 0.5823 - val_acc: 0.6902
#
# Epoch 00107: val_loss did not improve from 0.58051
# Epoch 108/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5522 - acc: 0.7170 - val_loss: 0.5811 - val_acc: 0.6895
#
# Epoch 00108: val_loss did not improve from 0.58051
# Epoch 109/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5505 - acc: 0.7187 - val_loss: 0.5828 - val_acc: 0.6908
#
# Epoch 00109: val_loss did not improve from 0.58051
# Epoch 110/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5521 - acc: 0.7215 - val_loss: 0.5819 - val_acc: 0.6902
#
# Epoch 00110: val_loss did not improve from 0.58051
# Epoch 111/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5514 - acc: 0.7230 - val_loss: 0.5805 - val_acc: 0.6902
#
# Epoch 00111: val_loss did not improve from 0.58051
# Epoch 112/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5507 - acc: 0.7194 - val_loss: 0.5820 - val_acc: 0.6902
#
# Epoch 00112: val_loss did not improve from 0.58051
# Epoch 113/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5496 - acc: 0.7196 - val_loss: 0.5831 - val_acc: 0.6902
#
# Epoch 00113: val_loss did not improve from 0.58051
# Epoch 114/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5518 - acc: 0.7222 - val_loss: 0.5818 - val_acc: 0.6889
#
# Epoch 00114: val_loss did not improve from 0.58051
# Epoch 115/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5514 - acc: 0.7241 - val_loss: 0.5813 - val_acc: 0.6921
#
# Epoch 00115: val_loss did not improve from 0.58051
# Epoch 116/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5493 - acc: 0.7202 - val_loss: 0.5830 - val_acc: 0.6921
#
# Epoch 00116: val_loss did not improve from 0.58051
# Epoch 117/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5482 - acc: 0.7237 - val_loss: 0.5840 - val_acc: 0.6902
#
# Epoch 00117: val_loss did not improve from 0.58051
# Epoch 118/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5475 - acc: 0.7224 - val_loss: 0.5825 - val_acc: 0.6895
#
# Epoch 00118: val_loss did not improve from 0.58051
# Epoch 119/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5477 - acc: 0.7213 - val_loss: 0.5835 - val_acc: 0.6928
#
# Epoch 00119: val_loss did not improve from 0.58051
# Epoch 120/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5483 - acc: 0.7211 - val_loss: 0.5820 - val_acc: 0.6940
#
# Epoch 00120: val_loss did not improve from 0.58051
# Epoch 121/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5473 - acc: 0.7252 - val_loss: 0.5830 - val_acc: 0.6902
#
# Epoch 00121: val_loss did not improve from 0.58051
# Epoch 122/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5477 - acc: 0.7250 - val_loss: 0.5828 - val_acc: 0.6908
#
# Epoch 00122: val_loss did not improve from 0.58051
# Epoch 123/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5466 - acc: 0.7237 - val_loss: 0.5834 - val_acc: 0.6908
#
# Epoch 00123: val_loss did not improve from 0.58051
# Epoch 124/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.5472 - acc: 0.7233 - val_loss: 0.5820 - val_acc: 0.6934
#
# Epoch 00124: val_loss did not improve from 0.58051
# Epoch 125/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.5473 - acc: 0.7239 - val_loss: 0.5828 - val_acc: 0.6960
#
# Epoch 00125: val_loss did not improve from 0.58051
# Epoch 126/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5450 - acc: 0.7222 - val_loss: 0.5846 - val_acc: 0.6953
#
# Epoch 00126: val_loss did not improve from 0.58051
# Epoch 127/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5448 - acc: 0.7237 - val_loss: 0.5845 - val_acc: 0.6947
#
# Epoch 00127: val_loss did not improve from 0.58051
# Epoch 128/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5463 - acc: 0.7209 - val_loss: 0.5840 - val_acc: 0.6921
#
# Epoch 00128: val_loss did not improve from 0.58051
# Epoch 129/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5450 - acc: 0.7228 - val_loss: 0.5822 - val_acc: 0.6960
#
# Epoch 00129: val_loss did not improve from 0.58051
# Epoch 130/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5443 - acc: 0.7222 - val_loss: 0.5853 - val_acc: 0.6960
#
# Epoch 00130: val_loss did not improve from 0.58051
# Epoch 131/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5432 - acc: 0.7230 - val_loss: 0.5844 - val_acc: 0.6953
#
# Epoch 00131: val_loss did not improve from 0.58051
# Epoch 132/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5428 - acc: 0.7267 - val_loss: 0.5852 - val_acc: 0.6947
#
# Epoch 00132: val_loss did not improve from 0.58051
# Epoch 133/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5448 - acc: 0.7243 - val_loss: 0.5871 - val_acc: 0.6934
#
# Epoch 00133: val_loss did not improve from 0.58051
# Epoch 134/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5445 - acc: 0.7235 - val_loss: 0.5847 - val_acc: 0.6960
#
# Epoch 00134: val_loss did not improve from 0.58051
# Epoch 135/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5418 - acc: 0.7230 - val_loss: 0.5880 - val_acc: 0.6895
#
# Epoch 00135: val_loss did not improve from 0.58051
# Epoch 136/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5440 - acc: 0.7211 - val_loss: 0.5873 - val_acc: 0.6856
#
# Epoch 00136: val_loss did not improve from 0.58051
# Epoch 137/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5432 - acc: 0.7209 - val_loss: 0.5871 - val_acc: 0.6895
#
# Epoch 00137: val_loss did not improve from 0.58051
# Epoch 138/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5433 - acc: 0.7271 - val_loss: 0.5890 - val_acc: 0.6921
#
# Epoch 00138: val_loss did not improve from 0.58051
# Epoch 139/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5417 - acc: 0.7261 - val_loss: 0.5884 - val_acc: 0.6928
#
# Epoch 00139: val_loss did not improve from 0.58051
# Epoch 140/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5410 - acc: 0.7245 - val_loss: 0.5877 - val_acc: 0.6876
#
# Epoch 00140: val_loss did not improve from 0.58051
# Epoch 141/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5405 - acc: 0.7248 - val_loss: 0.5904 - val_acc: 0.6889
#
# Epoch 00141: val_loss did not improve from 0.58051
# Epoch 142/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5389 - acc: 0.7280 - val_loss: 0.5907 - val_acc: 0.6947
#
# Epoch 00142: val_loss did not improve from 0.58051
# Epoch 143/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5413 - acc: 0.7271 - val_loss: 0.5892 - val_acc: 0.6915
#
# Epoch 00143: val_loss did not improve from 0.58051
# Epoch 144/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5407 - acc: 0.7254 - val_loss: 0.5908 - val_acc: 0.6908
#
# Epoch 00144: val_loss did not improve from 0.58051
# Epoch 145/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5386 - acc: 0.7252 - val_loss: 0.5932 - val_acc: 0.6895
#
# Epoch 00145: val_loss did not improve from 0.58051
# Epoch 146/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5395 - acc: 0.7252 - val_loss: 0.5898 - val_acc: 0.6902
#
# Epoch 00146: val_loss did not improve from 0.58051
# Epoch 147/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5396 - acc: 0.7248 - val_loss: 0.5919 - val_acc: 0.6915
#
# Epoch 00147: val_loss did not improve from 0.58051
# Epoch 148/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5351 - acc: 0.7302 - val_loss: 0.5943 - val_acc: 0.6902
#
# Epoch 00148: val_loss did not improve from 0.58051
# Epoch 149/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5376 - acc: 0.7252 - val_loss: 0.5947 - val_acc: 0.6902
#
# Epoch 00149: val_loss did not improve from 0.58051
# Epoch 150/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5374 - acc: 0.7291 - val_loss: 0.5963 - val_acc: 0.6902
#
# Epoch 00150: val_loss did not improve from 0.58051
# Epoch 151/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5383 - acc: 0.7267 - val_loss: 0.5939 - val_acc: 0.6902
#
# Epoch 00151: val_loss did not improve from 0.58051
# Epoch 152/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5372 - acc: 0.7261 - val_loss: 0.5937 - val_acc: 0.6928
#
# Epoch 00152: val_loss did not improve from 0.58051
# Epoch 153/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.5343 - acc: 0.7282 - val_loss: 0.5984 - val_acc: 0.6921
#
# Epoch 00153: val_loss did not improve from 0.58051
# Epoch 154/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5351 - acc: 0.7256 - val_loss: 0.5985 - val_acc: 0.6960
#
# Epoch 00154: val_loss did not improve from 0.58051
# Epoch 155/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5366 - acc: 0.7261 - val_loss: 0.5970 - val_acc: 0.6902
#
# Epoch 00155: val_loss did not improve from 0.58051
# Epoch 156/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5329 - acc: 0.7289 - val_loss: 0.6017 - val_acc: 0.6973
#
# Epoch 00156: val_loss did not improve from 0.58051
# Epoch 157/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5363 - acc: 0.7274 - val_loss: 0.5984 - val_acc: 0.6921
#
# Epoch 00157: val_loss did not improve from 0.58051
# Epoch 158/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5335 - acc: 0.7282 - val_loss: 0.6031 - val_acc: 0.6882
#
# Epoch 00158: val_loss did not improve from 0.58051
# Epoch 159/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5351 - acc: 0.7235 - val_loss: 0.5981 - val_acc: 0.6940
#
# Epoch 00159: val_loss did not improve from 0.58051
# Epoch 160/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5326 - acc: 0.7252 - val_loss: 0.5968 - val_acc: 0.6902
#
# Epoch 00160: val_loss did not improve from 0.58051
# Epoch 161/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5320 - acc: 0.7304 - val_loss: 0.6047 - val_acc: 0.6908
#
# Epoch 00161: val_loss did not improve from 0.58051
# Epoch 162/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5311 - acc: 0.7286 - val_loss: 0.6006 - val_acc: 0.6960
#
# Epoch 00162: val_loss did not improve from 0.58051
# Epoch 163/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5318 - acc: 0.7237 - val_loss: 0.6027 - val_acc: 0.6895
#
# Epoch 00163: val_loss did not improve from 0.58051
# Epoch 164/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5308 - acc: 0.7263 - val_loss: 0.6031 - val_acc: 0.6928
#
# Epoch 00164: val_loss did not improve from 0.58051
# Epoch 165/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5314 - acc: 0.7278 - val_loss: 0.6061 - val_acc: 0.6869
#
# Epoch 00165: val_loss did not improve from 0.58051
# Epoch 166/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5310 - acc: 0.7291 - val_loss: 0.6082 - val_acc: 0.6895
#
# Epoch 00166: val_loss did not improve from 0.58051
# Epoch 167/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5285 - acc: 0.7293 - val_loss: 0.6092 - val_acc: 0.6940
#
# Epoch 00167: val_loss did not improve from 0.58051
# Epoch 168/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5310 - acc: 0.7308 - val_loss: 0.6044 - val_acc: 0.6882
#
# Epoch 00168: val_loss did not improve from 0.58051
# Epoch 169/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5310 - acc: 0.7241 - val_loss: 0.6054 - val_acc: 0.6902
#
# Epoch 00169: val_loss did not improve from 0.58051
# Epoch 170/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5307 - acc: 0.7317 - val_loss: 0.6076 - val_acc: 0.6876
#
# Epoch 00170: val_loss did not improve from 0.58051
# Epoch 171/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5298 - acc: 0.7261 - val_loss: 0.6096 - val_acc: 0.6882
#
# Epoch 00171: val_loss did not improve from 0.58051
# Epoch 172/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5300 - acc: 0.7263 - val_loss: 0.6036 - val_acc: 0.6895
#
# Epoch 00172: val_loss did not improve from 0.58051
# Epoch 173/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5320 - acc: 0.7280 - val_loss: 0.6066 - val_acc: 0.6876
#
# Epoch 00173: val_loss did not improve from 0.58051
# Epoch 174/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5309 - acc: 0.7282 - val_loss: 0.6038 - val_acc: 0.6863
#
# Epoch 00174: val_loss did not improve from 0.58051
# Epoch 175/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5295 - acc: 0.7289 - val_loss: 0.6006 - val_acc: 0.6863
#
# Epoch 00175: val_loss did not improve from 0.58051
# Epoch 176/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5285 - acc: 0.7286 - val_loss: 0.6048 - val_acc: 0.6876
#
# Epoch 00176: val_loss did not improve from 0.58051
# Epoch 177/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5282 - acc: 0.7304 - val_loss: 0.6045 - val_acc: 0.6895
#
# Epoch 00177: val_loss did not improve from 0.58051
# Epoch 178/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5292 - acc: 0.7282 - val_loss: 0.5984 - val_acc: 0.6921
#
# Epoch 00178: val_loss did not improve from 0.58051
# Epoch 179/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5302 - acc: 0.7280 - val_loss: 0.5986 - val_acc: 0.6895
#
# Epoch 00179: val_loss did not improve from 0.58051
# Epoch 180/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5293 - acc: 0.7278 - val_loss: 0.5988 - val_acc: 0.6908
#
# Epoch 00180: val_loss did not improve from 0.58051
# Epoch 181/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5294 - acc: 0.7263 - val_loss: 0.6032 - val_acc: 0.6921
#
# Epoch 00181: val_loss did not improve from 0.58051
# Epoch 182/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5271 - acc: 0.7284 - val_loss: 0.6020 - val_acc: 0.6889
#
# Epoch 00182: val_loss did not improve from 0.58051
# Epoch 183/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5292 - acc: 0.7276 - val_loss: 0.6065 - val_acc: 0.6902
#
# Epoch 00183: val_loss did not improve from 0.58051
# Epoch 184/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5290 - acc: 0.7276 - val_loss: 0.6022 - val_acc: 0.6895
#
# Epoch 00184: val_loss did not improve from 0.58051
# Epoch 185/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5276 - acc: 0.7304 - val_loss: 0.6031 - val_acc: 0.6915
#
# Epoch 00185: val_loss did not improve from 0.58051
# Epoch 186/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5305 - acc: 0.7278 - val_loss: 0.6014 - val_acc: 0.6889
#
# Epoch 00186: val_loss did not improve from 0.58051
# Epoch 187/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5291 - acc: 0.7297 - val_loss: 0.5999 - val_acc: 0.6960
#
# Epoch 00187: val_loss did not improve from 0.58051
# Epoch 188/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5327 - acc: 0.7293 - val_loss: 0.5954 - val_acc: 0.6960
#
# Epoch 00188: val_loss did not improve from 0.58051
# Epoch 189/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5341 - acc: 0.7321 - val_loss: 0.5917 - val_acc: 0.7005
#
# Epoch 00189: val_loss did not improve from 0.58051
# Epoch 190/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5308 - acc: 0.7310 - val_loss: 0.5931 - val_acc: 0.6966
#
# Epoch 00190: val_loss did not improve from 0.58051
# Epoch 191/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5256 - acc: 0.7353 - val_loss: 0.5961 - val_acc: 0.6960
#
# Epoch 00191: val_loss did not improve from 0.58051
# Epoch 192/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5224 - acc: 0.7368 - val_loss: 0.5954 - val_acc: 0.6928
#
# Epoch 00192: val_loss did not improve from 0.58051
# Epoch 193/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5219 - acc: 0.7371 - val_loss: 0.5953 - val_acc: 0.6940
#
# Epoch 00193: val_loss did not improve from 0.58051
# Epoch 194/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5198 - acc: 0.7373 - val_loss: 0.5989 - val_acc: 0.6928
#
# Epoch 00194: val_loss did not improve from 0.58051
# Epoch 195/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5200 - acc: 0.7379 - val_loss: 0.5973 - val_acc: 0.6921
#
# Epoch 00195: val_loss did not improve from 0.58051
# Epoch 196/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5250 - acc: 0.7351 - val_loss: 0.5968 - val_acc: 0.6947
#
# Epoch 00196: val_loss did not improve from 0.58051
# Epoch 197/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5225 - acc: 0.7362 - val_loss: 0.5981 - val_acc: 0.6960
#
# Epoch 00197: val_loss did not improve from 0.58051
# Epoch 198/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5239 - acc: 0.7375 - val_loss: 0.6006 - val_acc: 0.6928
#
# Epoch 00198: val_loss did not improve from 0.58051
# Epoch 199/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5208 - acc: 0.7371 - val_loss: 0.6008 - val_acc: 0.6902
#
# Epoch 00199: val_loss did not improve from 0.58051
# Epoch 200/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5200 - acc: 0.7392 - val_loss: 0.5978 - val_acc: 0.6908
#
# Epoch 00200: val_loss did not improve from 0.58051
# Epoch 201/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5212 - acc: 0.7403 - val_loss: 0.6008 - val_acc: 0.6908
#
# Epoch 00201: val_loss did not improve from 0.58051
# Epoch 202/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5174 - acc: 0.7377 - val_loss: 0.6030 - val_acc: 0.6908
#
# Epoch 00202: val_loss did not improve from 0.58051
# Epoch 203/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5181 - acc: 0.7407 - val_loss: 0.6030 - val_acc: 0.6908
#
# Epoch 00203: val_loss did not improve from 0.58051
# Epoch 204/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5166 - acc: 0.7384 - val_loss: 0.6007 - val_acc: 0.6921
#
# Epoch 00204: val_loss did not improve from 0.58051
# Epoch 205/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5172 - acc: 0.7390 - val_loss: 0.6007 - val_acc: 0.6902
#
# Epoch 00205: val_loss did not improve from 0.58051
# Epoch 206/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5153 - acc: 0.7420 - val_loss: 0.6033 - val_acc: 0.6902
#
# Epoch 00206: val_loss did not improve from 0.58051
# Epoch 207/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5152 - acc: 0.7405 - val_loss: 0.6028 - val_acc: 0.6863
#
# Epoch 00207: val_loss did not improve from 0.58051
# Epoch 208/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5171 - acc: 0.7403 - val_loss: 0.6038 - val_acc: 0.6869
#
# Epoch 00208: val_loss did not improve from 0.58051
# Epoch 209/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5154 - acc: 0.7375 - val_loss: 0.6022 - val_acc: 0.6902
#
# Epoch 00209: val_loss did not improve from 0.58051
# Epoch 210/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5156 - acc: 0.7379 - val_loss: 0.6029 - val_acc: 0.6869
#
# Epoch 00210: val_loss did not improve from 0.58051
# Epoch 211/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5131 - acc: 0.7381 - val_loss: 0.6033 - val_acc: 0.6895
#
# Epoch 00211: val_loss did not improve from 0.58051
# Epoch 212/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5129 - acc: 0.7377 - val_loss: 0.6036 - val_acc: 0.6895
#
# Epoch 00212: val_loss did not improve from 0.58051
# Epoch 213/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5149 - acc: 0.7373 - val_loss: 0.6028 - val_acc: 0.6837
#
# Epoch 00213: val_loss did not improve from 0.58051
# Epoch 214/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5140 - acc: 0.7394 - val_loss: 0.6090 - val_acc: 0.6882
#
# Epoch 00214: val_loss did not improve from 0.58051
# Epoch 215/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5132 - acc: 0.7358 - val_loss: 0.6060 - val_acc: 0.6876
#
# Epoch 00215: val_loss did not improve from 0.58051
# Epoch 216/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5146 - acc: 0.7386 - val_loss: 0.6127 - val_acc: 0.6863
#
# Epoch 00216: val_loss did not improve from 0.58051
# Epoch 217/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5148 - acc: 0.7375 - val_loss: 0.6214 - val_acc: 0.6837
#
# Epoch 00217: val_loss did not improve from 0.58051
# Epoch 218/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5135 - acc: 0.7388 - val_loss: 0.6259 - val_acc: 0.6831
#
# Epoch 00218: val_loss did not improve from 0.58051
# Epoch 219/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5105 - acc: 0.7412 - val_loss: 0.6191 - val_acc: 0.6824
#
# Epoch 00219: val_loss did not improve from 0.58051
# Epoch 220/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5099 - acc: 0.7392 - val_loss: 0.6210 - val_acc: 0.6818
#
# Epoch 00220: val_loss did not improve from 0.58051
# Epoch 221/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5047 - acc: 0.7420 - val_loss: 0.6260 - val_acc: 0.6805
#
# Epoch 00221: val_loss did not improve from 0.58051
# Epoch 222/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5047 - acc: 0.7455 - val_loss: 0.6236 - val_acc: 0.6843
#
# Epoch 00222: val_loss did not improve from 0.58051
# Epoch 223/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5021 - acc: 0.7437 - val_loss: 0.6235 - val_acc: 0.6831
#
# Epoch 00223: val_loss did not improve from 0.58051
# Epoch 224/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5027 - acc: 0.7500 - val_loss: 0.6282 - val_acc: 0.6882
#
# Epoch 00224: val_loss did not improve from 0.58051
# Epoch 225/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5019 - acc: 0.7431 - val_loss: 0.6321 - val_acc: 0.6818
#
# Epoch 00225: val_loss did not improve from 0.58051
# Epoch 226/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5033 - acc: 0.7437 - val_loss: 0.6282 - val_acc: 0.6818
#
# Epoch 00226: val_loss did not improve from 0.58051
# Epoch 227/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5027 - acc: 0.7444 - val_loss: 0.6272 - val_acc: 0.6824
#
# Epoch 00227: val_loss did not improve from 0.58051
# Epoch 228/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5008 - acc: 0.7455 - val_loss: 0.6347 - val_acc: 0.6798
#
# Epoch 00228: val_loss did not improve from 0.58051
# Epoch 229/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5003 - acc: 0.7425 - val_loss: 0.6314 - val_acc: 0.6805
#
# Epoch 00229: val_loss did not improve from 0.58051
# Epoch 230/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.4972 - acc: 0.7468 - val_loss: 0.6280 - val_acc: 0.6856
#
# Epoch 00230: val_loss did not improve from 0.58051
# Epoch 231/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.4983 - acc: 0.7487 - val_loss: 0.6363 - val_acc: 0.6869
#
# Epoch 00231: val_loss did not improve from 0.58051
# Epoch 232/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.4954 - acc: 0.7498 - val_loss: 0.6340 - val_acc: 0.6863
#
# Epoch 00232: val_loss did not improve from 0.58051
# Epoch 233/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.4965 - acc: 0.7494 - val_loss: 0.6419 - val_acc: 0.6811
#
# Epoch 00233: val_loss did not improve from 0.58051
# Epoch 234/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.4928 - acc: 0.7457 - val_loss: 0.6422 - val_acc: 0.6772
#
# Epoch 00234: val_loss did not improve from 0.58051
# Epoch 235/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.4908 - acc: 0.7468 - val_loss: 0.6417 - val_acc: 0.6843
#
# Epoch 00235: val_loss did not improve from 0.58051
# Epoch 236/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.4933 - acc: 0.7498 - val_loss: 0.6384 - val_acc: 0.6811
#
# Epoch 00236: val_loss did not improve from 0.58051
# Epoch 237/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.4923 - acc: 0.7494 - val_loss: 0.6378 - val_acc: 0.6843
#
# Epoch 00237: val_loss did not improve from 0.58051
# Epoch 238/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.4910 - acc: 0.7474 - val_loss: 0.6541 - val_acc: 0.6798
#
# Epoch 00238: val_loss did not improve from 0.58051
# Epoch 239/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.4910 - acc: 0.7440 - val_loss: 0.6507 - val_acc: 0.6734
# Restoring model weights from the end of the best epoch.
#
# Epoch 00239: val_loss did not improve from 0.58051
# Epoch 00239: early stopping
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 정확도 :0.7074433656957929, seed_num = 0
# 정확도 :0.7055016181229773, seed_num = 1
# 정확도 :0.7003236245954693, seed_num = 2
# 정확도 :0.7100323624595469, seed_num = 3
# 정확도 :0.7080906148867314, seed_num = 4
# 정확도 :0.7022653721682848, seed_num = 5
# 정확도 :0.6899676375404531, seed_num = 6
# 정확도 :0.7022653721682848, seed_num = 7
# 정확도 :0.7132686084142394, seed_num = 8
# 정확도 :0.7029126213592233, seed_num = 9
# 정확도 :0.7055016181229773, seed_num = 10
# 정확도 :0.7022653721682848, seed_num = 11
# 정확도 :0.7152103559870551, seed_num = 12
# 정확도 :0.7074433656957929, seed_num = 13
# 정확도 :0.7061488673139159, seed_num = 14
# 정확도 :0.7016181229773463, seed_num = 15
# 정확도 :0.7126213592233009, seed_num = 16
# 정확도 :0.7016181229773463, seed_num = 17
# 정확도 :0.7171521035598706, seed_num = 18
# 정확도 :0.7035598705501618, seed_num = 19
# 정확도 :0.7009708737864078, seed_num = 20
# 정확도 :0.684789644012945, seed_num = 21
# 정확도 :0.6990291262135923, seed_num = 22
# 정확도 :0.6886731391585761, seed_num = 23
# 정확도 :0.6873786407766991, seed_num = 24
# 정확도 :0.7190938511326861, seed_num = 25
# 정확도 :0.6957928802588996, seed_num = 26
# 정확도 :0.6957928802588996, seed_num = 27
# 정확도 :0.7035598705501618, seed_num = 28
# 정확도 :0.6912621359223301, seed_num = 29
# 정확도 :0.7210355987055016, seed_num = 30
# 정확도 :0.6925566343042071, seed_num = 31
# 정확도 :0.7093851132686084, seed_num = 32
# 정확도 :0.7080906148867314, seed_num = 33
# 정확도 :0.7145631067961165, seed_num = 34
# 정확도 :0.7042071197411003, seed_num = 35
# 정확도 :0.7132686084142394, seed_num = 36
# 정확도 :0.7242718446601941, seed_num = 37
# 정확도 :0.7113268608414239, seed_num = 38
# 정확도 :0.7281553398058253, seed_num = 39
# 정확도 :0.7190938511326861, seed_num = 40
# 정확도 :0.7152103559870551, seed_num = 41
# 정확도 :0.6886731391585761, seed_num = 42
# 정확도 :0.7042071197411003, seed_num = 43
# 정확도 :0.6796116504854369, seed_num = 44
# 정확도 :0.6951456310679611, seed_num = 45
# 정확도 :0.7061488673139159, seed_num = 46
# 정확도 :0.7067961165048544, seed_num = 47
# 정확도 :0.7249190938511327, seed_num = 48
# 정확도 :0.6996763754045308, seed_num = 49
# 정확도 df 만들고 평균 확인 : [0.70495793]

# %% [markdown]
# ### absum 그래프

# %%
m1_new_top10 = list(m1_new_top10)
absum(m1_new_top10,m1_new_top10[:10])

# %% [markdown]
# ### violin plot

# %%
FI_merge_list(m1_new_top10)
# Out:
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 10it [02:02, 12.21s/it]

# %% [markdown]
# ## m1_new_bottom10

# %%
m1_new = pd.read_csv('m1_new.csv')
m1_new_bottom10 = m1_new['feature'].values[-10:]
m1_new_bottom10
# Out:
# array([  409672924, 55390000401,      224277,     8084199,       51221,
#              51237,       50861,       51249,           0, 63323026201])

# %% [markdown]
# ### (63.5) RF

# %%
RF_정확도(m1_new_bottom10,'m1_new_bottom10')
# Out:
# itemlist의 index :  [2212, 3456, 307, 619, 174, 182, 19, 187, 0, 3832]
# 정확도 : 0.6148867313915858, seed_num = 42
# 정확도 : 0.6233009708737864, seed_num = 43
# 정확도 : 0.6148867313915858, seed_num = 44
# 정확도 : 0.6576051779935275, seed_num = 45
# 정확도 : 0.6433656957928803, seed_num = 46
# 정확도 : 0.6537216828478964, seed_num = 47
# 정확도 : 0.6472491909385113, seed_num = 48
# 정확도 : 0.6245954692556634, seed_num = 49
# 정확도 : 0.6530744336569579, seed_num = 50
# 정확도 : 0.623948220064725, seed_num = 51
# 정확도 df 만들고 평균 확인 : [0.63566343]

# %% [markdown]
# ### (67) LSTM

# %%
LSTM_정확도(m1_new_bottom10,'m1_new_bottom10')
# Out:
# itemlist의 index :  [2212, 3456, 307, 619, 174, 182, 19, 187, 0, 3832]
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/500
# 37/37 [==============================] - 6s 72ms/step - loss: 0.6759 - acc: 0.5984 - val_loss: 0.6660 - val_acc: 0.6177
#
# Epoch 00001: val_loss improved from inf to 0.66601, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-01-0.6660.hdf5
# Epoch 2/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6732 - acc: 0.6066 - val_loss: 0.6662 - val_acc: 0.6177
#
# Epoch 00002: val_loss did not improve from 0.66601
# Epoch 3/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6740 - acc: 0.6083 - val_loss: 0.6655 - val_acc: 0.6177
#
# Epoch 00003: val_loss improved from 0.66601 to 0.66547, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-03-0.6655.hdf5
# Epoch 4/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6710 - acc: 0.6100 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00004: val_loss improved from 0.66547 to 0.66517, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-04-0.6652.hdf5
# Epoch 5/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6705 - acc: 0.6096 - val_loss: 0.6649 - val_acc: 0.6177
#
# Epoch 00005: val_loss improved from 0.66517 to 0.66493, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-05-0.6649.hdf5
# Epoch 6/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.6718 - acc: 0.6115 - val_loss: 0.6645 - val_acc: 0.6177
#
# Epoch 00006: val_loss improved from 0.66493 to 0.66449, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-06-0.6645.hdf5
# Epoch 7/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6693 - acc: 0.6111 - val_loss: 0.6593 - val_acc: 0.6177
#
# Epoch 00007: val_loss improved from 0.66449 to 0.65935, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-07-0.6593.hdf5
# Epoch 8/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6592 - acc: 0.6109 - val_loss: 0.6422 - val_acc: 0.6177
#
# Epoch 00008: val_loss improved from 0.65935 to 0.64218, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-08-0.6422.hdf5
# Epoch 9/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6461 - acc: 0.6178 - val_loss: 0.6408 - val_acc: 0.6462
#
# Epoch 00009: val_loss improved from 0.64218 to 0.64076, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-09-0.6408.hdf5
# Epoch 10/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6497 - acc: 0.6273 - val_loss: 0.6386 - val_acc: 0.6468
#
# Epoch 00010: val_loss improved from 0.64076 to 0.63863, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-10-0.6386.hdf5
# Epoch 11/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6454 - acc: 0.6247 - val_loss: 0.6432 - val_acc: 0.6378
#
# Epoch 00011: val_loss did not improve from 0.63863
# Epoch 12/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6467 - acc: 0.6212 - val_loss: 0.6375 - val_acc: 0.6410
#
# Epoch 00012: val_loss improved from 0.63863 to 0.63753, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-12-0.6375.hdf5
# Epoch 13/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.6454 - acc: 0.6197 - val_loss: 0.6389 - val_acc: 0.6436
#
# Epoch 00013: val_loss did not improve from 0.63753
# Epoch 14/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6447 - acc: 0.6221 - val_loss: 0.6387 - val_acc: 0.6436
#
# Epoch 00014: val_loss did not improve from 0.63753
# Epoch 15/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6445 - acc: 0.6234 - val_loss: 0.6359 - val_acc: 0.6410
#
# Epoch 00015: val_loss improved from 0.63753 to 0.63593, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-15-0.6359.hdf5
# Epoch 16/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6435 - acc: 0.6255 - val_loss: 0.6372 - val_acc: 0.6384
#
# Epoch 00016: val_loss did not improve from 0.63593
# Epoch 17/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6442 - acc: 0.6189 - val_loss: 0.6368 - val_acc: 0.6397
#
# Epoch 00017: val_loss did not improve from 0.63593
# Epoch 18/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6429 - acc: 0.6275 - val_loss: 0.6358 - val_acc: 0.6404
#
# Epoch 00018: val_loss improved from 0.63593 to 0.63577, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-18-0.6358.hdf5
# Epoch 19/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.6428 - acc: 0.6208 - val_loss: 0.6360 - val_acc: 0.6397
#
# Epoch 00019: val_loss did not improve from 0.63577
# Epoch 20/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.6432 - acc: 0.6292 - val_loss: 0.6348 - val_acc: 0.6397
#
# Epoch 00020: val_loss improved from 0.63577 to 0.63484, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-20-0.6348.hdf5
# Epoch 21/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6412 - acc: 0.6268 - val_loss: 0.6356 - val_acc: 0.6404
#
# Epoch 00021: val_loss did not improve from 0.63484
# Epoch 22/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6415 - acc: 0.6232 - val_loss: 0.6346 - val_acc: 0.6397
#
# Epoch 00022: val_loss improved from 0.63484 to 0.63455, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-22-0.6346.hdf5
# Epoch 23/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6420 - acc: 0.6139 - val_loss: 0.6350 - val_acc: 0.6397
#
# Epoch 00023: val_loss did not improve from 0.63455
# Epoch 24/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6420 - acc: 0.6305 - val_loss: 0.6340 - val_acc: 0.6378
#
# Epoch 00024: val_loss improved from 0.63455 to 0.63397, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-24-0.6340.hdf5
# Epoch 25/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6410 - acc: 0.6314 - val_loss: 0.6349 - val_acc: 0.6397
#
# Epoch 00025: val_loss did not improve from 0.63397
# Epoch 26/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6401 - acc: 0.6314 - val_loss: 0.6357 - val_acc: 0.6397
#
# Epoch 00026: val_loss did not improve from 0.63397
# Epoch 27/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6407 - acc: 0.6262 - val_loss: 0.6341 - val_acc: 0.6384
#
# Epoch 00027: val_loss did not improve from 0.63397
# Epoch 28/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6392 - acc: 0.6335 - val_loss: 0.6334 - val_acc: 0.6358
#
# Epoch 00028: val_loss improved from 0.63397 to 0.63343, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-28-0.6334.hdf5
# Epoch 29/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6401 - acc: 0.6327 - val_loss: 0.6332 - val_acc: 0.6352
#
# Epoch 00029: val_loss improved from 0.63343 to 0.63320, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-29-0.6332.hdf5
# Epoch 30/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6405 - acc: 0.6279 - val_loss: 0.6333 - val_acc: 0.6378
#
# Epoch 00030: val_loss did not improve from 0.63320
# Epoch 31/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6405 - acc: 0.6324 - val_loss: 0.6327 - val_acc: 0.6352
#
# Epoch 00031: val_loss improved from 0.63320 to 0.63269, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-31-0.6327.hdf5
# Epoch 32/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6411 - acc: 0.6327 - val_loss: 0.6330 - val_acc: 0.6352
#
# Epoch 00032: val_loss did not improve from 0.63269
# Epoch 33/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6394 - acc: 0.6260 - val_loss: 0.6326 - val_acc: 0.6339
#
# Epoch 00033: val_loss improved from 0.63269 to 0.63264, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-33-0.6326.hdf5
# Epoch 34/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6403 - acc: 0.6281 - val_loss: 0.6316 - val_acc: 0.6345
#
# Epoch 00034: val_loss improved from 0.63264 to 0.63155, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-34-0.6316.hdf5
# Epoch 35/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6394 - acc: 0.6301 - val_loss: 0.6309 - val_acc: 0.6345
#
# Epoch 00035: val_loss improved from 0.63155 to 0.63089, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-35-0.6309.hdf5
# Epoch 36/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6403 - acc: 0.6322 - val_loss: 0.6314 - val_acc: 0.6404
#
# Epoch 00036: val_loss did not improve from 0.63089
# Epoch 37/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6384 - acc: 0.6350 - val_loss: 0.6314 - val_acc: 0.6404
#
# Epoch 00037: val_loss did not improve from 0.63089
# Epoch 38/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6376 - acc: 0.6355 - val_loss: 0.6314 - val_acc: 0.6423
#
# Epoch 00038: val_loss did not improve from 0.63089
# Epoch 39/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.6393 - acc: 0.6309 - val_loss: 0.6288 - val_acc: 0.6404
#
# Epoch 00039: val_loss improved from 0.63089 to 0.62884, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-39-0.6288.hdf5
# Epoch 40/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6377 - acc: 0.6361 - val_loss: 0.6296 - val_acc: 0.6417
#
# Epoch 00040: val_loss did not improve from 0.62884
# Epoch 41/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6383 - acc: 0.6337 - val_loss: 0.6302 - val_acc: 0.6442
#
# Epoch 00041: val_loss did not improve from 0.62884
# Epoch 42/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6371 - acc: 0.6365 - val_loss: 0.6287 - val_acc: 0.6468
#
# Epoch 00042: val_loss improved from 0.62884 to 0.62868, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-42-0.6287.hdf5
# Epoch 43/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6379 - acc: 0.6359 - val_loss: 0.6294 - val_acc: 0.6507
#
# Epoch 00043: val_loss did not improve from 0.62868
# Epoch 44/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6380 - acc: 0.6352 - val_loss: 0.6265 - val_acc: 0.6488
#
# Epoch 00044: val_loss improved from 0.62868 to 0.62654, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-44-0.6265.hdf5
# Epoch 45/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6344 - acc: 0.6406 - val_loss: 0.6266 - val_acc: 0.6527
#
# Epoch 00045: val_loss did not improve from 0.62654
# Epoch 46/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6355 - acc: 0.6445 - val_loss: 0.6258 - val_acc: 0.6527
#
# Epoch 00046: val_loss improved from 0.62654 to 0.62584, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-46-0.6258.hdf5
# Epoch 47/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6353 - acc: 0.6396 - val_loss: 0.6241 - val_acc: 0.6578
#
# Epoch 00047: val_loss improved from 0.62584 to 0.62414, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-47-0.6241.hdf5
# Epoch 48/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6339 - acc: 0.6506 - val_loss: 0.6251 - val_acc: 0.6669
#
# Epoch 00048: val_loss did not improve from 0.62414
# Epoch 49/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6334 - acc: 0.6458 - val_loss: 0.6224 - val_acc: 0.6675
#
# Epoch 00049: val_loss improved from 0.62414 to 0.62244, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-49-0.6224.hdf5
# Epoch 50/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6327 - acc: 0.6475 - val_loss: 0.6220 - val_acc: 0.6656
#
# Epoch 00050: val_loss improved from 0.62244 to 0.62196, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-50-0.6220.hdf5
# Epoch 51/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6289 - acc: 0.6506 - val_loss: 0.6219 - val_acc: 0.6675
#
# Epoch 00051: val_loss improved from 0.62196 to 0.62185, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-51-0.6219.hdf5
# Epoch 52/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6290 - acc: 0.6598 - val_loss: 0.6223 - val_acc: 0.6649
#
# Epoch 00052: val_loss did not improve from 0.62185
# Epoch 53/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6296 - acc: 0.6525 - val_loss: 0.6217 - val_acc: 0.6669
#
# Epoch 00053: val_loss improved from 0.62185 to 0.62174, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-53-0.6217.hdf5
# Epoch 54/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6280 - acc: 0.6536 - val_loss: 0.6209 - val_acc: 0.6624
#
# Epoch 00054: val_loss improved from 0.62174 to 0.62086, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-54-0.6209.hdf5
# Epoch 55/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.6278 - acc: 0.6607 - val_loss: 0.6207 - val_acc: 0.6578
#
# Epoch 00055: val_loss improved from 0.62086 to 0.62073, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-55-0.6207.hdf5
# Epoch 56/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6249 - acc: 0.6592 - val_loss: 0.6205 - val_acc: 0.6643
#
# Epoch 00056: val_loss improved from 0.62073 to 0.62050, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-56-0.6205.hdf5
# Epoch 57/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6267 - acc: 0.6624 - val_loss: 0.6209 - val_acc: 0.6604
#
# Epoch 00057: val_loss did not improve from 0.62050
# Epoch 58/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6246 - acc: 0.6626 - val_loss: 0.6218 - val_acc: 0.6572
#
# Epoch 00058: val_loss did not improve from 0.62050
# Epoch 59/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6261 - acc: 0.6674 - val_loss: 0.6212 - val_acc: 0.6572
#
# Epoch 00059: val_loss did not improve from 0.62050
# Epoch 60/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6244 - acc: 0.6667 - val_loss: 0.6230 - val_acc: 0.6585
#
# Epoch 00060: val_loss did not improve from 0.62050
# Epoch 61/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6255 - acc: 0.6648 - val_loss: 0.6217 - val_acc: 0.6591
#
# Epoch 00061: val_loss did not improve from 0.62050
# Epoch 62/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6255 - acc: 0.6624 - val_loss: 0.6213 - val_acc: 0.6591
#
# Epoch 00062: val_loss did not improve from 0.62050
# Epoch 63/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6255 - acc: 0.6670 - val_loss: 0.6207 - val_acc: 0.6598
#
# Epoch 00063: val_loss did not improve from 0.62050
# Epoch 64/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6256 - acc: 0.6650 - val_loss: 0.6201 - val_acc: 0.6656
#
# Epoch 00064: val_loss improved from 0.62050 to 0.62009, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-64-0.6201.hdf5
# Epoch 65/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6232 - acc: 0.6654 - val_loss: 0.6208 - val_acc: 0.6649
#
# Epoch 00065: val_loss did not improve from 0.62009
# Epoch 66/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.6197 - acc: 0.6646 - val_loss: 0.6211 - val_acc: 0.6636
#
# Epoch 00066: val_loss did not improve from 0.62009
# Epoch 67/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6219 - acc: 0.6665 - val_loss: 0.6218 - val_acc: 0.6643
#
# Epoch 00067: val_loss did not improve from 0.62009
# Epoch 68/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6220 - acc: 0.6663 - val_loss: 0.6204 - val_acc: 0.6636
#
# Epoch 00068: val_loss did not improve from 0.62009
# Epoch 69/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6222 - acc: 0.6652 - val_loss: 0.6216 - val_acc: 0.6649
#
# Epoch 00069: val_loss did not improve from 0.62009
# Epoch 70/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6214 - acc: 0.6689 - val_loss: 0.6208 - val_acc: 0.6649
#
# Epoch 00070: val_loss did not improve from 0.62009
# Epoch 71/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6196 - acc: 0.6659 - val_loss: 0.6211 - val_acc: 0.6636
#
# Epoch 00071: val_loss did not improve from 0.62009
# Epoch 72/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6196 - acc: 0.6661 - val_loss: 0.6205 - val_acc: 0.6636
#
# Epoch 00072: val_loss did not improve from 0.62009
# Epoch 73/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6209 - acc: 0.6691 - val_loss: 0.6195 - val_acc: 0.6617
#
# Epoch 00073: val_loss improved from 0.62009 to 0.61953, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-73-0.6195.hdf5
# Epoch 74/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6211 - acc: 0.6678 - val_loss: 0.6203 - val_acc: 0.6578
#
# Epoch 00074: val_loss did not improve from 0.61953
# Epoch 75/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6190 - acc: 0.6682 - val_loss: 0.6209 - val_acc: 0.6624
#
# Epoch 00075: val_loss did not improve from 0.61953
# Epoch 76/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6199 - acc: 0.6680 - val_loss: 0.6199 - val_acc: 0.6591
#
# Epoch 00076: val_loss did not improve from 0.61953
# Epoch 77/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6190 - acc: 0.6689 - val_loss: 0.6193 - val_acc: 0.6559
#
# Epoch 00077: val_loss improved from 0.61953 to 0.61928, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-77-0.6193.hdf5
# Epoch 78/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6187 - acc: 0.6670 - val_loss: 0.6199 - val_acc: 0.6598
#
# Epoch 00078: val_loss did not improve from 0.61928
# Epoch 79/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6171 - acc: 0.6741 - val_loss: 0.6199 - val_acc: 0.6565
#
# Epoch 00079: val_loss did not improve from 0.61928
# Epoch 80/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.6177 - acc: 0.6726 - val_loss: 0.6199 - val_acc: 0.6559
#
# Epoch 00080: val_loss did not improve from 0.61928
# Epoch 81/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6179 - acc: 0.6706 - val_loss: 0.6197 - val_acc: 0.6559
#
# Epoch 00081: val_loss did not improve from 0.61928
# Epoch 82/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6175 - acc: 0.6723 - val_loss: 0.6203 - val_acc: 0.6591
#
# Epoch 00082: val_loss did not improve from 0.61928
# Epoch 83/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.6149 - acc: 0.6695 - val_loss: 0.6196 - val_acc: 0.6591
#
# Epoch 00083: val_loss did not improve from 0.61928
# Epoch 84/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6154 - acc: 0.6706 - val_loss: 0.6192 - val_acc: 0.6585
#
# Epoch 00084: val_loss improved from 0.61928 to 0.61920, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-84-0.6192.hdf5
# Epoch 85/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.6163 - acc: 0.6736 - val_loss: 0.6196 - val_acc: 0.6565
#
# Epoch 00085: val_loss did not improve from 0.61920
# Epoch 86/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6153 - acc: 0.6769 - val_loss: 0.6196 - val_acc: 0.6585
#
# Epoch 00086: val_loss did not improve from 0.61920
# Epoch 87/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6144 - acc: 0.6747 - val_loss: 0.6196 - val_acc: 0.6604
#
# Epoch 00087: val_loss did not improve from 0.61920
# Epoch 88/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6156 - acc: 0.6728 - val_loss: 0.6194 - val_acc: 0.6604
#
# Epoch 00088: val_loss did not improve from 0.61920
# Epoch 89/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6139 - acc: 0.6706 - val_loss: 0.6185 - val_acc: 0.6598
#
# Epoch 00089: val_loss improved from 0.61920 to 0.61846, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-89-0.6185.hdf5
# Epoch 90/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6145 - acc: 0.6706 - val_loss: 0.6189 - val_acc: 0.6572
#
# Epoch 00090: val_loss did not improve from 0.61846
# Epoch 91/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6135 - acc: 0.6711 - val_loss: 0.6191 - val_acc: 0.6611
#
# Epoch 00091: val_loss did not improve from 0.61846
# Epoch 92/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6146 - acc: 0.6773 - val_loss: 0.6184 - val_acc: 0.6585
#
# Epoch 00092: val_loss improved from 0.61846 to 0.61837, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-92-0.6184.hdf5
# Epoch 93/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6147 - acc: 0.6749 - val_loss: 0.6188 - val_acc: 0.6565
#
# Epoch 00093: val_loss did not improve from 0.61837
# Epoch 94/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6150 - acc: 0.6726 - val_loss: 0.6187 - val_acc: 0.6617
#
# Epoch 00094: val_loss did not improve from 0.61837
# Epoch 95/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6126 - acc: 0.6756 - val_loss: 0.6190 - val_acc: 0.6585
#
# Epoch 00095: val_loss did not improve from 0.61837
# Epoch 96/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6143 - acc: 0.6702 - val_loss: 0.6191 - val_acc: 0.6572
#
# Epoch 00096: val_loss did not improve from 0.61837
# Epoch 97/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6122 - acc: 0.6739 - val_loss: 0.6187 - val_acc: 0.6552
#
# Epoch 00097: val_loss did not improve from 0.61837
# Epoch 98/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6103 - acc: 0.6767 - val_loss: 0.6195 - val_acc: 0.6604
#
# Epoch 00098: val_loss did not improve from 0.61837
# Epoch 99/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6112 - acc: 0.6752 - val_loss: 0.6193 - val_acc: 0.6591
# Restoring model weights from the end of the best epoch.
#
# Epoch 00099: val_loss did not improve from 0.61837
# Epoch 00099: early stopping
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Using TensorFlow backend.
# 정확도 :0.6666666666666666, seed_num = 0
# 정확도 :0.6627831715210356, seed_num = 1
# 정확도 :0.6744336569579288, seed_num = 2
# 정확도 :0.6608414239482201, seed_num = 3
# 정확도 :0.6718446601941748, seed_num = 4
# 정확도 :0.6802588996763754, seed_num = 5
# 정확도 :0.6731391585760518, seed_num = 6
# 정확도 :0.6530744336569579, seed_num = 7
# 정확도 :0.6822006472491909, seed_num = 8
# 정확도 :0.6822006472491909, seed_num = 9
# 정확도 :0.6673139158576051, seed_num = 10
# 정확도 :0.6783171521035599, seed_num = 11
# 정확도 :0.6608414239482201, seed_num = 12
# 정확도 :0.6530744336569579, seed_num = 13
# 정확도 :0.6873786407766991, seed_num = 14
# 정확도 :0.6925566343042071, seed_num = 15
# 정확도 :0.6776699029126214, seed_num = 16
# 정확도 :0.654368932038835, seed_num = 17
# 정확도 :0.6666666666666666, seed_num = 18
# 정확도 :0.658252427184466, seed_num = 19
# 정확도 :0.6686084142394823, seed_num = 20
# 정확도 :0.654368932038835, seed_num = 21
# 정확도 :0.658252427184466, seed_num = 22
# 정확도 :0.6692556634304208, seed_num = 23
# 정확도 :0.6640776699029126, seed_num = 24
# 정확도 :0.6621359223300971, seed_num = 25
# 정확도 :0.6588996763754046, seed_num = 26
# 정확도 :0.683495145631068, seed_num = 27
# 정확도 :0.6660194174757281, seed_num = 28
# 정확도 :0.6699029126213593, seed_num = 29
# 정확도 :0.6796116504854369, seed_num = 30
# 정확도 :0.655663430420712, seed_num = 31
# 정확도 :0.6692556634304208, seed_num = 32
# 정확도 :0.6595469255663431, seed_num = 33
# 정확도 :0.6770226537216828, seed_num = 34
# 정확도 :0.6776699029126214, seed_num = 35
# 정확도 :0.6718446601941748, seed_num = 36
# 정확도 :0.6809061488673139, seed_num = 37
# 정확도 :0.6763754045307443, seed_num = 38
# 정확도 :0.6563106796116505, seed_num = 39
# 정확도 :0.6614886731391586, seed_num = 40
# 정확도 :0.686084142394822, seed_num = 41
# 정확도 :0.6666666666666666, seed_num = 42
# 정확도 :0.6621359223300971, seed_num = 43
# 정확도 :0.6627831715210356, seed_num = 44
# 정확도 :0.6880258899676376, seed_num = 45
# 정확도 :0.6705501618122978, seed_num = 46
# 정확도 :0.6938511326860841, seed_num = 47
# 정확도 :0.6886731391585761, seed_num = 48
# 정확도 :0.6744336569579288, seed_num = 49
# 정확도 df 만들고 평균 확인 : [0.67035599]

# %% [markdown]
# ### absum 그래프

# %%
m1_new_bottom10 = list(m1_new_bottom10)
absum(m1_new_bottom10,m1_new_bottom10[:10])

# %% [markdown]
# ### violin plot

# %%
FI_merge_list(m1_new_bottom10)
# Out:
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 10it [01:59, 11.96s/it]

# %% [markdown]
# # 2️⃣ median(0to1) - median(1to0)

# %% [markdown]
# # 3️⃣ E(pair diff) - E(0)

# %%
from scipy import stats

# 1) DATA 
x = np.load('/project/LSH/x_(7727,10,4068).npy')
y = np.load('/project/LSH/y_(7727,1).npy')

with tf.device('/device:GPU:0'):
    tf.config.experimental.set_virtual_device_configuration(gpus[0], 
                                                        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5*1024)])
    # 2) MODEL
    from keras.models import load_model
    lstm2 = load_model('./model/allfit2_seed42-06-0.5519.hdf5')
    
    total_data = pd.read_csv('total_data_7727.csv')
    features = total_data['ITEMID'].sort_values().unique()

    results = []
    for itemid in tqdm(features):

        k = list(features).index(itemid) # itemid의 index
        save_col = x[:,:,k].copy()

        # 3) 0 to 1
        x[:,:,k]= np.where(x[:,:,k]==0, 1, x[:,:,k])
        pred_0to1 = pd.DataFrame(lstm2.predict(x))

        # 4) 1 to 0
        x[:,:,k] = np.where(x[:,:,k]==1, 0, x[:,:,k])
        pred_1to0 = pd.DataFrame(lstm2.predict(x))

        x[:,:,k] = save_col

        # 5) Merge
        FI_merge_df = pd.concat([pred_0to1, pred_1to0], axis=1)
        FI_merge_df.columns = ['pred_0to1', 'pred_1to0']
        FI_merge_df['diff'] = FI_merge_df['pred_0to1'] - FI_merge_df['pred_1to0']
        FI_merge_df['mean_diff'] = np.mean(FI_merge_df['diff'])
        
        mean_diff_value = FI_merge_df['mean_diff'].unique()[0]
        results.append({'feature':itemid,'mean_diff':mean_diff_value})
# Out:
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 100%|██████████| 4068/4068 [5:37:11<00:00,  4.97s/it]

# %%
df = pd.DataFrame(results)
df.to_csv('m1_mean_pair_diff.csv',index=False)

# %%
df
# Out:
#           feature  mean_diff
# 0               0  -0.038531
# 1           50803  -0.004673
# 2           50804   0.020569
# 3           50805  -0.018933
# 4           50806   0.025720
# ...           ...        ...
# 4063  78112001103  -0.017707
# 4064  79511050204  -0.001604
# 4065  87701071218   0.028135
# 4066  87701083336  -0.007425
# 4067  87701089415  -0.021743
#
# [4068 rows x 2 columns]

# %%
## 시간 단축 코드 도전.. -> 조금 향상?
### df 생성하지 않음 / .index()로 k찾는 대신 features 길이만큼 순서대로 index 부여 

from scipy import stats

# 1) DATA 
x = np.load('/project/LSH/x_(7727,10,4068).npy')
y = np.load('/project/LSH/y_(7727,1).npy')

with tf.device('/device:GPU:0'):
    tf.config.experimental.set_virtual_device_configuration(gpus[0], 
                                                        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5*1024)])
    # 2) MODEL
    from keras.models import load_model
    lstm2 = load_model('./model/allfit2_seed42-06-0.5519.hdf5')
    
    total_data = pd.read_csv('total_data_7727.csv')
    features = total_data['ITEMID'].sort_values().unique()

    results = []
    for k in tqdm(range(len(features))):
        
        save_col = x[:,:,k].copy()

        # 3) 0 to 1
        x[:,:,k]= np.where(x[:,:,k]==0, 1, x[:,:,k])
        pred_0to1 = lstm2.predict(x)

        # 4) 1 to 0
        x[:,:,k] = np.where(x[:,:,k]==1, 0, x[:,:,k])
        pred_1to0 = lstm2.predict(x)

        x[:,:,k] = save_col

        # 5) Merge
        diff = pred_0to1-pred_1to0    
        mean_diff_value = np.mean(diff)
        results.append({'feature':features[k],'mean_diff':mean_diff_value})

# %% [markdown]
# # 4️⃣ ttest_1samp(pair diff,0)

# %%
def statistic(itemid): # itemid 1개 입력 
    
    from scipy import stats
    
    # 1) DATA 
    x = np.load('/project/LSH/x_(7727,10,4068).npy')
    y = np.load('/project/LSH/y_(7727,1).npy')
    
    with tf.device('/device:GPU:0'):
        tf.config.experimental.set_virtual_device_configuration(gpus[0], 
                                                            [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5*1024)])
        # 2) MODEL
        from keras.models import load_model
        lstm2 = load_model('./model/allfit2_seed42-06-0.5519.hdf5')

        # 3) 환자별 base pred (Y')
        base_pred = pd.DataFrame(lstm2.predict(x))

        total_data = pd.read_csv('total_data_7727.csv')
        features = total_data['ITEMID'].sort_values().unique()

        k = list(features).index(itemid)
        save_col = x[:,:,k].copy()

        # 4) 0 to 1
        x[:,:,k]= np.where(x[:,:,k]==0, 1, x[:,:,k])
        pred_0to1 = pd.DataFrame(lstm2.predict(x))

        # 5) 1 to 0
        x[:,:,k] = np.where(x[:,:,k]==1, 0, x[:,:,k])
        pred_1to0 = pd.DataFrame(lstm2.predict(x))

        # 6) inverse
        x[:,:,k] = save_col
        x[:,:,k] = np.where(x[:,:,k]==1, 2, x[:,:,k])
        x[:,:,k] = np.where(x[:,:,k]==0, 1, x[:,:,k])
        x[:,:,k] = np.where(x[:,:,k]==2, 0, x[:,:,k])
        pred_inverse = pd.DataFrame(lstm2.predict(x))

        # 7) Merge & Visualize
        FI_merge_df = pd.concat([base_pred, pred_0to1, pred_1to0, pred_inverse], axis=1)
        FI_merge_df.columns = ['base_pred', 'pred_0to1', 'pred_1to0', 'pred_inverse']
        FI_merge_df['diff'] = FI_merge_df['pred_0to1'] - FI_merge_df['pred_1to0']
        FI_merge_df['statistic'] = stats.ttest_1samp(FI_merge_df['diff'],0)[0]
        FI_merge_df['mean_diff'] = np.mean(FI_merge_df['diff'])
        return FI_merge_df

# %%
statistic(63323026201)
# Out:
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#       base_pred  pred_0to1  pred_1to0  pred_inverse      diff  statistic  \
# 0      0.920581   0.884245   0.920581      0.884245 -0.036336  -74.53184
# 1      0.899965   0.840888   0.899965      0.840888 -0.059077  -74.53184
# 2      0.946021   0.943067   0.946021      0.943067 -0.002954  -74.53184
# 3      0.176535   0.174945   0.183385      0.181450 -0.008440  -74.53184
# 4      0.864114   0.717415   0.864114      0.717415 -0.146699  -74.53184
# ...         ...        ...        ...           ...       ...        ...
# 7722   0.163760   0.163760   0.164891      0.164891 -0.001131  -74.53184
# 7723   0.178220   0.175616   0.183127      0.180162 -0.007511  -74.53184
# 7724   0.171547   0.171285   0.176781      0.176457 -0.005495  -74.53184
# 7725   0.215960   0.207942   0.243422      0.232807 -0.035480  -74.53184
# 7726   0.233033   0.233033   0.262605      0.262605 -0.029572  -74.53184
#
#       mean_diff
# 0     -0.067464
# 1     -0.067464
# 2     -0.067464
# 3     -0.067464
# 4     -0.067464
# ...         ...
# 7722  -0.067464
# 7723  -0.067464
# 7724  -0.067464
# 7725  -0.067464
# 7726  -0.067464
#
# [7727 rows x 7 columns]
