# %% [markdown]
# # Library

# %%
import numpy as np, os
import pandas as pd
import tensorflow as tf
from tqdm import tqdm
import seaborn as sns
import matplotlib.pyplot as plt

# 결과 확인을 용이하게 하기 위한 코드
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

#한글설정
import matplotlib.font_manager as fm

font_dirs = ['/usr/share/fonts/truetype/nanum', ]
font_files = fm.findSystemFonts(fontpaths=font_dirs)

for font_file in font_files:
    fm.fontManager.addfont(font_file)
    
# 한글 출력을 위해서 폰트 옵션을 설정합니다.
# "axes.unicode_minus" : 마이너스가 깨질 것을 방지

sns.set(font="NanumBarunGothic", 
        rc={"axes.unicode_minus":False},
        style='darkgrid')

# GPU 용량 설정
gpus = tf.config.experimental.list_physical_devices('GPU')
print(gpus)
if gpus:  # gpu가 있다면, 용량 한도를 5GB로 설정
    tf.config.experimental.set_virtual_device_configuration(gpus[0], 
                                                            [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5*1024)])
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %% [markdown]
# # Data Load

# %%
m1 = pd.read_csv('method1_df.csv')
m2 = pd.read_csv('method2_df.csv')

# %% [markdown]
# # RF 정확도 함수

# %%
def RF_정확도(itemlist,name):

    # itemlist만을 가진 x_(7727,10)_itemlist 만들기
    item_list = list(total_data['ITEMID'].sort_values().unique())
    
    item_index = []
    for i in itemlist:
        item_index.append(item_list.index(i))

    print('itemlist의 index : ',item_index)

    x = np.load('x_(7727,4068).npy')
    x_2d = x[:,item_index]
    x_2d
    
    np.save(f'x_(7727,10)_{name}.npy',x_2d)
    
    import random
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.metrics import accuracy_score

    model = RandomForestClassifier()

    data={}
    for seed in range(42, 52):
        random.seed(seed)
        
        x = np.load(f'./x_(7727,10)_{name}.npy')
        y = np.load('./y_(7727,1).npy')

        idx = list(range(len(x)))
        random.shuffle(idx)

        i = round(x.shape[0]*0.8)
        X_train, y_train = x[idx[:i],:], y[idx[:i]]
        X_test, y_test = x[idx[i:],:], y[idx[i:]]

        _ = model.fit(X_train, y_train)
        y_pred_train = model.predict(X_train)
        y_pred_test = model.predict(X_test)

        acc = accuracy_score(y_test, y_pred_test)
        data[seed]=acc
        print(f'정확도 : {acc}, seed_num = {seed}')

    df = pd.DataFrame.from_dict(data, orient='index')
    print(f'정확도 df 만들고 평균 확인 : {df.mean().values}')

# %% [markdown]
# # LSTM 정확도 함수

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, InputLayer
from tensorflow.keras.callbacks import EarlyStopping
from sklearn import metrics 
from tensorflow import keras
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

import random

def LSTM_정확도(itemlist, name):

    # itemlist만을 가진 x_(7727,10,10)_itemlist 만들기
    total_data = pd.read_csv('total_data_7727.csv')
    item_list = list(total_data['ITEMID'].sort_values().unique())

    item_index = []
    for i in itemlist:
        item_index.append(item_list.index(i))

    print('itemlist의 index : ',item_index)

    x = np.load('x_(7727,10,4068).npy')
    x_3d = x[:,:,item_index]
    
    np.save(f'x_(7727,10,10)_{name}.npy',x_3d)
    
    seed_num = 42
    random.seed(seed_num)
    
    x = np.load(f'x_(7727,10,10)_{name}.npy')
    y = np.load('y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
    X_test, y_test = x[idx[i:],:,:], y[idx[i:]]

    # ---------------------
    seed_num = 42 
    # ---------------------
    tf.random.set_seed(seed_num)

    lstm = Sequential()
    lstm.add(InputLayer(input_shape=(X_train.shape[1],X_train.shape[2])))
    lstm.add(LSTM(units=128, activation='hard_sigmoid', return_sequences=True))
    lstm.add(LSTM(units=64, activation='hard_sigmoid', return_sequences=True))
    lstm.add(Dropout(0.2))
    lstm.add(LSTM(units=64, activation='hard_sigmoid', return_sequences=True))
    lstm.add(LSTM(units=32, activation='hard_sigmoid', return_sequences=False))
    lstm.add(Dropout(0.2))
    lstm.add(Dense(units=1, activation='sigmoid'))

    from tensorflow.keras.callbacks import ModelCheckpoint
    import os

    MODEL_SAVE_FOLDER_PATH = f'./model/{name}'
    if not os.path.exists(MODEL_SAVE_FOLDER_PATH):
        os.mkdir(MODEL_SAVE_FOLDER_PATH)

    model_path = MODEL_SAVE_FOLDER_PATH + f'/{name}_seed42-'+'{epoch:02d}'+'-{val_loss:.4f}.hdf5'

    cb_checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss',
                                    verbose=1, save_best_only=True)

    early_stop = EarlyStopping(monitor='val_acc', patience=50, verbose=1, restore_best_weights=True)
    lstm.compile(optimizer= keras.optimizers.Adam(learning_rate = 0.001), loss = "binary_crossentropy", metrics=['acc'])
    lstm.fit(X_train, y_train, validation_split=0.25, batch_size=128, epochs=500,  callbacks=[early_stop,cb_checkpoint], shuffle=False)
    
    with tf.device('/device:GPU:0'):
        tf.config.experimental.set_virtual_device_configuration(gpus[0], 
                                                            [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5*1024)])

        from pathlib import Path
        paths = sorted(Path(MODEL_SAVE_FOLDER_PATH).iterdir(), key=os.path.getmtime)[-1]
        best_model_path = str(paths)

        from keras.models import load_model
        best_model = load_model(best_model_path) 

        dic_42={}
        for seed in range(0, 50):
            random.seed(seed)

            x = np.load(f'x_(7727,10,10)_{name}.npy')
            y = np.load('y_(7727,1).npy')

            idx = list(range(len(x)))
            random.shuffle(idx)

            i = round(x.shape[0]*0.8)
            X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
            X_test, y_test = x[idx[i:],:,:], y[idx[i:]]

            pred = best_model.predict(X_test)
            pred[pred>0.5]=1
            pred[pred<=0.5]=0
            acc = metrics.accuracy_score(y_test, pred)
            dic_42[seed]=acc
            print(f'정확도 :{metrics.accuracy_score(y_test, pred)}, seed_num = {seed}')

        df_42 = pd.DataFrame.from_dict(dic_42, orient='index')
        print(f'정확도 df 만들고 평균 확인 : {df_42.mean().values}')

# %% [markdown]
# # Method 1 : 상위 10개 feature
# - 절대값 취하고 절대값 기준으로 내림차순 후 상위 10개 뽑기

# %%
m1['abs'] = abs(m1['mul'])
m1 = m1.sort_values(by='abs', ascending=False)
m1_top10 = m1['feature'].values[:10]
m1_top10
# Out:
# array([  409606211,    74606211,    67434504,    54817525, 10019055302,
#             227194,    54858516,    74706811,    45006701,     4003822])

# %% [markdown]
# ## (65.1) RF

# %%
# m1_top10만을 가진 x_(7727,10)_m1 만들기
item_list = list(total_data['ITEMID'].sort_values().unique())

m1_top10_index = []
for i in m1_top10:
    m1_top10_index.append(item_list.index(i))

print('m1_top10의 index : ',m1_top10_index)

x = np.load('x_(7727,4068).npy')
x_2d = x[:,m1_top10_index]
x_2d.shape

# np.save('x_(7727,10)_m1.npy',x_2d)
# Out:
# m1_top10의 index :  [2195, 1276, 1081, 982, 2744, 383, 1011, 1306, 845, 469]
# (7727, 10)

# %%
import random
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

model = RandomForestClassifier()

data={}
for seed in range(42, 52):
    random.seed(seed)
    
    x = np.load('./x_(7727,10)_m1.npy')
    y = np.load('./y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_train, y_train = x[idx[:i],:], y[idx[:i]]
    X_test, y_test = x[idx[i:],:], y[idx[i:]]
    
    _ = model.fit(X_train, y_train)
    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)
    
    acc = accuracy_score(y_test, y_pred_test)
    data[seed]=acc
    print(f'정확도 : {acc}, seed_num = {seed}')

df = pd.DataFrame.from_dict(data, orient='index')
print(f'정확도 df 만들고 평균 확인 : {df.mean().values}')
# Out:
# 정확도 : 0.6355987055016181, seed_num = 42
# 정확도 : 0.6330097087378641, seed_num = 43
# 정확도 : 0.6349514563106796, seed_num = 44
# 정확도 : 0.6576051779935275, seed_num = 45
# 정확도 : 0.6466019417475728, seed_num = 46
# 정확도 : 0.6634304207119741, seed_num = 47
# 정확도 : 0.6750809061488673, seed_num = 48
# 정확도 : 0.654368932038835, seed_num = 49
# 정확도 : 0.6640776699029126, seed_num = 50
# 정확도 : 0.6511326860841424, seed_num = 51
# 정확도 df 만들고 평균 확인 : [0.65158576]

# %% [markdown]
# ## (64.9) LSTM

# %%
# m1_top10만을 가진 x_(7727,10,10)_m1 만들기
item_list = list(total_data['ITEMID'].sort_values().unique())

m1_top10_index = []
for i in m1_top10:
    m1_top10_index.append(item_list.index(i))

print('m1_top10의 index : ',m1_top10_index)

x = np.load('x_(7727,10,4068).npy')
x_3d = x[:,:,m1_top10_index]
x_3d.shape
x_3d.sum()

# np.save('x_(7727,10,10)_m1.npy',x_3d)
# Out:
# m1_top10의 index :  [2195, 1276, 1081, 982, 2744, 383, 1011, 1306, 845, 469]
# (7727, 10, 10)
# 6187.0

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings(action='ignore')

import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, InputLayer
from tensorflow.keras.callbacks import EarlyStopping
from sklearn import metrics 
from tensorflow import keras
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

import random
# ----------------------
seed_num = 42
# ----------------------
random.seed(seed_num)

x = np.load('x_(7727,10,10)_m1.npy')
y = np.load('y_(7727,1).npy')

idx = list(range(len(x)))
random.shuffle(idx)

i = round(x.shape[0]*0.8)
X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
X_test, y_test = x[idx[i:],:,:], y[idx[i:]]

# ---------------------
seed_num = 42 
# ---------------------
tf.random.set_seed(seed_num)

lstm = Sequential()
lstm.add(InputLayer(input_shape=(X_train.shape[1],X_train.shape[2])))
lstm.add(LSTM(units=128, activation='hard_sigmoid', return_sequences=True))
lstm.add(LSTM(units=64, activation='hard_sigmoid', return_sequences=True))
lstm.add(Dropout(0.2))
lstm.add(LSTM(units=64, activation='hard_sigmoid', return_sequences=True))
lstm.add(LSTM(units=32, activation='hard_sigmoid', return_sequences=False))
lstm.add(Dropout(0.2))
lstm.add(Dense(units=1, activation='sigmoid'))

from tensorflow.keras.callbacks import ModelCheckpoint
import os

MODEL_SAVE_FOLDER_PATH = './model/'
if not os.path.exists(MODEL_SAVE_FOLDER_PATH):
    os.mkdir(MODEL_SAVE_FOLDER_PATH)

model_path = MODEL_SAVE_FOLDER_PATH + 'm1_top10_seed42-{epoch:02d}-{val_loss:.4f}.hdf5'

cb_checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss',
                                verbose=1, save_best_only=True)

early_stop = EarlyStopping(monitor='val_acc', patience=50, verbose=1, restore_best_weights=True)
lstm.compile(optimizer= keras.optimizers.Adam(learning_rate = 0.001), loss = "binary_crossentropy", metrics=['acc'])
lstm.fit(X_train, y_train, validation_split=0.25, batch_size=128, epochs=500,  callbacks=[early_stop,cb_checkpoint], shuffle=False)
# Out:
# Epoch 1/500
# 37/37 [==============================] - 6s 55ms/step - loss: 0.6759 - acc: 0.5984 - val_loss: 0.6660 - val_acc: 0.6177
#
# Epoch 00001: val_loss improved from inf to 0.66603, saving model to ./model/10개 feature/seed42-01-0.6660.hdf5
# Epoch 2/500
# 37/37 [==============================] - 2s 43ms/step - loss: 0.6732 - acc: 0.6066 - val_loss: 0.6662 - val_acc: 0.6177
#
# Epoch 00002: val_loss did not improve from 0.66603
# Epoch 3/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6740 - acc: 0.6083 - val_loss: 0.6655 - val_acc: 0.6177
#
# Epoch 00003: val_loss improved from 0.66603 to 0.66551, saving model to ./model/10개 feature/seed42-03-0.6655.hdf5
# Epoch 4/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6711 - acc: 0.6100 - val_loss: 0.6653 - val_acc: 0.6177
#
# Epoch 00004: val_loss improved from 0.66551 to 0.66526, saving model to ./model/10개 feature/seed42-04-0.6653.hdf5
# Epoch 5/500
# 37/37 [==============================] - 2s 43ms/step - loss: 0.6706 - acc: 0.6091 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00005: val_loss improved from 0.66526 to 0.66517, saving model to ./model/10개 feature/seed42-05-0.6652.hdf5
# Epoch 6/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6721 - acc: 0.6113 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00006: val_loss improved from 0.66517 to 0.66515, saving model to ./model/10개 feature/seed42-06-0.6652.hdf5
# Epoch 7/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6710 - acc: 0.6111 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00007: val_loss did not improve from 0.66515
# Epoch 8/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6715 - acc: 0.6111 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00008: val_loss did not improve from 0.66515
# Epoch 9/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6702 - acc: 0.6113 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00009: val_loss did not improve from 0.66515
# Epoch 10/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6700 - acc: 0.6115 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00010: val_loss did not improve from 0.66515
# Epoch 11/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6698 - acc: 0.6115 - val_loss: 0.6651 - val_acc: 0.6177
#
# Epoch 00011: val_loss improved from 0.66515 to 0.66515, saving model to ./model/10개 feature/seed42-11-0.6651.hdf5
# Epoch 12/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6694 - acc: 0.6115 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00012: val_loss did not improve from 0.66515
# Epoch 13/500
# 37/37 [==============================] - 2s 43ms/step - loss: 0.6698 - acc: 0.6117 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00013: val_loss did not improve from 0.66515
# Epoch 14/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6694 - acc: 0.6115 - val_loss: 0.6651 - val_acc: 0.6177
#
# Epoch 00014: val_loss did not improve from 0.66515
# Epoch 15/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6691 - acc: 0.6115 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00015: val_loss did not improve from 0.66515
# Epoch 16/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6701 - acc: 0.6115 - val_loss: 0.6651 - val_acc: 0.6177
#
# Epoch 00016: val_loss improved from 0.66515 to 0.66508, saving model to ./model/10개 feature/seed42-16-0.6651.hdf5
# Epoch 17/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6706 - acc: 0.6115 - val_loss: 0.6650 - val_acc: 0.6177
#
# Epoch 00017: val_loss improved from 0.66508 to 0.66503, saving model to ./model/10개 feature/seed42-17-0.6650.hdf5
# Epoch 18/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6686 - acc: 0.6115 - val_loss: 0.6648 - val_acc: 0.6177
#
# Epoch 00018: val_loss improved from 0.66503 to 0.66481, saving model to ./model/10개 feature/seed42-18-0.6648.hdf5
# Epoch 19/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6689 - acc: 0.6115 - val_loss: 0.6646 - val_acc: 0.6177
#
# Epoch 00019: val_loss improved from 0.66481 to 0.66464, saving model to ./model/10개 feature/seed42-19-0.6646.hdf5
# Epoch 20/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6686 - acc: 0.6115 - val_loss: 0.6640 - val_acc: 0.6177
#
# Epoch 00020: val_loss improved from 0.66464 to 0.66395, saving model to ./model/10개 feature/seed42-20-0.6640.hdf5
# Epoch 21/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6646 - acc: 0.6115 - val_loss: 0.6632 - val_acc: 0.6177
#
# Epoch 00021: val_loss improved from 0.66395 to 0.66321, saving model to ./model/10개 feature/seed42-21-0.6632.hdf5
# Epoch 22/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6584 - acc: 0.6115 - val_loss: 0.6465 - val_acc: 0.6177
#
# Epoch 00022: val_loss improved from 0.66321 to 0.64649, saving model to ./model/10개 feature/seed42-22-0.6465.hdf5
# Epoch 23/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6395 - acc: 0.6113 - val_loss: 0.6399 - val_acc: 0.6197
#
# Epoch 00023: val_loss improved from 0.64649 to 0.63987, saving model to ./model/10개 feature/seed42-23-0.6399.hdf5
# Epoch 24/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6272 - acc: 0.6126 - val_loss: 0.6341 - val_acc: 0.6229
#
# Epoch 00024: val_loss improved from 0.63987 to 0.63407, saving model to ./model/10개 feature/seed42-24-0.6341.hdf5
# Epoch 25/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6264 - acc: 0.6055 - val_loss: 0.6319 - val_acc: 0.6177
#
# Epoch 00025: val_loss improved from 0.63407 to 0.63192, saving model to ./model/10개 feature/seed42-25-0.6319.hdf5
# Epoch 26/500
# 37/37 [==============================] - 2s 43ms/step - loss: 0.6223 - acc: 0.6107 - val_loss: 0.6433 - val_acc: 0.6197
#
# Epoch 00026: val_loss did not improve from 0.63192
# Epoch 27/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6220 - acc: 0.6094 - val_loss: 0.6278 - val_acc: 0.6177
#
# Epoch 00027: val_loss improved from 0.63192 to 0.62785, saving model to ./model/10개 feature/seed42-27-0.6278.hdf5
# Epoch 28/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6202 - acc: 0.6139 - val_loss: 0.6339 - val_acc: 0.6177
#
# Epoch 00028: val_loss did not improve from 0.62785
# Epoch 29/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6244 - acc: 0.6001 - val_loss: 0.6261 - val_acc: 0.6177
#
# Epoch 00029: val_loss improved from 0.62785 to 0.62609, saving model to ./model/10개 feature/seed42-29-0.6261.hdf5
# Epoch 30/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6181 - acc: 0.6204 - val_loss: 0.6332 - val_acc: 0.6229
#
# Epoch 00030: val_loss did not improve from 0.62609
# Epoch 31/500
# 37/37 [==============================] - 2s 43ms/step - loss: 0.6175 - acc: 0.6189 - val_loss: 0.6297 - val_acc: 0.6229
#
# Epoch 00031: val_loss did not improve from 0.62609
# Epoch 32/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6186 - acc: 0.6150 - val_loss: 0.6296 - val_acc: 0.6229
#
# Epoch 00032: val_loss did not improve from 0.62609
# Epoch 33/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6176 - acc: 0.6204 - val_loss: 0.6306 - val_acc: 0.6223
#
# Epoch 00033: val_loss did not improve from 0.62609
# Epoch 34/500
# 37/37 [==============================] - 2s 43ms/step - loss: 0.6169 - acc: 0.6137 - val_loss: 0.6265 - val_acc: 0.6229
#
# Epoch 00034: val_loss did not improve from 0.62609
# Epoch 35/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6149 - acc: 0.6266 - val_loss: 0.6273 - val_acc: 0.6248
#
# Epoch 00035: val_loss did not improve from 0.62609
# Epoch 36/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6159 - acc: 0.6219 - val_loss: 0.6262 - val_acc: 0.6229
#
# Epoch 00036: val_loss did not improve from 0.62609
# Epoch 37/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6134 - acc: 0.6320 - val_loss: 0.6208 - val_acc: 0.6410
#
# Epoch 00037: val_loss improved from 0.62609 to 0.62075, saving model to ./model/10개 feature/seed42-37-0.6208.hdf5
# Epoch 38/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6126 - acc: 0.6503 - val_loss: 0.6193 - val_acc: 0.6423
#
# Epoch 00038: val_loss improved from 0.62075 to 0.61935, saving model to ./model/10개 feature/seed42-38-0.6193.hdf5
# Epoch 39/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6109 - acc: 0.6381 - val_loss: 0.6170 - val_acc: 0.6475
#
# Epoch 00039: val_loss improved from 0.61935 to 0.61702, saving model to ./model/10개 feature/seed42-39-0.6170.hdf5
# Epoch 40/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6101 - acc: 0.6372 - val_loss: 0.6157 - val_acc: 0.6481
#
# Epoch 00040: val_loss improved from 0.61702 to 0.61572, saving model to ./model/10개 feature/seed42-40-0.6157.hdf5
# Epoch 41/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6077 - acc: 0.6413 - val_loss: 0.6145 - val_acc: 0.6514
#
# Epoch 00041: val_loss improved from 0.61572 to 0.61446, saving model to ./model/10개 feature/seed42-41-0.6145.hdf5
# Epoch 42/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6034 - acc: 0.6462 - val_loss: 0.6134 - val_acc: 0.6514
#
# Epoch 00042: val_loss improved from 0.61446 to 0.61336, saving model to ./model/10개 feature/seed42-42-0.6134.hdf5
# Epoch 43/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6052 - acc: 0.6510 - val_loss: 0.6133 - val_acc: 0.6514
#
# Epoch 00043: val_loss improved from 0.61336 to 0.61330, saving model to ./model/10개 feature/seed42-43-0.6133.hdf5
# Epoch 44/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6029 - acc: 0.6521 - val_loss: 0.6134 - val_acc: 0.6514
#
# Epoch 00044: val_loss did not improve from 0.61330
# Epoch 45/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6006 - acc: 0.6538 - val_loss: 0.6144 - val_acc: 0.6514
#
# Epoch 00045: val_loss did not improve from 0.61330
# Epoch 46/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6028 - acc: 0.6523 - val_loss: 0.6152 - val_acc: 0.6507
#
# Epoch 00046: val_loss did not improve from 0.61330
# Epoch 47/500
# 37/37 [==============================] - 2s 43ms/step - loss: 0.6014 - acc: 0.6514 - val_loss: 0.6157 - val_acc: 0.6507
#
# Epoch 00047: val_loss did not improve from 0.61330
# Epoch 48/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6020 - acc: 0.6521 - val_loss: 0.6174 - val_acc: 0.6494
#
# Epoch 00048: val_loss did not improve from 0.61330
# Epoch 49/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6018 - acc: 0.6544 - val_loss: 0.6197 - val_acc: 0.6494
#
# Epoch 00049: val_loss did not improve from 0.61330
# Epoch 50/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6084 - acc: 0.6447 - val_loss: 0.6186 - val_acc: 0.6442
#
# Epoch 00050: val_loss did not improve from 0.61330
# Epoch 51/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6029 - acc: 0.6501 - val_loss: 0.6148 - val_acc: 0.6514
#
# Epoch 00051: val_loss did not improve from 0.61330
# Epoch 52/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6011 - acc: 0.6544 - val_loss: 0.6160 - val_acc: 0.6494
#
# Epoch 00052: val_loss did not improve from 0.61330
# Epoch 53/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6027 - acc: 0.6534 - val_loss: 0.6137 - val_acc: 0.6533
#
# Epoch 00053: val_loss did not improve from 0.61330
# Epoch 54/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6008 - acc: 0.6540 - val_loss: 0.6152 - val_acc: 0.6533
#
# Epoch 00054: val_loss did not improve from 0.61330
# Epoch 55/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6014 - acc: 0.6540 - val_loss: 0.6134 - val_acc: 0.6533
#
# Epoch 00055: val_loss did not improve from 0.61330
# Epoch 56/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5983 - acc: 0.6540 - val_loss: 0.6156 - val_acc: 0.6533
#
# Epoch 00056: val_loss did not improve from 0.61330
# Epoch 57/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6028 - acc: 0.6538 - val_loss: 0.6126 - val_acc: 0.6533
#
# Epoch 00057: val_loss improved from 0.61330 to 0.61263, saving model to ./model/10개 feature/seed42-57-0.6126.hdf5
# Epoch 58/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5990 - acc: 0.6544 - val_loss: 0.6157 - val_acc: 0.6533
#
# Epoch 00058: val_loss did not improve from 0.61263
# Epoch 59/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6031 - acc: 0.6542 - val_loss: 0.6125 - val_acc: 0.6533
#
# Epoch 00059: val_loss improved from 0.61263 to 0.61251, saving model to ./model/10개 feature/seed42-59-0.6125.hdf5
# Epoch 60/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5989 - acc: 0.6542 - val_loss: 0.6166 - val_acc: 0.6533
#
# Epoch 00060: val_loss did not improve from 0.61251
# Epoch 61/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6011 - acc: 0.6531 - val_loss: 0.6127 - val_acc: 0.6533
#
# Epoch 00061: val_loss did not improve from 0.61251
# Epoch 62/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6015 - acc: 0.6540 - val_loss: 0.6159 - val_acc: 0.6533
#
# Epoch 00062: val_loss did not improve from 0.61251
# Epoch 63/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5999 - acc: 0.6549 - val_loss: 0.6137 - val_acc: 0.6527
#
# Epoch 00063: val_loss did not improve from 0.61251
# Epoch 64/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6006 - acc: 0.6538 - val_loss: 0.6144 - val_acc: 0.6533
#
# Epoch 00064: val_loss did not improve from 0.61251
# Epoch 65/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5997 - acc: 0.6540 - val_loss: 0.6148 - val_acc: 0.6533
#
# Epoch 00065: val_loss did not improve from 0.61251
# Epoch 66/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5983 - acc: 0.6540 - val_loss: 0.6146 - val_acc: 0.6533
#
# Epoch 00066: val_loss did not improve from 0.61251
# Epoch 67/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5992 - acc: 0.6542 - val_loss: 0.6164 - val_acc: 0.6533
#
# Epoch 00067: val_loss did not improve from 0.61251
# Epoch 68/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6012 - acc: 0.6547 - val_loss: 0.6127 - val_acc: 0.6533
#
# Epoch 00068: val_loss did not improve from 0.61251
# Epoch 69/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5990 - acc: 0.6540 - val_loss: 0.6153 - val_acc: 0.6533
#
# Epoch 00069: val_loss did not improve from 0.61251
# Epoch 70/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5988 - acc: 0.6544 - val_loss: 0.6147 - val_acc: 0.6533
#
# Epoch 00070: val_loss did not improve from 0.61251
# Epoch 71/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5976 - acc: 0.6542 - val_loss: 0.6153 - val_acc: 0.6533
#
# Epoch 00071: val_loss did not improve from 0.61251
# Epoch 72/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5991 - acc: 0.6538 - val_loss: 0.6137 - val_acc: 0.6533
#
# Epoch 00072: val_loss did not improve from 0.61251
# Epoch 73/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5994 - acc: 0.6534 - val_loss: 0.6147 - val_acc: 0.6533
#
# Epoch 00073: val_loss did not improve from 0.61251
# Epoch 74/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5988 - acc: 0.6549 - val_loss: 0.6147 - val_acc: 0.6533
#
# Epoch 00074: val_loss did not improve from 0.61251
# Epoch 75/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6007 - acc: 0.6547 - val_loss: 0.6138 - val_acc: 0.6533
#
# Epoch 00075: val_loss did not improve from 0.61251
# Epoch 76/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5987 - acc: 0.6538 - val_loss: 0.6148 - val_acc: 0.6533
#
# Epoch 00076: val_loss did not improve from 0.61251
# Epoch 77/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5991 - acc: 0.6542 - val_loss: 0.6139 - val_acc: 0.6527
#
# Epoch 00077: val_loss did not improve from 0.61251
# Epoch 78/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5985 - acc: 0.6542 - val_loss: 0.6153 - val_acc: 0.6533
#
# Epoch 00078: val_loss did not improve from 0.61251
# Epoch 79/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5983 - acc: 0.6542 - val_loss: 0.6144 - val_acc: 0.6533
#
# Epoch 00079: val_loss did not improve from 0.61251
# Epoch 80/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5987 - acc: 0.6542 - val_loss: 0.6153 - val_acc: 0.6533
#
# Epoch 00080: val_loss did not improve from 0.61251
# Epoch 81/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5987 - acc: 0.6540 - val_loss: 0.6138 - val_acc: 0.6533
#
# Epoch 00081: val_loss did not improve from 0.61251
# Epoch 82/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5985 - acc: 0.6540 - val_loss: 0.6154 - val_acc: 0.6533
#
# Epoch 00082: val_loss did not improve from 0.61251
# Epoch 83/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5980 - acc: 0.6536 - val_loss: 0.6161 - val_acc: 0.6533
#
# Epoch 00083: val_loss did not improve from 0.61251
# Epoch 84/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6000 - acc: 0.6547 - val_loss: 0.6123 - val_acc: 0.6533
#
# Epoch 00084: val_loss improved from 0.61251 to 0.61229, saving model to ./model/10개 feature/seed42-84-0.6123.hdf5
# Epoch 85/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5988 - acc: 0.6536 - val_loss: 0.6151 - val_acc: 0.6533
#
# Epoch 00085: val_loss did not improve from 0.61229
# Epoch 86/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5976 - acc: 0.6547 - val_loss: 0.6146 - val_acc: 0.6533
#
# Epoch 00086: val_loss did not improve from 0.61229
# Epoch 87/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5981 - acc: 0.6540 - val_loss: 0.6140 - val_acc: 0.6533
#
# Epoch 00087: val_loss did not improve from 0.61229
# Epoch 88/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5979 - acc: 0.6538 - val_loss: 0.6149 - val_acc: 0.6533
#
# Epoch 00088: val_loss did not improve from 0.61229
# Epoch 89/500
# 37/37 [==============================] - 2s 41ms/step - loss: 0.5976 - acc: 0.6540 - val_loss: 0.6143 - val_acc: 0.6533
#
# Epoch 00089: val_loss did not improve from 0.61229
# Epoch 90/500
# 37/37 [==============================] - 2s 43ms/step - loss: 0.5988 - acc: 0.6540 - val_loss: 0.6138 - val_acc: 0.6527
#
# Epoch 00090: val_loss did not improve from 0.61229
# Epoch 91/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5966 - acc: 0.6538 - val_loss: 0.6159 - val_acc: 0.6533
#
# Epoch 00091: val_loss did not improve from 0.61229
# Epoch 92/500
# 37/37 [==============================] - 2s 43ms/step - loss: 0.5993 - acc: 0.6551 - val_loss: 0.6127 - val_acc: 0.6533
#
# Epoch 00092: val_loss did not improve from 0.61229
# Epoch 93/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5979 - acc: 0.6538 - val_loss: 0.6146 - val_acc: 0.6533
#
# Epoch 00093: val_loss did not improve from 0.61229
# Epoch 94/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5990 - acc: 0.6549 - val_loss: 0.6141 - val_acc: 0.6533
#
# Epoch 00094: val_loss did not improve from 0.61229
# Epoch 95/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5977 - acc: 0.6544 - val_loss: 0.6136 - val_acc: 0.6533
#
# Epoch 00095: val_loss did not improve from 0.61229
# Epoch 96/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5987 - acc: 0.6538 - val_loss: 0.6135 - val_acc: 0.6533
#
# Epoch 00096: val_loss did not improve from 0.61229
# Epoch 97/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5968 - acc: 0.6538 - val_loss: 0.6136 - val_acc: 0.6533
#
# Epoch 00097: val_loss did not improve from 0.61229
# Epoch 98/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5979 - acc: 0.6538 - val_loss: 0.6142 - val_acc: 0.6533
#
# Epoch 00098: val_loss did not improve from 0.61229
# Epoch 99/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5967 - acc: 0.6540 - val_loss: 0.6143 - val_acc: 0.6533
#
# Epoch 00099: val_loss did not improve from 0.61229
# Epoch 100/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5981 - acc: 0.6536 - val_loss: 0.6139 - val_acc: 0.6533
#
# Epoch 00100: val_loss did not improve from 0.61229
# Epoch 101/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5967 - acc: 0.6540 - val_loss: 0.6151 - val_acc: 0.6533
#
# Epoch 00101: val_loss did not improve from 0.61229
# Epoch 102/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5976 - acc: 0.6542 - val_loss: 0.6139 - val_acc: 0.6533
#
# Epoch 00102: val_loss did not improve from 0.61229
# Epoch 103/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.5969 - acc: 0.6544 - val_loss: 0.6149 - val_acc: 0.6533
# Restoring model weights from the end of the best epoch.
#
# Epoch 00103: val_loss did not improve from 0.61229
# Epoch 00103: early stopping

# %%
from keras.models import load_model
best_model = load_model('./model/m1_top10_seed42-84-0.6123.hdf5') 

dic_42={}
for seed in range(0, 50):
    random.seed(seed)

    x = np.load('x_(7727,10,10)_m1.npy')
    y = np.load('y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
    X_test, y_test = x[idx[i:],:,:], y[idx[i:]]
    
    pred = best_model.predict(X_test)
    pred[pred>0.5]=1
    pred[pred<=0.5]=0
    acc = metrics.accuracy_score(y_test, pred)
    dic_42[seed]=acc
    print(f'정확도 :{metrics.accuracy_score(y_test, pred)}, seed_num = {seed}')
# Out:
# 정확도 :0.6466019417475728, seed_num = 0
# 정확도 :0.6427184466019418, seed_num = 1
# 정확도 :0.6498381877022654, seed_num = 2
# 정확도 :0.6375404530744336, seed_num = 3
# 정확도 :0.654368932038835, seed_num = 4
# 정확도 :0.655663430420712, seed_num = 5
# 정확도 :0.6537216828478964, seed_num = 6
# 정확도 :0.629126213592233, seed_num = 7
# 정확도 :0.6614886731391586, seed_num = 8
# 정확도 :0.6498381877022654, seed_num = 9
# 정확도 :0.627831715210356, seed_num = 10
# 정확도 :0.6711974110032363, seed_num = 11
# 정확도 :0.6472491909385113, seed_num = 12
# 정확도 :0.6414239482200648, seed_num = 13
# 정확도 :0.6466019417475728, seed_num = 14
# 정확도 :0.656957928802589, seed_num = 15
# 정확도 :0.6692556634304208, seed_num = 16
# 정확도 :0.6453074433656958, seed_num = 17
# 정확도 :0.6459546925566343, seed_num = 18
# 정확도 :0.6414239482200648, seed_num = 19
# 정확도 :0.6601941747572816, seed_num = 20
# 정확도 :0.6595469255663431, seed_num = 21
# 정확도 :0.6375404530744336, seed_num = 22
# 정확도 :0.6550161812297735, seed_num = 23
# 정확도 :0.6530744336569579, seed_num = 24
# 정확도 :0.6491909385113268, seed_num = 25
# 정확도 :0.6284789644012945, seed_num = 26
# 정확도 :0.6608414239482201, seed_num = 27
# 정확도 :0.6453074433656958, seed_num = 28
# 정확도 :0.6446601941747573, seed_num = 29
# 정확도 :0.6530744336569579, seed_num = 30
# 정확도 :0.6472491909385113, seed_num = 31
# 정확도 :0.654368932038835, seed_num = 32
# 정확도 :0.6517799352750809, seed_num = 33
# 정확도 :0.6601941747572816, seed_num = 34
# 정확도 :0.6614886731391586, seed_num = 35
# 정확도 :0.6427184466019418, seed_num = 36
# 정확도 :0.6472491909385113, seed_num = 37
# 정확도 :0.6362459546925566, seed_num = 38
# 정확도 :0.6634304207119741, seed_num = 39
# 정확도 :0.63042071197411, seed_num = 40
# 정확도 :0.6446601941747573, seed_num = 41
# 정확도 :0.6349514563106796, seed_num = 42
# 정확도 :0.6330097087378641, seed_num = 43
# 정확도 :0.6355987055016181, seed_num = 44
# 정확도 :0.656957928802589, seed_num = 45
# 정확도 :0.6472491909385113, seed_num = 46
# 정확도 :0.6634304207119741, seed_num = 47
# 정확도 :0.6750809061488673, seed_num = 48
# 정확도 :0.6530744336569579, seed_num = 49

# %%
# seed = 42의 정확도 df 만들고 평균 확인 => 64.9
df_42 = pd.DataFrame.from_dict(dic_42, orient='index')
df_42.mean()
# Out:
# 0    0.649204
# dtype: float64

# %% [markdown]
# ## (64.9) not saved LSTM

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings(action='ignore')

import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, InputLayer
from tensorflow.keras.callbacks import EarlyStopping
from sklearn import metrics 
from tensorflow import keras
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

import random
# ----------------------
seed_num = 42
# ----------------------
random.seed(seed_num)

x = np.load('x_(7727,10,10)_m1.npy')
y = np.load('y_(7727,1).npy')

idx = list(range(len(x)))
random.shuffle(idx)

i = round(x.shape[0]*0.8)
X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
X_test, y_test = x[idx[i:],:,:], y[idx[i:]]

# ---------------------
seed_num = 42 
# ---------------------
tf.random.set_seed(seed_num)

lstm = Sequential()
lstm.add(InputLayer(input_shape=(X_train.shape[1],X_train.shape[2])))
lstm.add(LSTM(units=128, activation='hard_sigmoid', return_sequences=True))
lstm.add(LSTM(units=64, activation='hard_sigmoid', return_sequences=True))
lstm.add(Dropout(0.2))
lstm.add(LSTM(units=64, activation='hard_sigmoid', return_sequences=True))
lstm.add(LSTM(units=32, activation='hard_sigmoid', return_sequences=False))
lstm.add(Dropout(0.2))
lstm.add(Dense(units=1, activation='sigmoid'))

early_stop = EarlyStopping(monitor='val_acc', patience=50, verbose=1, restore_best_weights=False)
lstm.compile(optimizer= keras.optimizers.Adam(learning_rate = 0.001), loss = "binary_crossentropy", metrics=['acc'])
lstm.fit(X_train, y_train, validation_split=0.25, batch_size=128, epochs=500,  callbacks=[early_stop], shuffle=False)
# Out:
# Epoch 1/500
# 37/37 [==============================] - 4s 46ms/step - loss: 0.6759 - acc: 0.5984 - val_loss: 0.6660 - val_acc: 0.6177
# Epoch 2/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6732 - acc: 0.6066 - val_loss: 0.6662 - val_acc: 0.6177
# Epoch 3/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6740 - acc: 0.6083 - val_loss: 0.6655 - val_acc: 0.6177
# Epoch 4/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6711 - acc: 0.6100 - val_loss: 0.6653 - val_acc: 0.6177
# Epoch 5/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6706 - acc: 0.6091 - val_loss: 0.6652 - val_acc: 0.6177
# Epoch 6/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6721 - acc: 0.6113 - val_loss: 0.6652 - val_acc: 0.6177
# Epoch 7/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6710 - acc: 0.6111 - val_loss: 0.6652 - val_acc: 0.6177
# Epoch 8/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6715 - acc: 0.6111 - val_loss: 0.6652 - val_acc: 0.6177
# Epoch 9/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6702 - acc: 0.6113 - val_loss: 0.6652 - val_acc: 0.6177
# Epoch 10/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6700 - acc: 0.6115 - val_loss: 0.6652 - val_acc: 0.6177
# Epoch 11/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6698 - acc: 0.6115 - val_loss: 0.6651 - val_acc: 0.6177
# Epoch 12/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6694 - acc: 0.6115 - val_loss: 0.6652 - val_acc: 0.6177
# Epoch 13/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6698 - acc: 0.6117 - val_loss: 0.6652 - val_acc: 0.6177
# Epoch 14/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6694 - acc: 0.6115 - val_loss: 0.6651 - val_acc: 0.6177
# Epoch 15/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6691 - acc: 0.6115 - val_loss: 0.6652 - val_acc: 0.6177
# Epoch 16/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6701 - acc: 0.6115 - val_loss: 0.6651 - val_acc: 0.6177
# Epoch 17/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6706 - acc: 0.6115 - val_loss: 0.6650 - val_acc: 0.6177
# Epoch 18/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6686 - acc: 0.6115 - val_loss: 0.6648 - val_acc: 0.6177
# Epoch 19/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.6689 - acc: 0.6115 - val_loss: 0.6646 - val_acc: 0.6177
# Epoch 20/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6686 - acc: 0.6115 - val_loss: 0.6640 - val_acc: 0.6177
# Epoch 21/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6646 - acc: 0.6115 - val_loss: 0.6632 - val_acc: 0.6177
# Epoch 22/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6584 - acc: 0.6115 - val_loss: 0.6465 - val_acc: 0.6177
# Epoch 23/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6395 - acc: 0.6113 - val_loss: 0.6399 - val_acc: 0.6197
# Epoch 24/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6272 - acc: 0.6126 - val_loss: 0.6341 - val_acc: 0.6229
# Epoch 25/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6264 - acc: 0.6055 - val_loss: 0.6319 - val_acc: 0.6177
# Epoch 26/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.6223 - acc: 0.6107 - val_loss: 0.6433 - val_acc: 0.6197
# Epoch 27/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6220 - acc: 0.6094 - val_loss: 0.6278 - val_acc: 0.6177
# Epoch 28/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6202 - acc: 0.6139 - val_loss: 0.6339 - val_acc: 0.6177
# Epoch 29/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6244 - acc: 0.6001 - val_loss: 0.6261 - val_acc: 0.6177
# Epoch 30/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6181 - acc: 0.6204 - val_loss: 0.6332 - val_acc: 0.6229
# Epoch 31/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6175 - acc: 0.6189 - val_loss: 0.6297 - val_acc: 0.6229
# Epoch 32/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6186 - acc: 0.6150 - val_loss: 0.6296 - val_acc: 0.6229
# Epoch 33/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.6176 - acc: 0.6204 - val_loss: 0.6306 - val_acc: 0.6223
# Epoch 34/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6169 - acc: 0.6137 - val_loss: 0.6265 - val_acc: 0.6229
# Epoch 35/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.6149 - acc: 0.6266 - val_loss: 0.6273 - val_acc: 0.6248
# Epoch 36/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6159 - acc: 0.6219 - val_loss: 0.6262 - val_acc: 0.6229
# Epoch 37/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6134 - acc: 0.6320 - val_loss: 0.6208 - val_acc: 0.6410
# Epoch 38/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6126 - acc: 0.6503 - val_loss: 0.6193 - val_acc: 0.6423
# Epoch 39/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6109 - acc: 0.6381 - val_loss: 0.6170 - val_acc: 0.6475
# Epoch 40/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6101 - acc: 0.6372 - val_loss: 0.6157 - val_acc: 0.6481
# Epoch 41/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.6077 - acc: 0.6413 - val_loss: 0.6145 - val_acc: 0.6514
# Epoch 42/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6034 - acc: 0.6462 - val_loss: 0.6134 - val_acc: 0.6514
# Epoch 43/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6052 - acc: 0.6510 - val_loss: 0.6133 - val_acc: 0.6514
# Epoch 44/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6029 - acc: 0.6521 - val_loss: 0.6134 - val_acc: 0.6514
# Epoch 45/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6006 - acc: 0.6538 - val_loss: 0.6144 - val_acc: 0.6514
# Epoch 46/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6028 - acc: 0.6523 - val_loss: 0.6152 - val_acc: 0.6507
# Epoch 47/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6014 - acc: 0.6514 - val_loss: 0.6157 - val_acc: 0.6507
# Epoch 48/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.6020 - acc: 0.6521 - val_loss: 0.6174 - val_acc: 0.6494
# Epoch 49/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6018 - acc: 0.6544 - val_loss: 0.6197 - val_acc: 0.6494
# Epoch 50/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.6084 - acc: 0.6447 - val_loss: 0.6186 - val_acc: 0.6442
# Epoch 51/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6029 - acc: 0.6501 - val_loss: 0.6148 - val_acc: 0.6514
# Epoch 52/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6011 - acc: 0.6544 - val_loss: 0.6160 - val_acc: 0.6494
# Epoch 53/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6027 - acc: 0.6534 - val_loss: 0.6137 - val_acc: 0.6533
# Epoch 54/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6008 - acc: 0.6540 - val_loss: 0.6152 - val_acc: 0.6533
# Epoch 55/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6014 - acc: 0.6540 - val_loss: 0.6134 - val_acc: 0.6533
# Epoch 56/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5983 - acc: 0.6540 - val_loss: 0.6156 - val_acc: 0.6533
# Epoch 57/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6028 - acc: 0.6538 - val_loss: 0.6126 - val_acc: 0.6533
# Epoch 58/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.5990 - acc: 0.6544 - val_loss: 0.6157 - val_acc: 0.6533
# Epoch 59/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.6031 - acc: 0.6542 - val_loss: 0.6125 - val_acc: 0.6533
# Epoch 60/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.5989 - acc: 0.6542 - val_loss: 0.6166 - val_acc: 0.6533
# Epoch 61/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.6011 - acc: 0.6531 - val_loss: 0.6127 - val_acc: 0.6533
# Epoch 62/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6015 - acc: 0.6540 - val_loss: 0.6159 - val_acc: 0.6533
# Epoch 63/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5999 - acc: 0.6549 - val_loss: 0.6137 - val_acc: 0.6527
# Epoch 64/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6006 - acc: 0.6538 - val_loss: 0.6144 - val_acc: 0.6533
# Epoch 65/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5997 - acc: 0.6540 - val_loss: 0.6148 - val_acc: 0.6533
# Epoch 66/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5983 - acc: 0.6540 - val_loss: 0.6146 - val_acc: 0.6533
# Epoch 67/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5992 - acc: 0.6542 - val_loss: 0.6164 - val_acc: 0.6533
# Epoch 68/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6012 - acc: 0.6547 - val_loss: 0.6127 - val_acc: 0.6533
# Epoch 69/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5990 - acc: 0.6540 - val_loss: 0.6153 - val_acc: 0.6533
# Epoch 70/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5988 - acc: 0.6544 - val_loss: 0.6147 - val_acc: 0.6533
# Epoch 71/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5976 - acc: 0.6542 - val_loss: 0.6153 - val_acc: 0.6533
# Epoch 72/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5991 - acc: 0.6538 - val_loss: 0.6137 - val_acc: 0.6533
# Epoch 73/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5994 - acc: 0.6534 - val_loss: 0.6147 - val_acc: 0.6533
# Epoch 74/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5988 - acc: 0.6549 - val_loss: 0.6147 - val_acc: 0.6533
# Epoch 75/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.6007 - acc: 0.6547 - val_loss: 0.6138 - val_acc: 0.6533
# Epoch 76/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5987 - acc: 0.6538 - val_loss: 0.6148 - val_acc: 0.6533
# Epoch 77/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.5991 - acc: 0.6542 - val_loss: 0.6139 - val_acc: 0.6527
# Epoch 78/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.5985 - acc: 0.6542 - val_loss: 0.6153 - val_acc: 0.6533
# Epoch 79/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5983 - acc: 0.6542 - val_loss: 0.6144 - val_acc: 0.6533
# Epoch 80/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5987 - acc: 0.6542 - val_loss: 0.6153 - val_acc: 0.6533
# Epoch 81/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5987 - acc: 0.6540 - val_loss: 0.6138 - val_acc: 0.6533
# Epoch 82/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5985 - acc: 0.6540 - val_loss: 0.6154 - val_acc: 0.6533
# Epoch 83/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5980 - acc: 0.6536 - val_loss: 0.6161 - val_acc: 0.6533
# Epoch 84/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6000 - acc: 0.6547 - val_loss: 0.6123 - val_acc: 0.6533
# Epoch 85/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5988 - acc: 0.6536 - val_loss: 0.6151 - val_acc: 0.6533
# Epoch 86/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5976 - acc: 0.6547 - val_loss: 0.6146 - val_acc: 0.6533
# Epoch 87/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.5981 - acc: 0.6540 - val_loss: 0.6140 - val_acc: 0.6533
# Epoch 88/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5979 - acc: 0.6538 - val_loss: 0.6149 - val_acc: 0.6533
# Epoch 89/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5976 - acc: 0.6540 - val_loss: 0.6143 - val_acc: 0.6533
# Epoch 90/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5988 - acc: 0.6540 - val_loss: 0.6138 - val_acc: 0.6527
# Epoch 91/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5966 - acc: 0.6538 - val_loss: 0.6159 - val_acc: 0.6533
# Epoch 92/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5993 - acc: 0.6551 - val_loss: 0.6127 - val_acc: 0.6533
# Epoch 93/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5979 - acc: 0.6538 - val_loss: 0.6146 - val_acc: 0.6533
# Epoch 94/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5990 - acc: 0.6549 - val_loss: 0.6141 - val_acc: 0.6533
# Epoch 95/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5977 - acc: 0.6544 - val_loss: 0.6136 - val_acc: 0.6533
# Epoch 96/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5987 - acc: 0.6538 - val_loss: 0.6135 - val_acc: 0.6533
# Epoch 97/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5968 - acc: 0.6538 - val_loss: 0.6136 - val_acc: 0.6533
# Epoch 98/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5979 - acc: 0.6538 - val_loss: 0.6142 - val_acc: 0.6533
# Epoch 99/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5967 - acc: 0.6540 - val_loss: 0.6143 - val_acc: 0.6533
# Epoch 100/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5981 - acc: 0.6536 - val_loss: 0.6139 - val_acc: 0.6533
# Epoch 101/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5967 - acc: 0.6540 - val_loss: 0.6151 - val_acc: 0.6533
# Epoch 102/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5976 - acc: 0.6542 - val_loss: 0.6139 - val_acc: 0.6533
# Epoch 103/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5969 - acc: 0.6544 - val_loss: 0.6149 - val_acc: 0.6533
# Epoch 00103: early stopping

# %%
dic_42={}
for seed in range(0, 50):
    random.seed(seed)

    x = np.load('x_(7727,10,10)_m1.npy')
    y = np.load('y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
    X_test, y_test = x[idx[i:],:,:], y[idx[i:]]
    
    pred = lstm.predict(X_test)
    pred[pred>0.5]=1
    pred[pred<=0.5]=0
    acc = metrics.accuracy_score(y_test, pred)
    dic_42[seed]=acc
    print(f'정확도 :{metrics.accuracy_score(y_test, pred)}, seed_num = {seed}')
# Out:
# 정확도 :0.6459546925566343, seed_num = 0
# 정확도 :0.6427184466019418, seed_num = 1
# 정확도 :0.6498381877022654, seed_num = 2
# 정확도 :0.6375404530744336, seed_num = 3
# 정확도 :0.654368932038835, seed_num = 4
# 정확도 :0.655663430420712, seed_num = 5
# 정확도 :0.6537216828478964, seed_num = 6
# 정확도 :0.629126213592233, seed_num = 7
# 정확도 :0.6614886731391586, seed_num = 8
# 정확도 :0.6491909385113268, seed_num = 9
# 정확도 :0.627831715210356, seed_num = 10
# 정확도 :0.6711974110032363, seed_num = 11
# 정확도 :0.6472491909385113, seed_num = 12
# 정확도 :0.6414239482200648, seed_num = 13
# 정확도 :0.6466019417475728, seed_num = 14
# 정확도 :0.6563106796116505, seed_num = 15
# 정확도 :0.6692556634304208, seed_num = 16
# 정확도 :0.6446601941747573, seed_num = 17
# 정확도 :0.6453074433656958, seed_num = 18
# 정확도 :0.6414239482200648, seed_num = 19
# 정확도 :0.6601941747572816, seed_num = 20
# 정확도 :0.6588996763754046, seed_num = 21
# 정확도 :0.6375404530744336, seed_num = 22
# 정확도 :0.6550161812297735, seed_num = 23
# 정확도 :0.6530744336569579, seed_num = 24
# 정확도 :0.6491909385113268, seed_num = 25
# 정확도 :0.627831715210356, seed_num = 26
# 정확도 :0.6601941747572816, seed_num = 27
# 정확도 :0.6453074433656958, seed_num = 28
# 정확도 :0.6446601941747573, seed_num = 29
# 정확도 :0.6530744336569579, seed_num = 30
# 정확도 :0.6472491909385113, seed_num = 31
# 정확도 :0.654368932038835, seed_num = 32
# 정확도 :0.6511326860841424, seed_num = 33
# 정확도 :0.6595469255663431, seed_num = 34
# 정확도 :0.6614886731391586, seed_num = 35
# 정확도 :0.6427184466019418, seed_num = 36
# 정확도 :0.6472491909385113, seed_num = 37
# 정확도 :0.6362459546925566, seed_num = 38
# 정확도 :0.6627831715210356, seed_num = 39
# 정확도 :0.63042071197411, seed_num = 40
# 정확도 :0.6440129449838188, seed_num = 41
# 정확도 :0.6349514563106796, seed_num = 42
# 정확도 :0.6323624595469256, seed_num = 43
# 정확도 :0.6349514563106796, seed_num = 44
# 정확도 :0.656957928802589, seed_num = 45
# 정확도 :0.6472491909385113, seed_num = 46
# 정확도 :0.6634304207119741, seed_num = 47
# 정확도 :0.6750809061488673, seed_num = 48
# 정확도 :0.6524271844660194, seed_num = 49

# %%
# seed = 42의 정확도 df 만들고 평균 확인 => 64.9
df_42 = pd.DataFrame.from_dict(dic_42, orient='index')
df_42.mean()
# Out:
# 0    0.64901
# dtype: float64

# %% [markdown]
# # RF : 상위 10개 feature
# - x_(7727,10)_rf.npy 저장

# %%
# x_(7727,4068).npy 저장
x1 = np.load('x_(7727,10,4068).npy')
x1 = x1.sum(axis=1)
x1.sum(), x1.shape

x1_ = x1.copy()
x1_[x1_>1] = 1
x1_.sum()

# np.save('x_(7727,4068).npy', x1_)
# Out:
# (2042722.0, (7727, 4068))
# 510420.0

# %%
# RF 기준으로 상위 10개 feature 선별
total_data = pd.read_csv('total_data_7727.csv')
features = list(total_data['ITEMID'].sort_values().unique())

import random
random.seed(42)
x = np.load('x_(7727,4068).npy')
y = np.load('y_(7727,1).npy')

# %%
# RF에 내장된 feature importance 
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics 

model = RandomForestClassifier()
model.fit(x, y)

importances = model.feature_importances_

result = []
for f in range(x.shape[1]):
    result.append({'feature' : features[f], 'importance' : importances[f]})
# Out:
# RandomForestClassifier()

# %%
# rf_top10 itemid 골라내기 
df = pd.DataFrame(result)
df = df.sort_values(by='importance',ascending=False)
rf_top10 = df['feature'].values[:10]
rf_bottom10 = df['feature'].values[-10:]
rf_top10
rf_bottom10
# Out:
# array([      51277,       50912,       51006, 63323026201,       50862,
#              50983,       51003,       51275,   904224461,       50882])
# array([55390012210,   536479301,   536376701,   536185097, 55390013910,
#        55390014301,   527155201,     2704001,   517420125,   575022530])

# %%
# rf_top10만을 가진 x_(7727,10)_rf 만들기
item_list = list(total_data['ITEMID'].sort_values().unique())

rf_top10_index = []
for i in rf_top10:
    rf_top10_index.append(item_list.index(i))

print('rf_top10의 index : ',rf_top10_index)

x_2d = x[:,rf_top10_index]
x_2d.shape

# np.save('x_(7727,10)_rf.npy',x_2d)
# Out:
# rf_top10의 index :  [206, 121, 56, 20, 103, 3832, 34, 2611, 2195, 119]
# (7727, 10)

# %% [markdown]
# ## absum 그래프

# %%
total_data = pd.read_csv('total_data_7727.csv')
x = np.load('/project/LSH/x_(7727,10,4068).npy')

def absum(PPL_list,top_or_down):
    # 1) PRE_top10의 index 구하기
    PPL_top10 = top_or_down
    item_list = total_data['ITEMID'].sort_values().unique()

    PPL_index = []
    for i in PPL_top10:
        a = list(item_list).index(i)
        PPL_index.append(a)
    
    # 2) 생존자 index 구하기 
    sub7727 = total_data['SUBJECT_ID'].unique()

    patient = pd.read_csv('폐렴환자.csv')
    patient = patient.sort_values(by='SUBJECT_ID')
    patient = patient[patient['SUBJECT_ID'].isin(sub7727)]
    sub_1_list = patient[patient['EXPIRE_FLAG']==0]['SUBJECT_ID'].values

    생존자_index = []
    for i in sub_1_list:
        생존자_index.append(list(sub7727).index(i))
        
    # 3) 생존자 3009명의 D-10 ~ D-1 feature별 abnormal sum 
    x_생존자 = x[생존자_index,:,:]

    result1 = []
    for i in PPL_index:
        for j in range(10):
            result1.append(x_생존자[:,j,i].sum())

    result1 = np.array(result1)
    result1 = result1.reshape(10,-1)
    df_PPL = pd.DataFrame(result1)
    df_PPL.columns = [f'D-{i}' for i in range(10,0,-1)]
    df_PPL.index = PPL_top10

    # 생존한 4718명에 대한 비율 계산
    for i in PPL_top10:
        df_PPL.loc[f'{i}_생존'] = df_PPL.loc[i].iloc[:]/x_생존자.shape[0]
        
    # 4) 사망자 4718명의 D-10 ~ D-1 feature별 abnormal sum 
    사망자_index = list(set(range(0,7727))-set(생존자_index))

    x_사망자 = x[사망자_index,:,:]

    result2 = []
    for i in PPL_index:
        for j in range(10):
            result2.append(x_사망자[:,j,i].sum())

    result2 = np.array(result2)
    result2 = result2.reshape(10,-1)
    df_PPL_사망자 = pd.DataFrame(result2)
    df_PPL_사망자.columns = [f'D-{i}' for i in range(10,0,-1)]
    df_PPL_사망자.index = PPL_top10

    # 사망한 3009명에 대한 비율 계산
    for i in PPL_top10:
        df_PPL_사망자.loc[f'{i}_사망'] = df_PPL_사망자.loc[i]/x_사망자.shape[0] 
        
    # 5) for문으로 각 feature에 대한 비율 추이 그래프 그리기 

    df_PPL_trans = df_PPL.transpose()
    df_PPL_사망자_trans = df_PPL_사망자.transpose()

    _ = plt.figure(figsize = (13,12),dpi=150)
    for i, f in enumerate(PPL_top10): 
        _ = plt.subplot(4,3,1+i)
        _ = plt.title(f)
        _ = ax = sns.lineplot(data = df_PPL_사망자_trans, x = df_PPL_사망자_trans.index, y = f'{f}_사망')
        _ = ax = sns.lineplot(data = df_PPL_trans, x = df_PPL_trans.index, y = f'{f}_생존')
        _ = ax.legend(labels = ['사망', '생존'], loc = 'upper left', fontsize=12)
        _ = ax.set_ylabel('per', fontsize = 12)

    plt.tight_layout()

# %%
RF_list = list(rf_top10)
absum(RF_list,RF_list[:10])

# %% [markdown]
# ## (67.3) RF

# %%
import random
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

model = RandomForestClassifier()

data={}
for seed in range(42, 52):
    random.seed(seed)
    
    x = np.load('./x_(7727,10)_rf.npy')
    y = np.load('./y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_train, y_train = x[idx[:i],:], y[idx[:i]]
    X_test, y_test = x[idx[i:],:], y[idx[i:]]
    
    _ = model.fit(X_train, y_train)
    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)
    
    acc = accuracy_score(y_test, y_pred_test)
    data[seed]=acc
    print(f'정확도 : {acc}, seed_num = {seed}')

df = pd.DataFrame.from_dict(data, orient='index')
print(f'정확도 df 만들고 평균 확인 : {df.mean().values}')
# Out:
# 정확도 : 0.6763754045307443, seed_num = 42
# 정확도 : 0.6692556634304208, seed_num = 43
# 정확도 : 0.6550161812297735, seed_num = 44
# 정확도 : 0.6653721682847896, seed_num = 45
# 정확도 : 0.6899676375404531, seed_num = 46
# 정확도 : 0.6673139158576051, seed_num = 47
# 정확도 : 0.6957928802588996, seed_num = 48
# 정확도 : 0.6802588996763754, seed_num = 49
# 정확도 : 0.658252427184466, seed_num = 50
# 정확도 : 0.6724919093851133, seed_num = 51
# 정확도 df 만들고 평균 확인 : [0.67300971]

# %% [markdown]
# ## (72.0) LSTM

# %%
# rf_top10만을 가진 x_(7727,10,10)_rf 만들기
item_list = list(total_data['ITEMID'].sort_values().unique())

rf_top10_index = []
for i in rf_top10:
    rf_top10_index.append(item_list.index(i))

print('rf_top10의 index : ',rf_top10_index)

x = np.load('x_(7727,10,4068).npy')
x_3d = x[:,:,rf_top10_index]
x_3d.shape
x_3d.sum()

# np.save('x_(7727,10,10)_rf.npy',x_3d)
# Out:
# rf_top10의 index :  [206, 121, 56, 20, 103, 3832, 34, 2611, 2195, 119]
# (7727, 10, 10)
# 148506.0

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings(action='ignore')

import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, InputLayer
from tensorflow.keras.callbacks import EarlyStopping
from sklearn import metrics 
from tensorflow import keras
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

import random
# ----------------------
seed_num = 42
# ----------------------
random.seed(seed_num)

x = np.load('x_(7727,10,10)_rf.npy')
y = np.load('y_(7727,1).npy')

idx = list(range(len(x)))
random.shuffle(idx)

i = round(x.shape[0]*0.8)
X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
X_test, y_test = x[idx[i:],:,:], y[idx[i:]]

# ---------------------
seed_num = 42 
# ---------------------
tf.random.set_seed(seed_num)

lstm = Sequential()
lstm.add(InputLayer(input_shape=(X_train.shape[1],X_train.shape[2])))
lstm.add(LSTM(units=128, activation='hard_sigmoid', return_sequences=True))
lstm.add(LSTM(units=64, activation='hard_sigmoid', return_sequences=True))
lstm.add(Dropout(0.2))
lstm.add(LSTM(units=64, activation='hard_sigmoid', return_sequences=True))
lstm.add(LSTM(units=32, activation='hard_sigmoid', return_sequences=False))
lstm.add(Dropout(0.2))
lstm.add(Dense(units=1, activation='sigmoid'))

from tensorflow.keras.callbacks import ModelCheckpoint
import os

MODEL_SAVE_FOLDER_PATH = './model/'
if not os.path.exists(MODEL_SAVE_FOLDER_PATH):
    os.mkdir(MODEL_SAVE_FOLDER_PATH)

model_path = MODEL_SAVE_FOLDER_PATH + 'rf_top10_seed42-{epoch:02d}-{val_loss:.4f}.hdf5'

cb_checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss',
                                verbose=1, save_best_only=True)

early_stop = EarlyStopping(monitor='val_acc', patience=50, verbose=1, restore_best_weights=True)
lstm.compile(optimizer= keras.optimizers.Adam(learning_rate = 0.001), loss = "binary_crossentropy", metrics=['acc'])
lstm.fit(X_train, y_train, validation_split=0.25, batch_size=128, epochs=500,  callbacks=[early_stop,cb_checkpoint], shuffle=False)
# Out:
# Epoch 1/500
# 37/37 [==============================] - 5s 54ms/step - loss: 0.6758 - acc: 0.5984 - val_loss: 0.6660 - val_acc: 0.6177
#
# Epoch 00001: val_loss improved from inf to 0.66596, saving model to ./model/rf_top10_seed42-01-0.6660.hdf5
# Epoch 2/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6730 - acc: 0.6068 - val_loss: 0.6660 - val_acc: 0.6177
#
# Epoch 00002: val_loss did not improve from 0.66596
# Epoch 3/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6730 - acc: 0.6085 - val_loss: 0.6632 - val_acc: 0.6177
#
# Epoch 00003: val_loss improved from 0.66596 to 0.66323, saving model to ./model/rf_top10_seed42-03-0.6632.hdf5
# Epoch 4/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6547 - acc: 0.6158 - val_loss: 0.6207 - val_acc: 0.6177
#
# Epoch 00004: val_loss improved from 0.66323 to 0.62068, saving model to ./model/rf_top10_seed42-04-0.6207.hdf5
# Epoch 5/500
# 37/37 [==============================] - 2s 44ms/step - loss: 0.6056 - acc: 0.6700 - val_loss: 0.5873 - val_acc: 0.6953
#
# Epoch 00005: val_loss improved from 0.62068 to 0.58725, saving model to ./model/rf_top10_seed42-05-0.5873.hdf5
# Epoch 6/500
# 37/37 [==============================] - 1s 40ms/step - loss: 0.5886 - acc: 0.6931 - val_loss: 0.5807 - val_acc: 0.6979
#
# Epoch 00006: val_loss improved from 0.58725 to 0.58069, saving model to ./model/rf_top10_seed42-06-0.5807.hdf5
# Epoch 7/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.5838 - acc: 0.6993 - val_loss: 0.5712 - val_acc: 0.6999
#
# Epoch 00007: val_loss improved from 0.58069 to 0.57124, saving model to ./model/rf_top10_seed42-07-0.5712.hdf5
# Epoch 8/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.5792 - acc: 0.7028 - val_loss: 0.5695 - val_acc: 0.7012
#
# Epoch 00008: val_loss improved from 0.57124 to 0.56950, saving model to ./model/rf_top10_seed42-08-0.5695.hdf5
# Epoch 9/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5732 - acc: 0.7062 - val_loss: 0.5691 - val_acc: 0.7044
#
# Epoch 00009: val_loss improved from 0.56950 to 0.56909, saving model to ./model/rf_top10_seed42-09-0.5691.hdf5
# Epoch 10/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5693 - acc: 0.7120 - val_loss: 0.5677 - val_acc: 0.7031
#
# Epoch 00010: val_loss improved from 0.56909 to 0.56768, saving model to ./model/rf_top10_seed42-10-0.5677.hdf5
# Epoch 11/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5704 - acc: 0.7038 - val_loss: 0.5683 - val_acc: 0.7031
#
# Epoch 00011: val_loss did not improve from 0.56768
# Epoch 12/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.5665 - acc: 0.7082 - val_loss: 0.5691 - val_acc: 0.7044
#
# Epoch 00012: val_loss did not improve from 0.56768
# Epoch 13/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.5668 - acc: 0.7088 - val_loss: 0.5669 - val_acc: 0.7031
#
# Epoch 00013: val_loss improved from 0.56768 to 0.56686, saving model to ./model/rf_top10_seed42-13-0.5669.hdf5
# Epoch 14/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.5637 - acc: 0.7084 - val_loss: 0.5689 - val_acc: 0.7025
#
# Epoch 00014: val_loss did not improve from 0.56686
# Epoch 15/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.5652 - acc: 0.7131 - val_loss: 0.5699 - val_acc: 0.7083
#
# Epoch 00015: val_loss did not improve from 0.56686
# Epoch 16/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5650 - acc: 0.7082 - val_loss: 0.5693 - val_acc: 0.7076
#
# Epoch 00016: val_loss did not improve from 0.56686
# Epoch 17/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5648 - acc: 0.7120 - val_loss: 0.5701 - val_acc: 0.7057
#
# Epoch 00017: val_loss did not improve from 0.56686
# Epoch 18/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5608 - acc: 0.7092 - val_loss: 0.5716 - val_acc: 0.7063
#
# Epoch 00018: val_loss did not improve from 0.56686
# Epoch 19/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5636 - acc: 0.7094 - val_loss: 0.5733 - val_acc: 0.7044
#
# Epoch 00019: val_loss did not improve from 0.56686
# Epoch 20/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5634 - acc: 0.7112 - val_loss: 0.5726 - val_acc: 0.7044
#
# Epoch 00020: val_loss did not improve from 0.56686
# Epoch 21/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.5613 - acc: 0.7082 - val_loss: 0.5729 - val_acc: 0.7038
#
# Epoch 00021: val_loss did not improve from 0.56686
# Epoch 22/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.5615 - acc: 0.7140 - val_loss: 0.5727 - val_acc: 0.7063
#
# Epoch 00022: val_loss did not improve from 0.56686
# Epoch 23/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5628 - acc: 0.7127 - val_loss: 0.5706 - val_acc: 0.7089
#
# Epoch 00023: val_loss did not improve from 0.56686
# Epoch 24/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.5600 - acc: 0.7138 - val_loss: 0.5683 - val_acc: 0.7050
#
# Epoch 00024: val_loss did not improve from 0.56686
# Epoch 25/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.5599 - acc: 0.7172 - val_loss: 0.5660 - val_acc: 0.7063
#
# Epoch 00025: val_loss improved from 0.56686 to 0.56601, saving model to ./model/rf_top10_seed42-25-0.5660.hdf5
# Epoch 26/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5562 - acc: 0.7174 - val_loss: 0.5670 - val_acc: 0.7063
#
# Epoch 00026: val_loss did not improve from 0.56601
# Epoch 27/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5561 - acc: 0.7172 - val_loss: 0.5645 - val_acc: 0.7050
#
# Epoch 00027: val_loss improved from 0.56601 to 0.56451, saving model to ./model/rf_top10_seed42-27-0.5645.hdf5
# Epoch 28/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5546 - acc: 0.7174 - val_loss: 0.5634 - val_acc: 0.7031
#
# Epoch 00028: val_loss improved from 0.56451 to 0.56342, saving model to ./model/rf_top10_seed42-28-0.5634.hdf5
# Epoch 29/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5538 - acc: 0.7164 - val_loss: 0.5628 - val_acc: 0.7038
#
# Epoch 00029: val_loss improved from 0.56342 to 0.56282, saving model to ./model/rf_top10_seed42-29-0.5628.hdf5
# Epoch 30/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5558 - acc: 0.7176 - val_loss: 0.5624 - val_acc: 0.7050
#
# Epoch 00030: val_loss improved from 0.56282 to 0.56241, saving model to ./model/rf_top10_seed42-30-0.5624.hdf5
# Epoch 31/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.5520 - acc: 0.7192 - val_loss: 0.5619 - val_acc: 0.7050
#
# Epoch 00031: val_loss improved from 0.56241 to 0.56194, saving model to ./model/rf_top10_seed42-31-0.5619.hdf5
# Epoch 32/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5544 - acc: 0.7176 - val_loss: 0.5604 - val_acc: 0.7025
#
# Epoch 00032: val_loss improved from 0.56194 to 0.56041, saving model to ./model/rf_top10_seed42-32-0.5604.hdf5
# Epoch 33/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5529 - acc: 0.7181 - val_loss: 0.5606 - val_acc: 0.7044
#
# Epoch 00033: val_loss did not improve from 0.56041
# Epoch 34/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5506 - acc: 0.7211 - val_loss: 0.5611 - val_acc: 0.7070
#
# Epoch 00034: val_loss did not improve from 0.56041
# Epoch 35/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5518 - acc: 0.7213 - val_loss: 0.5605 - val_acc: 0.7076
#
# Epoch 00035: val_loss did not improve from 0.56041
# Epoch 36/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5517 - acc: 0.7187 - val_loss: 0.5594 - val_acc: 0.7031
#
# Epoch 00036: val_loss improved from 0.56041 to 0.55944, saving model to ./model/rf_top10_seed42-36-0.5594.hdf5
# Epoch 37/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5488 - acc: 0.7233 - val_loss: 0.5589 - val_acc: 0.7005
#
# Epoch 00037: val_loss improved from 0.55944 to 0.55895, saving model to ./model/rf_top10_seed42-37-0.5589.hdf5
# Epoch 38/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5495 - acc: 0.7198 - val_loss: 0.5586 - val_acc: 0.7005
#
# Epoch 00038: val_loss improved from 0.55895 to 0.55857, saving model to ./model/rf_top10_seed42-38-0.5586.hdf5
# Epoch 39/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.5503 - acc: 0.7204 - val_loss: 0.5570 - val_acc: 0.7038
#
# Epoch 00039: val_loss improved from 0.55857 to 0.55695, saving model to ./model/rf_top10_seed42-39-0.5570.hdf5
# Epoch 40/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.5485 - acc: 0.7220 - val_loss: 0.5567 - val_acc: 0.7031
#
# Epoch 00040: val_loss improved from 0.55695 to 0.55672, saving model to ./model/rf_top10_seed42-40-0.5567.hdf5
# Epoch 41/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5504 - acc: 0.7183 - val_loss: 0.5572 - val_acc: 0.7018
#
# Epoch 00041: val_loss did not improve from 0.55672
# Epoch 42/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5464 - acc: 0.7174 - val_loss: 0.5568 - val_acc: 0.6999
#
# Epoch 00042: val_loss did not improve from 0.55672
# Epoch 43/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5488 - acc: 0.7213 - val_loss: 0.5577 - val_acc: 0.7031
#
# Epoch 00043: val_loss did not improve from 0.55672
# Epoch 44/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.5480 - acc: 0.7211 - val_loss: 0.5547 - val_acc: 0.7031
#
# Epoch 00044: val_loss improved from 0.55672 to 0.55472, saving model to ./model/rf_top10_seed42-44-0.5547.hdf5
# Epoch 45/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5456 - acc: 0.7217 - val_loss: 0.5576 - val_acc: 0.7018
#
# Epoch 00045: val_loss did not improve from 0.55472
# Epoch 46/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5480 - acc: 0.7209 - val_loss: 0.5565 - val_acc: 0.7005
#
# Epoch 00046: val_loss did not improve from 0.55472
# Epoch 47/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5443 - acc: 0.7215 - val_loss: 0.5561 - val_acc: 0.7038
#
# Epoch 00047: val_loss did not improve from 0.55472
# Epoch 48/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5467 - acc: 0.7233 - val_loss: 0.5564 - val_acc: 0.7018
#
# Epoch 00048: val_loss did not improve from 0.55472
# Epoch 49/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5466 - acc: 0.7245 - val_loss: 0.5547 - val_acc: 0.7050
#
# Epoch 00049: val_loss improved from 0.55472 to 0.55466, saving model to ./model/rf_top10_seed42-49-0.5547.hdf5
# Epoch 50/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5459 - acc: 0.7222 - val_loss: 0.5555 - val_acc: 0.7038
#
# Epoch 00050: val_loss did not improve from 0.55466
# Epoch 51/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.5439 - acc: 0.7263 - val_loss: 0.5552 - val_acc: 0.7038
#
# Epoch 00051: val_loss did not improve from 0.55466
# Epoch 52/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5434 - acc: 0.7211 - val_loss: 0.5565 - val_acc: 0.7005
#
# Epoch 00052: val_loss did not improve from 0.55466
# Epoch 53/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.5452 - acc: 0.7202 - val_loss: 0.5560 - val_acc: 0.7031
#
# Epoch 00053: val_loss did not improve from 0.55466
# Epoch 54/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.5442 - acc: 0.7194 - val_loss: 0.5556 - val_acc: 0.7031
#
# Epoch 00054: val_loss did not improve from 0.55466
# Epoch 55/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.5437 - acc: 0.7235 - val_loss: 0.5557 - val_acc: 0.7031
#
# Epoch 00055: val_loss did not improve from 0.55466
# Epoch 56/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5413 - acc: 0.7261 - val_loss: 0.5557 - val_acc: 0.7044
#
# Epoch 00056: val_loss did not improve from 0.55466
# Epoch 57/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5423 - acc: 0.7233 - val_loss: 0.5550 - val_acc: 0.7038
#
# Epoch 00057: val_loss did not improve from 0.55466
# Epoch 58/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5408 - acc: 0.7274 - val_loss: 0.5560 - val_acc: 0.7018
#
# Epoch 00058: val_loss did not improve from 0.55466
# Epoch 59/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.5430 - acc: 0.7239 - val_loss: 0.5557 - val_acc: 0.7018
#
# Epoch 00059: val_loss did not improve from 0.55466
# Epoch 60/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5404 - acc: 0.7245 - val_loss: 0.5559 - val_acc: 0.7038
#
# Epoch 00060: val_loss did not improve from 0.55466
# Epoch 61/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5402 - acc: 0.7261 - val_loss: 0.5560 - val_acc: 0.7012
#
# Epoch 00061: val_loss did not improve from 0.55466
# Epoch 62/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.5417 - acc: 0.7211 - val_loss: 0.5559 - val_acc: 0.7018
#
# Epoch 00062: val_loss did not improve from 0.55466
# Epoch 63/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5412 - acc: 0.7241 - val_loss: 0.5573 - val_acc: 0.7018
#
# Epoch 00063: val_loss did not improve from 0.55466
# Epoch 64/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.5420 - acc: 0.7263 - val_loss: 0.5546 - val_acc: 0.7083
#
# Epoch 00064: val_loss improved from 0.55466 to 0.55457, saving model to ./model/rf_top10_seed42-64-0.5546.hdf5
# Epoch 65/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.5388 - acc: 0.7222 - val_loss: 0.5568 - val_acc: 0.7025
#
# Epoch 00065: val_loss did not improve from 0.55457
# Epoch 66/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.5382 - acc: 0.7267 - val_loss: 0.5551 - val_acc: 0.7031
#
# Epoch 00066: val_loss did not improve from 0.55457
# Epoch 67/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5373 - acc: 0.7291 - val_loss: 0.5559 - val_acc: 0.7057
#
# Epoch 00067: val_loss did not improve from 0.55457
# Epoch 68/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.5384 - acc: 0.7239 - val_loss: 0.5563 - val_acc: 0.7050
#
# Epoch 00068: val_loss did not improve from 0.55457
# Epoch 69/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5403 - acc: 0.7237 - val_loss: 0.5559 - val_acc: 0.7057
#
# Epoch 00069: val_loss did not improve from 0.55457
# Epoch 70/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.5392 - acc: 0.7265 - val_loss: 0.5560 - val_acc: 0.7063
#
# Epoch 00070: val_loss did not improve from 0.55457
# Epoch 71/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5375 - acc: 0.7280 - val_loss: 0.5564 - val_acc: 0.7018
#
# Epoch 00071: val_loss did not improve from 0.55457
# Epoch 72/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.5368 - acc: 0.7276 - val_loss: 0.5572 - val_acc: 0.7018
#
# Epoch 00072: val_loss did not improve from 0.55457
# Epoch 73/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.5379 - acc: 0.7254 - val_loss: 0.5569 - val_acc: 0.7057
# Restoring model weights from the end of the best epoch.
#
# Epoch 00073: val_loss did not improve from 0.55457
# Epoch 00073: early stopping

# %%
from keras.models import load_model
best_model = load_model('./model/rf_top10_seed42-64-0.5546.hdf5') 

dic_42={}
for seed in range(0, 50):
    random.seed(seed)

    x = np.load('x_(7727,10,10)_rf.npy')
    y = np.load('y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
    X_test, y_test = x[idx[i:],:,:], y[idx[i:]]
    
    pred = best_model.predict(X_test)
    pred[pred>0.5]=1
    pred[pred<=0.5]=0
    acc = metrics.accuracy_score(y_test, pred)
    dic_42[seed]=acc
    print(f'정확도 :{metrics.accuracy_score(y_test, pred)}, seed_num = {seed}')
# Out:
# 정확도 :0.7165048543689321, seed_num = 0
# 정확도 :0.7249190938511327, seed_num = 1
# 정확도 :0.7171521035598706, seed_num = 2
# 정확도 :0.7242718446601941, seed_num = 3
# 정확도 :0.7242718446601941, seed_num = 4
# 정확도 :0.7165048543689321, seed_num = 5
# 정확도 :0.7190938511326861, seed_num = 6
# 정확도 :0.7216828478964401, seed_num = 7
# 정확도 :0.7313915857605178, seed_num = 8
# 정확도 :0.7216828478964401, seed_num = 9
# 정확도 :0.7249190938511327, seed_num = 10
# 정확도 :0.7385113268608414, seed_num = 11
# 정확도 :0.7365695792880259, seed_num = 12
# 정확도 :0.7190938511326861, seed_num = 13
# 정확도 :0.7288025889967638, seed_num = 14
# 정확도 :0.7190938511326861, seed_num = 15
# 정확도 :0.7190938511326861, seed_num = 16
# 정확도 :0.7158576051779936, seed_num = 17
# 정확도 :0.7268608414239482, seed_num = 18
# 정확도 :0.7216828478964401, seed_num = 19
# 정확도 :0.7126213592233009, seed_num = 20
# 정확도 :0.6996763754045308, seed_num = 21
# 정확도 :0.7223300970873786, seed_num = 22
# 정확도 :0.713915857605178, seed_num = 23
# 정확도 :0.7003236245954693, seed_num = 24
# 정확도 :0.7307443365695793, seed_num = 25
# 정확도 :0.7171521035598706, seed_num = 26
# 정확도 :0.7022653721682848, seed_num = 27
# 정확도 :0.7190938511326861, seed_num = 28
# 정확도 :0.7158576051779936, seed_num = 29
# 정확도 :0.7333333333333333, seed_num = 30
# 정확도 :0.7152103559870551, seed_num = 31
# 정확도 :0.7132686084142394, seed_num = 32
# 정확도 :0.7255663430420712, seed_num = 33
# 정확도 :0.7313915857605178, seed_num = 34
# 정확도 :0.7113268608414239, seed_num = 35
# 정확도 :0.7177993527508091, seed_num = 36
# 정확도 :0.7411003236245954, seed_num = 37
# 정확도 :0.7268608414239482, seed_num = 38
# 정확도 :0.7216828478964401, seed_num = 39
# 정확도 :0.7262135922330097, seed_num = 40
# 정확도 :0.7223300970873786, seed_num = 41
# 정확도 :0.7119741100323624, seed_num = 42
# 정확도 :0.7262135922330097, seed_num = 43
# 정확도 :0.6970873786407767, seed_num = 44
# 정확도 :0.7152103559870551, seed_num = 45
# 정확도 :0.7229773462783171, seed_num = 46
# 정확도 :0.7268608414239482, seed_num = 47
# 정확도 :0.7378640776699029, seed_num = 48
# 정확도 :0.7074433656957929, seed_num = 49

# %%
# seed = 42의 정확도 df 만들고 평균 확인 => 72.0
df_42 = pd.DataFrame.from_dict(dic_42, orient='index')
df_42.mean()
# Out:
# 0    0.720673
# dtype: float64

# %% [markdown]
# # Method 2 : 상위 10개 feature
# - 절대값 취하고 절대값 기준으로 내림차순 후 상위 10개 뽑기

# %%
m2['abs'] = abs(m2['diff2'])
m2 = m2.sort_values(by='abs', ascending=False)
m2_top10 = m2['feature'].values[:10]
m2_top10
# Out:
# array([  409606211,    74606211,    67434504,    54817525, 10019055302,
#           54858516,    74706811,    45006701,      228125, 63323016501])

# %% [markdown]
# ## (60.9) RF

# %%
# m2_top10만을 가진 x_(7727,10)_m2 만들기
item_list = list(total_data['ITEMID'].sort_values().unique())

m2_top10_index = []
for i in m2_top10:
    m2_top10_index.append(item_list.index(i))

print('m2_top10의 index : ',m2_top10_index)

x = np.load('x_(7727,4068).npy')
x_2d = x[:,m2_top10_index]
x_2d.shape

# np.save('x_(7727,10)_m2.npy',x_2d)
# Out:
# m2_top10의 index :  [2195, 1276, 1081, 982, 2744, 1011, 1306, 845, 392, 3820]
# (7727, 10)

# %%
import random
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

model = RandomForestClassifier()

data={}
for seed in range(42, 52):
    random.seed(seed)
    
    x = np.load('./x_(7727,10)_m2.npy')
    y = np.load('./y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_train, y_train = x[idx[:i],:], y[idx[:i]]
    X_test, y_test = x[idx[i:],:], y[idx[i:]]
    
    _ = model.fit(X_train, y_train)
    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)
    
    acc = accuracy_score(y_test, y_pred_test)
    data[seed]=acc
    print(f'정확도 : {acc}, seed_num = {seed}')

df = pd.DataFrame.from_dict(data, orient='index')
print(f'정확도 df 만들고 평균 확인 : {df.mean().values}')
# Out:
# 정확도 : 0.6006472491909385, seed_num = 42
# 정확도 : 0.5844660194174758, seed_num = 43
# 정확도 : 0.594822006472492, seed_num = 44
# 정확도 : 0.6148867313915858, seed_num = 45
# 정확도 : 0.6116504854368932, seed_num = 46
# 정확도 : 0.626537216828479, seed_num = 47
# 정확도 : 0.627831715210356, seed_num = 48
# 정확도 : 0.5980582524271845, seed_num = 49
# 정확도 : 0.625242718446602, seed_num = 50
# 정확도 : 0.6122977346278318, seed_num = 51
# 정확도 df 만들고 평균 확인 : [0.60964401]

# %% [markdown]
# ## (60.8) LSTM

# %%
# m2_top10만을 가진 x_(7727,10,10)_m2 만들기
item_list = list(total_data['ITEMID'].sort_values().unique())

m2_top10_index = []
for i in m2_top10:
    m2_top10_index.append(item_list.index(i))

print('m2_top10의 index : ',m2_top10_index)

x = np.load('x_(7727,10,4068).npy')
x_3d = x[:,:,m2_top10_index]
x_3d.shape
x_3d.sum()

# np.save('x_(7727,10,10)_m2.npy',x_3d)
# Out:
# m2_top10의 index :  [2195, 1276, 1081, 982, 2744, 1011, 1306, 845, 392, 3820]
# (7727, 10, 10)
# 5833.0

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings(action='ignore')

import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, InputLayer
from tensorflow.keras.callbacks import EarlyStopping
from sklearn import metrics 
from tensorflow import keras
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

import random
# ----------------------
seed_num = 42
# ----------------------
random.seed(seed_num)

x = np.load('x_(7727,10,10)_m2.npy')
y = np.load('y_(7727,1).npy')

idx = list(range(len(x)))
random.shuffle(idx)

i = round(x.shape[0]*0.8)
X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
X_test, y_test = x[idx[i:],:,:], y[idx[i:]]

# ---------------------
seed_num = 42 
# ---------------------
tf.random.set_seed(seed_num)

lstm = Sequential()
lstm.add(InputLayer(input_shape=(X_train.shape[1],X_train.shape[2])))
lstm.add(LSTM(units=128, activation='hard_sigmoid', return_sequences=True))
lstm.add(LSTM(units=64, activation='hard_sigmoid', return_sequences=True))
lstm.add(Dropout(0.2))
lstm.add(LSTM(units=64, activation='hard_sigmoid', return_sequences=True))
lstm.add(LSTM(units=32, activation='hard_sigmoid', return_sequences=False))
lstm.add(Dropout(0.2))
lstm.add(Dense(units=1, activation='sigmoid'))

from tensorflow.keras.callbacks import ModelCheckpoint
import os

MODEL_SAVE_FOLDER_PATH = './model/'
if not os.path.exists(MODEL_SAVE_FOLDER_PATH):
    os.mkdir(MODEL_SAVE_FOLDER_PATH)

model_path = MODEL_SAVE_FOLDER_PATH + 'm2_top10_seed42-{epoch:02d}-{val_loss:.4f}.hdf5'

cb_checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss',
                                verbose=1, save_best_only=True)

early_stop = EarlyStopping(monitor='val_acc', patience=50, verbose=1, restore_best_weights=True)
lstm.compile(optimizer= keras.optimizers.Adam(learning_rate = 0.001), loss = "binary_crossentropy", metrics=['acc'])
lstm.fit(X_train, y_train, validation_split=0.25, batch_size=128, epochs=500,  callbacks=[early_stop,cb_checkpoint], shuffle=False)
# Out:
# Epoch 1/500
# 37/37 [==============================] - 4s 47ms/step - loss: 0.6759 - acc: 0.5984 - val_loss: 0.6660 - val_acc: 0.6177
#
# Epoch 00001: val_loss improved from inf to 0.66603, saving model to ./model/m2_top10_seed42-01-0.6660.hdf5
# Epoch 2/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6732 - acc: 0.6066 - val_loss: 0.6662 - val_acc: 0.6177
#
# Epoch 00002: val_loss did not improve from 0.66603
# Epoch 3/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6740 - acc: 0.6083 - val_loss: 0.6655 - val_acc: 0.6177
#
# Epoch 00003: val_loss improved from 0.66603 to 0.66551, saving model to ./model/m2_top10_seed42-03-0.6655.hdf5
# Epoch 4/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6711 - acc: 0.6100 - val_loss: 0.6653 - val_acc: 0.6177
#
# Epoch 00004: val_loss improved from 0.66551 to 0.66526, saving model to ./model/m2_top10_seed42-04-0.6653.hdf5
# Epoch 5/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6706 - acc: 0.6091 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00005: val_loss improved from 0.66526 to 0.66517, saving model to ./model/m2_top10_seed42-05-0.6652.hdf5
# Epoch 6/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6721 - acc: 0.6113 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00006: val_loss improved from 0.66517 to 0.66515, saving model to ./model/m2_top10_seed42-06-0.6652.hdf5
# Epoch 7/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6710 - acc: 0.6111 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00007: val_loss did not improve from 0.66515
# Epoch 8/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6715 - acc: 0.6111 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00008: val_loss did not improve from 0.66515
# Epoch 9/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6702 - acc: 0.6113 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00009: val_loss did not improve from 0.66515
# Epoch 10/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6700 - acc: 0.6115 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00010: val_loss did not improve from 0.66515
# Epoch 11/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6698 - acc: 0.6115 - val_loss: 0.6651 - val_acc: 0.6177
#
# Epoch 00011: val_loss improved from 0.66515 to 0.66515, saving model to ./model/m2_top10_seed42-11-0.6651.hdf5
# Epoch 12/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6694 - acc: 0.6115 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00012: val_loss did not improve from 0.66515
# Epoch 13/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6698 - acc: 0.6117 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00013: val_loss did not improve from 0.66515
# Epoch 14/500
# 37/37 [==============================] - 1s 38ms/step - loss: 0.6694 - acc: 0.6115 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00014: val_loss did not improve from 0.66515
# Epoch 15/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6691 - acc: 0.6115 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00015: val_loss did not improve from 0.66515
# Epoch 16/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6701 - acc: 0.6115 - val_loss: 0.6651 - val_acc: 0.6177
#
# Epoch 00016: val_loss improved from 0.66515 to 0.66509, saving model to ./model/m2_top10_seed42-16-0.6651.hdf5
# Epoch 17/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6706 - acc: 0.6115 - val_loss: 0.6650 - val_acc: 0.6177
#
# Epoch 00017: val_loss improved from 0.66509 to 0.66505, saving model to ./model/m2_top10_seed42-17-0.6650.hdf5
# Epoch 18/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6687 - acc: 0.6115 - val_loss: 0.6648 - val_acc: 0.6177
#
# Epoch 00018: val_loss improved from 0.66505 to 0.66482, saving model to ./model/m2_top10_seed42-18-0.6648.hdf5
# Epoch 19/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6689 - acc: 0.6115 - val_loss: 0.6647 - val_acc: 0.6177
#
# Epoch 00019: val_loss improved from 0.66482 to 0.66468, saving model to ./model/m2_top10_seed42-19-0.6647.hdf5
# Epoch 20/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6687 - acc: 0.6115 - val_loss: 0.6639 - val_acc: 0.6177
#
# Epoch 00020: val_loss improved from 0.66468 to 0.66395, saving model to ./model/m2_top10_seed42-20-0.6639.hdf5
# Epoch 21/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6643 - acc: 0.6115 - val_loss: 0.6579 - val_acc: 0.6177
#
# Epoch 00021: val_loss improved from 0.66395 to 0.65786, saving model to ./model/m2_top10_seed42-21-0.6579.hdf5
# Epoch 22/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6529 - acc: 0.6115 - val_loss: 0.6412 - val_acc: 0.6177
#
# Epoch 00022: val_loss improved from 0.65786 to 0.64125, saving model to ./model/m2_top10_seed42-22-0.6412.hdf5
# Epoch 23/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6346 - acc: 0.6091 - val_loss: 0.6316 - val_acc: 0.6177
#
# Epoch 00023: val_loss improved from 0.64125 to 0.63157, saving model to ./model/m2_top10_seed42-23-0.6316.hdf5
# Epoch 24/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6259 - acc: 0.6087 - val_loss: 0.6286 - val_acc: 0.6177
#
# Epoch 00024: val_loss improved from 0.63157 to 0.62862, saving model to ./model/m2_top10_seed42-24-0.6286.hdf5
# Epoch 25/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6240 - acc: 0.6068 - val_loss: 0.6310 - val_acc: 0.6177
#
# Epoch 00025: val_loss did not improve from 0.62862
# Epoch 26/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6231 - acc: 0.6076 - val_loss: 0.6268 - val_acc: 0.6177
#
# Epoch 00026: val_loss improved from 0.62862 to 0.62678, saving model to ./model/m2_top10_seed42-26-0.6268.hdf5
# Epoch 27/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6204 - acc: 0.6119 - val_loss: 0.6263 - val_acc: 0.6177
#
# Epoch 00027: val_loss improved from 0.62678 to 0.62633, saving model to ./model/m2_top10_seed42-27-0.6263.hdf5
# Epoch 28/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6205 - acc: 0.6100 - val_loss: 0.6260 - val_acc: 0.6177
#
# Epoch 00028: val_loss improved from 0.62633 to 0.62596, saving model to ./model/m2_top10_seed42-28-0.6260.hdf5
# Epoch 29/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6222 - acc: 0.6102 - val_loss: 0.6253 - val_acc: 0.6177
#
# Epoch 00029: val_loss improved from 0.62596 to 0.62535, saving model to ./model/m2_top10_seed42-29-0.6253.hdf5
# Epoch 30/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6194 - acc: 0.6096 - val_loss: 0.6253 - val_acc: 0.6177
#
# Epoch 00030: val_loss improved from 0.62535 to 0.62534, saving model to ./model/m2_top10_seed42-30-0.6253.hdf5
# Epoch 31/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6185 - acc: 0.6104 - val_loss: 0.6251 - val_acc: 0.6177
#
# Epoch 00031: val_loss improved from 0.62534 to 0.62508, saving model to ./model/m2_top10_seed42-31-0.6251.hdf5
# Epoch 32/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6193 - acc: 0.6096 - val_loss: 0.6247 - val_acc: 0.6177
#
# Epoch 00032: val_loss improved from 0.62508 to 0.62466, saving model to ./model/m2_top10_seed42-32-0.6247.hdf5
# Epoch 33/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6177 - acc: 0.6126 - val_loss: 0.6245 - val_acc: 0.6177
#
# Epoch 00033: val_loss improved from 0.62466 to 0.62455, saving model to ./model/m2_top10_seed42-33-0.6245.hdf5
# Epoch 34/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6174 - acc: 0.6111 - val_loss: 0.6246 - val_acc: 0.6177
#
# Epoch 00034: val_loss did not improve from 0.62455
# Epoch 35/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6163 - acc: 0.6115 - val_loss: 0.6241 - val_acc: 0.6177
#
# Epoch 00035: val_loss improved from 0.62455 to 0.62408, saving model to ./model/m2_top10_seed42-35-0.6241.hdf5
# Epoch 36/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6179 - acc: 0.6119 - val_loss: 0.6240 - val_acc: 0.6177
#
# Epoch 00036: val_loss improved from 0.62408 to 0.62398, saving model to ./model/m2_top10_seed42-36-0.6240.hdf5
# Epoch 37/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6163 - acc: 0.6109 - val_loss: 0.6240 - val_acc: 0.6177
#
# Epoch 00037: val_loss did not improve from 0.62398
# Epoch 38/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6165 - acc: 0.6113 - val_loss: 0.6238 - val_acc: 0.6177
#
# Epoch 00038: val_loss improved from 0.62398 to 0.62382, saving model to ./model/m2_top10_seed42-38-0.6238.hdf5
# Epoch 39/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6154 - acc: 0.6119 - val_loss: 0.6235 - val_acc: 0.6177
#
# Epoch 00039: val_loss improved from 0.62382 to 0.62352, saving model to ./model/m2_top10_seed42-39-0.6235.hdf5
# Epoch 40/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6156 - acc: 0.6113 - val_loss: 0.6239 - val_acc: 0.6177
#
# Epoch 00040: val_loss did not improve from 0.62352
# Epoch 41/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6159 - acc: 0.6111 - val_loss: 0.6237 - val_acc: 0.6177
#
# Epoch 00041: val_loss did not improve from 0.62352
# Epoch 42/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6133 - acc: 0.6115 - val_loss: 0.6237 - val_acc: 0.6177
#
# Epoch 00042: val_loss did not improve from 0.62352
# Epoch 43/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6164 - acc: 0.6113 - val_loss: 0.6235 - val_acc: 0.6177
#
# Epoch 00043: val_loss did not improve from 0.62352
# Epoch 44/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6150 - acc: 0.6117 - val_loss: 0.6234 - val_acc: 0.6177
#
# Epoch 00044: val_loss improved from 0.62352 to 0.62337, saving model to ./model/m2_top10_seed42-44-0.6234.hdf5
# Epoch 45/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6137 - acc: 0.6115 - val_loss: 0.6228 - val_acc: 0.6177
#
# Epoch 00045: val_loss improved from 0.62337 to 0.62285, saving model to ./model/m2_top10_seed42-45-0.6228.hdf5
# Epoch 46/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6155 - acc: 0.6115 - val_loss: 0.6226 - val_acc: 0.6177
#
# Epoch 00046: val_loss improved from 0.62285 to 0.62259, saving model to ./model/m2_top10_seed42-46-0.6226.hdf5
# Epoch 47/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6134 - acc: 0.6115 - val_loss: 0.6232 - val_acc: 0.6177
#
# Epoch 00047: val_loss did not improve from 0.62259
# Epoch 48/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6144 - acc: 0.6117 - val_loss: 0.6233 - val_acc: 0.6177
#
# Epoch 00048: val_loss did not improve from 0.62259
# Epoch 49/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6132 - acc: 0.6113 - val_loss: 0.6242 - val_acc: 0.6177
#
# Epoch 00049: val_loss did not improve from 0.62259
# Epoch 50/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6153 - acc: 0.6115 - val_loss: 0.6229 - val_acc: 0.6177
#
# Epoch 00050: val_loss did not improve from 0.62259
# Epoch 51/500
# 37/37 [==============================] - 1s 37ms/step - loss: 0.6129 - acc: 0.6117 - val_loss: 0.6228 - val_acc: 0.6177
# Restoring model weights from the end of the best epoch.
#
# Epoch 00051: val_loss did not improve from 0.62259
# Epoch 00051: early stopping

# %%
from keras.models import load_model
best_model = load_model('./model/m2_top10_seed42-46-0.6226.hdf5') 

dic_42={}
for seed in range(0, 50):
    random.seed(seed)

    x = np.load('x_(7727,10,10)_m2.npy')
    y = np.load('y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
    X_test, y_test = x[idx[i:],:,:], y[idx[i:]]
    
    pred = best_model.predict(X_test)
    pred[pred>0.5]=1
    pred[pred<=0.5]=0
    acc = metrics.accuracy_score(y_test, pred)
    dic_42[seed]=acc
    print(f'정확도 :{metrics.accuracy_score(y_test, pred)}, seed_num = {seed}')
# Out:
# 정확도 :0.6045307443365696, seed_num = 0
# 정확도 :0.6051779935275081, seed_num = 1
# 정확도 :0.6110032362459547, seed_num = 2
# 정확도 :0.602588996763754, seed_num = 3
# 정확도 :0.6097087378640776, seed_num = 4
# 정확도 :0.6110032362459547, seed_num = 5
# 정확도 :0.6110032362459547, seed_num = 6
# 정확도 :0.5928802588996763, seed_num = 7
# 정확도 :0.6226537216828479, seed_num = 8
# 정확도 :0.6129449838187703, seed_num = 9
# 정확도 :0.5909385113268608, seed_num = 10
# 정확도 :0.6297734627831715, seed_num = 11
# 정확도 :0.601294498381877, seed_num = 12
# 정확도 :0.598705501618123, seed_num = 13
# 정확도 :0.6071197411003236, seed_num = 14
# 정확도 :0.6135922330097088, seed_num = 15
# 정확도 :0.6330097087378641, seed_num = 16
# 정확도 :0.598705501618123, seed_num = 17
# 정확도 :0.6045307443365696, seed_num = 18
# 정확도 :0.596116504854369, seed_num = 19
# 정확도 :0.6187702265372168, seed_num = 20
# 정확도 :0.6135922330097088, seed_num = 21
# 정확도 :0.6, seed_num = 22
# 정확도 :0.6032362459546926, seed_num = 23
# 정확도 :0.6032362459546926, seed_num = 24
# 정확도 :0.6071197411003236, seed_num = 25
# 정확도 :0.5954692556634305, seed_num = 26
# 정확도 :0.6110032362459547, seed_num = 27
# 정확도 :0.6045307443365696, seed_num = 28
# 정확도 :0.6064724919093851, seed_num = 29
# 정확도 :0.6110032362459547, seed_num = 30
# 정확도 :0.6077669902912621, seed_num = 31
# 정확도 :0.6187702265372168, seed_num = 32
# 정확도 :0.6038834951456311, seed_num = 33
# 정확도 :0.6161812297734628, seed_num = 34
# 정확도 :0.6226537216828479, seed_num = 35
# 정확도 :0.6038834951456311, seed_num = 36
# 정확도 :0.6194174757281553, seed_num = 37
# 정확도 :0.601294498381877, seed_num = 38
# 정확도 :0.629126213592233, seed_num = 39
# 정확도 :0.6, seed_num = 40
# 정확도 :0.5993527508090615, seed_num = 41
# 정확도 :0.6006472491909385, seed_num = 42
# 정확도 :0.5844660194174758, seed_num = 43
# 정확도 :0.594822006472492, seed_num = 44
# 정확도 :0.6148867313915858, seed_num = 45
# 정확도 :0.6122977346278318, seed_num = 46
# 정확도 :0.626537216828479, seed_num = 47
# 정확도 :0.6284789644012945, seed_num = 48
# 정확도 :0.598705501618123, seed_num = 49

# %%
# seed = 42의 정확도 df 만들고 평균 확인 => 60.8
df_42 = pd.DataFrame.from_dict(dic_42, orient='index')
df_42.mean()
# Out:
# 0    0.608298
# dtype: float64

# %% [markdown]
# # Method 1 - LSTM all fit
# - 절대값 취하고 절대값 기준으로 내림차순 후 상위 10개 뽑기

# %%
m1_all = pd.read_csv('method1_df_allfit.csv')
m1_all['abs'] = abs(m1_all['mul'])
m1_all = m1_all.sort_values(by='abs', ascending=False)
m1_top10 = m1_all['feature'].values[:10]
m1_top10
# Out:
# array([  409606211,      227194,     4003822,       50889,   182138167,
#           74606211,       51200, 25021011210, 63323016101, 63323038810])

# %% [markdown]
# ## (65.7) RF

# %%
# m1_top10만을 가진 x_(7727,10)_m1_allfit 만들기
total_data = pd.read_csv('total_data_7727.csv')
item_list = list(total_data['ITEMID'].sort_values().unique())

m1_top10_index = []
for i in m1_top10:
    m1_top10_index.append(item_list.index(i))

print('m1_top10의 index : ',m1_top10_index)

x = np.load('x_(7727,4068).npy')
x_2d = x[:,m1_top10_index]
x_2d.shape

# np.save('x_(7727,10)_m1_allfit.npy',x_2d)
# Out:
# m1_top10의 index :  [2195, 383, 469, 37, 1815, 1276, 162, 2860, 3818, 3852]
# (7727, 10)

# %%
import random
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

model = RandomForestClassifier()

data={}
for seed in range(42, 52):
    random.seed(seed)
    
    x = np.load('./x_(7727,10)_m1_allfit.npy')
    y = np.load('./y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_train, y_train = x[idx[:i],:], y[idx[:i]]
    X_test, y_test = x[idx[i:],:], y[idx[i:]]
    
    _ = model.fit(X_train, y_train)
    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)
    
    acc = accuracy_score(y_test, y_pred_test)
    data[seed]=acc
    print(f'정확도 : {acc}, seed_num = {seed}')

df = pd.DataFrame.from_dict(data, orient='index')
print(f'정확도 df 만들고 평균 확인 : {df.mean().values}')
# Out:
# 정확도 : 0.6407766990291263, seed_num = 42
# 정확도 : 0.6498381877022654, seed_num = 43
# 정확도 : 0.6472491909385113, seed_num = 44
# 정확도 : 0.6627831715210356, seed_num = 45
# 정확도 : 0.6524271844660194, seed_num = 46
# 정확도 : 0.6634304207119741, seed_num = 47
# 정확도 : 0.6750809061488673, seed_num = 48
# 정확도 : 0.6576051779935275, seed_num = 49
# 정확도 : 0.6731391585760518, seed_num = 50
# 정확도 : 0.6537216828478964, seed_num = 51
# 정확도 df 만들고 평균 확인 : [0.65760518]

# %% [markdown]
# ## (65.4) LSTM

# %%
# m1_top10만을 가진 x_(7727,10,10)_m1_allfit 만들기
item_list = list(total_data['ITEMID'].sort_values().unique())

m1_top10_index = []
for i in m1_top10:
    m1_top10_index.append(item_list.index(i))

print('m1_top10의 index : ',m1_top10_index)

x = np.load('x_(7727,10,4068).npy')
x_3d = x[:,:,m1_top10_index]
x_3d.shape
x_3d.sum()

np.save('x_(7727,10,10)_m1_allfit.npy',x_3d)
# Out:
# m1_top10의 index :  [2195, 383, 469, 37, 1815, 1276, 162, 2860, 3818, 3852]
# (7727, 10, 10)
# 4419.0

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings(action='ignore')

import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, InputLayer
from tensorflow.keras.callbacks import EarlyStopping
from sklearn import metrics 
from tensorflow import keras
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

import random
# ----------------------
seed_num = 42
# ----------------------
random.seed(seed_num)

x = np.load('x_(7727,10,10)_m1_allfit.npy')
y = np.load('y_(7727,1).npy')

idx = list(range(len(x)))
random.shuffle(idx)

i = round(x.shape[0]*0.8)
X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
X_test, y_test = x[idx[i:],:,:], y[idx[i:]]

# ---------------------
seed_num = 42 
# ---------------------
tf.random.set_seed(seed_num)

lstm = Sequential()
lstm.add(InputLayer(input_shape=(X_train.shape[1],X_train.shape[2])))
lstm.add(LSTM(units=128, activation='hard_sigmoid', return_sequences=True))
lstm.add(LSTM(units=64, activation='hard_sigmoid', return_sequences=True))
lstm.add(Dropout(0.2))
lstm.add(LSTM(units=64, activation='hard_sigmoid', return_sequences=True))
lstm.add(LSTM(units=32, activation='hard_sigmoid', return_sequences=False))
lstm.add(Dropout(0.2))
lstm.add(Dense(units=1, activation='sigmoid'))

from tensorflow.keras.callbacks import ModelCheckpoint
import os

MODEL_SAVE_FOLDER_PATH = './model/'
if not os.path.exists(MODEL_SAVE_FOLDER_PATH):
    os.mkdir(MODEL_SAVE_FOLDER_PATH)

model_path = MODEL_SAVE_FOLDER_PATH + 'm1_top10_allfit_seed42-{epoch:02d}-{val_loss:.4f}.hdf5'

cb_checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss',
                                verbose=1, save_best_only=True)

early_stop = EarlyStopping(monitor='val_acc', patience=50, verbose=1, restore_best_weights=True)
lstm.compile(optimizer= keras.optimizers.Adam(learning_rate = 0.001), loss = "binary_crossentropy", metrics=['acc'])
lstm.fit(X_train, y_train, validation_split=0.25, batch_size=128, epochs=500,  callbacks=[early_stop,cb_checkpoint], shuffle=False)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/500
# 37/37 [==============================] - 6s 73ms/step - loss: 0.6759 - acc: 0.5984 - val_loss: 0.6660 - val_acc: 0.6177
#
# Epoch 00001: val_loss improved from inf to 0.66603, saving model to ./model/m1_top10_allfit_seed42-01-0.6660.hdf5
# Epoch 2/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6732 - acc: 0.6068 - val_loss: 0.6662 - val_acc: 0.6177
#
# Epoch 00002: val_loss did not improve from 0.66603
# Epoch 3/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6740 - acc: 0.6083 - val_loss: 0.6655 - val_acc: 0.6177
#
# Epoch 00003: val_loss improved from 0.66603 to 0.66552, saving model to ./model/m1_top10_allfit_seed42-03-0.6655.hdf5
# Epoch 4/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.6711 - acc: 0.6100 - val_loss: 0.6653 - val_acc: 0.6177
#
# Epoch 00004: val_loss improved from 0.66552 to 0.66527, saving model to ./model/m1_top10_allfit_seed42-04-0.6653.hdf5
# Epoch 5/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6706 - acc: 0.6089 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00005: val_loss improved from 0.66527 to 0.66517, saving model to ./model/m1_top10_allfit_seed42-05-0.6652.hdf5
# Epoch 6/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6721 - acc: 0.6111 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00006: val_loss improved from 0.66517 to 0.66516, saving model to ./model/m1_top10_allfit_seed42-06-0.6652.hdf5
# Epoch 7/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6710 - acc: 0.6111 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00007: val_loss did not improve from 0.66516
# Epoch 8/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6715 - acc: 0.6111 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00008: val_loss did not improve from 0.66516
# Epoch 9/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6702 - acc: 0.6113 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00009: val_loss did not improve from 0.66516
# Epoch 10/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6700 - acc: 0.6115 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00010: val_loss did not improve from 0.66516
# Epoch 11/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6698 - acc: 0.6115 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00011: val_loss did not improve from 0.66516
# Epoch 12/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6694 - acc: 0.6115 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00012: val_loss did not improve from 0.66516
# Epoch 13/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6698 - acc: 0.6117 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00013: val_loss did not improve from 0.66516
# Epoch 14/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6694 - acc: 0.6115 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00014: val_loss did not improve from 0.66516
# Epoch 15/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6691 - acc: 0.6115 - val_loss: 0.6653 - val_acc: 0.6177
#
# Epoch 00015: val_loss did not improve from 0.66516
# Epoch 16/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6702 - acc: 0.6115 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00016: val_loss did not improve from 0.66516
# Epoch 17/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6707 - acc: 0.6115 - val_loss: 0.6653 - val_acc: 0.6177
#
# Epoch 00017: val_loss did not improve from 0.66516
# Epoch 18/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6689 - acc: 0.6115 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00018: val_loss did not improve from 0.66516
# Epoch 19/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6695 - acc: 0.6115 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00019: val_loss did not improve from 0.66516
# Epoch 20/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6698 - acc: 0.6115 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00020: val_loss did not improve from 0.66516
# Epoch 21/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6688 - acc: 0.6115 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00021: val_loss did not improve from 0.66516
# Epoch 22/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6688 - acc: 0.6115 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00022: val_loss did not improve from 0.66516
# Epoch 23/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.6701 - acc: 0.6115 - val_loss: 0.6653 - val_acc: 0.6177
#
# Epoch 00023: val_loss did not improve from 0.66516
# Epoch 24/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6695 - acc: 0.6115 - val_loss: 0.6653 - val_acc: 0.6177
#
# Epoch 00024: val_loss did not improve from 0.66516
# Epoch 25/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6694 - acc: 0.6115 - val_loss: 0.6653 - val_acc: 0.6177
#
# Epoch 00025: val_loss did not improve from 0.66516
# Epoch 26/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6692 - acc: 0.6115 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00026: val_loss did not improve from 0.66516
# Epoch 27/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6683 - acc: 0.6115 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00027: val_loss did not improve from 0.66516
# Epoch 28/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6684 - acc: 0.6115 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00028: val_loss did not improve from 0.66516
# Epoch 29/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6691 - acc: 0.6115 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00029: val_loss did not improve from 0.66516
# Epoch 30/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6685 - acc: 0.6115 - val_loss: 0.6651 - val_acc: 0.6177
#
# Epoch 00030: val_loss improved from 0.66516 to 0.66507, saving model to ./model/m1_top10_allfit_seed42-30-0.6651.hdf5
# Epoch 31/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6687 - acc: 0.6115 - val_loss: 0.6650 - val_acc: 0.6177
#
# Epoch 00031: val_loss improved from 0.66507 to 0.66503, saving model to ./model/m1_top10_allfit_seed42-31-0.6650.hdf5
# Epoch 32/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6695 - acc: 0.6115 - val_loss: 0.6650 - val_acc: 0.6177
#
# Epoch 00032: val_loss improved from 0.66503 to 0.66500, saving model to ./model/m1_top10_allfit_seed42-32-0.6650.hdf5
# Epoch 33/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6682 - acc: 0.6115 - val_loss: 0.6648 - val_acc: 0.6177
#
# Epoch 00033: val_loss improved from 0.66500 to 0.66480, saving model to ./model/m1_top10_allfit_seed42-33-0.6648.hdf5
# Epoch 34/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.6686 - acc: 0.6115 - val_loss: 0.6645 - val_acc: 0.6177
#
# Epoch 00034: val_loss improved from 0.66480 to 0.66453, saving model to ./model/m1_top10_allfit_seed42-34-0.6645.hdf5
# Epoch 35/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6675 - acc: 0.6115 - val_loss: 0.6645 - val_acc: 0.6177
#
# Epoch 00035: val_loss improved from 0.66453 to 0.66452, saving model to ./model/m1_top10_allfit_seed42-35-0.6645.hdf5
# Epoch 36/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6674 - acc: 0.6115 - val_loss: 0.6638 - val_acc: 0.6177
#
# Epoch 00036: val_loss improved from 0.66452 to 0.66382, saving model to ./model/m1_top10_allfit_seed42-36-0.6638.hdf5
# Epoch 37/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6640 - acc: 0.6115 - val_loss: 0.6605 - val_acc: 0.6177
# Epoch 00037: val_loss improved from 0.66382 to 0.66052, saving model to ./model/m1_top10_allfit_seed42-37-0.6605.hdf5
# Epoch 38/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.6567 - acc: 0.6115 - val_loss: 0.6538 - val_acc: 0.6177
#
# Epoch 00038: val_loss improved from 0.66052 to 0.65376, saving model to ./model/m1_top10_allfit_seed42-38-0.6538.hdf5
# Epoch 39/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6487 - acc: 0.6115 - val_loss: 0.6420 - val_acc: 0.6177
#
# Epoch 00039: val_loss improved from 0.65376 to 0.64197, saving model to ./model/m1_top10_allfit_seed42-39-0.6420.hdf5
# Epoch 40/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6390 - acc: 0.6115 - val_loss: 0.6373 - val_acc: 0.6177
#
# Epoch 00040: val_loss improved from 0.64197 to 0.63726, saving model to ./model/m1_top10_allfit_seed42-40-0.6373.hdf5
# Epoch 41/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6363 - acc: 0.6122 - val_loss: 0.6352 - val_acc: 0.6177
#
# Epoch 00041: val_loss improved from 0.63726 to 0.63522, saving model to ./model/m1_top10_allfit_seed42-41-0.6352.hdf5
# Epoch 42/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6321 - acc: 0.6199 - val_loss: 0.6351 - val_acc: 0.6255
#
# Epoch 00042: val_loss improved from 0.63522 to 0.63506, saving model to ./model/m1_top10_allfit_seed42-42-0.6351.hdf5
# Epoch 43/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6323 - acc: 0.6301 - val_loss: 0.6339 - val_acc: 0.6255
#
# Epoch 00043: val_loss improved from 0.63506 to 0.63390, saving model to ./model/m1_top10_allfit_seed42-43-0.6339.hdf5
# Epoch 44/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6298 - acc: 0.6352 - val_loss: 0.6343 - val_acc: 0.6274
#
# Epoch 00044: val_loss did not improve from 0.63390
# Epoch 45/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6248 - acc: 0.6441 - val_loss: 0.6376 - val_acc: 0.6268
#
# Epoch 00045: val_loss did not improve from 0.63390
# Epoch 46/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6281 - acc: 0.6404 - val_loss: 0.6297 - val_acc: 0.6352
#
# Epoch 00046: val_loss improved from 0.63390 to 0.62966, saving model to ./model/m1_top10_allfit_seed42-46-0.6297.hdf5
# Epoch 47/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6204 - acc: 0.6514 - val_loss: 0.6306 - val_acc: 0.6384
#
# Epoch 00047: val_loss did not improve from 0.62966
# Epoch 48/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6192 - acc: 0.6547 - val_loss: 0.6275 - val_acc: 0.6352
#
# Epoch 00048: val_loss improved from 0.62966 to 0.62750, saving model to ./model/m1_top10_allfit_seed42-48-0.6275.hdf5
# Epoch 49/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6186 - acc: 0.6523 - val_loss: 0.6291 - val_acc: 0.6384
#
# Epoch 00049: val_loss did not improve from 0.62750
# Epoch 50/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6169 - acc: 0.6566 - val_loss: 0.6286 - val_acc: 0.6442
#
# Epoch 00050: val_loss did not improve from 0.62750
# Epoch 51/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.6137 - acc: 0.6566 - val_loss: 0.6261 - val_acc: 0.6468
#
# Epoch 00051: val_loss improved from 0.62750 to 0.62614, saving model to ./model/m1_top10_allfit_seed42-51-0.6261.hdf5
# Epoch 52/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6130 - acc: 0.6570 - val_loss: 0.6283 - val_acc: 0.6436
#
# Epoch 00052: val_loss did not improve from 0.62614
# Epoch 53/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6150 - acc: 0.6583 - val_loss: 0.6266 - val_acc: 0.6449
#
# Epoch 00053: val_loss did not improve from 0.62614
# Epoch 54/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6136 - acc: 0.6603 - val_loss: 0.6277 - val_acc: 0.6462
#
# Epoch 00054: val_loss did not improve from 0.62614
# Epoch 55/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6155 - acc: 0.6560 - val_loss: 0.6313 - val_acc: 0.6307
#
# Epoch 00055: val_loss did not improve from 0.62614
# Epoch 56/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6184 - acc: 0.6538 - val_loss: 0.6247 - val_acc: 0.6475
#
# Epoch 00056: val_loss improved from 0.62614 to 0.62469, saving model to ./model/m1_top10_allfit_seed42-56-0.6247.hdf5
# Epoch 57/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6165 - acc: 0.6544 - val_loss: 0.6252 - val_acc: 0.6481
#
# Epoch 00057: val_loss did not improve from 0.62469
# Epoch 58/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6155 - acc: 0.6590 - val_loss: 0.6232 - val_acc: 0.6468
#
# Epoch 00058: val_loss improved from 0.62469 to 0.62325, saving model to ./model/m1_top10_allfit_seed42-58-0.6232.hdf5
# Epoch 59/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6146 - acc: 0.6572 - val_loss: 0.6232 - val_acc: 0.6468
#
# Epoch 00059: val_loss improved from 0.62325 to 0.62318, saving model to ./model/m1_top10_allfit_seed42-59-0.6232.hdf5
# Epoch 60/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6120 - acc: 0.6592 - val_loss: 0.6238 - val_acc: 0.6481
#
# Epoch 00060: val_loss did not improve from 0.62318
# Epoch 61/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6152 - acc: 0.6590 - val_loss: 0.6222 - val_acc: 0.6475
#
# Epoch 00061: val_loss improved from 0.62318 to 0.62223, saving model to ./model/m1_top10_allfit_seed42-61-0.6222.hdf5
# Epoch 62/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6129 - acc: 0.6590 - val_loss: 0.6233 - val_acc: 0.6475
#
# Epoch 00062: val_loss did not improve from 0.62223
# Epoch 63/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6153 - acc: 0.6583 - val_loss: 0.6220 - val_acc: 0.6481
#
# Epoch 00063: val_loss improved from 0.62223 to 0.62202, saving model to ./model/m1_top10_allfit_seed42-63-0.6220.hdf5
# Epoch 64/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6119 - acc: 0.6596 - val_loss: 0.6223 - val_acc: 0.6501
#
# Epoch 00064: val_loss did not improve from 0.62202
# Epoch 65/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6119 - acc: 0.6601 - val_loss: 0.6222 - val_acc: 0.6507
#
# Epoch 00065: val_loss did not improve from 0.62202
# Epoch 66/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.6097 - acc: 0.6622 - val_loss: 0.6227 - val_acc: 0.6514
#
# Epoch 00066: val_loss did not improve from 0.62202
# Epoch 67/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6115 - acc: 0.6603 - val_loss: 0.6225 - val_acc: 0.6501
#
# Epoch 00067: val_loss did not improve from 0.62202
# Epoch 68/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6116 - acc: 0.6583 - val_loss: 0.6220 - val_acc: 0.6552
#
# Epoch 00068: val_loss improved from 0.62202 to 0.62197, saving model to ./model/m1_top10_allfit_seed42-68-0.6220.hdf5
# Epoch 69/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6104 - acc: 0.6620 - val_loss: 0.6219 - val_acc: 0.6539
#
# Epoch 00069: val_loss improved from 0.62197 to 0.62191, saving model to ./model/m1_top10_allfit_seed42-69-0.6219.hdf5
# Epoch 70/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6100 - acc: 0.6624 - val_loss: 0.6221 - val_acc: 0.6539
#
# Epoch 00070: val_loss did not improve from 0.62191
# Epoch 71/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.6092 - acc: 0.6616 - val_loss: 0.6221 - val_acc: 0.6552
#
# Epoch 00071: val_loss did not improve from 0.62191
# Epoch 72/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6112 - acc: 0.6642 - val_loss: 0.6215 - val_acc: 0.6546
#
# Epoch 00072: val_loss improved from 0.62191 to 0.62155, saving model to ./model/m1_top10_allfit_seed42-72-0.6215.hdf5
# Epoch 73/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6105 - acc: 0.6620 - val_loss: 0.6217 - val_acc: 0.6552
#
# Epoch 00073: val_loss did not improve from 0.62155
# Epoch 74/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6100 - acc: 0.6616 - val_loss: 0.6218 - val_acc: 0.6552
#
# Epoch 00074: val_loss did not improve from 0.62155
# Epoch 75/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6101 - acc: 0.6639 - val_loss: 0.6220 - val_acc: 0.6539
#
# Epoch 00075: val_loss did not improve from 0.62155
# Epoch 76/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.6113 - acc: 0.6635 - val_loss: 0.6213 - val_acc: 0.6552
#
# Epoch 00076: val_loss improved from 0.62155 to 0.62132, saving model to ./model/m1_top10_allfit_seed42-76-0.6213.hdf5
# Epoch 77/500
# 37/37 [==============================] - 2s 66ms/step - loss: 0.6101 - acc: 0.6611 - val_loss: 0.6214 - val_acc: 0.6546
#
# Epoch 00077: val_loss did not improve from 0.62132
# Epoch 78/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6098 - acc: 0.6609 - val_loss: 0.6220 - val_acc: 0.6546
#
# Epoch 00078: val_loss did not improve from 0.62132
# Epoch 79/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6082 - acc: 0.6646 - val_loss: 0.6221 - val_acc: 0.6552
#
# Epoch 00079: val_loss did not improve from 0.62132
# Epoch 80/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6107 - acc: 0.6629 - val_loss: 0.6216 - val_acc: 0.6546
#
# Epoch 00080: val_loss did not improve from 0.62132
# Epoch 81/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6093 - acc: 0.6613 - val_loss: 0.6218 - val_acc: 0.6546
#
# Epoch 00081: val_loss did not improve from 0.62132
# Epoch 82/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6082 - acc: 0.6624 - val_loss: 0.6223 - val_acc: 0.6546
#
# Epoch 00082: val_loss did not improve from 0.62132
# Epoch 83/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6083 - acc: 0.6616 - val_loss: 0.6225 - val_acc: 0.6552
#
# Epoch 00083: val_loss did not improve from 0.62132
# Epoch 84/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6096 - acc: 0.6624 - val_loss: 0.6215 - val_acc: 0.6552
#
# Epoch 00084: val_loss did not improve from 0.62132
# Epoch 85/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6099 - acc: 0.6631 - val_loss: 0.6222 - val_acc: 0.6539
#
# Epoch 00085: val_loss did not improve from 0.62132
# Epoch 86/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6085 - acc: 0.6624 - val_loss: 0.6221 - val_acc: 0.6539
#
# Epoch 00086: val_loss did not improve from 0.62132
# Epoch 87/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6093 - acc: 0.6622 - val_loss: 0.6218 - val_acc: 0.6546
#
# Epoch 00087: val_loss did not improve from 0.62132
# Epoch 88/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6092 - acc: 0.6629 - val_loss: 0.6221 - val_acc: 0.6546
#
# Epoch 00088: val_loss did not improve from 0.62132
# Epoch 89/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6084 - acc: 0.6637 - val_loss: 0.6220 - val_acc: 0.6539
#
# Epoch 00089: val_loss did not improve from 0.62132
# Epoch 90/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6095 - acc: 0.6639 - val_loss: 0.6217 - val_acc: 0.6546
#
# Epoch 00090: val_loss did not improve from 0.62132
# Epoch 91/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6080 - acc: 0.6629 - val_loss: 0.6223 - val_acc: 0.6539
#
# Epoch 00091: val_loss did not improve from 0.62132
# Epoch 92/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6083 - acc: 0.6620 - val_loss: 0.6218 - val_acc: 0.6539
#
# Epoch 00092: val_loss did not improve from 0.62132
# Epoch 93/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6098 - acc: 0.6635 - val_loss: 0.6212 - val_acc: 0.6539
#
# Epoch 00093: val_loss improved from 0.62132 to 0.62121, saving model to ./model/m1_top10_allfit_seed42-93-0.6212.hdf5
# Epoch 94/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6092 - acc: 0.6644 - val_loss: 0.6243 - val_acc: 0.6546
#
# Epoch 00094: val_loss did not improve from 0.62121
# Epoch 95/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6109 - acc: 0.6642 - val_loss: 0.6213 - val_acc: 0.6546
#
# Epoch 00095: val_loss did not improve from 0.62121
# Epoch 96/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6088 - acc: 0.6631 - val_loss: 0.6220 - val_acc: 0.6546
#
# Epoch 00096: val_loss did not improve from 0.62121
# Epoch 97/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6072 - acc: 0.6631 - val_loss: 0.6223 - val_acc: 0.6520
#
# Epoch 00097: val_loss did not improve from 0.62121
# Epoch 98/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6083 - acc: 0.6620 - val_loss: 0.6227 - val_acc: 0.6546
#
# Epoch 00098: val_loss did not improve from 0.62121
# Epoch 99/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6087 - acc: 0.6633 - val_loss: 0.6216 - val_acc: 0.6539
#
# Epoch 00099: val_loss did not improve from 0.62121
# Epoch 100/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6084 - acc: 0.6622 - val_loss: 0.6228 - val_acc: 0.6539
#
# Epoch 00100: val_loss did not improve from 0.62121
# Epoch 101/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6091 - acc: 0.6637 - val_loss: 0.6221 - val_acc: 0.6539
#
# Epoch 00101: val_loss did not improve from 0.62121
# Epoch 102/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6089 - acc: 0.6635 - val_loss: 0.6224 - val_acc: 0.6546
#
# Epoch 00102: val_loss did not improve from 0.62121
# Epoch 103/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6078 - acc: 0.6631 - val_loss: 0.6223 - val_acc: 0.6546
#
# Epoch 00103: val_loss did not improve from 0.62121
# Epoch 104/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6085 - acc: 0.6629 - val_loss: 0.6224 - val_acc: 0.6546
#
# Epoch 00104: val_loss did not improve from 0.62121
# Epoch 105/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6072 - acc: 0.6642 - val_loss: 0.6225 - val_acc: 0.6546
#
# Epoch 00105: val_loss did not improve from 0.62121
# Epoch 106/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6082 - acc: 0.6616 - val_loss: 0.6228 - val_acc: 0.6539
#
# Epoch 00106: val_loss did not improve from 0.62121
# Epoch 107/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6086 - acc: 0.6635 - val_loss: 0.6229 - val_acc: 0.6546
#
# Epoch 00107: val_loss did not improve from 0.62121
# Epoch 108/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6077 - acc: 0.6631 - val_loss: 0.6230 - val_acc: 0.6539
#
# Epoch 00108: val_loss did not improve from 0.62121
# Epoch 109/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6074 - acc: 0.6626 - val_loss: 0.6234 - val_acc: 0.6546
#
# Epoch 00109: val_loss did not improve from 0.62121
# Epoch 110/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6087 - acc: 0.6626 - val_loss: 0.6223 - val_acc: 0.6539
#
# Epoch 00110: val_loss did not improve from 0.62121
# Epoch 111/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6081 - acc: 0.6637 - val_loss: 0.6228 - val_acc: 0.6546
#
# Epoch 00111: val_loss did not improve from 0.62121
# Epoch 112/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6072 - acc: 0.6629 - val_loss: 0.6229 - val_acc: 0.6546
#
# Epoch 00112: val_loss did not improve from 0.62121
# Epoch 113/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6076 - acc: 0.6618 - val_loss: 0.6230 - val_acc: 0.6546
#
# Epoch 00113: val_loss did not improve from 0.62121
# Epoch 114/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6081 - acc: 0.6635 - val_loss: 0.6230 - val_acc: 0.6546
#
# Epoch 00114: val_loss did not improve from 0.62121
# Epoch 115/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6085 - acc: 0.6644 - val_loss: 0.6226 - val_acc: 0.6514
#
# Epoch 00115: val_loss did not improve from 0.62121
# Epoch 116/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6079 - acc: 0.6637 - val_loss: 0.6232 - val_acc: 0.6539
#
# Epoch 00116: val_loss did not improve from 0.62121
# Epoch 117/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6081 - acc: 0.6624 - val_loss: 0.6227 - val_acc: 0.6514
#
# Epoch 00117: val_loss did not improve from 0.62121
# Epoch 118/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6063 - acc: 0.6635 - val_loss: 0.6234 - val_acc: 0.6539
# Restoring model weights from the end of the best epoch.
#
# Epoch 00118: val_loss did not improve from 0.62121
# Epoch 00118: early stopping

# %%
from keras.models import load_model
best_model = load_model('./model/m1_top10_allfit_seed42-93-0.6212.hdf5') 

dic_42={}
for seed in range(0, 50):
    random.seed(seed)

    x = np.load('x_(7727,10,10)_m1_allfit.npy')
    y = np.load('y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
    X_test, y_test = x[idx[i:],:,:], y[idx[i:]]
    
    pred = best_model.predict(X_test)
    pred[pred>0.5]=1
    pred[pred<=0.5]=0
    acc = metrics.accuracy_score(y_test, pred)
    dic_42[seed]=acc
    print(f'정확도 :{metrics.accuracy_score(y_test, pred)}, seed_num = {seed}')
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Using TensorFlow backend.
# 정확도 :0.6524271844660194, seed_num = 0
# 정확도 :0.6478964401294498, seed_num = 1
# 정확도 :0.6504854368932039, seed_num = 2
# 정확도 :0.6466019417475728, seed_num = 3
# 정확도 :0.6640776699029126, seed_num = 4
# 정확도 :0.6511326860841424, seed_num = 5
# 정확도 :0.6601941747572816, seed_num = 6
# 정확도 :0.6375404530744336, seed_num = 7
# 정확도 :0.6666666666666666, seed_num = 8
# 정확도 :0.6563106796116505, seed_num = 9
# 정확도 :0.63042071197411, seed_num = 10
# 정확도 :0.6692556634304208, seed_num = 11
# 정확도 :0.6530744336569579, seed_num = 12
# 정확도 :0.6524271844660194, seed_num = 13
# 정확도 :0.6537216828478964, seed_num = 14
# 정확도 :0.6711974110032363, seed_num = 15
# 정확도 :0.6679611650485436, seed_num = 16
# 정확도 :0.6537216828478964, seed_num = 17
# 정확도 :0.6485436893203883, seed_num = 18
# 정확도 :0.6466019417475728, seed_num = 19
# 정확도 :0.6640776699029126, seed_num = 20
# 정확도 :0.6647249190938511, seed_num = 21
# 정확도 :0.6459546925566343, seed_num = 22
# 정확도 :0.6634304207119741, seed_num = 23
# 정확도 :0.6537216828478964, seed_num = 24
# 정확도 :0.6660194174757281, seed_num = 25
# 정확도 :0.6362459546925566, seed_num = 26
# 정확도 :0.6679611650485436, seed_num = 27
# 정확도 :0.6504854368932039, seed_num = 28
# 정확도 :0.6504854368932039, seed_num = 29
# 정확도 :0.6517799352750809, seed_num = 30
# 정확도 :0.6472491909385113, seed_num = 31
# 정확도 :0.6576051779935275, seed_num = 32
# 정확도 :0.6640776699029126, seed_num = 33
# 정확도 :0.6595469255663431, seed_num = 34
# 정확도 :0.6666666666666666, seed_num = 35
# 정확도 :0.6466019417475728, seed_num = 36
# 정확도 :0.654368932038835, seed_num = 37
# 정확도 :0.6407766990291263, seed_num = 38
# 정확도 :0.6705501618122978, seed_num = 39
# 정확도 :0.6407766990291263, seed_num = 40
# 정확도 :0.6550161812297735, seed_num = 41
# 정확도 :0.6394822006472491, seed_num = 42
# 정확도 :0.6446601941747573, seed_num = 43
# 정확도 :0.6394822006472491, seed_num = 44
# 정확도 :0.6627831715210356, seed_num = 45
# 정확도 :0.6498381877022654, seed_num = 46
# 정확도 :0.6744336569579288, seed_num = 47
# 정확도 :0.6809061488673139, seed_num = 48
# 정확도 :0.6595469255663431, seed_num = 49

# %%
# seed = 42의 정확도 df 만들고 평균 확인 => 64.9
df_42 = pd.DataFrame.from_dict(dic_42, orient='index')
df_42.mean()
# Out:
# 0    0.65499
# dtype: float64

# %% [markdown]
# # M1 entropy
# - 절대값 취하고 절대값 기준으로 내림차순 후 상위 10개 뽑기

# %%
m1_entropy = pd.read_csv('m1_entropy.csv')
m1_entropy['abs'] = abs(m1_entropy['mul'])
m1_entropy = m1_entropy.sort_values(by='abs', ascending=False)
m1_entropy_top10 = m1_entropy['feature'].values[:10]
m1_entropy_top10
# Out:
# array([  409606211,    74606211,    67434504,    54817525, 10019055302,
#             227194,    54858516,    74706811,    45006701,     4003822])

# %% [markdown]
# ## (65.1) RF

# %%
# m1_entropy_top10만을 가진 x_(7727,10)_m1_entropy 만들기
item_list = list(total_data['ITEMID'].sort_values().unique())

m1_entropy_top10_index = []
for i in m1_entropy_top10:
    m1_entropy_top10_index.append(item_list.index(i))

print('m1_entropy_top10의 index : ',m1_entropy_top10_index)

x = np.load('x_(7727,4068).npy')
x_2d = x[:,m1_entropy_top10_index]
x_2d.shape

np.save('x_(7727,10)_m1_entropy.npy',x_2d)
# Out:
# m1_entropy_top10의 index :  [2195, 1276, 1081, 982, 2744, 383, 1011, 1306, 845, 469]
# (7727, 10)

# %%
import random
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

model = RandomForestClassifier()

data={}
for seed in range(42, 52):
    random.seed(seed)
    
    x = np.load('./x_(7727,10)_m1_entropy.npy')
    y = np.load('./y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_train, y_train = x[idx[:i],:], y[idx[:i]]
    X_test, y_test = x[idx[i:],:], y[idx[i:]]
    
    _ = model.fit(X_train, y_train)
    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)
    
    acc = accuracy_score(y_test, y_pred_test)
    data[seed]=acc
    print(f'정확도 : {acc}, seed_num = {seed}')

df = pd.DataFrame.from_dict(data, orient='index')
print(f'정확도 df 만들고 평균 확인 : {df.mean().values}')
# Out:
# 정확도 : 0.6355987055016181, seed_num = 42
# 정확도 : 0.6330097087378641, seed_num = 43
# 정확도 : 0.6349514563106796, seed_num = 44
# 정확도 : 0.6576051779935275, seed_num = 45
# 정확도 : 0.6466019417475728, seed_num = 46
# 정확도 : 0.6634304207119741, seed_num = 47
# 정확도 : 0.6750809061488673, seed_num = 48
# 정확도 : 0.654368932038835, seed_num = 49
# 정확도 : 0.6640776699029126, seed_num = 50
# 정확도 : 0.6511326860841424, seed_num = 51
# 정확도 df 만들고 평균 확인 : [0.65158576]

# %% [markdown]
# ## (64.9) LSTM

# %%
# m1_entropy_top10만을 가진 x_(7727,10,10)_m1 만들기
item_list = list(total_data['ITEMID'].sort_values().unique())

m1_top10_entropy_index = []
for i in m1_entropy_top10:
    m1_top10_entropy_index.append(item_list.index(i))

print('m1_entropy_top10의 index : ',m1_top10_entropy_index)

x = np.load('x_(7727,10,4068).npy')
x_3d = x[:,:,m1_top10_entropy_index]
x_3d.shape
x_3d.sum()

np.save('x_(7727,10,10)_m1_entropy.npy',x_3d)
# Out:
# m1_entropy_top10의 index :  [2195, 1276, 1081, 982, 2744, 383, 1011, 1306, 845, 469]
# (7727, 10, 10)
# 6187.0

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings(action='ignore')

import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, InputLayer
from tensorflow.keras.callbacks import EarlyStopping
from sklearn import metrics 
from tensorflow import keras
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

import random
# ----------------------
seed_num = 42
# ----------------------
random.seed(seed_num)

x = np.load('x_(7727,10,10)_m1_entropy.npy')
y = np.load('y_(7727,1).npy')

idx = list(range(len(x)))
random.shuffle(idx)

i = round(x.shape[0]*0.8)
X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
X_test, y_test = x[idx[i:],:,:], y[idx[i:]]

# ---------------------
seed_num = 42 
# ---------------------
tf.random.set_seed(seed_num)

lstm = Sequential()
lstm.add(InputLayer(input_shape=(X_train.shape[1],X_train.shape[2])))
lstm.add(LSTM(units=128, activation='hard_sigmoid', return_sequences=True))
lstm.add(LSTM(units=64, activation='hard_sigmoid', return_sequences=True))
lstm.add(Dropout(0.2))
lstm.add(LSTM(units=64, activation='hard_sigmoid', return_sequences=True))
lstm.add(LSTM(units=32, activation='hard_sigmoid', return_sequences=False))
lstm.add(Dropout(0.2))
lstm.add(Dense(units=1, activation='sigmoid'))

from tensorflow.keras.callbacks import ModelCheckpoint
import os

MODEL_SAVE_FOLDER_PATH = './model/'
if not os.path.exists(MODEL_SAVE_FOLDER_PATH):
    os.mkdir(MODEL_SAVE_FOLDER_PATH)

model_path = MODEL_SAVE_FOLDER_PATH + 'm1_entropy_top10_seed42-{epoch:02d}-{val_loss:.4f}.hdf5'

cb_checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss',
                                verbose=1, save_best_only=True)

early_stop = EarlyStopping(monitor='val_acc', patience=50, verbose=1, restore_best_weights=True)
lstm.compile(optimizer= keras.optimizers.Adam(learning_rate = 0.001), loss = "binary_crossentropy", metrics=['acc'])
lstm.fit(X_train, y_train, validation_split=0.25, batch_size=128, epochs=500,  callbacks=[early_stop,cb_checkpoint], shuffle=False)
# Out:
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/500
# 37/37 [==============================] - 5s 71ms/step - loss: 0.6759 - acc: 0.5984 - val_loss: 0.6660 - val_acc: 0.6177
#
# Epoch 00001: val_loss improved from inf to 0.66603, saving model to ./model/m1_entropy_top10_seed42-01-0.6660.hdf5
# Epoch 2/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6732 - acc: 0.6066 - val_loss: 0.6662 - val_acc: 0.6177
#
# Epoch 00002: val_loss did not improve from 0.66603
# Epoch 3/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6740 - acc: 0.6083 - val_loss: 0.6655 - val_acc: 0.6177
#
# Epoch 00003: val_loss improved from 0.66603 to 0.66551, saving model to ./model/m1_entropy_top10_seed42-03-0.6655.hdf5
# Epoch 4/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6711 - acc: 0.6100 - val_loss: 0.6653 - val_acc: 0.6177
#
# Epoch 00004: val_loss improved from 0.66551 to 0.66526, saving model to ./model/m1_entropy_top10_seed42-04-0.6653.hdf5
# Epoch 5/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6706 - acc: 0.6091 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00005: val_loss improved from 0.66526 to 0.66517, saving model to ./model/m1_entropy_top10_seed42-05-0.6652.hdf5
# Epoch 6/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6721 - acc: 0.6113 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00006: val_loss improved from 0.66517 to 0.66515, saving model to ./model/m1_entropy_top10_seed42-06-0.6652.hdf5
# Epoch 7/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6710 - acc: 0.6111 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00007: val_loss did not improve from 0.66515
# Epoch 8/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6715 - acc: 0.6111 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00008: val_loss did not improve from 0.66515
# Epoch 9/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6702 - acc: 0.6113 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00009: val_loss did not improve from 0.66515
# Epoch 10/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6700 - acc: 0.6115 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00010: val_loss did not improve from 0.66515
# Epoch 11/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6698 - acc: 0.6115 - val_loss: 0.6651 - val_acc: 0.6177
#
# Epoch 00011: val_loss improved from 0.66515 to 0.66515, saving model to ./model/m1_entropy_top10_seed42-11-0.6651.hdf5
# Epoch 12/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6694 - acc: 0.6115 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00012: val_loss did not improve from 0.66515
# Epoch 13/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.6698 - acc: 0.6117 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00013: val_loss did not improve from 0.66515
# Epoch 14/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6694 - acc: 0.6115 - val_loss: 0.6651 - val_acc: 0.6177
#
# Epoch 00014: val_loss did not improve from 0.66515
# Epoch 15/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6691 - acc: 0.6115 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00015: val_loss did not improve from 0.66515
# Epoch 16/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6701 - acc: 0.6115 - val_loss: 0.6651 - val_acc: 0.6177
#
# Epoch 00016: val_loss improved from 0.66515 to 0.66508, saving model to ./model/m1_entropy_top10_seed42-16-0.6651.hdf5
# Epoch 17/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6706 - acc: 0.6115 - val_loss: 0.6650 - val_acc: 0.6177
#
# Epoch 00017: val_loss improved from 0.66508 to 0.66502, saving model to ./model/m1_entropy_top10_seed42-17-0.6650.hdf5
# Epoch 18/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6686 - acc: 0.6115 - val_loss: 0.6648 - val_acc: 0.6177
#
# Epoch 00018: val_loss improved from 0.66502 to 0.66479, saving model to ./model/m1_entropy_top10_seed42-18-0.6648.hdf5
# Epoch 19/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6689 - acc: 0.6115 - val_loss: 0.6646 - val_acc: 0.6177
#
# Epoch 00019: val_loss improved from 0.66479 to 0.66463, saving model to ./model/m1_entropy_top10_seed42-19-0.6646.hdf5
# Epoch 20/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6686 - acc: 0.6115 - val_loss: 0.6639 - val_acc: 0.6177
#
# Epoch 00020: val_loss improved from 0.66463 to 0.66395, saving model to ./model/m1_entropy_top10_seed42-20-0.6639.hdf5
# Epoch 21/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6639 - acc: 0.6115 - val_loss: 0.6578 - val_acc: 0.6177
#
# Epoch 00021: val_loss improved from 0.66395 to 0.65783, saving model to ./model/m1_entropy_top10_seed42-21-0.6578.hdf5
# Epoch 22/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6545 - acc: 0.6115 - val_loss: 0.6432 - val_acc: 0.6177
#
# Epoch 00022: val_loss improved from 0.65783 to 0.64325, saving model to ./model/m1_entropy_top10_seed42-22-0.6432.hdf5
# Epoch 23/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6374 - acc: 0.6124 - val_loss: 0.6527 - val_acc: 0.6177
#
# Epoch 00023: val_loss did not improve from 0.64325
# Epoch 24/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6326 - acc: 0.6089 - val_loss: 0.6378 - val_acc: 0.6177
#
# Epoch 00024: val_loss improved from 0.64325 to 0.63781, saving model to ./model/m1_entropy_top10_seed42-24-0.6378.hdf5
# Epoch 25/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6264 - acc: 0.6091 - val_loss: 0.6336 - val_acc: 0.6177
#
# Epoch 00025: val_loss improved from 0.63781 to 0.63357, saving model to ./model/m1_entropy_top10_seed42-25-0.6336.hdf5
# Epoch 26/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6237 - acc: 0.6079 - val_loss: 0.6323 - val_acc: 0.6177
#
# Epoch 00026: val_loss improved from 0.63357 to 0.63225, saving model to ./model/m1_entropy_top10_seed42-26-0.6323.hdf5
# Epoch 27/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6212 - acc: 0.6139 - val_loss: 0.6280 - val_acc: 0.6177
#
# Epoch 00027: val_loss improved from 0.63225 to 0.62801, saving model to ./model/m1_entropy_top10_seed42-27-0.6280.hdf5
# Epoch 28/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6201 - acc: 0.6145 - val_loss: 0.6321 - val_acc: 0.6177
#
# Epoch 00028: val_loss did not improve from 0.62801
# Epoch 29/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6243 - acc: 0.6053 - val_loss: 0.6269 - val_acc: 0.6177
#
# Epoch 00029: val_loss improved from 0.62801 to 0.62686, saving model to ./model/m1_entropy_top10_seed42-29-0.6269.hdf5
# Epoch 30/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6183 - acc: 0.6189 - val_loss: 0.6324 - val_acc: 0.6229
#
# Epoch 00030: val_loss did not improve from 0.62686
# Epoch 31/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6177 - acc: 0.6195 - val_loss: 0.6285 - val_acc: 0.6223
#
# Epoch 00031: val_loss did not improve from 0.62686
# Epoch 32/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6183 - acc: 0.6160 - val_loss: 0.6278 - val_acc: 0.6229
#
# Epoch 00032: val_loss did not improve from 0.62686
# Epoch 33/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6169 - acc: 0.6232 - val_loss: 0.6273 - val_acc: 0.6229
#
# Epoch 00033: val_loss did not improve from 0.62686
# Epoch 34/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6159 - acc: 0.6210 - val_loss: 0.6238 - val_acc: 0.6242
#
# Epoch 00034: val_loss improved from 0.62686 to 0.62377, saving model to ./model/m1_entropy_top10_seed42-34-0.6238.hdf5
# Epoch 35/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6141 - acc: 0.6311 - val_loss: 0.6219 - val_acc: 0.6210
#
# Epoch 00035: val_loss improved from 0.62377 to 0.62185, saving model to ./model/m1_entropy_top10_seed42-35-0.6219.hdf5
# Epoch 36/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6144 - acc: 0.6342 - val_loss: 0.6234 - val_acc: 0.6345
#
# Epoch 00036: val_loss did not improve from 0.62185
# Epoch 37/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6133 - acc: 0.6333 - val_loss: 0.6196 - val_acc: 0.6423
#
# Epoch 00037: val_loss improved from 0.62185 to 0.61956, saving model to ./model/m1_entropy_top10_seed42-37-0.6196.hdf5
# Epoch 38/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6128 - acc: 0.6430 - val_loss: 0.6188 - val_acc: 0.6423
#
# Epoch 00038: val_loss improved from 0.61956 to 0.61877, saving model to ./model/m1_entropy_top10_seed42-38-0.6188.hdf5
# Epoch 39/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6102 - acc: 0.6402 - val_loss: 0.6181 - val_acc: 0.6475
#
# Epoch 00039: val_loss improved from 0.61877 to 0.61812, saving model to ./model/m1_entropy_top10_seed42-39-0.6181.hdf5
# Epoch 40/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6095 - acc: 0.6430 - val_loss: 0.6154 - val_acc: 0.6514
#
# Epoch 00040: val_loss improved from 0.61812 to 0.61541, saving model to ./model/m1_entropy_top10_seed42-40-0.6154.hdf5
# Epoch 41/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6076 - acc: 0.6409 - val_loss: 0.6146 - val_acc: 0.6481
#
# Epoch 00041: val_loss improved from 0.61541 to 0.61459, saving model to ./model/m1_entropy_top10_seed42-41-0.6146.hdf5
# Epoch 42/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6031 - acc: 0.6473 - val_loss: 0.6135 - val_acc: 0.6514
#
# Epoch 00042: val_loss improved from 0.61459 to 0.61349, saving model to ./model/m1_entropy_top10_seed42-42-0.6135.hdf5
# Epoch 43/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6058 - acc: 0.6491 - val_loss: 0.6131 - val_acc: 0.6514
#
# Epoch 00043: val_loss improved from 0.61349 to 0.61309, saving model to ./model/m1_entropy_top10_seed42-43-0.6131.hdf5
# Epoch 44/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6026 - acc: 0.6510 - val_loss: 0.6134 - val_acc: 0.6514
#
# Epoch 00044: val_loss did not improve from 0.61309
# Epoch 45/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.6008 - acc: 0.6549 - val_loss: 0.6136 - val_acc: 0.6514
#
# Epoch 00045: val_loss did not improve from 0.61309
# Epoch 46/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6029 - acc: 0.6529 - val_loss: 0.6151 - val_acc: 0.6514
#
# Epoch 00046: val_loss did not improve from 0.61309
# Epoch 47/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6012 - acc: 0.6525 - val_loss: 0.6150 - val_acc: 0.6514
#
# Epoch 00047: val_loss did not improve from 0.61309
# Epoch 48/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6018 - acc: 0.6516 - val_loss: 0.6162 - val_acc: 0.6494
#
# Epoch 00048: val_loss did not improve from 0.61309
# Epoch 49/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6012 - acc: 0.6555 - val_loss: 0.6183 - val_acc: 0.6494
#
# Epoch 00049: val_loss did not improve from 0.61309
# Epoch 50/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6055 - acc: 0.6497 - val_loss: 0.6199 - val_acc: 0.6455
#
# Epoch 00050: val_loss did not improve from 0.61309
# Epoch 51/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6067 - acc: 0.6467 - val_loss: 0.6150 - val_acc: 0.6494
#
# Epoch 00051: val_loss did not improve from 0.61309
# Epoch 52/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6013 - acc: 0.6523 - val_loss: 0.6158 - val_acc: 0.6533
#
# Epoch 00052: val_loss did not improve from 0.61309
# Epoch 53/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6028 - acc: 0.6544 - val_loss: 0.6139 - val_acc: 0.6527
#
# Epoch 00053: val_loss did not improve from 0.61309
# Epoch 54/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6016 - acc: 0.6544 - val_loss: 0.6145 - val_acc: 0.6533
#
# Epoch 00054: val_loss did not improve from 0.61309
# Epoch 55/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6008 - acc: 0.6549 - val_loss: 0.6139 - val_acc: 0.6533
#
# Epoch 00055: val_loss did not improve from 0.61309
# Epoch 56/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5987 - acc: 0.6540 - val_loss: 0.6151 - val_acc: 0.6533
#
# Epoch 00056: val_loss did not improve from 0.61309
# Epoch 57/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6029 - acc: 0.6540 - val_loss: 0.6127 - val_acc: 0.6533
#
# Epoch 00057: val_loss improved from 0.61309 to 0.61271, saving model to ./model/m1_entropy_top10_seed42-57-0.6127.hdf5
# Epoch 58/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5991 - acc: 0.6542 - val_loss: 0.6157 - val_acc: 0.6533
#
# Epoch 00058: val_loss did not improve from 0.61271
# Epoch 59/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6029 - acc: 0.6542 - val_loss: 0.6128 - val_acc: 0.6533
#
# Epoch 00059: val_loss did not improve from 0.61271
# Epoch 60/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5990 - acc: 0.6542 - val_loss: 0.6164 - val_acc: 0.6533
#
# Epoch 00060: val_loss did not improve from 0.61271
# Epoch 61/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6010 - acc: 0.6540 - val_loss: 0.6128 - val_acc: 0.6533
#
# Epoch 00061: val_loss did not improve from 0.61271
# Epoch 62/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6016 - acc: 0.6540 - val_loss: 0.6156 - val_acc: 0.6533
#
# Epoch 00062: val_loss did not improve from 0.61271
# Epoch 63/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5998 - acc: 0.6547 - val_loss: 0.6137 - val_acc: 0.6533
#
# Epoch 00063: val_loss did not improve from 0.61271
# Epoch 64/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6008 - acc: 0.6542 - val_loss: 0.6141 - val_acc: 0.6533
#
# Epoch 00064: val_loss did not improve from 0.61271
# Epoch 65/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5998 - acc: 0.6540 - val_loss: 0.6146 - val_acc: 0.6533
#
# Epoch 00065: val_loss did not improve from 0.61271
# Epoch 66/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5983 - acc: 0.6540 - val_loss: 0.6146 - val_acc: 0.6533
#
# Epoch 00066: val_loss did not improve from 0.61271
# Epoch 67/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5991 - acc: 0.6544 - val_loss: 0.6168 - val_acc: 0.6533
#
# Epoch 00067: val_loss did not improve from 0.61271
# Epoch 68/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6064 - acc: 0.6458 - val_loss: 0.6121 - val_acc: 0.6533
#
# Epoch 00068: val_loss improved from 0.61271 to 0.61211, saving model to ./model/m1_entropy_top10_seed42-68-0.6121.hdf5
# Epoch 69/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5996 - acc: 0.6531 - val_loss: 0.6143 - val_acc: 0.6533
#
# Epoch 00069: val_loss did not improve from 0.61211
# Epoch 70/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5989 - acc: 0.6547 - val_loss: 0.6149 - val_acc: 0.6533
#
# Epoch 00070: val_loss did not improve from 0.61211
# Epoch 71/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5978 - acc: 0.6542 - val_loss: 0.6150 - val_acc: 0.6533
#
# Epoch 00071: val_loss did not improve from 0.61211
# Epoch 72/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5990 - acc: 0.6538 - val_loss: 0.6141 - val_acc: 0.6527
#
# Epoch 00072: val_loss did not improve from 0.61211
# Epoch 73/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5994 - acc: 0.6538 - val_loss: 0.6141 - val_acc: 0.6527
#
# Epoch 00073: val_loss did not improve from 0.61211
# Epoch 74/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5988 - acc: 0.6544 - val_loss: 0.6149 - val_acc: 0.6533
#
# Epoch 00074: val_loss did not improve from 0.61211
# Epoch 75/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6007 - acc: 0.6547 - val_loss: 0.6135 - val_acc: 0.6533
# Epoch 00075: val_loss did not improve from 0.61211
# Epoch 76/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5986 - acc: 0.6540 - val_loss: 0.6150 - val_acc: 0.6533
#
# Epoch 00076: val_loss did not improve from 0.61211
# Epoch 77/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5990 - acc: 0.6540 - val_loss: 0.6137 - val_acc: 0.6527
#
# Epoch 00077: val_loss did not improve from 0.61211
# Epoch 78/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5985 - acc: 0.6540 - val_loss: 0.6150 - val_acc: 0.6533
#
# Epoch 00078: val_loss did not improve from 0.61211
# Epoch 79/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5984 - acc: 0.6540 - val_loss: 0.6144 - val_acc: 0.6533
#
# Epoch 00079: val_loss did not improve from 0.61211
# Epoch 80/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5987 - acc: 0.6540 - val_loss: 0.6150 - val_acc: 0.6533
#
# Epoch 00080: val_loss did not improve from 0.61211
# Epoch 81/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5986 - acc: 0.6540 - val_loss: 0.6141 - val_acc: 0.6527
#
# Epoch 00081: val_loss did not improve from 0.61211
# Epoch 82/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5986 - acc: 0.6540 - val_loss: 0.6152 - val_acc: 0.6533
#
# Epoch 00082: val_loss did not improve from 0.61211
# Epoch 83/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5981 - acc: 0.6540 - val_loss: 0.6163 - val_acc: 0.6533
#
# Epoch 00083: val_loss did not improve from 0.61211
# Epoch 84/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6002 - acc: 0.6549 - val_loss: 0.6120 - val_acc: 0.6533
#
# Epoch 00084: val_loss improved from 0.61211 to 0.61196, saving model to ./model/m1_entropy_top10_seed42-84-0.6120.hdf5
# Epoch 85/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5989 - acc: 0.6536 - val_loss: 0.6149 - val_acc: 0.6533
#
# Epoch 00085: val_loss did not improve from 0.61196
# Epoch 86/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5975 - acc: 0.6547 - val_loss: 0.6145 - val_acc: 0.6533
#
# Epoch 00086: val_loss did not improve from 0.61196
# Epoch 87/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5982 - acc: 0.6540 - val_loss: 0.6137 - val_acc: 0.6527
#
# Epoch 00087: val_loss did not improve from 0.61196
# Epoch 88/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5978 - acc: 0.6536 - val_loss: 0.6147 - val_acc: 0.6533
#
# Epoch 00088: val_loss did not improve from 0.61196
# Epoch 89/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5977 - acc: 0.6540 - val_loss: 0.6139 - val_acc: 0.6533
#
# Epoch 00089: val_loss did not improve from 0.61196
# Epoch 90/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5985 - acc: 0.6542 - val_loss: 0.6139 - val_acc: 0.6527
#
# Epoch 00090: val_loss did not improve from 0.61196
# Epoch 91/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5965 - acc: 0.6538 - val_loss: 0.6158 - val_acc: 0.6533
#
# Epoch 00091: val_loss did not improve from 0.61196
# Epoch 92/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5987 - acc: 0.6547 - val_loss: 0.6129 - val_acc: 0.6533
#
# Epoch 00092: val_loss did not improve from 0.61196
# Epoch 93/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5977 - acc: 0.6542 - val_loss: 0.6148 - val_acc: 0.6533
#
# Epoch 00093: val_loss did not improve from 0.61196
# Epoch 94/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5992 - acc: 0.6549 - val_loss: 0.6135 - val_acc: 0.6533
#
# Epoch 00094: val_loss did not improve from 0.61196
# Epoch 95/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5971 - acc: 0.6542 - val_loss: 0.6152 - val_acc: 0.6533
#
# Epoch 00095: val_loss did not improve from 0.61196
# Epoch 96/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5988 - acc: 0.6540 - val_loss: 0.6130 - val_acc: 0.6527
#
# Epoch 00096: val_loss did not improve from 0.61196
# Epoch 97/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5966 - acc: 0.6538 - val_loss: 0.6137 - val_acc: 0.6533
#
# Epoch 00097: val_loss did not improve from 0.61196
# Epoch 98/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5978 - acc: 0.6538 - val_loss: 0.6140 - val_acc: 0.6527
#
# Epoch 00098: val_loss did not improve from 0.61196
# Epoch 99/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5966 - acc: 0.6542 - val_loss: 0.6142 - val_acc: 0.6527
#
# Epoch 00099: val_loss did not improve from 0.61196
# Epoch 100/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5979 - acc: 0.6536 - val_loss: 0.6137 - val_acc: 0.6533
#
# Epoch 00100: val_loss did not improve from 0.61196
# Epoch 101/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5967 - acc: 0.6540 - val_loss: 0.6152 - val_acc: 0.6533
#
# Epoch 00101: val_loss did not improve from 0.61196
# Epoch 102/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5974 - acc: 0.6542 - val_loss: 0.6136 - val_acc: 0.6533
# Restoring model weights from the end of the best epoch.
#
# Epoch 00102: val_loss did not improve from 0.61196
# Epoch 00102: early stopping

# %%
from keras.models import load_model
best_model = load_model('./model/m1_entropy_top10_seed42-84-0.6120.hdf5') 

dic_42={}
for seed in range(0, 50):
    random.seed(seed)

    x = np.load('x_(7727,10,10)_m1_entropy.npy')
    y = np.load('y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
    X_test, y_test = x[idx[i:],:,:], y[idx[i:]]
    
    pred = best_model.predict(X_test)
    pred[pred>0.5]=1
    pred[pred<=0.5]=0
    acc = metrics.accuracy_score(y_test, pred)
    dic_42[seed]=acc
    print(f'정확도 :{metrics.accuracy_score(y_test, pred)}, seed_num = {seed}')
# Out:
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 정확도 :0.6466019417475728, seed_num = 0
# 정확도 :0.6427184466019418, seed_num = 1
# 정확도 :0.6498381877022654, seed_num = 2
# 정확도 :0.6375404530744336, seed_num = 3
# 정확도 :0.654368932038835, seed_num = 4
# 정확도 :0.655663430420712, seed_num = 5
# 정확도 :0.6537216828478964, seed_num = 6
# 정확도 :0.629126213592233, seed_num = 7
# 정확도 :0.6614886731391586, seed_num = 8
# 정확도 :0.6498381877022654, seed_num = 9
# 정확도 :0.627831715210356, seed_num = 10
# 정확도 :0.6711974110032363, seed_num = 11
# 정확도 :0.6472491909385113, seed_num = 12
# 정확도 :0.6414239482200648, seed_num = 13
# 정확도 :0.6466019417475728, seed_num = 14
# 정확도 :0.656957928802589, seed_num = 15
# 정확도 :0.6692556634304208, seed_num = 16
# 정확도 :0.6453074433656958, seed_num = 17
# 정확도 :0.6459546925566343, seed_num = 18
# 정확도 :0.6414239482200648, seed_num = 19
# 정확도 :0.6601941747572816, seed_num = 20
# 정확도 :0.6595469255663431, seed_num = 21
# 정확도 :0.6375404530744336, seed_num = 22
# 정확도 :0.6550161812297735, seed_num = 23
# 정확도 :0.6530744336569579, seed_num = 24
# 정확도 :0.6491909385113268, seed_num = 25
# 정확도 :0.6284789644012945, seed_num = 26
# 정확도 :0.6608414239482201, seed_num = 27
# 정확도 :0.6453074433656958, seed_num = 28
# 정확도 :0.6446601941747573, seed_num = 29
# 정확도 :0.6530744336569579, seed_num = 30
# 정확도 :0.6472491909385113, seed_num = 31
# 정확도 :0.654368932038835, seed_num = 32
# 정확도 :0.6517799352750809, seed_num = 33
# 정확도 :0.6601941747572816, seed_num = 34
# 정확도 :0.6614886731391586, seed_num = 35
# 정확도 :0.6427184466019418, seed_num = 36
# 정확도 :0.6472491909385113, seed_num = 37
# 정확도 :0.6362459546925566, seed_num = 38
# 정확도 :0.6634304207119741, seed_num = 39
# 정확도 :0.63042071197411, seed_num = 40
# 정확도 :0.6446601941747573, seed_num = 41
# 정확도 :0.6349514563106796, seed_num = 42
# 정확도 :0.6330097087378641, seed_num = 43
# 정확도 :0.6355987055016181, seed_num = 44
# 정확도 :0.656957928802589, seed_num = 45
# 정확도 :0.6472491909385113, seed_num = 46
# 정확도 :0.6634304207119741, seed_num = 47
# 정확도 :0.6750809061488673, seed_num = 48
# 정확도 :0.6530744336569579, seed_num = 49

# %%
# seed = 42의 정확도 df 만들고 평균 확인 => 64.9
df_42 = pd.DataFrame.from_dict(dic_42, orient='index')
df_42.mean()
# Out:
# 0    0.649204
# dtype: float64

# %% [markdown]
# # M2_df_원시간*근시간

# %%
total_data = pd.read_csv('total_data_7727.csv')
m2_변동성 = pd.read_csv('method2_df_원시간*근시간.csv')
m2_변동성_feature = m2_변동성['feature'].tolist()

# LAB, PRE, PRO의 item_list 생성 
LAB_item = total_data[total_data['TYPE']=='LAB']['ITEMID'].sort_values().unique()
PRE_item = total_data[total_data['TYPE']=='PRE']['ITEMID'].sort_values().unique()
PRO_item = total_data[total_data['TYPE']=='PRO']['ITEMID'].sort_values().unique()

LAB_list = []
PRE_list = []
PRO_list = []
for i in m2_변동성_feature:
    if i in LAB_item:
        LAB_list.append(i)
    elif i in PRE_item:
        PRE_list.append(i)
    else:
        PRO_list.append(i)

# %%
absum(PRE_list,PRE_list[:10])

# %%
absum(PRO_list,PRO_list[:10])

# %%
absum(LAB_list,LAB_list[:10])

# %%
absum(m2_변동성_feature,m2_변동성_feature[:10])

# %% [markdown]
# # E(0to1) - E(1to0)
# - 22.02.22 Tue

# %%
mm = pd.read_csv('FI_mean_merge.csv')
mm['E(0to1)-E(1to0)'] = mm['pred_0to1']-mm['pred_1to0']
mm_top10 = mm.sort_values(by='E(0to1)-E(1to0)',ascending=False)['feature'].values[:10]
mm_top10
# Out:
# array([  409606211,    74606211,    67434504, 10019055302,    54817525,
#              51277,    54858516,    45006701,    74706811,       51003])

# %% [markdown]
# ## (67.1) RF

# %%
# mean_diff_top10만을 가진 x_(7727,10)_mean_diff 만들기
item_list = list(total_data['ITEMID'].sort_values().unique())

mmlist_index = []
for i in mm_top10:
    mmlist_index.append(item_list.index(i))

print('mean_diff_top10의 index : ',mmlist_index)

x = np.load('x_(7727,4068).npy')
x_2d = x[:,mmlist_index]
x_2d.shape

# np.save('x_(7727,10)_mean_diff',x_2d)
# Out:
# mean_diff_top10의 index :  [2195, 1276, 1081, 2744, 982, 206, 1011, 845, 1306, 119]
# (7727, 10)

# %%
import random
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

model = RandomForestClassifier()

data={}
for seed in range(42, 52):
    random.seed(seed)
    
    x = np.load('./x_(7727,10)_mean_diff.npy')
    y = np.load('./y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_train, y_train = x[idx[:i],:], y[idx[:i]]
    X_test, y_test = x[idx[i:],:], y[idx[i:]]
    
    _ = model.fit(X_train, y_train)
    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)
    
    acc = accuracy_score(y_test, y_pred_test)
    data[seed]=acc
    print(f'정확도 : {acc}, seed_num = {seed}')

df = pd.DataFrame.from_dict(data, orient='index')
print(f'정확도 df 만들고 평균 확인 : {df.mean().values}')
# Out:
# 정확도 : 0.6576051779935275, seed_num = 42
# 정확도 : 0.6621359223300971, seed_num = 43
# 정확도 : 0.6517799352750809, seed_num = 44
# 정확도 : 0.6711974110032363, seed_num = 45
# 정확도 : 0.6776699029126214, seed_num = 46
# 정확도 : 0.6944983818770226, seed_num = 47
# 정확도 : 0.6977346278317152, seed_num = 48
# 정확도 : 0.6608414239482201, seed_num = 49
# 정확도 : 0.6653721682847896, seed_num = 50
# 정확도 : 0.6770226537216828, seed_num = 51
# 정확도 df 만들고 평균 확인 : [0.67158576]

# %% [markdown]
# ## (67.9) LSTM

# %%
# mm_top10만을 가진 x_(7727,10,10)_mean_diff 만들기
total_data = pd.read_csv('total_data_7727.csv')
item_list = list(total_data['ITEMID'].sort_values().unique())

mm_top10_index = []
for i in mm_top10:
    mm_top10_index.append(item_list.index(i))

print('mm_top10의 index : ',mm_top10_index)

x = np.load('x_(7727,10,4068).npy')
x_3d = x[:,:,mm_top10_index]
x_3d.shape
x_3d.sum()

# np.save('x_(7727,10,10)_mean_diff.npy',x_3d)
# Out:
# mm_top10의 index :  [2195, 1276, 1081, 2744, 982, 206, 1011, 845, 1306, 119]
# (7727, 10, 10)
# 35507.0

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings(action='ignore')

import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, InputLayer
from tensorflow.keras.callbacks import EarlyStopping
from sklearn import metrics 
from tensorflow import keras
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

import random
# ----------------------
seed_num = 42
# ----------------------
random.seed(seed_num)

x = np.load('x_(7727,10,10)_mean_diff.npy')
y = np.load('y_(7727,1).npy')

idx = list(range(len(x)))
random.shuffle(idx)

i = round(x.shape[0]*0.8)
X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
X_test, y_test = x[idx[i:],:,:], y[idx[i:]]

# ---------------------
seed_num = 42 
# ---------------------
tf.random.set_seed(seed_num)

lstm = Sequential()
lstm.add(InputLayer(input_shape=(X_train.shape[1],X_train.shape[2])))
lstm.add(LSTM(units=128, activation='hard_sigmoid', return_sequences=True))
lstm.add(LSTM(units=64, activation='hard_sigmoid', return_sequences=True))
lstm.add(Dropout(0.2))
lstm.add(LSTM(units=64, activation='hard_sigmoid', return_sequences=True))
lstm.add(LSTM(units=32, activation='hard_sigmoid', return_sequences=False))
lstm.add(Dropout(0.2))
lstm.add(Dense(units=1, activation='sigmoid'))

from tensorflow.keras.callbacks import ModelCheckpoint
import os

MODEL_SAVE_FOLDER_PATH = './model/'
if not os.path.exists(MODEL_SAVE_FOLDER_PATH):
    os.mkdir(MODEL_SAVE_FOLDER_PATH)

model_path = MODEL_SAVE_FOLDER_PATH + 'mean_diff_seed42-{epoch:02d}-{val_loss:.4f}.hdf5'

cb_checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss',
                                verbose=1, save_best_only=True)

early_stop = EarlyStopping(monitor='val_acc', patience=50, verbose=1, restore_best_weights=True)
lstm.compile(optimizer= keras.optimizers.Adam(learning_rate = 0.001), loss = "binary_crossentropy", metrics=['acc'])
lstm.fit(X_train, y_train, validation_split=0.25, batch_size=128, epochs=500,  callbacks=[early_stop,cb_checkpoint], shuffle=False)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/500
# 37/37 [==============================] - 6s 74ms/step - loss: 0.6759 - acc: 0.5984 - val_loss: 0.6660 - val_acc: 0.6177
#
# Epoch 00001: val_loss improved from inf to 0.66602, saving model to ./model/mean_diff_seed42-01-0.6660.hdf5
# Epoch 2/500
# 37/37 [==============================] - 2s 60ms/step - loss: 0.6732 - acc: 0.6068 - val_loss: 0.6662 - val_acc: 0.6177
#
# Epoch 00002: val_loss did not improve from 0.66602
# Epoch 3/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.6740 - acc: 0.6083 - val_loss: 0.6655 - val_acc: 0.6177
#
# Epoch 00003: val_loss improved from 0.66602 to 0.66549, saving model to ./model/mean_diff_seed42-03-0.6655.hdf5
# Epoch 4/500
# 37/37 [==============================] - 2s 59ms/step - loss: 0.6710 - acc: 0.6100 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00004: val_loss improved from 0.66549 to 0.66520, saving model to ./model/mean_diff_seed42-04-0.6652.hdf5
# Epoch 5/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.6705 - acc: 0.6098 - val_loss: 0.6650 - val_acc: 0.6177
#
# Epoch 00005: val_loss improved from 0.66520 to 0.66498, saving model to ./model/mean_diff_seed42-05-0.6650.hdf5
# Epoch 6/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6717 - acc: 0.6113 - val_loss: 0.6645 - val_acc: 0.6177
#
# Epoch 00006: val_loss improved from 0.66498 to 0.66453, saving model to ./model/mean_diff_seed42-06-0.6645.hdf5
# Epoch 7/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6675 - acc: 0.6107 - val_loss: 0.6542 - val_acc: 0.6177
#
# Epoch 00007: val_loss improved from 0.66453 to 0.65418, saving model to ./model/mean_diff_seed42-07-0.6542.hdf5
# Epoch 8/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.6502 - acc: 0.6132 - val_loss: 0.6354 - val_acc: 0.6177
#
# Epoch 00008: val_loss improved from 0.65418 to 0.63543, saving model to ./model/mean_diff_seed42-08-0.6354.hdf5
# Epoch 9/500
# 37/37 [==============================] - 2s 60ms/step - loss: 0.6376 - acc: 0.6227 - val_loss: 0.6329 - val_acc: 0.6177
#
# Epoch 00009: val_loss improved from 0.63543 to 0.63293, saving model to ./model/mean_diff_seed42-09-0.6329.hdf5
# Epoch 10/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6264 - acc: 0.6488 - val_loss: 0.6258 - val_acc: 0.6617
#
# Epoch 00010: val_loss improved from 0.63293 to 0.62578, saving model to ./model/mean_diff_seed42-10-0.6258.hdf5
# Epoch 11/500
# 37/37 [==============================] - 2s 60ms/step - loss: 0.6191 - acc: 0.6629 - val_loss: 0.6188 - val_acc: 0.6649
#
# Epoch 00011: val_loss improved from 0.62578 to 0.61882, saving model to ./model/mean_diff_seed42-11-0.6188.hdf5
# Epoch 12/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6115 - acc: 0.6717 - val_loss: 0.6138 - val_acc: 0.6701
#
# Epoch 00012: val_loss improved from 0.61882 to 0.61379, saving model to ./model/mean_diff_seed42-12-0.6138.hdf5
# Epoch 13/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.6068 - acc: 0.6756 - val_loss: 0.6092 - val_acc: 0.6695
#
# Epoch 00013: val_loss improved from 0.61379 to 0.60925, saving model to ./model/mean_diff_seed42-13-0.6092.hdf5
# Epoch 14/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.6007 - acc: 0.6758 - val_loss: 0.6055 - val_acc: 0.6701
#
# Epoch 00014: val_loss improved from 0.60925 to 0.60547, saving model to ./model/mean_diff_seed42-14-0.6055.hdf5
# Epoch 15/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5983 - acc: 0.6790 - val_loss: 0.6021 - val_acc: 0.6656
#
# Epoch 00015: val_loss improved from 0.60547 to 0.60210, saving model to ./model/mean_diff_seed42-15-0.6021.hdf5
# Epoch 16/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5959 - acc: 0.6773 - val_loss: 0.5997 - val_acc: 0.6669
#
# Epoch 00016: val_loss improved from 0.60210 to 0.59973, saving model to ./model/mean_diff_seed42-16-0.5997.hdf5
# Epoch 17/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5944 - acc: 0.6782 - val_loss: 0.5987 - val_acc: 0.6714
#
# Epoch 00017: val_loss improved from 0.59973 to 0.59867, saving model to ./model/mean_diff_seed42-17-0.5987.hdf5
# Epoch 18/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5910 - acc: 0.6767 - val_loss: 0.5971 - val_acc: 0.6675
#
# Epoch 00018: val_loss improved from 0.59867 to 0.59706, saving model to ./model/mean_diff_seed42-18-0.5971.hdf5
# Epoch 19/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5895 - acc: 0.6790 - val_loss: 0.5975 - val_acc: 0.6701
#
# Epoch 00019: val_loss did not improve from 0.59706
# Epoch 20/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5898 - acc: 0.6775 - val_loss: 0.5960 - val_acc: 0.6701
#
# Epoch 00020: val_loss improved from 0.59706 to 0.59601, saving model to ./model/mean_diff_seed42-20-0.5960.hdf5
# Epoch 21/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5879 - acc: 0.6767 - val_loss: 0.5967 - val_acc: 0.6682
#
# Epoch 00021: val_loss did not improve from 0.59601
# Epoch 22/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5868 - acc: 0.6827 - val_loss: 0.5970 - val_acc: 0.6675
#
# Epoch 00022: val_loss did not improve from 0.59601
# Epoch 23/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5872 - acc: 0.6771 - val_loss: 0.5972 - val_acc: 0.6662
#
# Epoch 00023: val_loss did not improve from 0.59601
# Epoch 24/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5839 - acc: 0.6790 - val_loss: 0.5978 - val_acc: 0.6643
#
# Epoch 00024: val_loss did not improve from 0.59601
# Epoch 25/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5854 - acc: 0.6771 - val_loss: 0.6012 - val_acc: 0.6611
#
# Epoch 00025: val_loss did not improve from 0.59601
# Epoch 26/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5839 - acc: 0.6803 - val_loss: 0.6041 - val_acc: 0.6617
#
# Epoch 00026: val_loss did not improve from 0.59601
# Epoch 27/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5826 - acc: 0.6827 - val_loss: 0.6031 - val_acc: 0.6611
#
# Epoch 00027: val_loss did not improve from 0.59601
# Epoch 28/500
# 37/37 [==============================] - 2s 60ms/step - loss: 0.5831 - acc: 0.6844 - val_loss: 0.6049 - val_acc: 0.6611
#
# Epoch 00028: val_loss did not improve from 0.59601
# Epoch 29/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5834 - acc: 0.6831 - val_loss: 0.6039 - val_acc: 0.6611
#
# Epoch 00029: val_loss did not improve from 0.59601
# Epoch 30/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5833 - acc: 0.6773 - val_loss: 0.6021 - val_acc: 0.6611
#
# Epoch 00030: val_loss did not improve from 0.59601
# Epoch 31/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5805 - acc: 0.6857 - val_loss: 0.6048 - val_acc: 0.6617
#
# Epoch 00031: val_loss did not improve from 0.59601
# Epoch 32/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5826 - acc: 0.6797 - val_loss: 0.6018 - val_acc: 0.6611
#
# Epoch 00032: val_loss did not improve from 0.59601
# Epoch 33/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5812 - acc: 0.6842 - val_loss: 0.6000 - val_acc: 0.6611
#
# Epoch 00033: val_loss did not improve from 0.59601
# Epoch 34/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5800 - acc: 0.6872 - val_loss: 0.5993 - val_acc: 0.6611
#
# Epoch 00034: val_loss did not improve from 0.59601
# Epoch 35/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5782 - acc: 0.6836 - val_loss: 0.5990 - val_acc: 0.6611
#
# Epoch 00035: val_loss did not improve from 0.59601
# Epoch 36/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5795 - acc: 0.6872 - val_loss: 0.5985 - val_acc: 0.6643
#
# Epoch 00036: val_loss did not improve from 0.59601
# Epoch 37/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5764 - acc: 0.6881 - val_loss: 0.5976 - val_acc: 0.6656
#
# Epoch 00037: val_loss did not improve from 0.59601
# Epoch 38/500
# 37/37 [==============================] - 2s 60ms/step - loss: 0.5780 - acc: 0.6855 - val_loss: 0.5963 - val_acc: 0.6656
#
# Epoch 00038: val_loss did not improve from 0.59601
# Epoch 39/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5766 - acc: 0.6829 - val_loss: 0.5981 - val_acc: 0.6649
#
# Epoch 00039: val_loss did not improve from 0.59601
# Epoch 40/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5750 - acc: 0.6866 - val_loss: 0.5976 - val_acc: 0.6643
#
# Epoch 00040: val_loss did not improve from 0.59601
# Epoch 41/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5771 - acc: 0.6877 - val_loss: 0.5981 - val_acc: 0.6611
#
# Epoch 00041: val_loss did not improve from 0.59601
# Epoch 42/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5736 - acc: 0.6905 - val_loss: 0.5974 - val_acc: 0.6649
#
# Epoch 00042: val_loss did not improve from 0.59601
# Epoch 43/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5757 - acc: 0.6877 - val_loss: 0.5979 - val_acc: 0.6656
#
# Epoch 00043: val_loss did not improve from 0.59601
# Epoch 44/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5745 - acc: 0.6883 - val_loss: 0.5968 - val_acc: 0.6611
#
# Epoch 00044: val_loss did not improve from 0.59601
# Epoch 45/500
# 37/37 [==============================] - 2s 60ms/step - loss: 0.5734 - acc: 0.6855 - val_loss: 0.5975 - val_acc: 0.6643
#
# Epoch 00045: val_loss did not improve from 0.59601
# Epoch 46/500
# 37/37 [==============================] - 2s 60ms/step - loss: 0.5758 - acc: 0.6872 - val_loss: 0.5975 - val_acc: 0.6649
#
# Epoch 00046: val_loss did not improve from 0.59601
# Epoch 47/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5720 - acc: 0.6890 - val_loss: 0.5987 - val_acc: 0.6649
#
# Epoch 00047: val_loss did not improve from 0.59601
# Epoch 48/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5732 - acc: 0.6890 - val_loss: 0.5988 - val_acc: 0.6611
#
# Epoch 00048: val_loss did not improve from 0.59601
# Epoch 49/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5740 - acc: 0.6926 - val_loss: 0.5974 - val_acc: 0.6643
#
# Epoch 00049: val_loss did not improve from 0.59601
# Epoch 50/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5750 - acc: 0.6885 - val_loss: 0.5964 - val_acc: 0.6643
#
# Epoch 00050: val_loss did not improve from 0.59601
# Epoch 51/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5715 - acc: 0.6885 - val_loss: 0.5982 - val_acc: 0.6643
#
# Epoch 00051: val_loss did not improve from 0.59601
# Epoch 52/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5718 - acc: 0.6911 - val_loss: 0.5986 - val_acc: 0.6649
#
# Epoch 00052: val_loss did not improve from 0.59601
# Epoch 53/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5734 - acc: 0.6881 - val_loss: 0.5984 - val_acc: 0.6649
#
# Epoch 00053: val_loss did not improve from 0.59601
# Epoch 54/500
# 37/37 [==============================] - 2s 60ms/step - loss: 0.5714 - acc: 0.6913 - val_loss: 0.5999 - val_acc: 0.6688
#
# Epoch 00054: val_loss did not improve from 0.59601
# Epoch 55/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5727 - acc: 0.6915 - val_loss: 0.5999 - val_acc: 0.6675
#
# Epoch 00055: val_loss did not improve from 0.59601
# Epoch 56/500
# 37/37 [==============================] - 2s 60ms/step - loss: 0.5689 - acc: 0.6911 - val_loss: 0.5990 - val_acc: 0.6636
#
# Epoch 00056: val_loss did not improve from 0.59601
# Epoch 57/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5720 - acc: 0.6926 - val_loss: 0.5990 - val_acc: 0.6695
#
# Epoch 00057: val_loss did not improve from 0.59601
# Epoch 58/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5698 - acc: 0.6933 - val_loss: 0.6004 - val_acc: 0.6688
#
# Epoch 00058: val_loss did not improve from 0.59601
# Epoch 59/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5712 - acc: 0.6941 - val_loss: 0.5989 - val_acc: 0.6636
#
# Epoch 00059: val_loss did not improve from 0.59601
# Epoch 60/500
# 37/37 [==============================] - 2s 60ms/step - loss: 0.5705 - acc: 0.6931 - val_loss: 0.5982 - val_acc: 0.6636
#
# Epoch 00060: val_loss did not improve from 0.59601
# Epoch 61/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5694 - acc: 0.6911 - val_loss: 0.5991 - val_acc: 0.6643
#
# Epoch 00061: val_loss did not improve from 0.59601
# Epoch 62/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5717 - acc: 0.6898 - val_loss: 0.6001 - val_acc: 0.6649
#
# Epoch 00062: val_loss did not improve from 0.59601
# Epoch 63/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5695 - acc: 0.6922 - val_loss: 0.6010 - val_acc: 0.6688
#
# Epoch 00063: val_loss did not improve from 0.59601
# Epoch 64/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5710 - acc: 0.6913 - val_loss: 0.6002 - val_acc: 0.6669
#
# Epoch 00064: val_loss did not improve from 0.59601
# Epoch 65/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5687 - acc: 0.6937 - val_loss: 0.6000 - val_acc: 0.6636
#
# Epoch 00065: val_loss did not improve from 0.59601
# Epoch 66/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5696 - acc: 0.6913 - val_loss: 0.5998 - val_acc: 0.6675
#
# Epoch 00066: val_loss did not improve from 0.59601
# Epoch 67/500
# 37/37 [==============================] - 2s 60ms/step - loss: 0.5676 - acc: 0.6920 - val_loss: 0.6012 - val_acc: 0.6669
# Restoring model weights from the end of the best epoch.
#
# Epoch 00067: val_loss did not improve from 0.59601
# Epoch 00067: early stopping

# %%
import random
from sklearn import metrics 

with tf.device('/device:GPU:0'):
    tf.config.experimental.set_virtual_device_configuration(gpus[0], 
                                                            [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5*1024)])

    from keras.models import load_model
    best_model = load_model('./model/mean_diff_seed42-20-0.5960.hdf5') 

    dic_42={}
    for seed in range(0, 50):
        random.seed(seed)

        x = np.load('x_(7727,10,10)_mean_diff.npy')
        y = np.load('y_(7727,1).npy')

        idx = list(range(len(x)))
        random.shuffle(idx)

        i = round(x.shape[0]*0.8)
        X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
        X_test, y_test = x[idx[i:],:,:], y[idx[i:]]

        pred = best_model.predict(X_test)
        pred[pred>0.5]=1
        pred[pred<=0.5]=0
        acc = metrics.accuracy_score(y_test, pred)
        dic_42[seed]=acc
        print(f'정확도 :{metrics.accuracy_score(y_test, pred)}, seed_num = {seed}')
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 정확도 :0.6737864077669903, seed_num = 0
# 정확도 :0.6750809061488673, seed_num = 1
# 정확도 :0.6893203883495146, seed_num = 2
# 정확도 :0.7009708737864078, seed_num = 3
# 정확도 :0.6822006472491909, seed_num = 4
# 정확도 :0.6880258899676376, seed_num = 5
# 정확도 :0.686084142394822, seed_num = 6
# 정확도 :0.683495145631068, seed_num = 7
# 정확도 :0.6783171521035599, seed_num = 8
# 정확도 :0.6731391585760518, seed_num = 9
# 정확도 :0.6796116504854369, seed_num = 10
# 정확도 :0.6796116504854369, seed_num = 11
# 정확도 :0.686084142394822, seed_num = 12
# 정확도 :0.6744336569579288, seed_num = 13
# 정확도 :0.6854368932038835, seed_num = 14
# 정확도 :0.6783171521035599, seed_num = 15
# 정확도 :0.6653721682847896, seed_num = 16
# 정확도 :0.6718446601941748, seed_num = 17
# 정확도 :0.6711974110032363, seed_num = 18
# 정확도 :0.6886731391585761, seed_num = 19
# 정확도 :0.6796116504854369, seed_num = 20
# 정확도 :0.6686084142394823, seed_num = 21
# 정확도 :0.6737864077669903, seed_num = 22
# 정확도 :0.6640776699029126, seed_num = 23
# 정확도 :0.6621359223300971, seed_num = 24
# 정확도 :0.6796116504854369, seed_num = 25
# 정확도 :0.6660194174757281, seed_num = 26
# 정확도 :0.6783171521035599, seed_num = 27
# 정확도 :0.6757281553398058, seed_num = 28
# 정확도 :0.6673139158576051, seed_num = 29
# 정확도 :0.6983818770226538, seed_num = 30
# 정확도 :0.6822006472491909, seed_num = 31
# 정확도 :0.6621359223300971, seed_num = 32
# 정확도 :0.6796116504854369, seed_num = 33
# 정확도 :0.6867313915857605, seed_num = 34
# 정확도 :0.6912621359223301, seed_num = 35
# 정확도 :0.6737864077669903, seed_num = 36
# 정확도 :0.7048543689320388, seed_num = 37
# 정확도 :0.683495145631068, seed_num = 38
# 정확도 :0.6789644012944984, seed_num = 39
# 정확도 :0.6880258899676376, seed_num = 40
# 정확도 :0.6951456310679611, seed_num = 41
# 정확도 :0.658252427184466, seed_num = 42
# 정확도 :0.6705501618122978, seed_num = 43
# 정확도 :0.654368932038835, seed_num = 44
# 정확도 :0.6822006472491909, seed_num = 45
# 정확도 :0.6737864077669903, seed_num = 46
# 정확도 :0.7042071197411003, seed_num = 47
# 정확도 :0.7022653721682848, seed_num = 48
# 정확도 :0.6666666666666666, seed_num = 49

# %%
# seed = 42의 정확도 df 만들고 평균 확인 => 67.9
df_42 = pd.DataFrame.from_dict(dic_42, orient='index')
df_42.mean()
# Out:
# 0    0.679262
# dtype: float64

# %% [markdown]
# ## absum 그래프

# %%
mm_list = [409606211, 74606211, 67434504, 10019055302, 54817525,
           51277, 54858516, 45006701, 74706811, 51003]
absum(mm_list,mm_list[:10])

# %% [markdown]
# # M1_new_top10
# - 22.02.22 Tue

# %%
m1_new = pd.read_csv('m1_new.csv')
m1_new_top10 = m1_new['feature'].values[:10]
m1_new_top10
# Out:
# array([    51277,     51006,     50912,     50882, 409176230,     50862,
#            51003,     50983,     50893, 487980125])

# %% [markdown]
# ## (65.6) RF

# %%
# m1_new만을 가진 x_(7727,10)_m1_new 만들기
item_list = list(total_data['ITEMID'].sort_values().unique())

m1_new_index = []
for i in m1_new_top10:
    m1_new_index.append(item_list.index(i))

print('m1_new_top10의 index : ',m1_new_index)

x = np.load('x_(7727,4068).npy')
x_2d = x[:,m1_new_index]
x_2d.shape

# np.save('x_(7727,10)_m1_new',x_2d)
# Out:
# m1_new_top10의 index :  [206, 121, 56, 34, 2148, 20, 119, 103, 41, 2291]
# (7727, 10)

# %%
import random
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

model = RandomForestClassifier()

data={}
for seed in range(42, 52):
    random.seed(seed)
    
    x = np.load('./x_(7727,10)_m1_new.npy')
    y = np.load('./y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_train, y_train = x[idx[:i],:], y[idx[:i]]
    X_test, y_test = x[idx[i:],:], y[idx[i:]]
    
    _ = model.fit(X_train, y_train)
    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)
    
    acc = accuracy_score(y_test, y_pred_test)
    data[seed]=acc
    print(f'정확도 : {acc}, seed_num = {seed}')

df = pd.DataFrame.from_dict(data, orient='index')
print(f'정확도 df 만들고 평균 확인 : {df.mean().values}')
# Out:
# 정확도 : 0.6524271844660194, seed_num = 42
# 정확도 : 0.6550161812297735, seed_num = 43
# 정확도 : 0.6381877022653721, seed_num = 44
# 정확도 : 0.6433656957928803, seed_num = 45
# 정확도 : 0.6588996763754046, seed_num = 46
# 정확도 : 0.6653721682847896, seed_num = 47
# 정확도 : 0.6815533980582524, seed_num = 48
# 정확도 : 0.6524271844660194, seed_num = 49
# 정확도 : 0.6608414239482201, seed_num = 50
# 정확도 : 0.6537216828478964, seed_num = 51
# 정확도 df 만들고 평균 확인 : [0.65618123]

# %% [markdown]
# ## (70.3) LSTM

# %%
# m1_new_top10만을 가진 x_(7727,10,10)_m1_new 만들기
total_data = pd.read_csv('total_data_7727.csv')
item_list = list(total_data['ITEMID'].sort_values().unique())

m1_new_top10_index = []
for i in m1_new_top10:
    m1_new_top10_index.append(item_list.index(i))

print('m1_new_top10의 index : ',m1_new_top10_index)

x = np.load('x_(7727,10,4068).npy')
x_3d = x[:,:,m1_new_top10_index]
x_3d.shape
x_3d.sum()

# np.save('x_(7727,10,10)_m1_new.npy',x_3d)
# Out:
# m1_new_top10의 index :  [206, 121, 56, 34, 2148, 20, 119, 103, 41, 2291]
# (7727, 10, 10)
# 160495.0

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings(action='ignore')

import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, InputLayer
from tensorflow.keras.callbacks import EarlyStopping
from sklearn import metrics 
from tensorflow import keras
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

import random
# ----------------------
seed_num = 42
# ----------------------
random.seed(seed_num)

x = np.load('x_(7727,10,10)_m1_new.npy')
y = np.load('y_(7727,1).npy')

idx = list(range(len(x)))
random.shuffle(idx)

i = round(x.shape[0]*0.8)
X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
X_test, y_test = x[idx[i:],:,:], y[idx[i:]]

# ---------------------
seed_num = 42 
# ---------------------
tf.random.set_seed(seed_num)

lstm = Sequential()
lstm.add(InputLayer(input_shape=(X_train.shape[1],X_train.shape[2])))
lstm.add(LSTM(units=128, activation='hard_sigmoid', return_sequences=True))
lstm.add(LSTM(units=64, activation='hard_sigmoid', return_sequences=True))
lstm.add(Dropout(0.2))
lstm.add(LSTM(units=64, activation='hard_sigmoid', return_sequences=True))
lstm.add(LSTM(units=32, activation='hard_sigmoid', return_sequences=False))
lstm.add(Dropout(0.2))
lstm.add(Dense(units=1, activation='sigmoid'))

from tensorflow.keras.callbacks import ModelCheckpoint
import os

MODEL_SAVE_FOLDER_PATH = './model/'
if not os.path.exists(MODEL_SAVE_FOLDER_PATH):
    os.mkdir(MODEL_SAVE_FOLDER_PATH)

model_path = MODEL_SAVE_FOLDER_PATH + 'm1_new_seed42-{epoch:02d}-{val_loss:.4f}.hdf5'

cb_checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss',
                                verbose=1, save_best_only=True)

early_stop = EarlyStopping(monitor='val_acc', patience=50, verbose=1, restore_best_weights=True)
lstm.compile(optimizer= keras.optimizers.Adam(learning_rate = 0.001), loss = "binary_crossentropy", metrics=['acc'])
lstm.fit(X_train, y_train, validation_split=0.25, batch_size=128, epochs=500,  callbacks=[early_stop,cb_checkpoint], shuffle=False)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/500
# 37/37 [==============================] - 6s 71ms/step - loss: 0.6758 - acc: 0.5984 - val_loss: 0.6660 - val_acc: 0.6177
#
# Epoch 00001: val_loss improved from inf to 0.66597, saving model to ./model/m1_new_seed42-01-0.6660.hdf5
# Epoch 2/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6731 - acc: 0.6068 - val_loss: 0.6661 - val_acc: 0.6177
#
# Epoch 00002: val_loss did not improve from 0.66597
# Epoch 3/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6734 - acc: 0.6083 - val_loss: 0.6646 - val_acc: 0.6177
#
# Epoch 00003: val_loss improved from 0.66597 to 0.66464, saving model to ./model/m1_new_seed42-03-0.6646.hdf5
# Epoch 4/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6646 - acc: 0.6117 - val_loss: 0.6475 - val_acc: 0.6177
#
# Epoch 00004: val_loss improved from 0.66464 to 0.64750, saving model to ./model/m1_new_seed42-04-0.6475.hdf5
# Epoch 5/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6422 - acc: 0.6111 - val_loss: 0.6341 - val_acc: 0.6177
#
# Epoch 00005: val_loss improved from 0.64750 to 0.63411, saving model to ./model/m1_new_seed42-05-0.6341.hdf5
# Epoch 6/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6270 - acc: 0.6445 - val_loss: 0.6224 - val_acc: 0.6611
#
# Epoch 00006: val_loss improved from 0.63411 to 0.62238, saving model to ./model/m1_new_seed42-06-0.6224.hdf5
# Epoch 7/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6163 - acc: 0.6635 - val_loss: 0.6231 - val_acc: 0.6630
#
# Epoch 00007: val_loss did not improve from 0.62238
# Epoch 8/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6141 - acc: 0.6687 - val_loss: 0.6143 - val_acc: 0.6811
#
# Epoch 00008: val_loss improved from 0.62238 to 0.61425, saving model to ./model/m1_new_seed42-08-0.6143.hdf5
# Epoch 9/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6067 - acc: 0.6736 - val_loss: 0.6095 - val_acc: 0.6721
#
# Epoch 00009: val_loss improved from 0.61425 to 0.60951, saving model to ./model/m1_new_seed42-09-0.6095.hdf5
# Epoch 10/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6012 - acc: 0.6844 - val_loss: 0.6069 - val_acc: 0.6721
#
# Epoch 00010: val_loss improved from 0.60951 to 0.60694, saving model to ./model/m1_new_seed42-10-0.6069.hdf5
# Epoch 11/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6008 - acc: 0.6877 - val_loss: 0.6059 - val_acc: 0.6766
#
# Epoch 00011: val_loss improved from 0.60694 to 0.60587, saving model to ./model/m1_new_seed42-11-0.6059.hdf5
# Epoch 12/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5963 - acc: 0.6864 - val_loss: 0.6054 - val_acc: 0.6818
#
# Epoch 00012: val_loss improved from 0.60587 to 0.60537, saving model to ./model/m1_new_seed42-12-0.6054.hdf5
# Epoch 13/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5951 - acc: 0.6898 - val_loss: 0.6022 - val_acc: 0.6753
#
# Epoch 00013: val_loss improved from 0.60537 to 0.60222, saving model to ./model/m1_new_seed42-13-0.6022.hdf5
# Epoch 14/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5932 - acc: 0.6900 - val_loss: 0.6013 - val_acc: 0.6753
#
# Epoch 00014: val_loss improved from 0.60222 to 0.60127, saving model to ./model/m1_new_seed42-14-0.6013.hdf5
# Epoch 15/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5920 - acc: 0.6915 - val_loss: 0.5989 - val_acc: 0.6759
#
# Epoch 00015: val_loss improved from 0.60127 to 0.59891, saving model to ./model/m1_new_seed42-15-0.5989.hdf5
# Epoch 16/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5904 - acc: 0.6926 - val_loss: 0.5981 - val_acc: 0.6766
#
# Epoch 00016: val_loss improved from 0.59891 to 0.59812, saving model to ./model/m1_new_seed42-16-0.5981.hdf5
# Epoch 17/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5912 - acc: 0.6941 - val_loss: 0.5967 - val_acc: 0.6785
#
# Epoch 00017: val_loss improved from 0.59812 to 0.59666, saving model to ./model/m1_new_seed42-17-0.5967.hdf5
# Epoch 18/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5865 - acc: 0.6989 - val_loss: 0.5972 - val_acc: 0.6785
#
# Epoch 00018: val_loss did not improve from 0.59666
# Epoch 19/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5887 - acc: 0.6918 - val_loss: 0.5950 - val_acc: 0.6779
#
# Epoch 00019: val_loss improved from 0.59666 to 0.59501, saving model to ./model/m1_new_seed42-19-0.5950.hdf5
# Epoch 20/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5873 - acc: 0.6939 - val_loss: 0.5933 - val_acc: 0.6766
#
# Epoch 00020: val_loss improved from 0.59501 to 0.59334, saving model to ./model/m1_new_seed42-20-0.5933.hdf5
# Epoch 21/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5847 - acc: 0.6984 - val_loss: 0.5944 - val_acc: 0.6818
#
# Epoch 00021: val_loss did not improve from 0.59334
# Epoch 22/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5853 - acc: 0.6976 - val_loss: 0.5930 - val_acc: 0.6811
#
# Epoch 00022: val_loss improved from 0.59334 to 0.59299, saving model to ./model/m1_new_seed42-22-0.5930.hdf5
# Epoch 23/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5856 - acc: 0.6933 - val_loss: 0.5921 - val_acc: 0.6811
#
# Epoch 00023: val_loss improved from 0.59299 to 0.59208, saving model to ./model/m1_new_seed42-23-0.5921.hdf5
# Epoch 24/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5836 - acc: 0.6946 - val_loss: 0.5901 - val_acc: 0.6766
#
# Epoch 00024: val_loss improved from 0.59208 to 0.59007, saving model to ./model/m1_new_seed42-24-0.5901.hdf5
# Epoch 25/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5832 - acc: 0.7008 - val_loss: 0.5899 - val_acc: 0.6785
#
# Epoch 00025: val_loss improved from 0.59007 to 0.58989, saving model to ./model/m1_new_seed42-25-0.5899.hdf5
# Epoch 26/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5812 - acc: 0.6993 - val_loss: 0.5895 - val_acc: 0.6792
#
# Epoch 00026: val_loss improved from 0.58989 to 0.58946, saving model to ./model/m1_new_seed42-26-0.5895.hdf5
# Epoch 27/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5801 - acc: 0.7021 - val_loss: 0.5889 - val_acc: 0.6785
#
# Epoch 00027: val_loss improved from 0.58946 to 0.58885, saving model to ./model/m1_new_seed42-27-0.5889.hdf5
# Epoch 28/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5785 - acc: 0.7015 - val_loss: 0.5884 - val_acc: 0.6805
#
# Epoch 00028: val_loss improved from 0.58885 to 0.58843, saving model to ./model/m1_new_seed42-28-0.5884.hdf5
# Epoch 29/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5794 - acc: 0.7015 - val_loss: 0.5876 - val_acc: 0.6785
#
# Epoch 00029: val_loss improved from 0.58843 to 0.58765, saving model to ./model/m1_new_seed42-29-0.5876.hdf5
# Epoch 30/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5793 - acc: 0.7015 - val_loss: 0.5875 - val_acc: 0.6785
#
# Epoch 00030: val_loss improved from 0.58765 to 0.58751, saving model to ./model/m1_new_seed42-30-0.5875.hdf5
# Epoch 31/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5768 - acc: 0.7017 - val_loss: 0.5876 - val_acc: 0.6818
#
# Epoch 00031: val_loss did not improve from 0.58751
# Epoch 32/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5801 - acc: 0.7025 - val_loss: 0.5860 - val_acc: 0.6792
#
# Epoch 00032: val_loss improved from 0.58751 to 0.58601, saving model to ./model/m1_new_seed42-32-0.5860.hdf5
# Epoch 33/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5776 - acc: 0.7034 - val_loss: 0.5859 - val_acc: 0.6772
#
# Epoch 00033: val_loss improved from 0.58601 to 0.58595, saving model to ./model/m1_new_seed42-33-0.5859.hdf5
# Epoch 34/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5754 - acc: 0.7028 - val_loss: 0.5865 - val_acc: 0.6811
#
# Epoch 00034: val_loss did not improve from 0.58595
# Epoch 35/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5769 - acc: 0.7034 - val_loss: 0.5871 - val_acc: 0.6818
#
# Epoch 00035: val_loss did not improve from 0.58595
# Epoch 36/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5779 - acc: 0.7002 - val_loss: 0.5852 - val_acc: 0.6785
#
# Epoch 00036: val_loss improved from 0.58595 to 0.58517, saving model to ./model/m1_new_seed42-36-0.5852.hdf5
# Epoch 37/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5743 - acc: 0.7019 - val_loss: 0.5848 - val_acc: 0.6785
#
# Epoch 00037: val_loss improved from 0.58517 to 0.58481, saving model to ./model/m1_new_seed42-37-0.5848.hdf5
# Epoch 38/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5748 - acc: 0.7034 - val_loss: 0.5852 - val_acc: 0.6831
#
# Epoch 00038: val_loss did not improve from 0.58481
# Epoch 39/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5764 - acc: 0.7010 - val_loss: 0.5840 - val_acc: 0.6798
#
# Epoch 00039: val_loss improved from 0.58481 to 0.58395, saving model to ./model/m1_new_seed42-39-0.5840.hdf5
# Epoch 40/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5746 - acc: 0.7028 - val_loss: 0.5843 - val_acc: 0.6785
#
# Epoch 00040: val_loss did not improve from 0.58395
# Epoch 41/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5762 - acc: 0.7006 - val_loss: 0.5845 - val_acc: 0.6811
#
# Epoch 00041: val_loss did not improve from 0.58395
# Epoch 42/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5718 - acc: 0.7073 - val_loss: 0.5844 - val_acc: 0.6824
#
# Epoch 00042: val_loss did not improve from 0.58395
# Epoch 43/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5741 - acc: 0.7047 - val_loss: 0.5847 - val_acc: 0.6818
#
# Epoch 00043: val_loss did not improve from 0.58395
# Epoch 44/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5732 - acc: 0.7030 - val_loss: 0.5835 - val_acc: 0.6798
#
# Epoch 00044: val_loss improved from 0.58395 to 0.58351, saving model to ./model/m1_new_seed42-44-0.5835.hdf5
# Epoch 45/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5718 - acc: 0.7028 - val_loss: 0.5851 - val_acc: 0.6882
#
# Epoch 00045: val_loss did not improve from 0.58351
# Epoch 46/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5747 - acc: 0.7043 - val_loss: 0.5842 - val_acc: 0.6798
#
# Epoch 00046: val_loss did not improve from 0.58351
# Epoch 47/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5719 - acc: 0.7043 - val_loss: 0.5835 - val_acc: 0.6818
#
# Epoch 00047: val_loss did not improve from 0.58351
# Epoch 48/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5723 - acc: 0.7043 - val_loss: 0.5843 - val_acc: 0.6843
#
# Epoch 00048: val_loss did not improve from 0.58351
# Epoch 49/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5721 - acc: 0.7034 - val_loss: 0.5832 - val_acc: 0.6798
#
# Epoch 00049: val_loss improved from 0.58351 to 0.58315, saving model to ./model/m1_new_seed42-49-0.5832.hdf5
# Epoch 50/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5714 - acc: 0.7062 - val_loss: 0.5834 - val_acc: 0.6818
#
# Epoch 00050: val_loss did not improve from 0.58315
# Epoch 51/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5696 - acc: 0.7025 - val_loss: 0.5831 - val_acc: 0.6805
#
# Epoch 00051: val_loss improved from 0.58315 to 0.58305, saving model to ./model/m1_new_seed42-51-0.5831.hdf5
# Epoch 52/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5695 - acc: 0.7041 - val_loss: 0.5833 - val_acc: 0.6850
#
# Epoch 00052: val_loss did not improve from 0.58305
# Epoch 53/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5708 - acc: 0.7049 - val_loss: 0.5829 - val_acc: 0.6824
#
# Epoch 00053: val_loss improved from 0.58305 to 0.58288, saving model to ./model/m1_new_seed42-53-0.5829.hdf5
# Epoch 54/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5685 - acc: 0.7064 - val_loss: 0.5838 - val_acc: 0.6843
#
# Epoch 00054: val_loss did not improve from 0.58288
# Epoch 55/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5695 - acc: 0.7082 - val_loss: 0.5838 - val_acc: 0.6850
#
# Epoch 00055: val_loss did not improve from 0.58288
# Epoch 56/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5671 - acc: 0.7060 - val_loss: 0.5831 - val_acc: 0.6863
#
# Epoch 00056: val_loss did not improve from 0.58288
# Epoch 57/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5689 - acc: 0.7086 - val_loss: 0.5832 - val_acc: 0.6850
#
# Epoch 00057: val_loss did not improve from 0.58288
# Epoch 58/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5669 - acc: 0.7079 - val_loss: 0.5838 - val_acc: 0.6863
#
# Epoch 00058: val_loss did not improve from 0.58288
# Epoch 59/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5681 - acc: 0.7090 - val_loss: 0.5831 - val_acc: 0.6895
#
# Epoch 00059: val_loss did not improve from 0.58288
# Epoch 60/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5660 - acc: 0.7069 - val_loss: 0.5826 - val_acc: 0.6902
#
# Epoch 00060: val_loss improved from 0.58288 to 0.58258, saving model to ./model/m1_new_seed42-60-0.5826.hdf5
# Epoch 61/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5669 - acc: 0.7041 - val_loss: 0.5828 - val_acc: 0.6889
#
# Epoch 00061: val_loss did not improve from 0.58258
# Epoch 62/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5678 - acc: 0.7073 - val_loss: 0.5830 - val_acc: 0.6902
#
# Epoch 00062: val_loss did not improve from 0.58258
# Epoch 63/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5672 - acc: 0.7101 - val_loss: 0.5832 - val_acc: 0.6902
#
# Epoch 00063: val_loss did not improve from 0.58258
# Epoch 64/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5668 - acc: 0.7088 - val_loss: 0.5821 - val_acc: 0.6908
#
# Epoch 00064: val_loss improved from 0.58258 to 0.58205, saving model to ./model/m1_new_seed42-64-0.5821.hdf5
# Epoch 65/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5650 - acc: 0.7101 - val_loss: 0.5836 - val_acc: 0.6902
#
# Epoch 00065: val_loss did not improve from 0.58205
# Epoch 66/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5648 - acc: 0.7077 - val_loss: 0.5816 - val_acc: 0.6934
#
# Epoch 00066: val_loss improved from 0.58205 to 0.58159, saving model to ./model/m1_new_seed42-66-0.5816.hdf5
# Epoch 67/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5631 - acc: 0.7125 - val_loss: 0.5826 - val_acc: 0.6915
#
# Epoch 00067: val_loss did not improve from 0.58159
# Epoch 68/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5656 - acc: 0.7107 - val_loss: 0.5825 - val_acc: 0.6921
#
# Epoch 00068: val_loss did not improve from 0.58159
# Epoch 69/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5639 - acc: 0.7099 - val_loss: 0.5824 - val_acc: 0.6921
#
# Epoch 00069: val_loss did not improve from 0.58159
# Epoch 70/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5656 - acc: 0.7125 - val_loss: 0.5823 - val_acc: 0.6915
#
# Epoch 00070: val_loss did not improve from 0.58159
# Epoch 71/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5608 - acc: 0.7071 - val_loss: 0.5829 - val_acc: 0.6908
#
# Epoch 00071: val_loss did not improve from 0.58159
# Epoch 72/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5624 - acc: 0.7116 - val_loss: 0.5837 - val_acc: 0.6921
#
# Epoch 00072: val_loss did not improve from 0.58159
# Epoch 73/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5625 - acc: 0.7112 - val_loss: 0.5822 - val_acc: 0.6934
#
# Epoch 00073: val_loss did not improve from 0.58159
# Epoch 74/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5634 - acc: 0.7133 - val_loss: 0.5822 - val_acc: 0.6915
#
# Epoch 00074: val_loss did not improve from 0.58159
# Epoch 75/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5624 - acc: 0.7084 - val_loss: 0.5825 - val_acc: 0.6915
#
# Epoch 00075: val_loss did not improve from 0.58159
# Epoch 76/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5626 - acc: 0.7116 - val_loss: 0.5813 - val_acc: 0.6895
#
# Epoch 00076: val_loss improved from 0.58159 to 0.58134, saving model to ./model/m1_new_seed42-76-0.5813.hdf5
# Epoch 77/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5591 - acc: 0.7131 - val_loss: 0.5827 - val_acc: 0.6921
#
# Epoch 00077: val_loss did not improve from 0.58134
# Epoch 78/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5619 - acc: 0.7105 - val_loss: 0.5821 - val_acc: 0.6889
#
# Epoch 00078: val_loss did not improve from 0.58134
# Epoch 79/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5631 - acc: 0.7148 - val_loss: 0.5811 - val_acc: 0.6921
#
# Epoch 00079: val_loss improved from 0.58134 to 0.58109, saving model to ./model/m1_new_seed42-79-0.5811.hdf5
# Epoch 80/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5603 - acc: 0.7142 - val_loss: 0.5824 - val_acc: 0.6889
#
# Epoch 00080: val_loss did not improve from 0.58109
# Epoch 81/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5606 - acc: 0.7131 - val_loss: 0.5808 - val_acc: 0.6921
#
# Epoch 00081: val_loss improved from 0.58109 to 0.58078, saving model to ./model/m1_new_seed42-81-0.5808.hdf5
# Epoch 82/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5605 - acc: 0.7138 - val_loss: 0.5817 - val_acc: 0.6915
#
# Epoch 00082: val_loss did not improve from 0.58078
# Epoch 83/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5584 - acc: 0.7142 - val_loss: 0.5823 - val_acc: 0.6908
#
# Epoch 00083: val_loss did not improve from 0.58078
# Epoch 84/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5608 - acc: 0.7133 - val_loss: 0.5814 - val_acc: 0.6908
#
# Epoch 00084: val_loss did not improve from 0.58078
# Epoch 85/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5600 - acc: 0.7105 - val_loss: 0.5815 - val_acc: 0.6921
#
# Epoch 00085: val_loss did not improve from 0.58078
# Epoch 86/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5602 - acc: 0.7170 - val_loss: 0.5815 - val_acc: 0.6915
#
# Epoch 00086: val_loss did not improve from 0.58078
# Epoch 87/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5594 - acc: 0.7187 - val_loss: 0.5806 - val_acc: 0.6928
#
# Epoch 00087: val_loss improved from 0.58078 to 0.58063, saving model to ./model/m1_new_seed42-87-0.5806.hdf5
# Epoch 88/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5580 - acc: 0.7144 - val_loss: 0.5818 - val_acc: 0.6928
#
# Epoch 00088: val_loss did not improve from 0.58063
# Epoch 89/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5579 - acc: 0.7148 - val_loss: 0.5810 - val_acc: 0.6915
#
# Epoch 00089: val_loss did not improve from 0.58063
# Epoch 90/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5578 - acc: 0.7140 - val_loss: 0.5821 - val_acc: 0.6902
#
# Epoch 00090: val_loss did not improve from 0.58063
# Epoch 91/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5568 - acc: 0.7168 - val_loss: 0.5809 - val_acc: 0.6934
#
# Epoch 00091: val_loss did not improve from 0.58063
# Epoch 92/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5556 - acc: 0.7153 - val_loss: 0.5808 - val_acc: 0.6940
#
# Epoch 00092: val_loss did not improve from 0.58063
# Epoch 93/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5582 - acc: 0.7148 - val_loss: 0.5814 - val_acc: 0.6908
#
# Epoch 00093: val_loss did not improve from 0.58063
# Epoch 94/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5580 - acc: 0.7176 - val_loss: 0.5812 - val_acc: 0.6947
#
# Epoch 00094: val_loss did not improve from 0.58063
# Epoch 95/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5556 - acc: 0.7174 - val_loss: 0.5822 - val_acc: 0.6863
#
# Epoch 00095: val_loss did not improve from 0.58063
# Epoch 96/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5561 - acc: 0.7189 - val_loss: 0.5818 - val_acc: 0.6895
#
# Epoch 00096: val_loss did not improve from 0.58063
# Epoch 97/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5558 - acc: 0.7185 - val_loss: 0.5819 - val_acc: 0.6915
#
# Epoch 00097: val_loss did not improve from 0.58063
# Epoch 98/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5560 - acc: 0.7140 - val_loss: 0.5810 - val_acc: 0.6915
#
# Epoch 00098: val_loss did not improve from 0.58063
# Epoch 99/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5572 - acc: 0.7159 - val_loss: 0.5812 - val_acc: 0.6934
#
# Epoch 00099: val_loss did not improve from 0.58063
# Epoch 100/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5559 - acc: 0.7153 - val_loss: 0.5808 - val_acc: 0.6895
#
# Epoch 00100: val_loss did not improve from 0.58063
# Epoch 101/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5548 - acc: 0.7157 - val_loss: 0.5816 - val_acc: 0.6889
#
# Epoch 00101: val_loss did not improve from 0.58063
# Epoch 102/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5544 - acc: 0.7170 - val_loss: 0.5815 - val_acc: 0.6934
#
# Epoch 00102: val_loss did not improve from 0.58063
# Epoch 103/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5531 - acc: 0.7164 - val_loss: 0.5833 - val_acc: 0.6908
#
# Epoch 00103: val_loss did not improve from 0.58063
# Epoch 104/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5528 - acc: 0.7159 - val_loss: 0.5827 - val_acc: 0.6953
#
# Epoch 00104: val_loss did not improve from 0.58063
# Epoch 105/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5554 - acc: 0.7155 - val_loss: 0.5818 - val_acc: 0.6915
#
# Epoch 00105: val_loss did not improve from 0.58063
# Epoch 106/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5575 - acc: 0.7207 - val_loss: 0.5806 - val_acc: 0.6921
#
# Epoch 00106: val_loss did not improve from 0.58063
# Epoch 107/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5540 - acc: 0.7192 - val_loss: 0.5826 - val_acc: 0.6908
#
# Epoch 00107: val_loss did not improve from 0.58063
# Epoch 108/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5525 - acc: 0.7176 - val_loss: 0.5814 - val_acc: 0.6915
#
# Epoch 00108: val_loss did not improve from 0.58063
# Epoch 109/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5502 - acc: 0.7200 - val_loss: 0.5828 - val_acc: 0.6915
#
# Epoch 00109: val_loss did not improve from 0.58063
# Epoch 110/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5521 - acc: 0.7196 - val_loss: 0.5820 - val_acc: 0.6915
#
# Epoch 00110: val_loss did not improve from 0.58063
# Epoch 111/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5510 - acc: 0.7228 - val_loss: 0.5809 - val_acc: 0.6921
#
# Epoch 00111: val_loss did not improve from 0.58063
# Epoch 112/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5508 - acc: 0.7200 - val_loss: 0.5824 - val_acc: 0.6921
#
# Epoch 00112: val_loss did not improve from 0.58063
# Epoch 113/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5495 - acc: 0.7194 - val_loss: 0.5835 - val_acc: 0.6915
#
# Epoch 00113: val_loss did not improve from 0.58063
# Epoch 114/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5517 - acc: 0.7213 - val_loss: 0.5820 - val_acc: 0.6915
#
# Epoch 00114: val_loss did not improve from 0.58063
# Epoch 115/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5516 - acc: 0.7220 - val_loss: 0.5818 - val_acc: 0.6895
#
# Epoch 00115: val_loss did not improve from 0.58063
# Epoch 116/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5495 - acc: 0.7196 - val_loss: 0.5834 - val_acc: 0.6895
#
# Epoch 00116: val_loss did not improve from 0.58063
# Epoch 117/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5485 - acc: 0.7233 - val_loss: 0.5849 - val_acc: 0.6908
#
# Epoch 00117: val_loss did not improve from 0.58063
# Epoch 118/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5479 - acc: 0.7207 - val_loss: 0.5830 - val_acc: 0.6934
#
# Epoch 00118: val_loss did not improve from 0.58063
# Epoch 119/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5482 - acc: 0.7192 - val_loss: 0.5840 - val_acc: 0.6934
#
# Epoch 00119: val_loss did not improve from 0.58063
# Epoch 120/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5486 - acc: 0.7233 - val_loss: 0.5824 - val_acc: 0.6966
#
# Epoch 00120: val_loss did not improve from 0.58063
# Epoch 121/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5477 - acc: 0.7256 - val_loss: 0.5832 - val_acc: 0.6915
#
# Epoch 00121: val_loss did not improve from 0.58063
# Epoch 122/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5479 - acc: 0.7235 - val_loss: 0.5843 - val_acc: 0.6928
#
# Epoch 00122: val_loss did not improve from 0.58063
# Epoch 123/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5476 - acc: 0.7245 - val_loss: 0.5836 - val_acc: 0.6940
#
# Epoch 00123: val_loss did not improve from 0.58063
# Epoch 124/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5474 - acc: 0.7226 - val_loss: 0.5826 - val_acc: 0.6940
#
# Epoch 00124: val_loss did not improve from 0.58063
# Epoch 125/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5473 - acc: 0.7228 - val_loss: 0.5841 - val_acc: 0.6966
#
# Epoch 00125: val_loss did not improve from 0.58063
# Epoch 126/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5453 - acc: 0.7230 - val_loss: 0.5857 - val_acc: 0.6960
#
# Epoch 00126: val_loss did not improve from 0.58063
# Epoch 127/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5451 - acc: 0.7235 - val_loss: 0.5854 - val_acc: 0.6928
#
# Epoch 00127: val_loss did not improve from 0.58063
# Epoch 128/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5466 - acc: 0.7230 - val_loss: 0.5847 - val_acc: 0.6902
#
# Epoch 00128: val_loss did not improve from 0.58063
# Epoch 129/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5458 - acc: 0.7217 - val_loss: 0.5836 - val_acc: 0.6921
#
# Epoch 00129: val_loss did not improve from 0.58063
# Epoch 130/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5445 - acc: 0.7239 - val_loss: 0.5866 - val_acc: 0.6915
#
# Epoch 00130: val_loss did not improve from 0.58063
# Epoch 131/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5434 - acc: 0.7207 - val_loss: 0.5860 - val_acc: 0.6947
#
# Epoch 00131: val_loss did not improve from 0.58063
# Epoch 132/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5430 - acc: 0.7263 - val_loss: 0.5860 - val_acc: 0.6921
#
# Epoch 00132: val_loss did not improve from 0.58063
# Epoch 133/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5454 - acc: 0.7230 - val_loss: 0.5896 - val_acc: 0.6921
#
# Epoch 00133: val_loss did not improve from 0.58063
# Epoch 134/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5450 - acc: 0.7228 - val_loss: 0.5869 - val_acc: 0.6889
#
# Epoch 00134: val_loss did not improve from 0.58063
# Epoch 135/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5424 - acc: 0.7224 - val_loss: 0.5899 - val_acc: 0.6928
#
# Epoch 00135: val_loss did not improve from 0.58063
# Epoch 136/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5446 - acc: 0.7230 - val_loss: 0.5884 - val_acc: 0.6895
#
# Epoch 00136: val_loss did not improve from 0.58063
# Epoch 137/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5440 - acc: 0.7217 - val_loss: 0.5891 - val_acc: 0.6915
#
# Epoch 00137: val_loss did not improve from 0.58063
# Epoch 138/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5442 - acc: 0.7228 - val_loss: 0.5903 - val_acc: 0.6921
#
# Epoch 00138: val_loss did not improve from 0.58063
# Epoch 139/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5429 - acc: 0.7258 - val_loss: 0.5891 - val_acc: 0.6902
#
# Epoch 00139: val_loss did not improve from 0.58063
# Epoch 140/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5416 - acc: 0.7235 - val_loss: 0.5892 - val_acc: 0.6921
#
# Epoch 00140: val_loss did not improve from 0.58063
# Epoch 141/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5419 - acc: 0.7237 - val_loss: 0.5912 - val_acc: 0.6908
#
# Epoch 00141: val_loss did not improve from 0.58063
# Epoch 142/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5404 - acc: 0.7250 - val_loss: 0.5920 - val_acc: 0.6902
#
# Epoch 00142: val_loss did not improve from 0.58063
# Epoch 143/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5426 - acc: 0.7274 - val_loss: 0.5907 - val_acc: 0.6889
#
# Epoch 00143: val_loss did not improve from 0.58063
# Epoch 144/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5418 - acc: 0.7215 - val_loss: 0.5918 - val_acc: 0.6947
#
# Epoch 00144: val_loss did not improve from 0.58063
# Epoch 145/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5399 - acc: 0.7252 - val_loss: 0.5945 - val_acc: 0.6915
#
# Epoch 00145: val_loss did not improve from 0.58063
# Epoch 146/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5399 - acc: 0.7237 - val_loss: 0.5917 - val_acc: 0.6921
#
# Epoch 00146: val_loss did not improve from 0.58063
# Epoch 147/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5409 - acc: 0.7235 - val_loss: 0.5935 - val_acc: 0.6934
#
# Epoch 00147: val_loss did not improve from 0.58063
# Epoch 148/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5362 - acc: 0.7297 - val_loss: 0.5962 - val_acc: 0.6940
#
# Epoch 00148: val_loss did not improve from 0.58063
# Epoch 149/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5387 - acc: 0.7239 - val_loss: 0.5964 - val_acc: 0.6902
#
# Epoch 00149: val_loss did not improve from 0.58063
# Epoch 150/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5391 - acc: 0.7243 - val_loss: 0.5977 - val_acc: 0.6921
#
# Epoch 00150: val_loss did not improve from 0.58063
# Epoch 151/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5393 - acc: 0.7252 - val_loss: 0.5936 - val_acc: 0.6934
#
# Epoch 00151: val_loss did not improve from 0.58063
# Epoch 152/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5393 - acc: 0.7245 - val_loss: 0.5953 - val_acc: 0.6928
#
# Epoch 00152: val_loss did not improve from 0.58063
# Epoch 153/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5355 - acc: 0.7286 - val_loss: 0.5970 - val_acc: 0.6928
#
# Epoch 00153: val_loss did not improve from 0.58063
# Epoch 154/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5365 - acc: 0.7282 - val_loss: 0.5986 - val_acc: 0.6921
#
# Epoch 00154: val_loss did not improve from 0.58063
# Epoch 155/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5382 - acc: 0.7250 - val_loss: 0.5961 - val_acc: 0.6940
#
# Epoch 00155: val_loss did not improve from 0.58063
# Epoch 156/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5352 - acc: 0.7297 - val_loss: 0.6003 - val_acc: 0.6928
#
# Epoch 00156: val_loss did not improve from 0.58063
# Epoch 157/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5372 - acc: 0.7243 - val_loss: 0.5975 - val_acc: 0.6928
#
# Epoch 00157: val_loss did not improve from 0.58063
# Epoch 158/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5347 - acc: 0.7267 - val_loss: 0.5996 - val_acc: 0.6915
#
# Epoch 00158: val_loss did not improve from 0.58063
# Epoch 159/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5363 - acc: 0.7258 - val_loss: 0.5984 - val_acc: 0.6915
#
# Epoch 00159: val_loss did not improve from 0.58063
# Epoch 160/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5336 - acc: 0.7250 - val_loss: 0.5964 - val_acc: 0.6928
#
# Epoch 00160: val_loss did not improve from 0.58063
# Epoch 161/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5339 - acc: 0.7304 - val_loss: 0.6010 - val_acc: 0.6921
#
# Epoch 00161: val_loss did not improve from 0.58063
# Epoch 162/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5327 - acc: 0.7286 - val_loss: 0.5973 - val_acc: 0.6915
#
# Epoch 00162: val_loss did not improve from 0.58063
# Epoch 163/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5334 - acc: 0.7263 - val_loss: 0.6013 - val_acc: 0.6921
#
# Epoch 00163: val_loss did not improve from 0.58063
# Epoch 164/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5319 - acc: 0.7269 - val_loss: 0.6014 - val_acc: 0.6928
#
# Epoch 00164: val_loss did not improve from 0.58063
# Epoch 165/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5325 - acc: 0.7252 - val_loss: 0.6031 - val_acc: 0.6908
#
# Epoch 00165: val_loss did not improve from 0.58063
# Epoch 166/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5328 - acc: 0.7295 - val_loss: 0.6056 - val_acc: 0.6934
#
# Epoch 00166: val_loss did not improve from 0.58063
# Epoch 167/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5302 - acc: 0.7289 - val_loss: 0.6044 - val_acc: 0.6934
#
# Epoch 00167: val_loss did not improve from 0.58063
# Epoch 168/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5331 - acc: 0.7280 - val_loss: 0.5966 - val_acc: 0.6953
#
# Epoch 00168: val_loss did not improve from 0.58063
# Epoch 169/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5300 - acc: 0.7286 - val_loss: 0.6013 - val_acc: 0.6973
#
# Epoch 00169: val_loss did not improve from 0.58063
# Epoch 170/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5314 - acc: 0.7302 - val_loss: 0.6031 - val_acc: 0.6921
#
# Epoch 00170: val_loss did not improve from 0.58063
# Epoch 171/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5302 - acc: 0.7284 - val_loss: 0.6053 - val_acc: 0.6947
#
# Epoch 00171: val_loss did not improve from 0.58063
# Epoch 172/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5309 - acc: 0.7291 - val_loss: 0.5997 - val_acc: 0.6915
#
# Epoch 00172: val_loss did not improve from 0.58063
# Epoch 173/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5316 - acc: 0.7278 - val_loss: 0.6021 - val_acc: 0.6979
#
# Epoch 00173: val_loss did not improve from 0.58063
# Epoch 174/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5318 - acc: 0.7263 - val_loss: 0.6013 - val_acc: 0.6986
#
# Epoch 00174: val_loss did not improve from 0.58063
# Epoch 175/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5310 - acc: 0.7278 - val_loss: 0.5962 - val_acc: 0.6966
#
# Epoch 00175: val_loss did not improve from 0.58063
# Epoch 176/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5350 - acc: 0.7258 - val_loss: 0.5971 - val_acc: 0.7031
#
# Epoch 00176: val_loss did not improve from 0.58063
# Epoch 177/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5330 - acc: 0.7269 - val_loss: 0.5949 - val_acc: 0.7063
#
# Epoch 00177: val_loss did not improve from 0.58063
# Epoch 178/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5280 - acc: 0.7312 - val_loss: 0.5970 - val_acc: 0.7025
#
# Epoch 00178: val_loss did not improve from 0.58063
# Epoch 179/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5296 - acc: 0.7271 - val_loss: 0.5964 - val_acc: 0.7025
#
# Epoch 00179: val_loss did not improve from 0.58063
# Epoch 180/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5276 - acc: 0.7332 - val_loss: 0.5982 - val_acc: 0.7018
#
# Epoch 00180: val_loss did not improve from 0.58063
# Epoch 181/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5278 - acc: 0.7293 - val_loss: 0.5985 - val_acc: 0.7025
#
# Epoch 00181: val_loss did not improve from 0.58063
# Epoch 182/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5262 - acc: 0.7334 - val_loss: 0.5956 - val_acc: 0.6986
#
# Epoch 00182: val_loss did not improve from 0.58063
# Epoch 183/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5256 - acc: 0.7332 - val_loss: 0.5984 - val_acc: 0.6940
#
# Epoch 00183: val_loss did not improve from 0.58063
# Epoch 184/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5258 - acc: 0.7306 - val_loss: 0.5972 - val_acc: 0.6934
#
# Epoch 00184: val_loss did not improve from 0.58063
# Epoch 185/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5242 - acc: 0.7349 - val_loss: 0.5973 - val_acc: 0.7012
#
# Epoch 00185: val_loss did not improve from 0.58063
# Epoch 186/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5242 - acc: 0.7334 - val_loss: 0.5989 - val_acc: 0.6966
#
# Epoch 00186: val_loss did not improve from 0.58063
# Epoch 187/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5246 - acc: 0.7343 - val_loss: 0.5962 - val_acc: 0.7012
#
# Epoch 00187: val_loss did not improve from 0.58063
# Epoch 188/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5265 - acc: 0.7327 - val_loss: 0.5975 - val_acc: 0.6992
#
# Epoch 00188: val_loss did not improve from 0.58063
# Epoch 189/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5249 - acc: 0.7349 - val_loss: 0.5968 - val_acc: 0.6947
#
# Epoch 00189: val_loss did not improve from 0.58063
# Epoch 190/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5249 - acc: 0.7349 - val_loss: 0.5951 - val_acc: 0.6973
#
# Epoch 00190: val_loss did not improve from 0.58063
# Epoch 191/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5213 - acc: 0.7362 - val_loss: 0.5995 - val_acc: 0.6973
#
# Epoch 00191: val_loss did not improve from 0.58063
# Epoch 192/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5211 - acc: 0.7349 - val_loss: 0.5969 - val_acc: 0.6973
#
# Epoch 00192: val_loss did not improve from 0.58063
# Epoch 193/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5198 - acc: 0.7381 - val_loss: 0.5993 - val_acc: 0.6928
#
# Epoch 00193: val_loss did not improve from 0.58063
# Epoch 194/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5189 - acc: 0.7373 - val_loss: 0.5978 - val_acc: 0.6940
#
# Epoch 00194: val_loss did not improve from 0.58063
# Epoch 195/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5180 - acc: 0.7386 - val_loss: 0.5991 - val_acc: 0.6947
#
# Epoch 00195: val_loss did not improve from 0.58063
# Epoch 196/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5204 - acc: 0.7349 - val_loss: 0.5994 - val_acc: 0.6953
#
# Epoch 00196: val_loss did not improve from 0.58063
# Epoch 197/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5187 - acc: 0.7347 - val_loss: 0.5996 - val_acc: 0.6915
#
# Epoch 00197: val_loss did not improve from 0.58063
# Epoch 198/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5186 - acc: 0.7379 - val_loss: 0.6026 - val_acc: 0.6921
#
# Epoch 00198: val_loss did not improve from 0.58063
# Epoch 199/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5165 - acc: 0.7377 - val_loss: 0.6035 - val_acc: 0.6895
#
# Epoch 00199: val_loss did not improve from 0.58063
# Epoch 200/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5177 - acc: 0.7366 - val_loss: 0.5999 - val_acc: 0.6953
#
# Epoch 00200: val_loss did not improve from 0.58063
# Epoch 201/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5167 - acc: 0.7405 - val_loss: 0.6018 - val_acc: 0.6979
#
# Epoch 00201: val_loss did not improve from 0.58063
# Epoch 202/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5130 - acc: 0.7384 - val_loss: 0.6041 - val_acc: 0.6928
#
# Epoch 00202: val_loss did not improve from 0.58063
# Epoch 203/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5152 - acc: 0.7414 - val_loss: 0.6042 - val_acc: 0.6992
#
# Epoch 00203: val_loss did not improve from 0.58063
# Epoch 204/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5120 - acc: 0.7388 - val_loss: 0.6047 - val_acc: 0.6902
#
# Epoch 00204: val_loss did not improve from 0.58063
# Epoch 205/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5145 - acc: 0.7399 - val_loss: 0.6020 - val_acc: 0.6895
#
# Epoch 00205: val_loss did not improve from 0.58063
# Epoch 206/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5137 - acc: 0.7399 - val_loss: 0.6050 - val_acc: 0.6915
#
# Epoch 00206: val_loss did not improve from 0.58063
# Epoch 207/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5127 - acc: 0.7390 - val_loss: 0.6070 - val_acc: 0.6908
#
# Epoch 00207: val_loss did not improve from 0.58063
# Epoch 208/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5126 - acc: 0.7407 - val_loss: 0.6095 - val_acc: 0.6934
#
# Epoch 00208: val_loss did not improve from 0.58063
# Epoch 209/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5129 - acc: 0.7403 - val_loss: 0.6072 - val_acc: 0.6940
#
# Epoch 00209: val_loss did not improve from 0.58063
# Epoch 210/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5103 - acc: 0.7399 - val_loss: 0.6080 - val_acc: 0.6902
#
# Epoch 00210: val_loss did not improve from 0.58063
# Epoch 211/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5114 - acc: 0.7355 - val_loss: 0.6059 - val_acc: 0.6863
#
# Epoch 00211: val_loss did not improve from 0.58063
# Epoch 212/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5113 - acc: 0.7379 - val_loss: 0.6064 - val_acc: 0.6876
#
# Epoch 00212: val_loss did not improve from 0.58063
# Epoch 213/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5104 - acc: 0.7399 - val_loss: 0.6071 - val_acc: 0.6876
#
# Epoch 00213: val_loss did not improve from 0.58063
# Epoch 214/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5104 - acc: 0.7405 - val_loss: 0.6067 - val_acc: 0.6902
#
# Epoch 00214: val_loss did not improve from 0.58063
# Epoch 215/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5084 - acc: 0.7427 - val_loss: 0.6068 - val_acc: 0.6921
#
# Epoch 00215: val_loss did not improve from 0.58063
# Epoch 216/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5138 - acc: 0.7414 - val_loss: 0.6072 - val_acc: 0.6837
#
# Epoch 00216: val_loss did not improve from 0.58063
# Epoch 217/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5171 - acc: 0.7373 - val_loss: 0.6116 - val_acc: 0.6824
#
# Epoch 00217: val_loss did not improve from 0.58063
# Epoch 218/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5232 - acc: 0.7338 - val_loss: 0.6265 - val_acc: 0.6727
#
# Epoch 00218: val_loss did not improve from 0.58063
# Epoch 219/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5198 - acc: 0.7336 - val_loss: 0.6137 - val_acc: 0.6843
#
# Epoch 00219: val_loss did not improve from 0.58063
# Epoch 220/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5147 - acc: 0.7390 - val_loss: 0.6160 - val_acc: 0.6824
#
# Epoch 00220: val_loss did not improve from 0.58063
# Epoch 221/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5095 - acc: 0.7399 - val_loss: 0.6211 - val_acc: 0.6856
#
# Epoch 00221: val_loss did not improve from 0.58063
# Epoch 222/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5100 - acc: 0.7431 - val_loss: 0.6203 - val_acc: 0.6824
#
# Epoch 00222: val_loss did not improve from 0.58063
# Epoch 223/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5058 - acc: 0.7407 - val_loss: 0.6244 - val_acc: 0.6824
#
# Epoch 00223: val_loss did not improve from 0.58063
# Epoch 224/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5056 - acc: 0.7433 - val_loss: 0.6242 - val_acc: 0.6837
#
# Epoch 00224: val_loss did not improve from 0.58063
# Epoch 225/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5053 - acc: 0.7418 - val_loss: 0.6254 - val_acc: 0.6831
#
# Epoch 00225: val_loss did not improve from 0.58063
# Epoch 226/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5058 - acc: 0.7399 - val_loss: 0.6361 - val_acc: 0.6831
#
# Epoch 00226: val_loss did not improve from 0.58063
# Epoch 227/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5101 - acc: 0.7396 - val_loss: 0.6307 - val_acc: 0.6850
# Restoring model weights from the end of the best epoch.
#
# Epoch 00227: val_loss did not improve from 0.58063
# Epoch 00227: early stopping

# %%
import random
from sklearn import metrics 

with tf.device('/device:GPU:0'):
    tf.config.experimental.set_virtual_device_configuration(gpus[0], 
                                                            [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5*1024)])

    from keras.models import load_model
    best_model = load_model('./model/m1_new_seed42-87-0.5806.hdf5') 

    dic_42={}
    for seed in range(0, 50):
        random.seed(seed)

        x = np.load('x_(7727,10,10)_m1_new.npy')
        y = np.load('y_(7727,1).npy')

        idx = list(range(len(x)))
        random.shuffle(idx)

        i = round(x.shape[0]*0.8)
        X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
        X_test, y_test = x[idx[i:],:,:], y[idx[i:]]

        pred = best_model.predict(X_test)
        pred[pred>0.5]=1
        pred[pred<=0.5]=0
        acc = metrics.accuracy_score(y_test, pred)
        dic_42[seed]=acc
        print(f'정확도 :{metrics.accuracy_score(y_test, pred)}, seed_num = {seed}')
        
df_42 = pd.DataFrame.from_dict(dic_42, orient='index')
print(f'정확도 df 만들고 평균 확인 : {df_42.mean().values}')
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Using TensorFlow backend.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 정확도 :0.7022653721682848, seed_num = 0
# 정확도 :0.7029126213592233, seed_num = 1
# 정확도 :0.6983818770226538, seed_num = 2
# 정확도 :0.7067961165048544, seed_num = 3
# 정확도 :0.7042071197411003, seed_num = 4
# 정확도 :0.7022653721682848, seed_num = 5
# 정확도 :0.6919093851132686, seed_num = 6
# 정확도 :0.6983818770226538, seed_num = 7
# 정확도 :0.7113268608414239, seed_num = 8
# 정확도 :0.6990291262135923, seed_num = 9
# 정확도 :0.7055016181229773, seed_num = 10
# 정확도 :0.7016181229773463, seed_num = 11
# 정확도 :0.7132686084142394, seed_num = 12
# 정확도 :0.7016181229773463, seed_num = 13
# 정확도 :0.7048543689320388, seed_num = 14
# 정확도 :0.7003236245954693, seed_num = 15
# 정확도 :0.7113268608414239, seed_num = 16
# 정확도 :0.7035598705501618, seed_num = 17
# 정확도 :0.713915857605178, seed_num = 18
# 정확도 :0.7048543689320388, seed_num = 19
# 정확도 :0.7016181229773463, seed_num = 20
# 정확도 :0.6854368932038835, seed_num = 21
# 정확도 :0.6970873786407767, seed_num = 22
# 정확도 :0.6880258899676376, seed_num = 23
# 정확도 :0.6893203883495146, seed_num = 24
# 정확도 :0.7177993527508091, seed_num = 25
# 정확도 :0.6925566343042071, seed_num = 26
# 정확도 :0.6957928802588996, seed_num = 27
# 정확도 :0.7003236245954693, seed_num = 28
# 정확도 :0.686084142394822, seed_num = 29
# 정확도 :0.7184466019417476, seed_num = 30
# 정확도 :0.6919093851132686, seed_num = 31
# 정확도 :0.7113268608414239, seed_num = 32
# 정확도 :0.7035598705501618, seed_num = 33
# 정확도 :0.7113268608414239, seed_num = 34
# 정확도 :0.7016181229773463, seed_num = 35
# 정확도 :0.7126213592233009, seed_num = 36
# 정확도 :0.7249190938511327, seed_num = 37
# 정확도 :0.7100323624595469, seed_num = 38
# 정확도 :0.7275080906148867, seed_num = 39
# 정확도 :0.713915857605178, seed_num = 40
# 정확도 :0.7126213592233009, seed_num = 41
# 정확도 :0.6867313915857605, seed_num = 42
# 정확도 :0.7003236245954693, seed_num = 43
# 정확도 :0.6757281553398058, seed_num = 44
# 정확도 :0.6925566343042071, seed_num = 45
# 정확도 :0.7074433656957929, seed_num = 46
# 정확도 :0.7061488673139159, seed_num = 47
# 정확도 :0.7210355987055016, seed_num = 48
# 정확도 :0.6957928802588996, seed_num = 49
# 정확도 df 만들고 평균 확인 : [0.70315858]

# %% [markdown]
# # M1_new_bottom10

# %%
m1_new = pd.read_csv('m1_new.csv')
m1_new_bottom10 = m1_new['feature'].values[-10:]
m1_new_bottom10
# Out:
# array([  409672924, 55390000401,      224277,     8084199,       51221,
#              51237,       50861,       51249,           0, 63323026201])

# %% [markdown]
# ## (63.6) RF

# %%
RF_정확도(m1_new_bottom10,'m1_new_bottom10')
# Out:
# itemlist의 index :  [2212, 3456, 307, 619, 174, 182, 19, 187, 0, 3832]
# 정확도 : 0.6161812297734628, seed_num = 42
# 정확도 : 0.6297734627831715, seed_num = 43
# 정확도 : 0.6148867313915858, seed_num = 44
# 정확도 : 0.6530744336569579, seed_num = 45
# 정확도 : 0.6440129449838188, seed_num = 46
# 정확도 : 0.655663430420712, seed_num = 47
# 정확도 : 0.6530744336569579, seed_num = 48
# 정확도 : 0.6207119741100323, seed_num = 49
# 정확도 : 0.6511326860841424, seed_num = 50
# 정확도 : 0.6258899676375405, seed_num = 51
# 정확도 df 만들고 평균 확인 : [0.63644013]

# %% [markdown]
# ## (67.1) LSTM

# %%
LSTM_정확도(m1_new_bottom10,'m1_new_bottom10')
# Out:
# itemlist의 index :  [2212, 3456, 307, 619, 174, 182, 19, 187, 0, 3832]
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/500
# 37/37 [==============================] - 6s 72ms/step - loss: 0.6759 - acc: 0.5984 - val_loss: 0.6660 - val_acc: 0.6177
#
# Epoch 00001: val_loss improved from inf to 0.66601, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-01-0.6660.hdf5
# Epoch 2/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6732 - acc: 0.6066 - val_loss: 0.6662 - val_acc: 0.6177
#
# Epoch 00002: val_loss did not improve from 0.66601
# Epoch 3/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6740 - acc: 0.6083 - val_loss: 0.6655 - val_acc: 0.6177
#
# Epoch 00003: val_loss improved from 0.66601 to 0.66547, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-03-0.6655.hdf5
# Epoch 4/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6710 - acc: 0.6100 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00004: val_loss improved from 0.66547 to 0.66517, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-04-0.6652.hdf5
# Epoch 5/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6705 - acc: 0.6096 - val_loss: 0.6649 - val_acc: 0.6177
#
# Epoch 00005: val_loss improved from 0.66517 to 0.66493, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-05-0.6649.hdf5
# Epoch 6/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6718 - acc: 0.6115 - val_loss: 0.6645 - val_acc: 0.6177
#
# Epoch 00006: val_loss improved from 0.66493 to 0.66449, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-06-0.6645.hdf5
# Epoch 7/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6693 - acc: 0.6111 - val_loss: 0.6593 - val_acc: 0.6177
#
# Epoch 00007: val_loss improved from 0.66449 to 0.65932, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-07-0.6593.hdf5
# Epoch 8/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6588 - acc: 0.6109 - val_loss: 0.6424 - val_acc: 0.6177
#
# Epoch 00008: val_loss improved from 0.65932 to 0.64240, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-08-0.6424.hdf5
# Epoch 9/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6478 - acc: 0.6137 - val_loss: 0.6445 - val_acc: 0.6171
#
# Epoch 00009: val_loss did not improve from 0.64240
# Epoch 10/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6497 - acc: 0.6299 - val_loss: 0.6389 - val_acc: 0.6501
#
# Epoch 00010: val_loss improved from 0.64240 to 0.63887, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-10-0.6389.hdf5
# Epoch 11/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6456 - acc: 0.6223 - val_loss: 0.6437 - val_acc: 0.6475
#
# Epoch 00011: val_loss did not improve from 0.63887
# Epoch 12/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6472 - acc: 0.6210 - val_loss: 0.6378 - val_acc: 0.6397
#
# Epoch 00012: val_loss improved from 0.63887 to 0.63782, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-12-0.6378.hdf5
# Epoch 13/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6452 - acc: 0.6182 - val_loss: 0.6385 - val_acc: 0.6475
#
# Epoch 00013: val_loss did not improve from 0.63782
# Epoch 14/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6447 - acc: 0.6186 - val_loss: 0.6385 - val_acc: 0.6429
#
# Epoch 00014: val_loss did not improve from 0.63782
# Epoch 15/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6445 - acc: 0.6236 - val_loss: 0.6360 - val_acc: 0.6384
#
# Epoch 00015: val_loss improved from 0.63782 to 0.63597, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-15-0.6360.hdf5
# Epoch 16/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6436 - acc: 0.6249 - val_loss: 0.6373 - val_acc: 0.6417
#
# Epoch 00016: val_loss did not improve from 0.63597
# Epoch 17/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6442 - acc: 0.6186 - val_loss: 0.6368 - val_acc: 0.6410
#
# Epoch 00017: val_loss did not improve from 0.63597
# Epoch 18/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6430 - acc: 0.6251 - val_loss: 0.6359 - val_acc: 0.6404
#
# Epoch 00018: val_loss improved from 0.63597 to 0.63585, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-18-0.6359.hdf5
# Epoch 19/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6429 - acc: 0.6195 - val_loss: 0.6358 - val_acc: 0.6397
#
# Epoch 00019: val_loss improved from 0.63585 to 0.63577, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-19-0.6358.hdf5
# Epoch 20/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6432 - acc: 0.6292 - val_loss: 0.6347 - val_acc: 0.6397
#
# Epoch 00020: val_loss improved from 0.63577 to 0.63471, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-20-0.6347.hdf5
# Epoch 21/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6414 - acc: 0.6273 - val_loss: 0.6353 - val_acc: 0.6410
#
# Epoch 00021: val_loss did not improve from 0.63471
# Epoch 22/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6414 - acc: 0.6238 - val_loss: 0.6345 - val_acc: 0.6391
#
# Epoch 00022: val_loss improved from 0.63471 to 0.63450, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-22-0.6345.hdf5
# Epoch 23/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6422 - acc: 0.6141 - val_loss: 0.6351 - val_acc: 0.6404
#
# Epoch 00023: val_loss did not improve from 0.63450
# Epoch 24/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6422 - acc: 0.6294 - val_loss: 0.6340 - val_acc: 0.6410
#
# Epoch 00024: val_loss improved from 0.63450 to 0.63396, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-24-0.6340.hdf5
# Epoch 25/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6411 - acc: 0.6309 - val_loss: 0.6348 - val_acc: 0.6371
#
# Epoch 00025: val_loss did not improve from 0.63396
# Epoch 26/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6401 - acc: 0.6316 - val_loss: 0.6357 - val_acc: 0.6397
#
# Epoch 00026: val_loss did not improve from 0.63396
# Epoch 27/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6408 - acc: 0.6264 - val_loss: 0.6341 - val_acc: 0.6358
#
# Epoch 00027: val_loss did not improve from 0.63396
# Epoch 28/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6392 - acc: 0.6314 - val_loss: 0.6337 - val_acc: 0.6352
#
# Epoch 00028: val_loss improved from 0.63396 to 0.63368, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-28-0.6337.hdf5
# Epoch 29/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6401 - acc: 0.6307 - val_loss: 0.6334 - val_acc: 0.6345
#
# Epoch 00029: val_loss improved from 0.63368 to 0.63342, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-29-0.6334.hdf5
# Epoch 30/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6406 - acc: 0.6279 - val_loss: 0.6336 - val_acc: 0.6371
#
# Epoch 00030: val_loss did not improve from 0.63342
# Epoch 31/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6406 - acc: 0.6309 - val_loss: 0.6329 - val_acc: 0.6352
#
# Epoch 00031: val_loss improved from 0.63342 to 0.63293, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-31-0.6329.hdf5
# Epoch 32/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6412 - acc: 0.6303 - val_loss: 0.6333 - val_acc: 0.6345
#
# Epoch 00032: val_loss did not improve from 0.63293
# Epoch 33/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6394 - acc: 0.6253 - val_loss: 0.6330 - val_acc: 0.6365
#
# Epoch 00033: val_loss did not improve from 0.63293
# Epoch 34/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6404 - acc: 0.6277 - val_loss: 0.6317 - val_acc: 0.6352
#
# Epoch 00034: val_loss improved from 0.63293 to 0.63166, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-34-0.6317.hdf5
# Epoch 35/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6395 - acc: 0.6294 - val_loss: 0.6311 - val_acc: 0.6339
#
# Epoch 00035: val_loss improved from 0.63166 to 0.63106, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-35-0.6311.hdf5
# Epoch 36/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6405 - acc: 0.6318 - val_loss: 0.6318 - val_acc: 0.6378
#
# Epoch 00036: val_loss did not improve from 0.63106
# Epoch 37/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.6386 - acc: 0.6348 - val_loss: 0.6318 - val_acc: 0.6378
#
# Epoch 00037: val_loss did not improve from 0.63106
# Epoch 38/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6378 - acc: 0.6352 - val_loss: 0.6318 - val_acc: 0.6423
#
# Epoch 00038: val_loss did not improve from 0.63106
# Epoch 39/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6394 - acc: 0.6299 - val_loss: 0.6294 - val_acc: 0.6378
#
# Epoch 00039: val_loss improved from 0.63106 to 0.62943, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-39-0.6294.hdf5
# Epoch 40/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6380 - acc: 0.6346 - val_loss: 0.6301 - val_acc: 0.6417
#
# Epoch 00040: val_loss did not improve from 0.62943
# Epoch 41/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6386 - acc: 0.6322 - val_loss: 0.6307 - val_acc: 0.6436
#
# Epoch 00041: val_loss did not improve from 0.62943
# Epoch 42/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6375 - acc: 0.6335 - val_loss: 0.6294 - val_acc: 0.6417
#
# Epoch 00042: val_loss improved from 0.62943 to 0.62943, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-42-0.6294.hdf5
# Epoch 43/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6384 - acc: 0.6350 - val_loss: 0.6301 - val_acc: 0.6468
#
# Epoch 00043: val_loss did not improve from 0.62943
# Epoch 44/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6384 - acc: 0.6346 - val_loss: 0.6274 - val_acc: 0.6410
#
# Epoch 00044: val_loss improved from 0.62943 to 0.62743, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-44-0.6274.hdf5
# Epoch 45/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6352 - acc: 0.6389 - val_loss: 0.6279 - val_acc: 0.6494
#
# Epoch 00045: val_loss did not improve from 0.62743
# Epoch 46/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6364 - acc: 0.6400 - val_loss: 0.6271 - val_acc: 0.6507
#
# Epoch 00046: val_loss improved from 0.62743 to 0.62713, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-46-0.6271.hdf5
# Epoch 47/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6364 - acc: 0.6361 - val_loss: 0.6257 - val_acc: 0.6507
#
# Epoch 00047: val_loss improved from 0.62713 to 0.62572, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-47-0.6257.hdf5
# Epoch 48/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6351 - acc: 0.6452 - val_loss: 0.6258 - val_acc: 0.6598
#
# Epoch 00048: val_loss did not improve from 0.62572
# Epoch 49/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6345 - acc: 0.6428 - val_loss: 0.6231 - val_acc: 0.6617
#
# Epoch 00049: val_loss improved from 0.62572 to 0.62308, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-49-0.6231.hdf5
# Epoch 50/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6338 - acc: 0.6441 - val_loss: 0.6229 - val_acc: 0.6643
#
# Epoch 00050: val_loss improved from 0.62308 to 0.62290, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-50-0.6229.hdf5
# Epoch 51/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6307 - acc: 0.6473 - val_loss: 0.6224 - val_acc: 0.6688
#
# Epoch 00051: val_loss improved from 0.62290 to 0.62238, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-51-0.6224.hdf5
# Epoch 52/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6301 - acc: 0.6562 - val_loss: 0.6233 - val_acc: 0.6643
#
# Epoch 00052: val_loss did not improve from 0.62238
# Epoch 53/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6308 - acc: 0.6493 - val_loss: 0.6227 - val_acc: 0.6669
#
# Epoch 00053: val_loss did not improve from 0.62238
# Epoch 54/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6291 - acc: 0.6531 - val_loss: 0.6211 - val_acc: 0.6643
#
# Epoch 00054: val_loss improved from 0.62238 to 0.62113, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-54-0.6211.hdf5
# Epoch 55/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6288 - acc: 0.6601 - val_loss: 0.6210 - val_acc: 0.6585
#
# Epoch 00055: val_loss improved from 0.62113 to 0.62103, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-55-0.6210.hdf5
# Epoch 56/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6257 - acc: 0.6588 - val_loss: 0.6208 - val_acc: 0.6649
#
# Epoch 00056: val_loss improved from 0.62103 to 0.62081, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-56-0.6208.hdf5
# Epoch 57/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6274 - acc: 0.6635 - val_loss: 0.6211 - val_acc: 0.6643
#
# Epoch 00057: val_loss did not improve from 0.62081
# Epoch 58/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6251 - acc: 0.6613 - val_loss: 0.6219 - val_acc: 0.6565
#
# Epoch 00058: val_loss did not improve from 0.62081
# Epoch 59/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6264 - acc: 0.6676 - val_loss: 0.6214 - val_acc: 0.6552
#
# Epoch 00059: val_loss did not improve from 0.62081
# Epoch 60/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.6247 - acc: 0.6633 - val_loss: 0.6232 - val_acc: 0.6578
#
# Epoch 00060: val_loss did not improve from 0.62081
# Epoch 61/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6257 - acc: 0.6633 - val_loss: 0.6222 - val_acc: 0.6539
#
# Epoch 00061: val_loss did not improve from 0.62081
# Epoch 62/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6261 - acc: 0.6616 - val_loss: 0.6223 - val_acc: 0.6572
#
# Epoch 00062: val_loss did not improve from 0.62081
# Epoch 63/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6261 - acc: 0.6648 - val_loss: 0.6211 - val_acc: 0.6572
#
# Epoch 00063: val_loss did not improve from 0.62081
# Epoch 64/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6262 - acc: 0.6646 - val_loss: 0.6206 - val_acc: 0.6636
#
# Epoch 00064: val_loss improved from 0.62081 to 0.62064, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-64-0.6206.hdf5
# Epoch 65/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6240 - acc: 0.6678 - val_loss: 0.6214 - val_acc: 0.6630
#
# Epoch 00065: val_loss did not improve from 0.62064
# Epoch 66/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6207 - acc: 0.6657 - val_loss: 0.6216 - val_acc: 0.6624
#
# Epoch 00066: val_loss did not improve from 0.62064
# Epoch 67/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6223 - acc: 0.6674 - val_loss: 0.6221 - val_acc: 0.6604
#
# Epoch 00067: val_loss did not improve from 0.62064
# Epoch 68/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6228 - acc: 0.6687 - val_loss: 0.6208 - val_acc: 0.6636
#
# Epoch 00068: val_loss did not improve from 0.62064
# Epoch 69/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6230 - acc: 0.6661 - val_loss: 0.6222 - val_acc: 0.6611
#
# Epoch 00069: val_loss did not improve from 0.62064
# Epoch 70/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6222 - acc: 0.6674 - val_loss: 0.6212 - val_acc: 0.6643
#
# Epoch 00070: val_loss did not improve from 0.62064
# Epoch 71/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6203 - acc: 0.6635 - val_loss: 0.6218 - val_acc: 0.6617
#
# Epoch 00071: val_loss did not improve from 0.62064
# Epoch 72/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6207 - acc: 0.6685 - val_loss: 0.6209 - val_acc: 0.6643
#
# Epoch 00072: val_loss did not improve from 0.62064
# Epoch 73/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6215 - acc: 0.6652 - val_loss: 0.6200 - val_acc: 0.6604
#
# Epoch 00073: val_loss improved from 0.62064 to 0.62005, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-73-0.6200.hdf5
# Epoch 74/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6215 - acc: 0.6689 - val_loss: 0.6206 - val_acc: 0.6617
#
# Epoch 00074: val_loss did not improve from 0.62005
# Epoch 75/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6197 - acc: 0.6678 - val_loss: 0.6214 - val_acc: 0.6611
#
# Epoch 00075: val_loss did not improve from 0.62005
# Epoch 76/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6206 - acc: 0.6685 - val_loss: 0.6201 - val_acc: 0.6624
#
# Epoch 00076: val_loss did not improve from 0.62005
# Epoch 77/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6195 - acc: 0.6687 - val_loss: 0.6197 - val_acc: 0.6591
#
# Epoch 00077: val_loss improved from 0.62005 to 0.61966, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-77-0.6197.hdf5
# Epoch 78/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6196 - acc: 0.6676 - val_loss: 0.6206 - val_acc: 0.6630
#
# Epoch 00078: val_loss did not improve from 0.61966
# Epoch 79/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6179 - acc: 0.6726 - val_loss: 0.6206 - val_acc: 0.6572
#
# Epoch 00079: val_loss did not improve from 0.61966
# Epoch 80/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6183 - acc: 0.6728 - val_loss: 0.6204 - val_acc: 0.6591
#
# Epoch 00080: val_loss did not improve from 0.61966
# Epoch 81/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6188 - acc: 0.6698 - val_loss: 0.6201 - val_acc: 0.6572
#
# Epoch 00081: val_loss did not improve from 0.61966
# Epoch 82/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6182 - acc: 0.6708 - val_loss: 0.6209 - val_acc: 0.6630
#
# Epoch 00082: val_loss did not improve from 0.61966
# Epoch 83/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.6158 - acc: 0.6713 - val_loss: 0.6198 - val_acc: 0.6559
#
# Epoch 00083: val_loss did not improve from 0.61966
# Epoch 84/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6164 - acc: 0.6723 - val_loss: 0.6198 - val_acc: 0.6565
#
# Epoch 00084: val_loss did not improve from 0.61966
# Epoch 85/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6173 - acc: 0.6715 - val_loss: 0.6203 - val_acc: 0.6572
#
# Epoch 00085: val_loss did not improve from 0.61966
# Epoch 86/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6162 - acc: 0.6752 - val_loss: 0.6199 - val_acc: 0.6572
#
# Epoch 00086: val_loss did not improve from 0.61966
# Epoch 87/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6151 - acc: 0.6760 - val_loss: 0.6204 - val_acc: 0.6598
#
# Epoch 00087: val_loss did not improve from 0.61966
# Epoch 88/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6166 - acc: 0.6730 - val_loss: 0.6198 - val_acc: 0.6585
#
# Epoch 00088: val_loss did not improve from 0.61966
# Epoch 89/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6146 - acc: 0.6693 - val_loss: 0.6193 - val_acc: 0.6591
#
# Epoch 00089: val_loss improved from 0.61966 to 0.61930, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-89-0.6193.hdf5
# Epoch 90/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6156 - acc: 0.6695 - val_loss: 0.6196 - val_acc: 0.6585
#
# Epoch 00090: val_loss did not improve from 0.61930
# Epoch 91/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6145 - acc: 0.6691 - val_loss: 0.6197 - val_acc: 0.6578
#
# Epoch 00091: val_loss did not improve from 0.61930
# Epoch 92/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6155 - acc: 0.6782 - val_loss: 0.6189 - val_acc: 0.6591
#
# Epoch 00092: val_loss improved from 0.61930 to 0.61889, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-92-0.6189.hdf5
# Epoch 93/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6155 - acc: 0.6739 - val_loss: 0.6190 - val_acc: 0.6591
#
# Epoch 00093: val_loss did not improve from 0.61889
# Epoch 94/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6160 - acc: 0.6723 - val_loss: 0.6193 - val_acc: 0.6578
#
# Epoch 00094: val_loss did not improve from 0.61889
# Epoch 95/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6138 - acc: 0.6732 - val_loss: 0.6191 - val_acc: 0.6598
#
# Epoch 00095: val_loss did not improve from 0.61889
# Epoch 96/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6151 - acc: 0.6702 - val_loss: 0.6189 - val_acc: 0.6572
#
# Epoch 00096: val_loss did not improve from 0.61889
# Epoch 97/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6134 - acc: 0.6736 - val_loss: 0.6187 - val_acc: 0.6591
#
# Epoch 00097: val_loss improved from 0.61889 to 0.61872, saving model to ./model/m1_new_bottom10/m1_new_bottom10_seed42-97-0.6187.hdf5
# Epoch 98/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6110 - acc: 0.6754 - val_loss: 0.6193 - val_acc: 0.6630
#
# Epoch 00098: val_loss did not improve from 0.61872
# Epoch 99/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6119 - acc: 0.6732 - val_loss: 0.6189 - val_acc: 0.6598
#
# Epoch 00099: val_loss did not improve from 0.61872
# Epoch 100/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.6130 - acc: 0.6758 - val_loss: 0.6190 - val_acc: 0.6636
#
# Epoch 00100: val_loss did not improve from 0.61872
# Epoch 101/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6112 - acc: 0.6782 - val_loss: 0.6198 - val_acc: 0.6611
# Restoring model weights from the end of the best epoch.
#
# Epoch 00101: val_loss did not improve from 0.61872
# Epoch 00101: early stopping
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 정확도 :0.6660194174757281, seed_num = 0
# 정확도 :0.6621359223300971, seed_num = 1
# 정확도 :0.6744336569579288, seed_num = 2
# 정확도 :0.6647249190938511, seed_num = 3
# 정확도 :0.6731391585760518, seed_num = 4
# 정확도 :0.6776699029126214, seed_num = 5
# 정확도 :0.6731391585760518, seed_num = 6
# 정확도 :0.6524271844660194, seed_num = 7
# 정확도 :0.6809061488673139, seed_num = 8
# 정확도 :0.6802588996763754, seed_num = 9
# 정확도 :0.6699029126213593, seed_num = 10
# 정확도 :0.6822006472491909, seed_num = 11
# 정확도 :0.6640776699029126, seed_num = 12
# 정확도 :0.6608414239482201, seed_num = 13
# 정확도 :0.6906148867313916, seed_num = 14
# 정확도 :0.6893203883495146, seed_num = 15
# 정확도 :0.6809061488673139, seed_num = 16
# 정확도 :0.6595469255663431, seed_num = 17
# 정확도 :0.6686084142394823, seed_num = 18
# 정확도 :0.6614886731391586, seed_num = 19
# 정확도 :0.6731391585760518, seed_num = 20
# 정확도 :0.658252427184466, seed_num = 21
# 정확도 :0.656957928802589, seed_num = 22
# 정확도 :0.6737864077669903, seed_num = 23
# 정확도 :0.6634304207119741, seed_num = 24
# 정확도 :0.6621359223300971, seed_num = 25
# 정확도 :0.6640776699029126, seed_num = 26
# 정확도 :0.6828478964401294, seed_num = 27
# 정확도 :0.6640776699029126, seed_num = 28
# 정확도 :0.6724919093851133, seed_num = 29
# 정확도 :0.6770226537216828, seed_num = 30
# 정확도 :0.656957928802589, seed_num = 31
# 정확도 :0.6731391585760518, seed_num = 32
# 정확도 :0.6692556634304208, seed_num = 33
# 정확도 :0.6783171521035599, seed_num = 34
# 정확도 :0.6796116504854369, seed_num = 35
# 정확도 :0.6737864077669903, seed_num = 36
# 정확도 :0.686084142394822, seed_num = 37
# 정확도 :0.6763754045307443, seed_num = 38
# 정확도 :0.6595469255663431, seed_num = 39
# 정확도 :0.6634304207119741, seed_num = 40
# 정확도 :0.6828478964401294, seed_num = 41
# 정확도 :0.6699029126213593, seed_num = 42
# 정확도 :0.658252427184466, seed_num = 43
# 정확도 :0.6627831715210356, seed_num = 44
# 정확도 :0.6880258899676376, seed_num = 45
# 정확도 :0.6731391585760518, seed_num = 46
# 정확도 :0.6951456310679611, seed_num = 47
# 정확도 :0.6925566343042071, seed_num = 48
# 정확도 :0.6776699029126214, seed_num = 49
# 정확도 df 만들고 평균 확인 : [0.67194822]
