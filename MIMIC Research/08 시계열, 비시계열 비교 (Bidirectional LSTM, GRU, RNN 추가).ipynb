# %% [markdown]
# # 시계열
# # LSTM
# - data_seed, model_seed = 42

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings(action='ignore')

import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, InputLayer
from tensorflow.keras.callbacks import EarlyStopping
from sklearn import metrics 
from tensorflow import keras
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam


import random
# ----------------------
seed_num = 42
# ----------------------
random.seed(seed_num)

x = np.load('/project/LSH/x_(7727,10,4069).npy')
y = np.load('/project/LSH/y_(7727,1).npy')

idx = list(range(len(x)))
random.shuffle(idx)

i = round(x.shape[0]*0.8)
X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
X_test, y_test = x[idx[i:],:,:], y[idx[i:]]

# ---------------------
seed_num = 42 
# ---------------------
tf.random.set_seed(seed_num)

lstm = Sequential()
lstm.add(InputLayer(input_shape=(X_train.shape[1],X_train.shape[2])))
lstm.add(LSTM(units=128, activation='hard_sigmoid', return_sequences=True))
lstm.add(LSTM(units=64, activation='hard_sigmoid', return_sequences=True))
lstm.add(Dropout(0.2))
lstm.add(LSTM(units=64, activation='hard_sigmoid', return_sequences=True))
lstm.add(LSTM(units=32, activation='hard_sigmoid', return_sequences=False))
lstm.add(Dropout(0.2))
lstm.add(Dense(units=1, activation='sigmoid'))

from tensorflow.keras.callbacks import ModelCheckpoint
import os

MODEL_SAVE_FOLDER_PATH = './model/'
if not os.path.exists(MODEL_SAVE_FOLDER_PATH):
    os.mkdir(MODEL_SAVE_FOLDER_PATH)

model_path = MODEL_SAVE_FOLDER_PATH + '(LSTM_best)seed42-{epoch:02d}-{val_loss:.4f}.hdf5'

cb_checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss',
                                verbose=1, save_best_only=True)

early_stop = EarlyStopping(monitor='val_acc', patience=30, verbose=1, restore_best_weights=False)
lstm.compile(optimizer= keras.optimizers.Adam(learning_rate = 0.001), loss = "binary_crossentropy", metrics=['acc'])
lstm.fit(X_train, y_train, validation_split=0.25, batch_size=128, epochs=500,  
         callbacks=[early_stop,cb_checkpoint], shuffle=False)
# Out:
# Epoch 1/500
# 37/37 [==============================] - 5s 64ms/step - loss: 0.6757 - acc: 0.5984 - val_loss: 0.6654 - val_acc: 0.6177
#
# Epoch 00001: val_loss improved from inf to 0.66544, saving model to ./model/(LSTM_best)seed42-01-0.6654.hdf5
# Epoch 2/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.6690 - acc: 0.6089 - val_loss: 0.6482 - val_acc: 0.6177
#
# Epoch 00002: val_loss improved from 0.66544 to 0.64818, saving model to ./model/(LSTM_best)seed42-02-0.6482.hdf5
# Epoch 3/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.6000 - acc: 0.6713 - val_loss: 0.5525 - val_acc: 0.7354
#
# Epoch 00003: val_loss improved from 0.64818 to 0.55246, saving model to ./model/(LSTM_best)seed42-03-0.5525.hdf5
# Epoch 4/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.4867 - acc: 0.7793 - val_loss: 0.5088 - val_acc: 0.7613
#
# Epoch 00004: val_loss improved from 0.55246 to 0.50875, saving model to ./model/(LSTM_best)seed42-04-0.5088.hdf5
# Epoch 5/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.4147 - acc: 0.8214 - val_loss: 0.5021 - val_acc: 0.7697
#
# Epoch 00005: val_loss improved from 0.50875 to 0.50213, saving model to ./model/(LSTM_best)seed42-05-0.5021.hdf5
# Epoch 6/500
# 37/37 [==============================] - 2s 54ms/step - loss: 0.3616 - acc: 0.8643 - val_loss: 0.5496 - val_acc: 0.7691
#
# Epoch 00006: val_loss did not improve from 0.50213
# Epoch 7/500
# 37/37 [==============================] - 2s 54ms/step - loss: 0.3290 - acc: 0.8801 - val_loss: 0.5499 - val_acc: 0.7652
#
# Epoch 00007: val_loss did not improve from 0.50213
# Epoch 8/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.3172 - acc: 0.8850 - val_loss: 0.6018 - val_acc: 0.7561
#
# Epoch 00008: val_loss did not improve from 0.50213
# Epoch 9/500
# 37/37 [==============================] - 2s 54ms/step - loss: 0.3039 - acc: 0.8829 - val_loss: 0.5770 - val_acc: 0.7678
#
# Epoch 00009: val_loss did not improve from 0.50213
# Epoch 10/500
# 37/37 [==============================] - 2s 54ms/step - loss: 0.2843 - acc: 0.8969 - val_loss: 0.6179 - val_acc: 0.7342
#
# Epoch 00010: val_loss did not improve from 0.50213
# Epoch 11/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2804 - acc: 0.8973 - val_loss: 0.6155 - val_acc: 0.7458
#
# Epoch 00011: val_loss did not improve from 0.50213
# Epoch 12/500
# 37/37 [==============================] - 2s 54ms/step - loss: 0.2768 - acc: 0.8997 - val_loss: 0.6302 - val_acc: 0.7309
#
# Epoch 00012: val_loss did not improve from 0.50213
# Epoch 13/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2969 - acc: 0.8829 - val_loss: 0.6412 - val_acc: 0.7464
#
# Epoch 00013: val_loss did not improve from 0.50213
# Epoch 14/500
# 37/37 [==============================] - 2s 54ms/step - loss: 0.2521 - acc: 0.9116 - val_loss: 0.6775 - val_acc: 0.7451
#
# Epoch 00014: val_loss did not improve from 0.50213
# Epoch 15/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2376 - acc: 0.9213 - val_loss: 0.7032 - val_acc: 0.7471
#
# Epoch 00015: val_loss did not improve from 0.50213
# Epoch 16/500
# 37/37 [==============================] - 2s 54ms/step - loss: 0.2223 - acc: 0.9262 - val_loss: 0.7252 - val_acc: 0.7503
#
# Epoch 00016: val_loss did not improve from 0.50213
# Epoch 17/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2226 - acc: 0.9297 - val_loss: 0.7507 - val_acc: 0.7510
#
# Epoch 00017: val_loss did not improve from 0.50213
# Epoch 18/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2256 - acc: 0.9284 - val_loss: 0.8704 - val_acc: 0.7277
#
# Epoch 00018: val_loss did not improve from 0.50213
# Epoch 19/500
# 37/37 [==============================] - 2s 54ms/step - loss: 0.2422 - acc: 0.9159 - val_loss: 0.8798 - val_acc: 0.7212
#
# Epoch 00019: val_loss did not improve from 0.50213
# Epoch 20/500
# 37/37 [==============================] - 2s 54ms/step - loss: 0.3754 - acc: 0.8419 - val_loss: 0.5583 - val_acc: 0.7587
#
# Epoch 00020: val_loss did not improve from 0.50213
# Epoch 21/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.2741 - acc: 0.9014 - val_loss: 0.5726 - val_acc: 0.7542
#
# Epoch 00021: val_loss did not improve from 0.50213
# Epoch 22/500
# 37/37 [==============================] - 2s 54ms/step - loss: 0.2127 - acc: 0.9271 - val_loss: 0.6388 - val_acc: 0.7555
#
# Epoch 00022: val_loss did not improve from 0.50213
# Epoch 23/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.1969 - acc: 0.9374 - val_loss: 0.6792 - val_acc: 0.7477
#
# Epoch 00023: val_loss did not improve from 0.50213
# Epoch 24/500
# 37/37 [==============================] - 2s 54ms/step - loss: 0.1727 - acc: 0.9489 - val_loss: 0.7240 - val_acc: 0.7445
#
# Epoch 00024: val_loss did not improve from 0.50213
# Epoch 25/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.1541 - acc: 0.9569 - val_loss: 0.7545 - val_acc: 0.7471
#
# Epoch 00025: val_loss did not improve from 0.50213
# Epoch 26/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.1382 - acc: 0.9642 - val_loss: 0.7859 - val_acc: 0.7477
#
# Epoch 00026: val_loss did not improve from 0.50213
# Epoch 27/500
# 37/37 [==============================] - 2s 54ms/step - loss: 0.1237 - acc: 0.9676 - val_loss: 0.8115 - val_acc: 0.7426
#
# Epoch 00027: val_loss did not improve from 0.50213
# Epoch 28/500
# 37/37 [==============================] - 2s 54ms/step - loss: 0.1161 - acc: 0.9698 - val_loss: 0.8344 - val_acc: 0.7426
#
# Epoch 00028: val_loss did not improve from 0.50213
# Epoch 29/500
# 37/37 [==============================] - 2s 54ms/step - loss: 0.1099 - acc: 0.9730 - val_loss: 0.8598 - val_acc: 0.7419
#
# Epoch 00029: val_loss did not improve from 0.50213
# Epoch 30/500
# 37/37 [==============================] - 2s 54ms/step - loss: 0.1046 - acc: 0.9754 - val_loss: 0.8826 - val_acc: 0.7432
#
# Epoch 00030: val_loss did not improve from 0.50213
# Epoch 31/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.0984 - acc: 0.9769 - val_loss: 0.9026 - val_acc: 0.7367
#
# Epoch 00031: val_loss did not improve from 0.50213
# Epoch 32/500
# 37/37 [==============================] - 2s 54ms/step - loss: 0.0947 - acc: 0.9780 - val_loss: 0.9245 - val_acc: 0.7380
#
# Epoch 00032: val_loss did not improve from 0.50213
# Epoch 33/500
# 37/37 [==============================] - 2s 54ms/step - loss: 0.0925 - acc: 0.9799 - val_loss: 0.9369 - val_acc: 0.7374
#
# Epoch 00033: val_loss did not improve from 0.50213
# Epoch 34/500
# 37/37 [==============================] - 2s 54ms/step - loss: 0.0885 - acc: 0.9804 - val_loss: 0.9541 - val_acc: 0.7374
#
# Epoch 00034: val_loss did not improve from 0.50213
# Epoch 35/500
# 37/37 [==============================] - 2s 53ms/step - loss: 0.0845 - acc: 0.9814 - val_loss: 0.9664 - val_acc: 0.7413
#
# Epoch 00035: val_loss did not improve from 0.50213
# Epoch 00035: early stopping

# %% [markdown]
# ## (81.8) lr = 0.01, de = 0.001

# %%
from keras.models import load_model
best_model = load_model('./model/(220125d)seed42-04-0.5367.hdf5') 

dic_42={}
for seed in range(42, 52):
    random.seed(seed)

    x = np.load('/project/LSH/x_(7727,10,4069).npy')
    y = np.load('/project/LSH/y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
    X_test, y_test = x[idx[i:],:,:], y[idx[i:]]
    
    pred = best_model.predict(X_test)
    pred[pred>0.5]=1
    pred[pred<=0.5]=0
    acc = metrics.accuracy_score(y_test, pred)
    dic_42[seed]=acc
    print(f'정확도 :{metrics.accuracy_score(y_test, pred)}, seed_num = {seed}')
    
df = pd.DataFrame.from_dict(dic_42, orient='index')
print(f'seed = {seed_num}의 정확도 df 만들고 평균 확인 : {df.mean().values}')
# Out:
# 정확도 :0.7637540453074434, seed_num = 42
# 정확도 :0.8375404530744337, seed_num = 43
# 정확도 :0.8038834951456311, seed_num = 44
# 정확도 :0.8271844660194175, seed_num = 45
# 정확도 :0.8135922330097087, seed_num = 46
# 정확도 :0.8362459546925566, seed_num = 47
# 정확도 :0.8362459546925566, seed_num = 48
# 정확도 :0.829126213592233, seed_num = 49
# 정확도 :0.8265372168284789, seed_num = 50
# 정확도 :0.8129449838187702, seed_num = 51
# seed = 42의 정확도 df 만들고 평균 확인 : [0.8187055]

# %% [markdown]
# ## (80.6) lr = 0.001, de = 0.01

# %%
from keras.models import load_model
best_model = load_model('./model/(220125d)seed42-07-0.4921.hdf5') 

dic_42={}
for seed in range(42, 52):
    random.seed(seed)

    x = np.load('/project/LSH/x_(7727,10,4069).npy')
    y = np.load('/project/LSH/y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
    X_test, y_test = x[idx[i:],:,:], y[idx[i:]]
    
    pred = best_model.predict(X_test)
    pred[pred>0.5]=1
    pred[pred<=0.5]=0
    acc = metrics.accuracy_score(y_test, pred)
    dic_42[seed]=acc
    print(f'정확도 :{metrics.accuracy_score(y_test, pred)}, seed_num = {seed}')
    
df = pd.DataFrame.from_dict(dic_42, orient='index')
print(f'seed = {seed_num}의 정확도 df 만들고 평균 확인 : {df.mean().values}')
# Out:
# 정확도 :0.7631067961165049, seed_num = 42
# 정확도 :0.8213592233009709, seed_num = 43
# 정확도 :0.8071197411003236, seed_num = 44
# 정확도 :0.8116504854368932, seed_num = 45
# 정확도 :0.7948220064724919, seed_num = 46
# 정확도 :0.8207119741100324, seed_num = 47
# 정확도 :0.8207119741100324, seed_num = 48
# 정확도 :0.8148867313915857, seed_num = 49
# 정확도 :0.8038834951456311, seed_num = 50
# 정확도 :0.8084142394822007, seed_num = 51
# seed = 42의 정확도 df 만들고 평균 확인 : [0.80666667]

# %% [markdown]
# ## (81.4) lr = 0.001, de = 0.001

# %%
from keras.models import load_model
best_model = load_model('./model/(220125)seed42-05-0.5004.hdf5') 

dic_42={}
for seed in range(42, 52):
    random.seed(seed)

    x = np.load('/project/LSH/x_(7727,10,4069).npy')
    y = np.load('/project/LSH/y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
    X_test, y_test = x[idx[i:],:,:], y[idx[i:]]
    
    pred = best_model.predict(X_test)
    pred[pred>0.5]=1
    pred[pred<=0.5]=0
    acc = metrics.accuracy_score(y_test, pred)
    dic_42[seed]=acc
    print(f'정확도 :{metrics.accuracy_score(y_test, pred)}, seed_num = {seed}')

df = pd.DataFrame.from_dict(dic_42, orient='index')
print(f'seed = {seed_num}의 정확도 df 만들고 평균 확인 : {df.mean().values}')
# Out:
# 정확도 :0.7734627831715211, seed_num = 42
# 정확도 :0.8310679611650486, seed_num = 43
# 정확도 :0.8103559870550162, seed_num = 44
# 정확도 :0.8194174757281554, seed_num = 45
# 정확도 :0.8077669902912621, seed_num = 46
# 정확도 :0.83042071197411, seed_num = 47
# 정확도 :0.83042071197411, seed_num = 48
# 정확도 :0.8187702265372169, seed_num = 49
# 정확도 :0.8097087378640777, seed_num = 50
# 정확도 :0.8168284789644013, seed_num = 51
# seed = 42의 정확도 df 만들고 평균 확인 : [0.81482201]

# %% [markdown]
# ## (82.2) lr = 0.001

# %%
from keras.models import load_model
best_model = load_model('./model/##(220125.nodecay)seed42-05-0.5021.hdf5') 

dic_42={}
for seed in range(42, 52):
    random.seed(seed)

    x = np.load('/project/LSH/x_(7727,10,4069).npy')
    y = np.load('/project/LSH/y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_test, y_test = x[idx[i:],:,:], y[idx[i:]]
    
    pred = best_model.predict(X_test)
    pred[pred>0.5]=1
    pred[pred<=0.5]=0
    acc = metrics.accuracy_score(y_test, pred)
    dic_42[seed]=acc
    print(f'정확도 :{metrics.accuracy_score(y_test, pred)}, seed_num = {seed}')

df = pd.DataFrame.from_dict(dic_42, orient='index')
print(f'seed = {seed_num}의 정확도 df 만들고 평균 확인 : {df.mean().values}')
# Out:
# 정확도 :0.7779935275080906, seed_num = 42
# 정확도 :0.8388349514563107, seed_num = 43
# 정확도 :0.8226537216828479, seed_num = 44
# 정확도 :0.8284789644012945, seed_num = 45
# 정확도 :0.8155339805825242, seed_num = 46
# 정확도 :0.8362459546925566, seed_num = 47
# 정확도 :0.8362459546925566, seed_num = 48
# 정확도 :0.8226537216828479, seed_num = 49
# 정확도 :0.8194174757281554, seed_num = 50
# 정확도 :0.8226537216828479, seed_num = 51
# seed = 42의 정확도 df 만들고 평균 확인 : [0.8220712]

# %%
from keras.models import load_model
best_model = load_model('./model/(220125.nodecay)seed42-05-0.5021.hdf5') 

dic_42={}
for seed in range(42, 52):
    random.seed(seed)

    x = np.load('/project/LSH/x_(7727,10,4069).npy')
    y = np.load('/project/LSH/y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
    X_test, y_test = x[idx[i:],:,:], y[idx[i:]]
    
    pred = best_model.predict(X_test)
    pred[pred>0.5]=1
    pred[pred<=0.5]=0
    acc = metrics.accuracy_score(y_test, pred)
    dic_42[seed]=acc
    print(f'정확도 :{metrics.accuracy_score(y_test, pred)}, seed_num = {seed}')

df = pd.DataFrame.from_dict(dic_42, orient='index')
print(f'seed = {seed_num}의 정확도 df 만들고 평균 확인 : {df.mean().values}')
# Out:
# 정확도 :0.7779935275080906, seed_num = 42
# 정확도 :0.8388349514563107, seed_num = 43
# 정확도 :0.8226537216828479, seed_num = 44
# 정확도 :0.8284789644012945, seed_num = 45
# 정확도 :0.8155339805825242, seed_num = 46
# 정확도 :0.8362459546925566, seed_num = 47
# 정확도 :0.8362459546925566, seed_num = 48
# 정확도 :0.8226537216828479, seed_num = 49
# 정확도 :0.8194174757281554, seed_num = 50
# 정확도 :0.8226537216828479, seed_num = 51
# seed = 42의 정확도 df 만들고 평균 확인 : [0.8220712]

# %% [markdown]
# # Bidirectional LSTM

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings(action='ignore')

import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, InputLayer, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping
from sklearn import metrics 
from tensorflow import keras
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam


import random
# ----------------------
seed_num = 42
# ----------------------
random.seed(seed_num)

x = np.load('/project/LSH/x_(7727,10,4069).npy')
y = np.load('/project/LSH/y_(7727,1).npy')

idx = list(range(len(x)))
random.shuffle(idx)

i = round(x.shape[0]*0.8)
X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
X_test, y_test = x[idx[i:],:,:], y[idx[i:]]

# ---------------------
seed_num = 42 
# ---------------------
tf.random.set_seed(seed_num)

bi_lstm = Sequential()
bi_lstm.add(InputLayer(input_shape=(X_train.shape[1],X_train.shape[2])))
bi_lstm.add(Bidirectional(LSTM(units=128, activation='hard_sigmoid', return_sequences=True)))
bi_lstm.add(Bidirectional(LSTM(units=64, activation='hard_sigmoid', return_sequences=True)))
bi_lstm.add(Dropout(0.2))
bi_lstm.add(Bidirectional(LSTM(units=64, activation='hard_sigmoid', return_sequences=True)))
bi_lstm.add(Bidirectional(LSTM(units=32, activation='hard_sigmoid', return_sequences=False)))
bi_lstm.add(Dropout(0.2))
bi_lstm.add(Dense(units=1, activation='sigmoid'))

from tensorflow.keras.callbacks import ModelCheckpoint
import os

MODEL_SAVE_FOLDER_PATH = './model/'
if not os.path.exists(MODEL_SAVE_FOLDER_PATH):
    os.mkdir(MODEL_SAVE_FOLDER_PATH)

model_path = MODEL_SAVE_FOLDER_PATH + '(##220125.bi)seed42-{epoch:02d}-{val_loss:.4f}.hdf5'

cb_checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss',
                                verbose=1, save_best_only=True)

early_stop = EarlyStopping(monitor='val_acc', patience=30, verbose=1, restore_best_weights=False)
bi_lstm.compile(optimizer= keras.optimizers.Adam(learning_rate = 0.001, decay = 0.001), loss = "binary_crossentropy", metrics=['acc'])
bi_lstm.fit(X_train, y_train, validation_split=0.25, batch_size=128, epochs=500,  
         callbacks=[early_stop,cb_checkpoint], shuffle=False)
# Out:
# Epoch 1/500
# 37/37 [==============================] - 9s 99ms/step - loss: 0.6775 - acc: 0.5999 - val_loss: 0.6665 - val_acc: 0.6177
#
# Epoch 00001: val_loss improved from inf to 0.66649, saving model to ./model/(##220125.bi)seed42-01-0.6665.hdf5
# Epoch 2/500
# 37/37 [==============================] - 3s 81ms/step - loss: 0.6739 - acc: 0.6035 - val_loss: 0.6639 - val_acc: 0.6177
#
# Epoch 00002: val_loss improved from 0.66649 to 0.66389, saving model to ./model/(##220125.bi)seed42-02-0.6639.hdf5
# Epoch 3/500
# 37/37 [==============================] - 3s 81ms/step - loss: 0.6504 - acc: 0.6184 - val_loss: 0.5851 - val_acc: 0.6934
#
# Epoch 00003: val_loss improved from 0.66389 to 0.58508, saving model to ./model/(##220125.bi)seed42-03-0.5851.hdf5
# Epoch 4/500
# 37/37 [==============================] - 3s 82ms/step - loss: 0.5190 - acc: 0.7528 - val_loss: 0.5023 - val_acc: 0.7633
#
# Epoch 00004: val_loss improved from 0.58508 to 0.50226, saving model to ./model/(##220125.bi)seed42-04-0.5023.hdf5
# Epoch 5/500
# 37/37 [==============================] - 3s 81ms/step - loss: 0.4419 - acc: 0.8080 - val_loss: 0.5103 - val_acc: 0.7704
#
# Epoch 00005: val_loss did not improve from 0.50226
# Epoch 6/500
# 37/37 [==============================] - 3s 81ms/step - loss: 0.3886 - acc: 0.8387 - val_loss: 0.5204 - val_acc: 0.7704
#
# Epoch 00006: val_loss did not improve from 0.50226
# Epoch 7/500
# 37/37 [==============================] - 3s 81ms/step - loss: 0.3489 - acc: 0.8628 - val_loss: 0.5621 - val_acc: 0.7574
#
# Epoch 00007: val_loss did not improve from 0.50226
# Epoch 8/500
# 37/37 [==============================] - 3s 81ms/step - loss: 0.3238 - acc: 0.8786 - val_loss: 0.5545 - val_acc: 0.7678
#
# Epoch 00008: val_loss did not improve from 0.50226
# Epoch 9/500
# 37/37 [==============================] - 3s 81ms/step - loss: 0.2978 - acc: 0.8917 - val_loss: 0.5843 - val_acc: 0.7626
#
# Epoch 00009: val_loss did not improve from 0.50226
# Epoch 10/500
# 37/37 [==============================] - 3s 82ms/step - loss: 0.2683 - acc: 0.9047 - val_loss: 0.6231 - val_acc: 0.7633
#
# Epoch 00010: val_loss did not improve from 0.50226
# Epoch 11/500
# 37/37 [==============================] - 3s 81ms/step - loss: 0.2428 - acc: 0.9148 - val_loss: 0.6904 - val_acc: 0.7374
#
# Epoch 00011: val_loss did not improve from 0.50226
# Epoch 12/500
# 37/37 [==============================] - 3s 82ms/step - loss: 0.2324 - acc: 0.9185 - val_loss: 0.7590 - val_acc: 0.7316
#
# Epoch 00012: val_loss did not improve from 0.50226
# Epoch 13/500
# 37/37 [==============================] - 3s 82ms/step - loss: 0.2618 - acc: 0.9064 - val_loss: 0.6006 - val_acc: 0.7587
#
# Epoch 00013: val_loss did not improve from 0.50226
# Epoch 14/500
# 37/37 [==============================] - 3s 82ms/step - loss: 0.2814 - acc: 0.8878 - val_loss: 0.5842 - val_acc: 0.7574
#
# Epoch 00014: val_loss did not improve from 0.50226
# Epoch 15/500
# 37/37 [==============================] - 3s 82ms/step - loss: 0.2494 - acc: 0.9109 - val_loss: 0.6814 - val_acc: 0.7445
#
# Epoch 00015: val_loss did not improve from 0.50226
# Epoch 16/500
# 37/37 [==============================] - 3s 82ms/step - loss: 0.2316 - acc: 0.9154 - val_loss: 0.7025 - val_acc: 0.7510
#
# Epoch 00016: val_loss did not improve from 0.50226
# Epoch 17/500
# 37/37 [==============================] - 3s 82ms/step - loss: 0.2079 - acc: 0.9284 - val_loss: 0.7365 - val_acc: 0.7471
#
# Epoch 00017: val_loss did not improve from 0.50226
# Epoch 18/500
# 37/37 [==============================] - 3s 81ms/step - loss: 0.2053 - acc: 0.9258 - val_loss: 0.7666 - val_acc: 0.7451
#
# Epoch 00018: val_loss did not improve from 0.50226
# Epoch 19/500
# 37/37 [==============================] - 3s 82ms/step - loss: 0.2151 - acc: 0.9226 - val_loss: 0.8290 - val_acc: 0.7251
#
# Epoch 00019: val_loss did not improve from 0.50226
# Epoch 20/500
# 37/37 [==============================] - 3s 82ms/step - loss: 0.2606 - acc: 0.9038 - val_loss: 0.9175 - val_acc: 0.7199
#
# Epoch 00020: val_loss did not improve from 0.50226
# Epoch 21/500
# 37/37 [==============================] - 3s 81ms/step - loss: 0.3405 - acc: 0.8527 - val_loss: 0.6499 - val_acc: 0.7503
#
# Epoch 00021: val_loss did not improve from 0.50226
# Epoch 22/500
# 37/37 [==============================] - 3s 82ms/step - loss: 0.2802 - acc: 0.8870 - val_loss: 0.6083 - val_acc: 0.7574
#
# Epoch 00022: val_loss did not improve from 0.50226
# Epoch 23/500
# 37/37 [==============================] - 3s 82ms/step - loss: 0.2015 - acc: 0.9247 - val_loss: 0.6581 - val_acc: 0.7536
#
# Epoch 00023: val_loss did not improve from 0.50226
# Epoch 24/500
# 37/37 [==============================] - 3s 81ms/step - loss: 0.1786 - acc: 0.9368 - val_loss: 0.6938 - val_acc: 0.7536
#
# Epoch 00024: val_loss did not improve from 0.50226
# Epoch 25/500
# 37/37 [==============================] - 3s 82ms/step - loss: 0.1590 - acc: 0.9469 - val_loss: 0.7326 - val_acc: 0.7497
#
# Epoch 00025: val_loss did not improve from 0.50226
# Epoch 26/500
# 37/37 [==============================] - 3s 82ms/step - loss: 0.1483 - acc: 0.9519 - val_loss: 0.7638 - val_acc: 0.7523
#
# Epoch 00026: val_loss did not improve from 0.50226
# Epoch 27/500
# 37/37 [==============================] - 3s 82ms/step - loss: 0.1361 - acc: 0.9588 - val_loss: 0.7830 - val_acc: 0.7529
#
# Epoch 00027: val_loss did not improve from 0.50226
# Epoch 28/500
# 37/37 [==============================] - 3s 82ms/step - loss: 0.1338 - acc: 0.9618 - val_loss: 0.8090 - val_acc: 0.7516
#
# Epoch 00028: val_loss did not improve from 0.50226
# Epoch 29/500
# 37/37 [==============================] - 3s 82ms/step - loss: 0.1254 - acc: 0.9629 - val_loss: 0.8314 - val_acc: 0.7484
#
# Epoch 00029: val_loss did not improve from 0.50226
# Epoch 30/500
# 37/37 [==============================] - 3s 82ms/step - loss: 0.1214 - acc: 0.9653 - val_loss: 0.8527 - val_acc: 0.7458
#
# Epoch 00030: val_loss did not improve from 0.50226
# Epoch 31/500
# 37/37 [==============================] - 3s 82ms/step - loss: 0.1188 - acc: 0.9679 - val_loss: 0.8681 - val_acc: 0.7445
#
# Epoch 00031: val_loss did not improve from 0.50226
# Epoch 32/500
# 37/37 [==============================] - 3s 82ms/step - loss: 0.1152 - acc: 0.9679 - val_loss: 0.8696 - val_acc: 0.7464
#
# Epoch 00032: val_loss did not improve from 0.50226
# Epoch 33/500
# 37/37 [==============================] - 3s 82ms/step - loss: 0.1112 - acc: 0.9713 - val_loss: 0.8757 - val_acc: 0.7445
#
# Epoch 00033: val_loss did not improve from 0.50226
# Epoch 34/500
# 37/37 [==============================] - 3s 82ms/step - loss: 0.1082 - acc: 0.9702 - val_loss: 0.8844 - val_acc: 0.7413
#
# Epoch 00034: val_loss did not improve from 0.50226
# Epoch 35/500
# 37/37 [==============================] - 3s 82ms/step - loss: 0.1082 - acc: 0.9715 - val_loss: 0.8944 - val_acc: 0.7413
#
# Epoch 00035: val_loss did not improve from 0.50226
# Epoch 00035: early stopping

# %% [markdown]
# ## (79) lr = 0.001, de = 0.001

# %%
from keras.models import load_model
best_model = load_model('./model/(220125.bi.ld)seed42-04-0.5023.hdf5') 

dic_42={}
for seed in range(42, 52):
    random.seed(seed)

    x = np.load('/project/LSH/x_(7727,10,4069).npy')
    y = np.load('/project/LSH/y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
    X_test, y_test = x[idx[i:],:,:], y[idx[i:]]
    
    pred = best_model.predict(X_test)
    pred[pred>0.5]=1
    pred[pred<=0.5]=0
    acc = metrics.accuracy_score(y_test, pred)
    dic_42[seed]=acc
    print(f'정확도 :{metrics.accuracy_score(y_test, pred)}, seed_num = {seed}')

df = pd.DataFrame.from_dict(dic_42, orient='index')
print(f'seed = {seed_num}의 정확도 df 만들고 평균 확인 : {df.mean().values}')
# Out:
# 정확도 :0.7663430420711974, seed_num = 42
# 정확도 :0.8032362459546926, seed_num = 43
# 정확도 :0.7838187702265372, seed_num = 44
# 정확도 :0.7883495145631068, seed_num = 45
# 정확도 :0.7695792880258899, seed_num = 46
# 정확도 :0.8122977346278317, seed_num = 47
# 정확도 :0.8051779935275081, seed_num = 48
# 정확도 :0.7987055016181229, seed_num = 49
# 정확도 :0.7883495145631068, seed_num = 50
# 정확도 :0.7889967637540453, seed_num = 51
# seed = 42의 정확도 df 만들고 평균 확인 : [0.79048544]

# %% [markdown]
# ## (79.8) lr = 0.001

# %%
from keras.models import load_model
best_model = load_model('./model/(220125.bi)seed42-04-0.4998.hdf5') 

dic_42={}
for seed in range(42, 52):
    random.seed(seed)

    x = np.load('/project/LSH/x_(7727,10,4069).npy')
    y = np.load('/project/LSH/y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
    X_test, y_test = x[idx[i:],:,:], y[idx[i:]]
    
    pred = best_model.predict(X_test)
    pred[pred>0.5]=1
    pred[pred<=0.5]=0
    acc = metrics.accuracy_score(y_test, pred)
    dic_42[seed]=acc
    print(f'정확도 :{metrics.accuracy_score(y_test, pred)}, seed_num = {seed}')

df = pd.DataFrame.from_dict(dic_42, orient='index')
print(f'seed = {seed_num}의 정확도 df 만들고 평균 확인 : {df.mean().values}')
# Out:
# 정확도 :0.7715210355987056, seed_num = 42
# 정확도 :0.8110032362459547, seed_num = 43
# 정확도 :0.7909385113268609, seed_num = 44
# 정확도 :0.7961165048543689, seed_num = 45
# 정확도 :0.7831715210355987, seed_num = 46
# 정확도 :0.8174757281553398, seed_num = 47
# 정확도 :0.8135922330097087, seed_num = 48
# 정확도 :0.8051779935275081, seed_num = 49
# 정확도 :0.7974110032362459, seed_num = 50
# 정확도 :0.7974110032362459, seed_num = 51
# seed = 42의 정확도 df 만들고 평균 확인 : [0.79838188]

# %% [markdown]
# # GRU

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings(action='ignore')

import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, InputLayer, GRU
from tensorflow.keras.callbacks import EarlyStopping
from sklearn import metrics 
from tensorflow import keras
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam


import random
# ----------------------
seed_num = 42
# ----------------------
random.seed(seed_num)

x = np.load('/project/LSH/x_(7727,10,4069).npy')
y = np.load('/project/LSH/y_(7727,1).npy')

idx = list(range(len(x)))
random.shuffle(idx)

i = round(x.shape[0]*0.8)
X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
X_test, y_test = x[idx[i:],:,:], y[idx[i:]]

# ---------------------
seed_num = 42 
# ---------------------
tf.random.set_seed(seed_num)

gru = Sequential()
gru.add(InputLayer(input_shape=(X_train.shape[1],X_train.shape[2])))
gru.add(GRU(units=128, activation='hard_sigmoid', return_sequences=True))
gru.add(GRU(units=64, activation='hard_sigmoid', return_sequences=True))
gru.add(Dropout(0.2))
gru.add(GRU(units=64, activation='hard_sigmoid', return_sequences=True))
gru.add(GRU(units=32, activation='hard_sigmoid', return_sequences=False))
gru.add(Dropout(0.2))
gru.add(Dense(units=1, activation='sigmoid'))

from tensorflow.keras.callbacks import ModelCheckpoint
import os

MODEL_SAVE_FOLDER_PATH = './model/'
if not os.path.exists(MODEL_SAVE_FOLDER_PATH):
    os.mkdir(MODEL_SAVE_FOLDER_PATH)

model_path = MODEL_SAVE_FOLDER_PATH + '(220125.gru)seed42-{epoch:02d}-{val_loss:.4f}.hdf5'

cb_checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss',
                                verbose=1, save_best_only=True)

early_stop = EarlyStopping(monitor='val_acc', patience=50, verbose=1, restore_best_weights=False)
gru.compile(optimizer= keras.optimizers.Adam(learning_rate = 0.001, decay = 0.001), loss = "binary_crossentropy", metrics=['acc'])
gru.fit(X_train, y_train, validation_split=0.25, batch_size=128, epochs=500,  
         callbacks=[early_stop,cb_checkpoint], shuffle=False)
# Out:
# Epoch 1/500
# 37/37 [==============================] - 5s 57ms/step - loss: 0.6856 - acc: 0.5856 - val_loss: 0.6661 - val_acc: 0.6177
#
# Epoch 00001: val_loss improved from inf to 0.66608, saving model to ./model/(220125.gru)seed42-01-0.6661.hdf5
# Epoch 2/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.6791 - acc: 0.5951 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00002: val_loss improved from 0.66608 to 0.66524, saving model to ./model/(220125.gru)seed42-02-0.6652.hdf5
# Epoch 3/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.6726 - acc: 0.6035 - val_loss: 0.6414 - val_acc: 0.6177
#
# Epoch 00003: val_loss improved from 0.66524 to 0.64135, saving model to ./model/(220125.gru)seed42-03-0.6414.hdf5
# Epoch 4/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.5974 - acc: 0.6829 - val_loss: 0.5415 - val_acc: 0.7393
#
# Epoch 00004: val_loss improved from 0.64135 to 0.54150, saving model to ./model/(220125.gru)seed42-04-0.5415.hdf5
# Epoch 5/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.4893 - acc: 0.7731 - val_loss: 0.4922 - val_acc: 0.7613
#
# Epoch 00005: val_loss improved from 0.54150 to 0.49219, saving model to ./model/(220125.gru)seed42-05-0.4922.hdf5
# Epoch 6/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.4296 - acc: 0.8147 - val_loss: 0.4859 - val_acc: 0.7755
#
# Epoch 00006: val_loss improved from 0.49219 to 0.48589, saving model to ./model/(220125.gru)seed42-06-0.4859.hdf5
# Epoch 7/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.3852 - acc: 0.8397 - val_loss: 0.4985 - val_acc: 0.7717
#
# Epoch 00007: val_loss did not improve from 0.48589
# Epoch 8/500
# 37/37 [==============================] - 2s 49ms/step - loss: 0.3488 - acc: 0.8624 - val_loss: 0.5191 - val_acc: 0.7704
#
# Epoch 00008: val_loss did not improve from 0.48589
# Epoch 9/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.3192 - acc: 0.8809 - val_loss: 0.5437 - val_acc: 0.7665
#
# Epoch 00009: val_loss did not improve from 0.48589
# Epoch 10/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.2954 - acc: 0.8962 - val_loss: 0.5685 - val_acc: 0.7652
#
# Epoch 00010: val_loss did not improve from 0.48589
# Epoch 11/500
# 37/37 [==============================] - 2s 49ms/step - loss: 0.2811 - acc: 0.8978 - val_loss: 0.5851 - val_acc: 0.7665
#
# Epoch 00011: val_loss did not improve from 0.48589
# Epoch 12/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.2591 - acc: 0.9088 - val_loss: 0.5991 - val_acc: 0.7613
#
# Epoch 00012: val_loss did not improve from 0.48589
# Epoch 13/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.2372 - acc: 0.9252 - val_loss: 0.6341 - val_acc: 0.7555
#
# Epoch 00013: val_loss did not improve from 0.48589
# Epoch 14/500
# 37/37 [==============================] - 2s 49ms/step - loss: 0.2205 - acc: 0.9327 - val_loss: 0.6564 - val_acc: 0.7607
#
# Epoch 00014: val_loss did not improve from 0.48589
# Epoch 15/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.2293 - acc: 0.9241 - val_loss: 0.6695 - val_acc: 0.7561
#
# Epoch 00015: val_loss did not improve from 0.48589
# Epoch 16/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.2449 - acc: 0.9120 - val_loss: 0.7813 - val_acc: 0.7342
#
# Epoch 00016: val_loss did not improve from 0.48589
# Epoch 17/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.2507 - acc: 0.9120 - val_loss: 0.6896 - val_acc: 0.7458
#
# Epoch 00017: val_loss did not improve from 0.48589
# Epoch 18/500
# 37/37 [==============================] - 2s 49ms/step - loss: 0.2403 - acc: 0.9133 - val_loss: 0.7456 - val_acc: 0.7413
#
# Epoch 00018: val_loss did not improve from 0.48589
# Epoch 19/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.2341 - acc: 0.9161 - val_loss: 0.7336 - val_acc: 0.7439
#
# Epoch 00019: val_loss did not improve from 0.48589
# Epoch 20/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.2464 - acc: 0.9094 - val_loss: 0.6581 - val_acc: 0.7516
#
# Epoch 00020: val_loss did not improve from 0.48589
# Epoch 21/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.2264 - acc: 0.9180 - val_loss: 0.6540 - val_acc: 0.7516
#
# Epoch 00021: val_loss did not improve from 0.48589
# Epoch 22/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.1918 - acc: 0.9403 - val_loss: 0.6692 - val_acc: 0.7581
#
# Epoch 00022: val_loss did not improve from 0.48589
# Epoch 23/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.1671 - acc: 0.9517 - val_loss: 0.7013 - val_acc: 0.7555
#
# Epoch 00023: val_loss did not improve from 0.48589
# Epoch 24/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.1579 - acc: 0.9558 - val_loss: 0.7264 - val_acc: 0.7529
#
# Epoch 00024: val_loss did not improve from 0.48589
# Epoch 25/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.1508 - acc: 0.9603 - val_loss: 0.7500 - val_acc: 0.7503
#
# Epoch 00025: val_loss did not improve from 0.48589
# Epoch 26/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.1447 - acc: 0.9599 - val_loss: 0.7693 - val_acc: 0.7490
#
# Epoch 00026: val_loss did not improve from 0.48589
# Epoch 27/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.1387 - acc: 0.9629 - val_loss: 0.7837 - val_acc: 0.7484
#
# Epoch 00027: val_loss did not improve from 0.48589
# Epoch 28/500
# 37/37 [==============================] - 2s 49ms/step - loss: 0.1361 - acc: 0.9635 - val_loss: 0.7986 - val_acc: 0.7464
#
# Epoch 00028: val_loss did not improve from 0.48589
# Epoch 29/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.1328 - acc: 0.9638 - val_loss: 0.8100 - val_acc: 0.7439
#
# Epoch 00029: val_loss did not improve from 0.48589
# Epoch 30/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.1315 - acc: 0.9659 - val_loss: 0.8245 - val_acc: 0.7419
#
# Epoch 00030: val_loss did not improve from 0.48589
# Epoch 31/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.1287 - acc: 0.9668 - val_loss: 0.8296 - val_acc: 0.7393
#
# Epoch 00031: val_loss did not improve from 0.48589
# Epoch 32/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.1254 - acc: 0.9683 - val_loss: 0.8451 - val_acc: 0.7400
#
# Epoch 00032: val_loss did not improve from 0.48589
# Epoch 33/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.1199 - acc: 0.9720 - val_loss: 0.8631 - val_acc: 0.7439
#
# Epoch 00033: val_loss did not improve from 0.48589
# Epoch 34/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.1174 - acc: 0.9722 - val_loss: 0.8682 - val_acc: 0.7413
#
# Epoch 00034: val_loss did not improve from 0.48589
# Epoch 35/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.1144 - acc: 0.9728 - val_loss: 0.8780 - val_acc: 0.7419
#
# Epoch 00035: val_loss did not improve from 0.48589
# Epoch 36/500
# 37/37 [==============================] - 2s 49ms/step - loss: 0.1156 - acc: 0.9733 - val_loss: 0.8874 - val_acc: 0.7361
#
# Epoch 00036: val_loss did not improve from 0.48589
# Epoch 37/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.1091 - acc: 0.9748 - val_loss: 0.8994 - val_acc: 0.7393
#
# Epoch 00037: val_loss did not improve from 0.48589
# Epoch 38/500
# 37/37 [==============================] - 2s 49ms/step - loss: 0.1076 - acc: 0.9754 - val_loss: 0.9062 - val_acc: 0.7354
#
# Epoch 00038: val_loss did not improve from 0.48589
# Epoch 39/500
# 37/37 [==============================] - 2s 49ms/step - loss: 0.1071 - acc: 0.9763 - val_loss: 0.9193 - val_acc: 0.7322
#
# Epoch 00039: val_loss did not improve from 0.48589
# Epoch 40/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.1028 - acc: 0.9754 - val_loss: 0.9325 - val_acc: 0.7309
#
# Epoch 00040: val_loss did not improve from 0.48589
# Epoch 41/500
# 37/37 [==============================] - 2s 49ms/step - loss: 0.1029 - acc: 0.9776 - val_loss: 0.9528 - val_acc: 0.7316
#
# Epoch 00041: val_loss did not improve from 0.48589
# Epoch 42/500
# 37/37 [==============================] - 2s 49ms/step - loss: 0.1003 - acc: 0.9769 - val_loss: 0.9543 - val_acc: 0.7303
#
# Epoch 00042: val_loss did not improve from 0.48589
# Epoch 43/500
# 37/37 [==============================] - 2s 49ms/step - loss: 0.1004 - acc: 0.9774 - val_loss: 0.9595 - val_acc: 0.7296
#
# Epoch 00043: val_loss did not improve from 0.48589
# Epoch 44/500
# 37/37 [==============================] - 2s 49ms/step - loss: 0.0951 - acc: 0.9789 - val_loss: 0.9677 - val_acc: 0.7309
#
# Epoch 00044: val_loss did not improve from 0.48589
# Epoch 45/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.0916 - acc: 0.9797 - val_loss: 0.9837 - val_acc: 0.7290
#
# Epoch 00045: val_loss did not improve from 0.48589
# Epoch 46/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.0927 - acc: 0.9793 - val_loss: 0.9907 - val_acc: 0.7251
#
# Epoch 00046: val_loss did not improve from 0.48589
# Epoch 47/500
# 37/37 [==============================] - 2s 49ms/step - loss: 0.0895 - acc: 0.9806 - val_loss: 1.0035 - val_acc: 0.7257
#
# Epoch 00047: val_loss did not improve from 0.48589
# Epoch 48/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.0870 - acc: 0.9812 - val_loss: 1.0141 - val_acc: 0.7212
#
# Epoch 00048: val_loss did not improve from 0.48589
# Epoch 49/500
# 37/37 [==============================] - 2s 49ms/step - loss: 0.0909 - acc: 0.9804 - val_loss: 1.0228 - val_acc: 0.7238
#
# Epoch 00049: val_loss did not improve from 0.48589
# Epoch 50/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.0888 - acc: 0.9802 - val_loss: 1.0276 - val_acc: 0.7199
#
# Epoch 00050: val_loss did not improve from 0.48589
# Epoch 51/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.0859 - acc: 0.9817 - val_loss: 1.0387 - val_acc: 0.7199
#
# Epoch 00051: val_loss did not improve from 0.48589
# Epoch 52/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.0841 - acc: 0.9821 - val_loss: 1.0467 - val_acc: 0.7186
#
# Epoch 00052: val_loss did not improve from 0.48589
# Epoch 53/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.0862 - acc: 0.9814 - val_loss: 1.0560 - val_acc: 0.7193
#
# Epoch 00053: val_loss did not improve from 0.48589
# Epoch 54/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.0822 - acc: 0.9827 - val_loss: 1.0556 - val_acc: 0.7193
#
# Epoch 00054: val_loss did not improve from 0.48589
# Epoch 55/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.0843 - acc: 0.9827 - val_loss: 1.0727 - val_acc: 0.7160
#
# Epoch 00055: val_loss did not improve from 0.48589
# Epoch 56/500
# 37/37 [==============================] - 2s 48ms/step - loss: 0.0824 - acc: 0.9834 - val_loss: 1.0727 - val_acc: 0.7173
#
# Epoch 00056: val_loss did not improve from 0.48589
# Epoch 00056: early stopping

# %% [markdown]
# ## (80.7) lr = 0.001, de = 0.001

# %%
from keras.models import load_model
best_model = load_model('./model/(220125.gru)seed42-06-0.4859.hdf5') 

dic_42={}
for seed in range(42, 52):
    random.seed(seed)

    x = np.load('/project/LSH/x_(7727,10,4069).npy')
    y = np.load('/project/LSH/y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_test, y_test = x[idx[i:],:,:], y[idx[i:]]
    
    pred = best_model.predict(X_test)
    pred[pred>0.5]=1
    pred[pred<=0.5]=0
    acc = metrics.accuracy_score(y_test, pred)
    dic_42[seed]=acc
    print(f'정확도 :{metrics.accuracy_score(y_test, pred)}, seed_num = {seed}')

df = pd.DataFrame.from_dict(dic_42, orient='index')
print(f'seed = {seed_num}의 정확도 df 만들고 평균 확인 : {df.mean().values}')
# Out:
# 정확도 :0.7656957928802589, seed_num = 42
# 정확도 :0.8187702265372169, seed_num = 43
# 정확도 :0.8051779935275081, seed_num = 44
# 정확도 :0.8110032362459547, seed_num = 45
# 정확도 :0.8, seed_num = 46
# 정확도 :0.8239482200647249, seed_num = 47
# 정확도 :0.8239482200647249, seed_num = 48
# 정확도 :0.8168284789644013, seed_num = 49
# 정확도 :0.8032362459546926, seed_num = 50
# 정확도 :0.8045307443365696, seed_num = 51
# seed = 42의 정확도 df 만들고 평균 확인 : [0.80731392]

# %% [markdown]
# ## (79.7) lr = 0.001

# %%
from keras.models import load_model
best_model = load_model('./model/(220125.gru.l)seed42-05-0.4885.hdf5') 

dic_42={}
for seed in range(42, 52):
    random.seed(seed)

    x = np.load('/project/LSH/x_(7727,10,4069).npy')
    y = np.load('/project/LSH/y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_test, y_test = x[idx[i:],:,:], y[idx[i:]]
    
    pred = best_model.predict(X_test)
    pred[pred>0.5]=1
    pred[pred<=0.5]=0
    acc = metrics.accuracy_score(y_test, pred)
    dic_42[seed]=acc
    print(f'정확도 :{metrics.accuracy_score(y_test, pred)}, seed_num = {seed}')

df = pd.DataFrame.from_dict(dic_42, orient='index')
print(f'seed = {seed_num}의 정확도 df 만들고 평균 확인 : {df.mean().values}')
# Out:
# 정확도 :0.7611650485436893, seed_num = 42
# 정확도 :0.8097087378640777, seed_num = 43
# 정확도 :0.7915857605177994, seed_num = 44
# 정확도 :0.7980582524271844, seed_num = 45
# 정확도 :0.7838187702265372, seed_num = 46
# 정확도 :0.8187702265372169, seed_num = 47
# 정확도 :0.8129449838187702, seed_num = 48
# 정확도 :0.8077669902912621, seed_num = 49
# 정확도 :0.7967637540453074, seed_num = 50
# 정확도 :0.7961165048543689, seed_num = 51
# seed = 42의 정확도 df 만들고 평균 확인 : [0.7976699]

# %% [markdown]
# # Bidirectional GRU

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings(action='ignore')

import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, InputLayer, Bidirectional, GRU
from tensorflow.keras.callbacks import EarlyStopping
from sklearn import metrics 
from tensorflow import keras
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

import random
# ----------------------
seed_num = 42
# ----------------------
random.seed(seed_num)

x = np.load('/project/LSH/x_(7727,10,4069).npy')
y = np.load('/project/LSH/y_(7727,1).npy')

idx = list(range(len(x)))
random.shuffle(idx)

i = round(x.shape[0]*0.8)
X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
X_test, y_test = x[idx[i:],:,:], y[idx[i:]]

# ---------------------
seed_num = 42 
# ---------------------
tf.random.set_seed(seed_num)

bi_GRU = Sequential()
bi_GRU.add(InputLayer(input_shape=(X_train.shape[1],X_train.shape[2])))
bi_GRU.add(Bidirectional(GRU(units=128, activation='hard_sigmoid', return_sequences=True)))
bi_GRU.add(Bidirectional(GRU(units=64, activation='hard_sigmoid', return_sequences=True)))
bi_GRU.add(Dropout(0.2))
bi_GRU.add(Bidirectional(GRU(units=64, activation='hard_sigmoid', return_sequences=True)))
bi_GRU.add(Bidirectional(GRU(units=32, activation='hard_sigmoid', return_sequences=False)))
bi_GRU.add(Dropout(0.2))
bi_GRU.add(Dense(units=1, activation='sigmoid'))

from tensorflow.keras.callbacks import ModelCheckpoint
import os

MODEL_SAVE_FOLDER_PATH = './model/'
if not os.path.exists(MODEL_SAVE_FOLDER_PATH):
    os.mkdir(MODEL_SAVE_FOLDER_PATH)

model_path = MODEL_SAVE_FOLDER_PATH + '(bi_gru_d)seed42-{epoch:02d}-{val_loss:.4f}.hdf5'

cb_checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss',
                                verbose=1, save_best_only=True)

early_stop = EarlyStopping(monitor='val_acc', patience=30, verbose=1, restore_best_weights=False)
bi_GRU.compile(optimizer= keras.optimizers.Adam(learning_rate = 0.001), loss = "binary_crossentropy", metrics=['acc'])
bi_GRU.fit(X_train, y_train, validation_split=0.25, batch_size=128, epochs=500,  
         callbacks=[early_stop,cb_checkpoint], shuffle=False)
# Out:
# Epoch 1/500
# 37/37 [==============================] - 9s 89ms/step - loss: 0.6849 - acc: 0.5895 - val_loss: 0.6667 - val_acc: 0.6177
#
# Epoch 00001: val_loss improved from inf to 0.66673, saving model to ./model/(bi_gru_d)seed42-01-0.6667.hdf5
# Epoch 2/500
# 37/37 [==============================] - 3s 74ms/step - loss: 0.6781 - acc: 0.5940 - val_loss: 0.6590 - val_acc: 0.6177
#
# Epoch 00002: val_loss improved from 0.66673 to 0.65897, saving model to ./model/(bi_gru_d)seed42-02-0.6590.hdf5
# Epoch 3/500
# 37/37 [==============================] - 3s 74ms/step - loss: 0.6157 - acc: 0.6609 - val_loss: 0.5281 - val_acc: 0.7348
#
# Epoch 00003: val_loss improved from 0.65897 to 0.52813, saving model to ./model/(bi_gru_d)seed42-03-0.5281.hdf5
# Epoch 4/500
# 37/37 [==============================] - 3s 74ms/step - loss: 0.4812 - acc: 0.7755 - val_loss: 0.4901 - val_acc: 0.7671
#
# Epoch 00004: val_loss improved from 0.52813 to 0.49012, saving model to ./model/(bi_gru_d)seed42-04-0.4901.hdf5
# Epoch 5/500
# 37/37 [==============================] - 3s 74ms/step - loss: 0.4110 - acc: 0.8240 - val_loss: 0.4910 - val_acc: 0.7775
#
# Epoch 00005: val_loss did not improve from 0.49012
# Epoch 6/500
# 37/37 [==============================] - 3s 74ms/step - loss: 0.3551 - acc: 0.8581 - val_loss: 0.5160 - val_acc: 0.7743
#
# Epoch 00006: val_loss did not improve from 0.49012
# Epoch 7/500
# 37/37 [==============================] - 3s 74ms/step - loss: 0.3012 - acc: 0.8896 - val_loss: 0.5607 - val_acc: 0.7671
#
# Epoch 00007: val_loss did not improve from 0.49012
# Epoch 8/500
# 37/37 [==============================] - 3s 74ms/step - loss: 0.2552 - acc: 0.9129 - val_loss: 0.6042 - val_acc: 0.7658
#
# Epoch 00008: val_loss did not improve from 0.49012
# Epoch 9/500
# 37/37 [==============================] - 3s 74ms/step - loss: 0.2170 - acc: 0.9310 - val_loss: 0.7738 - val_acc: 0.7147
#
# Epoch 00009: val_loss did not improve from 0.49012
# Epoch 10/500
# 37/37 [==============================] - 3s 74ms/step - loss: 0.2317 - acc: 0.9131 - val_loss: 0.6608 - val_acc: 0.7516
#
# Epoch 00010: val_loss did not improve from 0.49012
# Epoch 11/500
# 37/37 [==============================] - 3s 74ms/step - loss: 0.2052 - acc: 0.9301 - val_loss: 0.8084 - val_acc: 0.7270
#
# Epoch 00011: val_loss did not improve from 0.49012
# Epoch 12/500
# 37/37 [==============================] - 3s 75ms/step - loss: 0.1718 - acc: 0.9435 - val_loss: 0.7257 - val_acc: 0.7555
#
# Epoch 00012: val_loss did not improve from 0.49012
# Epoch 13/500
# 37/37 [==============================] - 3s 75ms/step - loss: 0.1413 - acc: 0.9564 - val_loss: 0.7802 - val_acc: 0.7523
#
# Epoch 00013: val_loss did not improve from 0.49012
# Epoch 14/500
# 37/37 [==============================] - 3s 75ms/step - loss: 0.1489 - acc: 0.9523 - val_loss: 0.8147 - val_acc: 0.7458
#
# Epoch 00014: val_loss did not improve from 0.49012
# Epoch 15/500
# 37/37 [==============================] - 3s 74ms/step - loss: 0.1739 - acc: 0.9398 - val_loss: 0.7969 - val_acc: 0.7406
#
# Epoch 00015: val_loss did not improve from 0.49012
# Epoch 16/500
# 37/37 [==============================] - 3s 75ms/step - loss: 0.2421 - acc: 0.9055 - val_loss: 0.7005 - val_acc: 0.7348
#
# Epoch 00016: val_loss did not improve from 0.49012
# Epoch 17/500
# 37/37 [==============================] - 3s 74ms/step - loss: 0.1671 - acc: 0.9437 - val_loss: 0.8670 - val_acc: 0.7238
#
# Epoch 00017: val_loss did not improve from 0.49012
# Epoch 18/500
# 37/37 [==============================] - 3s 75ms/step - loss: 0.1476 - acc: 0.9525 - val_loss: 0.9601 - val_acc: 0.7212
#
# Epoch 00018: val_loss did not improve from 0.49012
# Epoch 19/500
# 37/37 [==============================] - 3s 74ms/step - loss: 0.1516 - acc: 0.9528 - val_loss: 1.0184 - val_acc: 0.7199
#
# Epoch 00019: val_loss did not improve from 0.49012
# Epoch 20/500
# 37/37 [==============================] - 3s 74ms/step - loss: 0.1664 - acc: 0.9443 - val_loss: 1.0546 - val_acc: 0.7128
#
# Epoch 00020: val_loss did not improve from 0.49012
# Epoch 21/500
# 37/37 [==============================] - 3s 74ms/step - loss: 0.1952 - acc: 0.9299 - val_loss: 0.9074 - val_acc: 0.7290
#
# Epoch 00021: val_loss did not improve from 0.49012
# Epoch 22/500
# 37/37 [==============================] - 3s 75ms/step - loss: 0.2859 - acc: 0.8930 - val_loss: 0.6505 - val_acc: 0.7290
#
# Epoch 00022: val_loss did not improve from 0.49012
# Epoch 23/500
# 37/37 [==============================] - 3s 75ms/step - loss: 0.1556 - acc: 0.9467 - val_loss: 0.7468 - val_acc: 0.7516
#
# Epoch 00023: val_loss did not improve from 0.49012
# Epoch 24/500
# 37/37 [==============================] - 3s 75ms/step - loss: 0.1053 - acc: 0.9702 - val_loss: 0.8453 - val_acc: 0.7406
#
# Epoch 00024: val_loss did not improve from 0.49012
# Epoch 25/500
# 37/37 [==============================] - 3s 74ms/step - loss: 0.0926 - acc: 0.9754 - val_loss: 0.8980 - val_acc: 0.7387
#
# Epoch 00025: val_loss did not improve from 0.49012
# Epoch 26/500
# 37/37 [==============================] - 3s 74ms/step - loss: 0.0818 - acc: 0.9791 - val_loss: 0.9389 - val_acc: 0.7387
#
# Epoch 00026: val_loss did not improve from 0.49012
# Epoch 27/500
# 37/37 [==============================] - 3s 75ms/step - loss: 0.0750 - acc: 0.9793 - val_loss: 0.9802 - val_acc: 0.7322
#
# Epoch 00027: val_loss did not improve from 0.49012
# Epoch 28/500
# 37/37 [==============================] - 3s 74ms/step - loss: 0.0722 - acc: 0.9812 - val_loss: 1.0095 - val_acc: 0.7374
#
# Epoch 00028: val_loss did not improve from 0.49012
# Epoch 29/500
# 37/37 [==============================] - 3s 74ms/step - loss: 0.0682 - acc: 0.9832 - val_loss: 1.0351 - val_acc: 0.7367
#
# Epoch 00029: val_loss did not improve from 0.49012
# Epoch 30/500
# 37/37 [==============================] - 3s 74ms/step - loss: 0.0631 - acc: 0.9832 - val_loss: 1.0634 - val_acc: 0.7342
#
# Epoch 00030: val_loss did not improve from 0.49012
# Epoch 31/500
# 37/37 [==============================] - 3s 75ms/step - loss: 0.0609 - acc: 0.9855 - val_loss: 1.0878 - val_acc: 0.7316
#
# Epoch 00031: val_loss did not improve from 0.49012
# Epoch 32/500
# 37/37 [==============================] - 3s 74ms/step - loss: 0.0587 - acc: 0.9860 - val_loss: 1.1115 - val_acc: 0.7270
#
# Epoch 00032: val_loss did not improve from 0.49012
# Epoch 33/500
# 37/37 [==============================] - 3s 74ms/step - loss: 0.0566 - acc: 0.9851 - val_loss: 1.1319 - val_acc: 0.7270
#
# Epoch 00033: val_loss did not improve from 0.49012
# Epoch 34/500
# 37/37 [==============================] - 3s 75ms/step - loss: 0.0555 - acc: 0.9866 - val_loss: 1.1469 - val_acc: 0.7277
#
# Epoch 00034: val_loss did not improve from 0.49012
# Epoch 35/500
# 37/37 [==============================] - 3s 75ms/step - loss: 0.0541 - acc: 0.9866 - val_loss: 1.1796 - val_acc: 0.7245
#
# Epoch 00035: val_loss did not improve from 0.49012
# Epoch 00035: early stopping

# %% [markdown]
# ## (81.5) lr = 0.001, de = 0.001

# %%
from keras.models import load_model
best_model = load_model('./model/(bi_gru)seed42-05-0.4841.hdf5') 

dic_42={}
for seed in range(42, 52):
    random.seed(seed)

    x = np.load('/project/LSH/x_(7727,10,4069).npy')
    y = np.load('/project/LSH/y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_test, y_test = x[idx[i:],:,:], y[idx[i:]]
    
    pred = best_model.predict(X_test)
    pred[pred>0.5]=1
    pred[pred<=0.5]=0
    acc = metrics.accuracy_score(y_test, pred)
    dic_42[seed]=acc
    print(f'정확도 :{metrics.accuracy_score(y_test, pred)}, seed_num = {seed}')

df = pd.DataFrame.from_dict(dic_42, orient='index')
print(f'seed = {seed_num}의 정확도 df 만들고 평균 확인 : {df.mean().values}')
# Out:
# 정확도 :0.7741100323624596, seed_num = 42
# 정확도 :0.8330097087378641, seed_num = 43
# 정확도 :0.8084142394822007, seed_num = 44
# 정확도 :0.8200647249190939, seed_num = 45
# 정확도 :0.8038834951456311, seed_num = 46
# 정확도 :0.8336569579288026, seed_num = 47
# 정확도 :0.8330097087378641, seed_num = 48
# 정확도 :0.8265372168284789, seed_num = 49
# 정확도 :0.8129449838187702, seed_num = 50
# 정확도 :0.8058252427184466, seed_num = 51
# seed = 42의 정확도 df 만들고 평균 확인 : [0.81514563]

# %% [markdown]
# ## (79.4) lr = 0.001

# %%
from keras.models import load_model
best_model = load_model('./model/(bi_gru_d)seed42-04-0.4901.hdf5') 

dic_42={}
for seed in range(42, 52):
    random.seed(seed)

    x = np.load('/project/LSH/x_(7727,10,4069).npy')
    y = np.load('/project/LSH/y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_test, y_test = x[idx[i:],:,:], y[idx[i:]]
    
    pred = best_model.predict(X_test)
    pred[pred>0.5]=1
    pred[pred<=0.5]=0
    acc = metrics.accuracy_score(y_test, pred)
    dic_42[seed]=acc
    print(f'정확도 :{metrics.accuracy_score(y_test, pred)}, seed_num = {seed}')

df = pd.DataFrame.from_dict(dic_42, orient='index')
print(f'seed = {seed_num}의 정확도 df 만들고 평균 확인 : {df.mean().values}')
# Out:
# 정확도 :0.7644012944983819, seed_num = 42
# 정확도 :0.8077669902912621, seed_num = 43
# 정확도 :0.7818770226537217, seed_num = 44
# 정확도 :0.7993527508090615, seed_num = 45
# 정확도 :0.7870550161812297, seed_num = 46
# 정확도 :0.8161812297734627, seed_num = 47
# 정확도 :0.8135922330097087, seed_num = 48
# 정확도 :0.7974110032362459, seed_num = 49
# 정확도 :0.7870550161812297, seed_num = 50
# 정확도 :0.7896440129449838, seed_num = 51
# seed = 42의 정확도 df 만들고 평균 확인 : [0.79443366]

# %% [markdown]
# # RNN

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings(action='ignore')

import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, InputLayer, SimpleRNN
from tensorflow.keras.callbacks import EarlyStopping
from sklearn import metrics 
from tensorflow import keras
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam


import random
# ----------------------
seed_num = 42
# ----------------------
random.seed(seed_num)

x = np.load('/project/LSH/x_(7727,10,4069).npy')
y = np.load('/project/LSH/y_(7727,1).npy')

idx = list(range(len(x)))
random.shuffle(idx)

i = round(x.shape[0]*0.8)
X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
X_test, y_test = x[idx[i:],:,:], y[idx[i:]]

# ---------------------
seed_num = 42 
# ---------------------
tf.random.set_seed(seed_num)

rnn = Sequential()
rnn.add(InputLayer(input_shape=(X_train.shape[1],X_train.shape[2])))
rnn.add(SimpleRNN(units=128, activation='hard_sigmoid', return_sequences=True))
rnn.add(SimpleRNN(units=64, activation='hard_sigmoid', return_sequences=True))
rnn.add(Dropout(0.2))
rnn.add(SimpleRNN(units=64, activation='hard_sigmoid', return_sequences=True))
rnn.add(SimpleRNN(units=32, activation='hard_sigmoid', return_sequences=False))
rnn.add(Dropout(0.2))
rnn.add(Dense(units=1, activation='sigmoid'))

from tensorflow.keras.callbacks import ModelCheckpoint
import os

MODEL_SAVE_FOLDER_PATH = './model/'
if not os.path.exists(MODEL_SAVE_FOLDER_PATH):
    os.mkdir(MODEL_SAVE_FOLDER_PATH)

model_path = MODEL_SAVE_FOLDER_PATH + '(220125.rnn.d)seed42-{epoch:02d}-{val_loss:.4f}.hdf5'

cb_checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss',
                                verbose=1, save_best_only=True)

early_stop = EarlyStopping(monitor='val_acc', patience=30, verbose=1, restore_best_weights=False)
rnn.compile(optimizer= keras.optimizers.Adam(learning_rate = 0.001, decay=0.001), loss = "binary_crossentropy", metrics=['acc'])
rnn.fit(X_train, y_train, validation_split=0.25, batch_size=128, epochs=500,  
         callbacks=[early_stop,cb_checkpoint], shuffle=False)
# Out:
# Epoch 1/500
# 37/37 [==============================] - 3s 37ms/step - loss: 0.6837 - acc: 0.5887 - val_loss: 0.6639 - val_acc: 0.6177
#
# Epoch 00001: val_loss improved from inf to 0.66392, saving model to ./model/(220125.rnn.d)seed42-01-0.6639.hdf5
# Epoch 2/500
# 37/37 [==============================] - 1s 28ms/step - loss: 0.6672 - acc: 0.6025 - val_loss: 0.6301 - val_acc: 0.6177
#
# Epoch 00002: val_loss improved from 0.66392 to 0.63013, saving model to ./model/(220125.rnn.d)seed42-02-0.6301.hdf5
# Epoch 3/500
# 37/37 [==============================] - 1s 27ms/step - loss: 0.5924 - acc: 0.6870 - val_loss: 0.5440 - val_acc: 0.7154
#
# Epoch 00003: val_loss improved from 0.63013 to 0.54396, saving model to ./model/(220125.rnn.d)seed42-03-0.5440.hdf5
# Epoch 4/500
# 37/37 [==============================] - 1s 28ms/step - loss: 0.5026 - acc: 0.7591 - val_loss: 0.5003 - val_acc: 0.7490
#
# Epoch 00004: val_loss improved from 0.54396 to 0.50026, saving model to ./model/(220125.rnn.d)seed42-04-0.5003.hdf5
# Epoch 5/500
# 37/37 [==============================] - 1s 29ms/step - loss: 0.4407 - acc: 0.7972 - val_loss: 0.4843 - val_acc: 0.7620
#
# Epoch 00005: val_loss improved from 0.50026 to 0.48431, saving model to ./model/(220125.rnn.d)seed42-05-0.4843.hdf5
# Epoch 6/500
# 37/37 [==============================] - 1s 29ms/step - loss: 0.3990 - acc: 0.8270 - val_loss: 0.4953 - val_acc: 0.7691
#
# Epoch 00006: val_loss did not improve from 0.48431
# Epoch 7/500
# 37/37 [==============================] - 1s 28ms/step - loss: 0.3635 - acc: 0.8497 - val_loss: 0.5102 - val_acc: 0.7710
#
# Epoch 00007: val_loss did not improve from 0.48431
# Epoch 8/500
# 37/37 [==============================] - 1s 29ms/step - loss: 0.3392 - acc: 0.8617 - val_loss: 0.5326 - val_acc: 0.7697
#
# Epoch 00008: val_loss did not improve from 0.48431
# Epoch 9/500
# 37/37 [==============================] - 1s 29ms/step - loss: 0.3142 - acc: 0.8721 - val_loss: 0.5610 - val_acc: 0.7678
#
# Epoch 00009: val_loss did not improve from 0.48431
# Epoch 10/500
# 37/37 [==============================] - 1s 29ms/step - loss: 0.2877 - acc: 0.8885 - val_loss: 0.5891 - val_acc: 0.7620
#
# Epoch 00010: val_loss did not improve from 0.48431
# Epoch 11/500
# 37/37 [==============================] - 1s 28ms/step - loss: 0.2709 - acc: 0.8986 - val_loss: 0.6142 - val_acc: 0.7600
#
# Epoch 00011: val_loss did not improve from 0.48431
# Epoch 12/500
# 37/37 [==============================] - 1s 29ms/step - loss: 0.2569 - acc: 0.9008 - val_loss: 0.6480 - val_acc: 0.7523
#
# Epoch 00012: val_loss did not improve from 0.48431
# Epoch 13/500
# 37/37 [==============================] - 1s 29ms/step - loss: 0.2631 - acc: 0.9010 - val_loss: 0.7090 - val_acc: 0.7387
#
# Epoch 00013: val_loss did not improve from 0.48431
# Epoch 14/500
# 37/37 [==============================] - 1s 29ms/step - loss: 0.2513 - acc: 0.9027 - val_loss: 0.6619 - val_acc: 0.7439
#
# Epoch 00014: val_loss did not improve from 0.48431
# Epoch 15/500
# 37/37 [==============================] - 1s 29ms/step - loss: 0.2397 - acc: 0.9150 - val_loss: 0.6917 - val_acc: 0.7277
#
# Epoch 00015: val_loss did not improve from 0.48431
# Epoch 16/500
# 37/37 [==============================] - 1s 29ms/step - loss: 0.2485 - acc: 0.9042 - val_loss: 0.7152 - val_acc: 0.7160
#
# Epoch 00016: val_loss did not improve from 0.48431
# Epoch 17/500
# 37/37 [==============================] - 1s 28ms/step - loss: 0.2622 - acc: 0.8950 - val_loss: 0.7016 - val_acc: 0.7458
#
# Epoch 00017: val_loss did not improve from 0.48431
# Epoch 18/500
# 37/37 [==============================] - 1s 28ms/step - loss: 0.2200 - acc: 0.9180 - val_loss: 0.7313 - val_acc: 0.7439
#
# Epoch 00018: val_loss did not improve from 0.48431
# Epoch 19/500
# 37/37 [==============================] - 1s 29ms/step - loss: 0.2009 - acc: 0.9333 - val_loss: 0.7585 - val_acc: 0.7426
#
# Epoch 00019: val_loss did not improve from 0.48431
# Epoch 20/500
# 37/37 [==============================] - 1s 29ms/step - loss: 0.1944 - acc: 0.9355 - val_loss: 0.7966 - val_acc: 0.7451
#
# Epoch 00020: val_loss did not improve from 0.48431
# Epoch 21/500
# 37/37 [==============================] - 1s 29ms/step - loss: 0.1876 - acc: 0.9362 - val_loss: 0.8325 - val_acc: 0.7380
#
# Epoch 00021: val_loss did not improve from 0.48431
# Epoch 22/500
# 37/37 [==============================] - 1s 29ms/step - loss: 0.1818 - acc: 0.9400 - val_loss: 0.8668 - val_acc: 0.7348
#
# Epoch 00022: val_loss did not improve from 0.48431
# Epoch 23/500
# 37/37 [==============================] - 1s 29ms/step - loss: 0.1799 - acc: 0.9420 - val_loss: 0.8761 - val_acc: 0.7316
#
# Epoch 00023: val_loss did not improve from 0.48431
# Epoch 24/500
# 37/37 [==============================] - 1s 29ms/step - loss: 0.1862 - acc: 0.9424 - val_loss: 0.8964 - val_acc: 0.7303
#
# Epoch 00024: val_loss did not improve from 0.48431
# Epoch 25/500
# 37/37 [==============================] - 1s 29ms/step - loss: 0.1942 - acc: 0.9359 - val_loss: 0.9252 - val_acc: 0.7283
#
# Epoch 00025: val_loss did not improve from 0.48431
# Epoch 26/500
# 37/37 [==============================] - 1s 29ms/step - loss: 0.2118 - acc: 0.9258 - val_loss: 0.9723 - val_acc: 0.7219
#
# Epoch 00026: val_loss did not improve from 0.48431
# Epoch 27/500
# 37/37 [==============================] - 1s 28ms/step - loss: 0.2827 - acc: 0.8818 - val_loss: 0.8732 - val_acc: 0.7283
#
# Epoch 00027: val_loss did not improve from 0.48431
# Epoch 28/500
# 37/37 [==============================] - 1s 29ms/step - loss: 0.3053 - acc: 0.8699 - val_loss: 0.6807 - val_acc: 0.7264
#
# Epoch 00028: val_loss did not improve from 0.48431
# Epoch 29/500
# 37/37 [==============================] - 1s 29ms/step - loss: 0.2022 - acc: 0.9271 - val_loss: 0.6886 - val_acc: 0.7400
#
# Epoch 00029: val_loss did not improve from 0.48431
# Epoch 30/500
# 37/37 [==============================] - 1s 29ms/step - loss: 0.1830 - acc: 0.9390 - val_loss: 0.7271 - val_acc: 0.7419
#
# Epoch 00030: val_loss did not improve from 0.48431
# Epoch 31/500
# 37/37 [==============================] - 1s 29ms/step - loss: 0.1672 - acc: 0.9465 - val_loss: 0.7583 - val_acc: 0.7374
#
# Epoch 00031: val_loss did not improve from 0.48431
# Epoch 32/500
# 37/37 [==============================] - 1s 28ms/step - loss: 0.1594 - acc: 0.9502 - val_loss: 0.7851 - val_acc: 0.7387
#
# Epoch 00032: val_loss did not improve from 0.48431
# Epoch 33/500
# 37/37 [==============================] - 1s 29ms/step - loss: 0.1537 - acc: 0.9530 - val_loss: 0.8087 - val_acc: 0.7367
#
# Epoch 00033: val_loss did not improve from 0.48431
# Epoch 34/500
# 37/37 [==============================] - 1s 29ms/step - loss: 0.1454 - acc: 0.9577 - val_loss: 0.8316 - val_acc: 0.7374
#
# Epoch 00034: val_loss did not improve from 0.48431
# Epoch 35/500
# 37/37 [==============================] - 1s 29ms/step - loss: 0.1358 - acc: 0.9620 - val_loss: 0.8515 - val_acc: 0.7348
#
# Epoch 00035: val_loss did not improve from 0.48431
# Epoch 36/500
# 37/37 [==============================] - 1s 29ms/step - loss: 0.1349 - acc: 0.9616 - val_loss: 0.8709 - val_acc: 0.7367
#
# Epoch 00036: val_loss did not improve from 0.48431
# Epoch 37/500
# 37/37 [==============================] - 1s 29ms/step - loss: 0.1291 - acc: 0.9635 - val_loss: 0.8870 - val_acc: 0.7380
#
# Epoch 00037: val_loss did not improve from 0.48431
# Epoch 00037: early stopping

# %% [markdown]
# ## (79.9) lr = 0.001, de = 0.001

# %%
from keras.models import load_model
best_model = load_model('./model/(220125.rnn.d)seed42-05-0.4843.hdf5') 

dic_42={}
for seed in range(42, 52):
    random.seed(seed)

    x = np.load('/project/LSH/x_(7727,10,4069).npy')
    y = np.load('/project/LSH/y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_test, y_test = x[idx[i:],:,:], y[idx[i:]]
    
    pred = best_model.predict(X_test)
    pred[pred>0.5]=1
    pred[pred<=0.5]=0
    acc = metrics.accuracy_score(y_test, pred)
    dic_42[seed]=acc
    print(f'정확도 :{metrics.accuracy_score(y_test, pred)}, seed_num = {seed}')

df = pd.DataFrame.from_dict(dic_42, orient='index')
print(f'seed = {seed_num}의 정확도 df 만들고 평균 확인 : {df.mean().values}')
# Out:
# 정확도 :0.7585760517799353, seed_num = 42
# 정확도 :0.8058252427184466, seed_num = 43
# 정확도 :0.7948220064724919, seed_num = 44
# 정확도 :0.8064724919093851, seed_num = 45
# 정확도 :0.7922330097087379, seed_num = 46
# 정확도 :0.8148867313915857, seed_num = 47
# 정확도 :0.8220064724919094, seed_num = 48
# 정확도 :0.8032362459546926, seed_num = 49
# 정확도 :0.7980582524271844, seed_num = 50
# 정확도 :0.7987055016181229, seed_num = 51
# seed = 42의 정확도 df 만들고 평균 확인 : [0.7994822]

# %% [markdown]
# ## (80.3) lr = 0.001

# %%
from keras.models import load_model
best_model = load_model('./model/(220125.rnn)seed42-05-0.4856.hdf5') 

dic_42={}
for seed in range(42, 52):
    random.seed(seed)

    x = np.load('/project/LSH/x_(7727,10,4069).npy')
    y = np.load('/project/LSH/y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_test, y_test = x[idx[i:],:,:], y[idx[i:]]
    
    pred = best_model.predict(X_test)
    pred[pred>0.5]=1
    pred[pred<=0.5]=0
    acc = metrics.accuracy_score(y_test, pred)
    dic_42[seed]=acc
    print(f'정확도 :{metrics.accuracy_score(y_test, pred)}, seed_num = {seed}')

df = pd.DataFrame.from_dict(dic_42, orient='index')
print(f'seed = {seed_num}의 정확도 df 만들고 평균 확인 : {df.mean().values}')
# Out:
# Using TensorFlow backend.
# 정확도 :0.7579288025889968, seed_num = 42
# 정확도 :0.8122977346278317, seed_num = 43
# 정확도 :0.801294498381877, seed_num = 44
# 정확도 :0.8103559870550162, seed_num = 45
# 정확도 :0.7987055016181229, seed_num = 46
# 정확도 :0.8168284789644013, seed_num = 47
# 정확도 :0.8233009708737864, seed_num = 48
# 정확도 :0.8071197411003236, seed_num = 49
# 정확도 :0.8019417475728156, seed_num = 50
# 정확도 :0.8045307443365696, seed_num = 51
# seed = 42의 정확도 df 만들고 평균 확인 : [0.80343042]

# %% [markdown]
# # Bidirectional RNN

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings(action='ignore')

import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, SimpleRNN, InputLayer, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping
from sklearn import metrics 
from tensorflow import keras
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

import random
# ----------------------
seed_num = 42
# ----------------------
random.seed(seed_num)

x = np.load('/project/LSH/x_(7727,10,4069).npy')
y = np.load('/project/LSH/y_(7727,1).npy')

idx = list(range(len(x)))
random.shuffle(idx)

i = round(x.shape[0]*0.8)
X_train, y_train = x[idx[:i],:,:], y[idx[:i]]
X_test, y_test = x[idx[i:],:,:], y[idx[i:]]

# ---------------------
seed_num = 42 
# ---------------------
tf.random.set_seed(seed_num)

bi_rnn = Sequential()
bi_rnn.add(InputLayer(input_shape=(X_train.shape[1],X_train.shape[2])))
bi_rnn.add(Bidirectional(SimpleRNN(units=128, activation='hard_sigmoid', return_sequences=True)))
bi_rnn.add(Bidirectional(SimpleRNN(units=64, activation='hard_sigmoid', return_sequences=True)))
bi_rnn.add(Dropout(0.2))
bi_rnn.add(Bidirectional(SimpleRNN(units=64, activation='hard_sigmoid', return_sequences=True)))
bi_rnn.add(Bidirectional(SimpleRNN(units=32, activation='hard_sigmoid', return_sequences=False)))
bi_rnn.add(Dropout(0.2))
bi_rnn.add(Dense(units=1, activation='sigmoid'))

from tensorflow.keras.callbacks import ModelCheckpoint
import os

MODEL_SAVE_FOLDER_PATH = './model/'
if not os.path.exists(MODEL_SAVE_FOLDER_PATH):
    os.mkdir(MODEL_SAVE_FOLDER_PATH)

model_path = MODEL_SAVE_FOLDER_PATH + '(bi_rnn_d)seed42-{epoch:02d}-{val_loss:.4f}.hdf5'

cb_checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss',
                                verbose=1, save_best_only=True)

early_stop = EarlyStopping(monitor='val_acc', patience=30, verbose=1, restore_best_weights=False)
bi_rnn.compile(optimizer= keras.optimizers.Adam(learning_rate = 0.001), loss = "binary_crossentropy", metrics=['acc'])
bi_rnn.fit(X_train, y_train, validation_split=0.25, batch_size=128, epochs=500,  
         callbacks=[early_stop,cb_checkpoint], shuffle=False)
# Out:
# Epoch 1/500
# 37/37 [==============================] - 5s 56ms/step - loss: 0.6827 - acc: 0.5871 - val_loss: 0.6681 - val_acc: 0.6177
#
# Epoch 00001: val_loss improved from inf to 0.66811, saving model to ./model/(bi_rnn_d)seed42-01-0.6681.hdf5
# Epoch 2/500
# 37/37 [==============================] - 2s 42ms/step - loss: 0.6727 - acc: 0.5951 - val_loss: 0.6468 - val_acc: 0.6177
#
# Epoch 00002: val_loss improved from 0.66811 to 0.64684, saving model to ./model/(bi_rnn_d)seed42-02-0.6468.hdf5
# Epoch 3/500
# 37/37 [==============================] - 2s 41ms/step - loss: 0.6044 - acc: 0.6726 - val_loss: 0.5395 - val_acc: 0.7199
#
# Epoch 00003: val_loss improved from 0.64684 to 0.53950, saving model to ./model/(bi_rnn_d)seed42-03-0.5395.hdf5
# Epoch 4/500
# 37/37 [==============================] - 2s 41ms/step - loss: 0.4959 - acc: 0.7616 - val_loss: 0.4946 - val_acc: 0.7587
#
# Epoch 00004: val_loss improved from 0.53950 to 0.49458, saving model to ./model/(bi_rnn_d)seed42-04-0.4946.hdf5
# Epoch 5/500
# 37/37 [==============================] - 2s 41ms/step - loss: 0.4303 - acc: 0.8102 - val_loss: 0.4859 - val_acc: 0.7736
#
# Epoch 00005: val_loss improved from 0.49458 to 0.48585, saving model to ./model/(bi_rnn_d)seed42-05-0.4859.hdf5
# Epoch 6/500
# 37/37 [==============================] - 2s 41ms/step - loss: 0.3815 - acc: 0.8425 - val_loss: 0.5024 - val_acc: 0.7710
#
# Epoch 00006: val_loss did not improve from 0.48585
# Epoch 7/500
# 37/37 [==============================] - 2s 41ms/step - loss: 0.3436 - acc: 0.8607 - val_loss: 0.5280 - val_acc: 0.7691
#
# Epoch 00007: val_loss did not improve from 0.48585
# Epoch 8/500
# 37/37 [==============================] - 2s 41ms/step - loss: 0.3055 - acc: 0.8861 - val_loss: 0.5726 - val_acc: 0.7607
#
# Epoch 00008: val_loss did not improve from 0.48585
# Epoch 9/500
# 37/37 [==============================] - 2s 41ms/step - loss: 0.2776 - acc: 0.8999 - val_loss: 0.6424 - val_acc: 0.7354
#
# Epoch 00009: val_loss did not improve from 0.48585
# Epoch 10/500
# 37/37 [==============================] - 2s 41ms/step - loss: 0.2580 - acc: 0.9107 - val_loss: 0.6786 - val_acc: 0.7329
#
# Epoch 00010: val_loss did not improve from 0.48585
# Epoch 11/500
# 37/37 [==============================] - 2s 42ms/step - loss: 0.3215 - acc: 0.8719 - val_loss: 0.5894 - val_acc: 0.7490
#
# Epoch 00011: val_loss did not improve from 0.48585
# Epoch 12/500
# 37/37 [==============================] - 2s 42ms/step - loss: 0.2615 - acc: 0.9049 - val_loss: 0.6155 - val_acc: 0.7536
#
# Epoch 00012: val_loss did not improve from 0.48585
# Epoch 13/500
# 37/37 [==============================] - 2s 42ms/step - loss: 0.2555 - acc: 0.9116 - val_loss: 0.6496 - val_acc: 0.7419
#
# Epoch 00013: val_loss did not improve from 0.48585
# Epoch 14/500
# 37/37 [==============================] - 2s 42ms/step - loss: 0.2731 - acc: 0.8986 - val_loss: 0.6216 - val_acc: 0.7620
#
# Epoch 00014: val_loss did not improve from 0.48585
# Epoch 15/500
# 37/37 [==============================] - 2s 41ms/step - loss: 0.2347 - acc: 0.9206 - val_loss: 0.6904 - val_acc: 0.7451
#
# Epoch 00015: val_loss did not improve from 0.48585
# Epoch 16/500
# 37/37 [==============================] - 2s 42ms/step - loss: 0.2186 - acc: 0.9299 - val_loss: 0.6905 - val_acc: 0.7516
#
# Epoch 00016: val_loss did not improve from 0.48585
# Epoch 17/500
# 37/37 [==============================] - 2s 41ms/step - loss: 0.1916 - acc: 0.9431 - val_loss: 0.7055 - val_acc: 0.7574
#
# Epoch 00017: val_loss did not improve from 0.48585
# Epoch 18/500
# 37/37 [==============================] - 2s 42ms/step - loss: 0.1789 - acc: 0.9489 - val_loss: 0.7328 - val_acc: 0.7516
#
# Epoch 00018: val_loss did not improve from 0.48585
# Epoch 19/500
# 37/37 [==============================] - 2s 42ms/step - loss: 0.1825 - acc: 0.9461 - val_loss: 0.7495 - val_acc: 0.7503
#
# Epoch 00019: val_loss did not improve from 0.48585
# Epoch 20/500
# 37/37 [==============================] - 2s 42ms/step - loss: 0.1860 - acc: 0.9459 - val_loss: 0.8274 - val_acc: 0.7400
#
# Epoch 00020: val_loss did not improve from 0.48585
# Epoch 21/500
# 37/37 [==============================] - 2s 42ms/step - loss: 0.1867 - acc: 0.9398 - val_loss: 0.9307 - val_acc: 0.7309
#
# Epoch 00021: val_loss did not improve from 0.48585
# Epoch 22/500
# 37/37 [==============================] - 2s 42ms/step - loss: 0.2393 - acc: 0.9144 - val_loss: 0.7157 - val_acc: 0.7529
#
# Epoch 00022: val_loss did not improve from 0.48585
# Epoch 23/500
# 37/37 [==============================] - 2s 42ms/step - loss: 0.2183 - acc: 0.9247 - val_loss: 0.7539 - val_acc: 0.7484
#
# Epoch 00023: val_loss did not improve from 0.48585
# Epoch 24/500
# 37/37 [==============================] - 2s 42ms/step - loss: 0.1929 - acc: 0.9379 - val_loss: 0.8495 - val_acc: 0.7413
#
# Epoch 00024: val_loss did not improve from 0.48585
# Epoch 25/500
# 37/37 [==============================] - 2s 42ms/step - loss: 0.2043 - acc: 0.9349 - val_loss: 0.8563 - val_acc: 0.7400
#
# Epoch 00025: val_loss did not improve from 0.48585
# Epoch 26/500
# 37/37 [==============================] - 2s 42ms/step - loss: 0.2309 - acc: 0.9213 - val_loss: 0.8256 - val_acc: 0.7484
#
# Epoch 00026: val_loss did not improve from 0.48585
# Epoch 27/500
# 37/37 [==============================] - 2s 42ms/step - loss: 0.3156 - acc: 0.8745 - val_loss: 0.6651 - val_acc: 0.7510
#
# Epoch 00027: val_loss did not improve from 0.48585
# Epoch 28/500
# 37/37 [==============================] - 2s 42ms/step - loss: 0.2816 - acc: 0.8986 - val_loss: 0.6531 - val_acc: 0.7277
#
# Epoch 00028: val_loss did not improve from 0.48585
# Epoch 29/500
# 37/37 [==============================] - 2s 42ms/step - loss: 0.1918 - acc: 0.9387 - val_loss: 0.7148 - val_acc: 0.7419
#
# Epoch 00029: val_loss did not improve from 0.48585
# Epoch 30/500
# 37/37 [==============================] - 2s 43ms/step - loss: 0.1644 - acc: 0.9551 - val_loss: 0.7635 - val_acc: 0.7361
#
# Epoch 00030: val_loss did not improve from 0.48585
# Epoch 31/500
# 37/37 [==============================] - 2s 42ms/step - loss: 0.1499 - acc: 0.9592 - val_loss: 0.7986 - val_acc: 0.7354
#
# Epoch 00031: val_loss did not improve from 0.48585
# Epoch 32/500
# 37/37 [==============================] - 2s 42ms/step - loss: 0.1394 - acc: 0.9638 - val_loss: 0.8187 - val_acc: 0.7354
#
# Epoch 00032: val_loss did not improve from 0.48585
# Epoch 33/500
# 37/37 [==============================] - 2s 42ms/step - loss: 0.1291 - acc: 0.9676 - val_loss: 0.8396 - val_acc: 0.7387
#
# Epoch 00033: val_loss did not improve from 0.48585
# Epoch 34/500
# 37/37 [==============================] - 2s 42ms/step - loss: 0.1247 - acc: 0.9687 - val_loss: 0.8592 - val_acc: 0.7367
#
# Epoch 00034: val_loss did not improve from 0.48585
# Epoch 35/500
# 37/37 [==============================] - 2s 42ms/step - loss: 0.1243 - acc: 0.9692 - val_loss: 0.8743 - val_acc: 0.7361
#
# Epoch 00035: val_loss did not improve from 0.48585
# Epoch 00035: early stopping

# %% [markdown]
# ## (80.6) lr = 0.001, de = 0.001

# %%
from keras.models import load_model
best_model = load_model('./model/(bi_rnn)seed42-05-0.4841.hdf5') 

dic_42={}
for seed in range(42, 52):
    random.seed(seed)

    x = np.load('/project/LSH/x_(7727,10,4069).npy')
    y = np.load('/project/LSH/y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_test, y_test = x[idx[i:],:,:], y[idx[i:]]
    
    pred = best_model.predict(X_test)
    pred[pred>0.5]=1
    pred[pred<=0.5]=0
    acc = metrics.accuracy_score(y_test, pred)
    dic_42[seed]=acc
    print(f'정확도 :{metrics.accuracy_score(y_test, pred)}, seed_num = {seed}')

df = pd.DataFrame.from_dict(dic_42, orient='index')
print(f'seed = {seed_num}의 정확도 df 만들고 평균 확인 : {df.mean().values}')
# Out:
# Using TensorFlow backend.
# 정확도 :0.7689320388349514, seed_num = 42
# 정확도 :0.8194174757281554, seed_num = 43
# 정확도 :0.8045307443365696, seed_num = 44
# 정확도 :0.8148867313915857, seed_num = 45
# 정확도 :0.7954692556634304, seed_num = 46
# 정확도 :0.8310679611650486, seed_num = 47
# 정확도 :0.8181229773462784, seed_num = 48
# 정확도 :0.8110032362459547, seed_num = 49
# 정확도 :0.8071197411003236, seed_num = 50
# 정확도 :0.7993527508090615, seed_num = 51
# seed = 42의 정확도 df 만들고 평균 확인 : [0.80699029]

# %% [markdown]
# ## (81) lr = 0.001

# %%
from keras.models import load_model
best_model = load_model('./model/(bi_rnn_d)seed42-05-0.4859.hdf5') 

dic_42={}
for seed in range(42, 52):
    random.seed(seed)

    x = np.load('/project/LSH/x_(7727,10,4069).npy')
    y = np.load('/project/LSH/y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_test, y_test = x[idx[i:],:,:], y[idx[i:]]
    
    pred = best_model.predict(X_test)
    pred[pred>0.5]=1
    pred[pred<=0.5]=0
    acc = metrics.accuracy_score(y_test, pred)
    dic_42[seed]=acc
    print(f'정확도 :{metrics.accuracy_score(y_test, pred)}, seed_num = {seed}')

df = pd.DataFrame.from_dict(dic_42, orient='index')
print(f'seed = {seed_num}의 정확도 df 만들고 평균 확인 : {df.mean().values}')
# Out:
# 정확도 :0.7656957928802589, seed_num = 42
# 정확도 :0.8213592233009709, seed_num = 43
# 정확도 :0.8097087378640777, seed_num = 44
# 정확도 :0.8207119741100324, seed_num = 45
# 정확도 :0.8038834951456311, seed_num = 46
# 정확도 :0.8323624595469256, seed_num = 47
# 정확도 :0.8213592233009709, seed_num = 48
# 정확도 :0.8155339805825242, seed_num = 49
# 정확도 :0.8097087378640777, seed_num = 50
# 정확도 :0.8045307443365696, seed_num = 51
# seed = 42의 정확도 df 만들고 평균 확인 : [0.81048544]

# %% [markdown]
# # 비시계열
# - data seed = 42 ~ 51에 대해 정확도 계산

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
import random

model = SVC()

data={}
for seed in range(42, 52):
    random.seed(seed)
    
    x = np.load('./x_(7727,4069).npy')
    y = np.load('./y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_train, y_train = x[idx[:i],:], y[idx[:i]]
    X_test, y_test = x[idx[i:],:], y[idx[i:]]
    
    model.fit(X_train, y_train)
    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)
    
    acc = accuracy_score(y_test, y_pred_test)
    data[seed]=acc
    print(f'정확도 : {acc}, seed_num = {seed}')

df = pd.DataFrame.from_dict(data, orient='index')
print(f'seed = 정확도 df 만들고 평균 확인 : {df.mean().values}')
# Out:
# 정확도 : 0.7669902912621359, seed_num = 42
# 정확도 : 0.7915857605177994, seed_num = 43
# 정확도 : 0.7598705501618123, seed_num = 44
# 정확도 : 0.7799352750809061, seed_num = 45
# 정확도 : 0.7650485436893204, seed_num = 46
# 정확도 : 0.7831715210355987, seed_num = 47
# 정확도 : 0.7935275080906149, seed_num = 48
# 정확도 : 0.7754045307443366, seed_num = 49
# 정확도 : 0.7676375404530744, seed_num = 50
# 정확도 : 0.7754045307443366, seed_num = 51
# seed = 42의 정확도 df 만들고 평균 확인 : [0.77585761]

# %% [markdown]
# # GaussianNB

# %%
from sklearn.naive_bayes import GaussianNB
import random

model = GaussianNB()

data={}
for seed in range(42, 52):
    random.seed(seed)
    
    x = np.load('./x_(7727,4069).npy')
    y = np.load('./y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_train, y_train = x[idx[:i],:], y[idx[:i]]
    X_test, y_test = x[idx[i:],:], y[idx[i:]]
    
    model.fit(X_train, y_train)
    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)
    
    acc = accuracy_score(y_test, y_pred_test)
    data[seed]=acc
    print(f'정확도 : {acc}, seed_num = {seed}')

df = pd.DataFrame.from_dict(data, orient='index')
print(f'정확도 df 만들고 평균 확인 : {df.mean().values}')
# Out:
# 정확도 : 0.47896440129449835, seed_num = 42
# 정확도 : 0.5055016181229773, seed_num = 43
# 정확도 : 0.511326860841424, seed_num = 44
# 정확도 : 0.4796116504854369, seed_num = 45
# 정확도 : 0.4854368932038835, seed_num = 46
# 정확도 : 0.4640776699029126, seed_num = 47
# 정확도 : 0.47119741100323626, seed_num = 48
# 정확도 : 0.4809061488673139, seed_num = 49
# 정확도 : 0.4608414239482201, seed_num = 50
# 정확도 : 0.4802588996763754, seed_num = 51
# seed = 42의 정확도 df 만들고 평균 확인 : [0.4818123]

# %% [markdown]
# # KNN

# %%
import random
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier()

data={}
for seed in range(42, 52):
    random.seed(seed)
    
    x = np.load('./x_(7727,4069).npy')
    y = np.load('./y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_train, y_train = x[idx[:i],:], y[idx[:i]]
    X_test, y_test = x[idx[i:],:], y[idx[i:]]
    
    model.fit(X_train, y_train)
    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)
    
    acc = accuracy_score(y_test, y_pred_test)
    data[seed]=acc
    print(f'정확도 : {acc}, seed_num = {seed}')

df = pd.DataFrame.from_dict(data, orient='index')
print(f'정확도 df 만들고 평균 확인 : {df.mean().values}')
# Out:
# 정확도 : 0.6453074433656958, seed_num = 42
# 정확도 : 0.6414239482200648, seed_num = 43
# 정확도 : 0.6200647249190938, seed_num = 44
# 정확도 : 0.6550161812297735, seed_num = 45
# 정확도 : 0.6608414239482201, seed_num = 46
# 정확도 : 0.6692556634304208, seed_num = 47
# 정확도 : 0.683495145631068, seed_num = 48
# 정확도 : 0.6381877022653721, seed_num = 49
# 정확도 : 0.6718446601941748, seed_num = 50
# 정확도 : 0.6614886731391586, seed_num = 51
# seed = 42의 정확도 df 만들고 평균 확인 : [0.65469256]

# %% [markdown]
# # Random Forest

# %%
import random
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()

data={}
for seed in range(42, 52):
    random.seed(seed)
    
    x = np.load('./x_(7727,4069).npy')
    y = np.load('./y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_train, y_train = x[idx[:i],:], y[idx[:i]]
    X_test, y_test = x[idx[i:],:], y[idx[i:]]
    
    model.fit(X_train, y_train)
    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)
    
    acc = accuracy_score(y_test, y_pred_test)
    data[seed]=acc
    print(f'정확도 : {acc}, seed_num = {seed}')

df = pd.DataFrame.from_dict(data, orient='index')
print(f'seed = {seed_num}의 정확도 df 만들고 평균 확인 : {df.mean().values}')
# Out:
# 정확도 : 0.7411003236245954, seed_num = 42
# 정확도 : 0.7462783171521036, seed_num = 43
# 정확도 : 0.713915857605178, seed_num = 44
# 정확도 : 0.7501618122977346, seed_num = 45
# 정확도 : 0.7365695792880259, seed_num = 46
# 정확도 : 0.7566343042071197, seed_num = 47
# 정확도 : 0.7559870550161812, seed_num = 48
# 정확도 : 0.7436893203883496, seed_num = 49
# 정확도 : 0.7391585760517799, seed_num = 50
# 정확도 : 0.7313915857605178, seed_num = 51
# seed = 42의 정확도 df 만들고 평균 확인 : [0.74148867]

# %% [markdown]
# # Gradient boosting

# %%
import random 
from sklearn.ensemble import GradientBoostingClassifier

model = GradientBoostingClassifier()

data={}
for seed in range(42, 52):
    random.seed(seed)
    
    x = np.load('./x_(7727,4069).npy')
    y = np.load('./y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_train, y_train = x[idx[:i],:], y[idx[:i]]
    X_test, y_test = x[idx[i:],:], y[idx[i:]]
    
    model.fit(X_train, y_train)
    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)
    
    acc = accuracy_score(y_test, y_pred_test)
    data[seed]=acc
    print(f'정확도 : {acc}, seed_num = {seed}')

df = pd.DataFrame.from_dict(data, orient='index')
print(f'seed = {seed_num}의 정확도 df 만들고 평균 확인 : {df.mean().values}')
# Out:
# 정확도 : 0.7372168284789644, seed_num = 42
# 정확도 : 0.7391585760517799, seed_num = 43
# 정확도 : 0.7210355987055016, seed_num = 44
# 정확도 : 0.7585760517799353, seed_num = 45
# 정확도 : 0.7365695792880259, seed_num = 46
# 정확도 : 0.7637540453074434, seed_num = 47
# 정확도 : 0.7818770226537217, seed_num = 48
# 정확도 : 0.7469255663430421, seed_num = 49
# 정확도 : 0.7391585760517799, seed_num = 50
# 정확도 : 0.7469255663430421, seed_num = 51
# seed = 42의 정확도 df 만들고 평균 확인 : [0.74711974]

# %% [markdown]
# # Neural network

# %%
import random
from sklearn.neural_network import MLPClassifier

model = MLPClassifier(max_iter=1000)

data={}
for seed in range(42, 52):
    random.seed(seed)
    
    x = np.load('./x_(7727,4069).npy')
    y = np.load('./y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_train, y_train = x[idx[:i],:], y[idx[:i]]
    X_test, y_test = x[idx[i:],:], y[idx[i:]]
    
    model.fit(X_train, y_train)
    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)
    
    acc = accuracy_score(y_test, y_pred_test)
    data[seed]=acc
    print(f'정확도 : {acc}, seed_num = {seed}')

df = pd.DataFrame.from_dict(data, orient='index')
print(f'seed = {seed_num}의 정확도 df 만들고 평균 확인 : {df.mean().values}')
# Out:
# 정확도 : 0.7255663430420712, seed_num = 42
# 정확도 : 0.7436893203883496, seed_num = 43
# 정확도 : 0.7184466019417476, seed_num = 44
# 정확도 : 0.7398058252427184, seed_num = 45
# 정확도 : 0.7294498381877023, seed_num = 46
# 정확도 : 0.7482200647249191, seed_num = 47
# 정확도 : 0.7449838187702266, seed_num = 48
# 정확도 : 0.7372168284789644, seed_num = 49
# 정확도 : 0.713915857605178, seed_num = 50
# 정확도 : 0.7229773462783171, seed_num = 51
# seed = 42의 정확도 df 만들고 평균 확인 : [0.73242718]

# %% [markdown]
# # Adaboost

# %%
import random
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score

clf = AdaBoostClassifier(n_estimators=500, 
                        random_state=10, 
                        learning_rate=0.1)

data={}
for seed in range(42, 52):
    random.seed(seed)
    
    x = np.load('./x_(7727,4069).npy')
    y = np.load('./y_(7727,1).npy')

    idx = list(range(len(x)))
    random.shuffle(idx)

    i = round(x.shape[0]*0.8)
    X_train, y_train = x[idx[:i],:], y[idx[:i]]
    X_test, y_test = x[idx[i:],:], y[idx[i:]]
    
    model.fit(X_train, y_train)
    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)
    
    acc = accuracy_score(y_test, y_pred_test)
    data[seed]=acc
    print(f'정확도 : {acc}, seed_num = {seed}')

df = pd.DataFrame.from_dict(data, orient='index')
print(f'seed = {seed_num}의 정확도 df 만들고 평균 확인 : {df.mean().values}')
# Out:
# 정확도 : 0.7300970873786408, seed_num = 42
# 정확도 : 0.7339805825242719, seed_num = 43
# 정확도 : 0.7190938511326861, seed_num = 44
# 정확도 : 0.7385113268608414, seed_num = 45
# 정확도 : 0.7423948220064724, seed_num = 46
# 정확도 : 0.7469255663430421, seed_num = 47
# 정확도 : 0.7475728155339806, seed_num = 48
# 정확도 : 0.7411003236245954, seed_num = 49
# 정확도 : 0.7255663430420712, seed_num = 50
# 정확도 : 0.7307443365695793, seed_num = 51
# seed = 42의 정확도 df 만들고 평균 확인 : [0.73559871]
